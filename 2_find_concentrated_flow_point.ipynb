# %%
# %%capture
#from jupyterthemes import jtplot
#jtplot.style()
import numpy as np
import operator
import seaborn as sns; sns.set()
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
from scipy import stats
from scipy.stats import sem
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from pylab import show, figure
from landlab.plot.imshow import imshow_grid 

# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure
from matplotlib.lines import Line2D
# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120)
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()
from statsmodels.formula.api import ols
from scipy.stats import t
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def slopeWindowMperM(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_m_per_m = rise_run
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_m_per_m
def catchmentDicts(area_grid, gn, gh_nodes):
    """Creates a dictionary of node ID:catcment area values."""
    area_dict = {}
    nodes = gh_nodes
    x_axis_length = gn.shape[1]
    for i in nodes:
        row = int(np.floor(i / x_axis_length))
        col = int(i - (row*x_axis_length))
        area = area_grid[row,col]
        area_dict[i] = area
    return area_dict
def upslopeDivergence(catchment_area_list, change_detection_factor, step_size, comparison_distance):
    
    """"Looks at whether catchment area is increasing at any point upstream of a gully head.
    
    - 'catchment_area_list' is an ordered list of node catchment areas moving upstream.
    
    - 'change_detection_factor' is the percentage increase required for the function to consider the change
    to represent a point of divergent flow.
    
    - 'step_size' is the number of grid cells to be compared in downstream to upstream groups. E.g. step_size == 1 
    will compare node 1 and node 2, but step_size == 2 will compare node 1 and 2 to node 3 and 4.
    
    - 'comparison_distance' is the distance between the downstream nodes being compared to upstream nodes."""
    
    max_value_length = len(catchment_area_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = catchment_area_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptreat_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = catchment_area_list[start_of_upstream_nodes:end_of_usptreat_nodes]
        
        required_catchment_area_increase = max(downstream_nodes) + (max(downstream_nodes) * change_detection_factor)
        
        if all(nodes >= required_catchment_area_increase for nodes in upstream_nodes):
            divergence = 1
            break
        else:
            divergence = 0
    return divergence
def findGullyHeadNode(gully_heads, grid_nodes, DEM, ca, input_DEM_resolution, 
                      distance_from_node, contributing_fraction, required_ca):
    
    catchment_area_dict = {}
    catchment_area_node_list = []
    distance_from_node = int(np.ceil(distance_from_node/input_DEM_resolution))

    for i in gully_heads:

        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset = DEM[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        #################################################################################################
        ca_subset = ca[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        print('max ca: ', np.amax(ca_subset))
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');

        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');
        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);
        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        for j in range(0, distance_from_node):
            # Begin at the point (node) digitized as the intersection between the central flow line and the gully head.
            if j == 0:
                candidate_gridcell = catchment_outlet_id;
            else:
                candidate_gridcell = next_cell_downstream;
            # Get all receiver nodes of the current node.
            grid_cell_receiver_nodes = frp[candidate_gridcell,:];
            # Check if there is a node that receives >= 'contributing_fraction' from the current node.
            candidate_gridcell_list = [candidate_gridcell]
            node_ca_int = catchmentDicts(ca_subset, grid_nodes_sub, candidate_gridcell_list) # Find the node's contributing area.
            node_ca = node_ca_int[candidate_gridcell]
            print('Node id: ', candidate_gridcell, 'Catchment area: ', node_ca)
            if np.amax(grid_cell_receiver_nodes) < contributing_fraction or node_ca < required_ca:
                # Check if this is the last possible grid cell in the subset that could meet the criteria. If so, then there
                # is no suitable grid cell (node).
                if j == distance_from_node - 1:
                    catchment_area_dict[i] = 'No grid cell found'
                else:
                    # Otherwise, find the next downslope grid cell receiving the highest proportion of flow and check that 
                    # in the next iteration.
                    index_next_cell_downstream = np.where(grid_cell_receiver_nodes == np.amax(grid_cell_receiver_nodes))[0][0];
                    next_cell_downstream = frn[candidate_gridcell, index_next_cell_downstream];
            else:
                # Find the position of the gridcell (node) that meets the criteria both in the subset and in the whole DEM
                # and record the node ID.
                final_node_index_lat =  np.where(grid_nodes_sub == candidate_gridcell)[0][0]
                final_node_index_lon =  np.where(grid_nodes_sub == candidate_gridcell)[1][0]
                
                # Find the offest between the index position of the node the loop ends on, and the index position of
                # the node that it started on. 
                final_lat_offset = final_node_index_lat - node_lat
                final_lon_offset = final_node_index_lon - node_lon
                # Then apply this offest to the index position of the starting node with respect top the whole DEM to find the 
                # node ID of the grid cell that met the criteria above.
                final_row_index = row_index + final_lat_offset
                final_col_index = col_index + final_lon_offset
                node_of_area_record = grid_nodes[final_row_index, final_col_index] # - this range is more than 1
                catchment_area_dict[i] = node_of_area_record
                catchment_area_node_list.append(node_of_area_record)
                break
                             
    return catchment_area_dict, catchment_area_node_list
def upstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, catchment_outlet_ids, 
                         step_size_m, comparison_distance_m, change_detection_factor, slope_above_head):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        print(target_distance, ' ', target_distance * input_DEM_resolution)
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        area_along_central_drainage_line = []
        for key, value in node_area_dict.items():
            area_along_central_drainage_line.append(value)
        median_area_along_central_drainage_line = ndimage.median_filter(area_along_central_drainage_line, size=step_size_m)
        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_area_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            divergence_occuring = upslopeDivergence(median_area_along_central_drainage_line, change_detection_factor, 
                                                    step_size, comparison_distance)
            upslope_divergence_dict[i] = divergence_occuring
            
    return upslope_divergence_dict, slope_dict, slope_at_head
def roundup(x):
    return int(math.ceil(x / 10.0)) * 10
def findPoint5mDownstream(gully_heads, grid_nodes, DEM, ca, input_DEM_resolution, 
                      distance_from_node, contributing_fraction, required_ca):
    
    catchment_area_dict = {}
    catchment_area_node_list = []
    distance_from_node = int(np.ceil(distance_from_node/input_DEM_resolution))

    for i in gully_heads:

        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset = DEM[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        #################################################################################################
        ca_subset = ca[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        print('max ca: ', np.amax(ca_subset))
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');

        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');
        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);
        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        for j in range(0, distance_from_node):
            # Begin at the point (node) digitized as the intersection between the central flow line and the gully head.
            if j == 0:
                candidate_gridcell = catchment_outlet_id;
            else:
                candidate_gridcell = next_cell_downstream;
            # Get all receiver nodes of the current node.
            grid_cell_receiver_nodes = frp[candidate_gridcell,:];
            # Check if there is a node that receives >= 'contributing_fraction' from the current node.
            candidate_gridcell_list = [candidate_gridcell]
            node_ca_int = catchmentDicts(ca_subset, grid_nodes_sub, candidate_gridcell_list) # Find the node's contributing area.
            node_ca = node_ca_int[candidate_gridcell]
            print('Node id: ', candidate_gridcell, 'Catchment area: ', node_ca)
            if j + 1 < distance_from_node:
                
                # Otherwise, find the next downslope grid cell receiving the highest proportion of flow and check that 
                # in the next iteration.
                index_next_cell_downstream = np.where(grid_cell_receiver_nodes == np.amax(grid_cell_receiver_nodes))[0][0];
                next_cell_downstream = frn[candidate_gridcell, index_next_cell_downstream];
            else:
                print(j)
                # Find the position of the gridcell (node) that meets the criteria both in the subset and in the whole DEM
                # and record the node ID.
                final_node_index_lat =  np.where(grid_nodes_sub == candidate_gridcell)[0][0]
                final_node_index_lon =  np.where(grid_nodes_sub == candidate_gridcell)[1][0]
                
                # Find the offest between the index position of the node the loop ends on, and the index position of
                # the node that it started on. 
                final_lat_offset = final_node_index_lat - node_lat
                final_lon_offset = final_node_index_lon - node_lon
                # Then apply this offest to the index position of the starting node with respect top the whole DEM to find the 
                # node ID of the grid cell that met the criteria above.
                final_row_index = row_index + final_lat_offset
                final_col_index = col_index + final_lon_offset
                node_of_area_record = grid_nodes[final_row_index, final_col_index] # - this range is more than 1
                catchment_area_dict[i] = node_of_area_record
                catchment_area_node_list.append(node_of_area_record)
                break
                             
    return catchment_area_dict, catchment_area_node_list

# %%
input_DEM_resolution = 1
working_resolution = 1

location = (r'C:\PhD\junk')
os.chdir(location)

input_geotiff = gdal.Open('fann_sub_2.tif')
x = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())
empty_grid_rows = roundup(x.shape[0])
empty_grid_cols = roundup(x.shape[1])
input_DEM = np.zeros([empty_grid_rows,empty_grid_cols])
input_DEM[:x.shape[0], :x.shape[1]] = x

gully_head_layer = gdal.Open('fann_first_gullies.tif')
gh = np.array(gully_head_layer.GetRasterBand(1).ReadAsArray()).astype('uint8')

#input_ca_grid = gdal.Open('wean_t_M8.tif')
#ca_grid = np.array(input_ca_grid.GetRasterBand(1).ReadAsArray())

# %%
flow_acc_surf = np.copy(input_DEM).astype('float64');
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

# %%
grid_nodes = np.array(mg.nodes.reshape(mg.shape))

# %%
grid_nodes_float = grid_nodes.astype('float64')

# %% [markdown]
# ## Isolate all gully head nodes

# %%
find_nodes = np.multiply(gh, grid_nodes);

# %% [markdown]
# ## Create array of only gully head nodes

# %%
gh_array = np.unique(find_nodes);

# %% [markdown]
# ## Turn gully head node array into a list and remove the value 0

# %%
gh_list = gh_array.tolist();
gh_list.remove(0);

# %%
len(gh_list)
# Out:
# 68

# %% [markdown]
# # Run multiple-direction flow routing algorithm

# %%
flow_acc_surf = np.copy(input_DEM).astype('float64');
#################################################################################################
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

sfb = SinkFillerBarnes(mg, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();
fa = FlowAccumulator(mg,
                    surface = 'topographic__elevation',
                    flow_director = 'FlowDirectorMFD',
                    diagonals = True);
fa.run_one_step();
fd = FlowDirectorMFD(mg, 'topographic__elevation', diagonals = True);
fd.run_one_step();

da = np.array(mg.at_node['drainage_area'].round(4))
frn = mg.at_node['flow__receiver_node']
drainage_area = np.flip(da.reshape(mg.shape), 0);
frp = np.array(mg.at_node['flow__receiver_proportions']);
ns = np.flip(mg.status_at_node.reshape(mg.shape), 0)
flow_rec_surf_rows = cols * rows;
flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);

# %%
catchment_area = da.reshape(mg.shape) / (10000 * (1/working_resolution**2))

# %%
plt.figure(figsize=(20,10));
plt.imshow(catchment_area, cmap="gist_earth_r", vmax = 1);
plt.colorbar();

# %% [markdown]
# ### The final variable in the function below sets the threshold catchment area at the point of convergence required to keep the gully head as a candidate. Default set to 0.1 ha.

# %% [markdown]
# ## Work through list finding index positions of each node

# %%
catchment_area_dict, catchment_area_node_list = findGullyHeadNode(gh_list, grid_nodes, input_DEM, catchment_area,
                                                                  input_DEM_resolution, 10, 0.9, 0.1)
# Out:
# max ca:  0.26630761
# Node id:  220 Catchment area:  0.11226898
# Node id:  241 Catchment area:  0.09268434
# Node id:  262 Catchment area:  0.14635211
# max ca:  0.35872553
# Node id:  220 Catchment area:  0.30491547
# max ca:  0.36512975
# Node id:  220 Catchment area:  0.11727363
# max ca:  1.05432132
# Node id:  220 Catchment area:  0.58452598
# max ca:  1.05432132
# Node id:  220 Catchment area:  0.21621121
# Node id:  240 Catchment area:  0.39192846
# max ca:  1.42544922
# Node id:  220 Catchment area:  0.76583295
# Node id:  240 Catchment area:  0.82834667
# max ca:  1.77313039
# Node id:  220 Catchment area:  0.1007065
# max ca:  2.357534
# Node id:  220 Catchment area:  0.59267971
# Node id:  241 Catchment area:  0.45405845
# Node id:  261 Catchment area:  0.85103343
# max ca:  2.54330438
# Node id:  220 Catchment area:  0.11819419
# Node id:  240 Catchment area:  0.10005415
# Node id:  261 Catchment area:  0.08128381
# Node id:  281 Catchment area:  0.35666969
# Node id:  301 Catchment area:  1.17240206
# Node id:  321 Catchment area:  1.45389296
# Node id:  341 Catchment area:  0.85359005
# max ca:  2.58615127
# Node id:  220 Catchment area:  0.43014091
# Node id:  240 Catchment area:  0.31624414
# Node id:  260 Catchment area:  0.3003327
# Node id:  280 Catchment area:  0.33168782
# max ca:  2.72197428
# Node id:  220 Catchment area:  1.73166318
# Node id:  199 Catchment area:  1.39321661
# Node id:  179 Catchment area:  2.42494949
# max ca:  2.29049575
# Node id:  220 Catchment area:  0.25877403
# max ca:  2.69707077
# Node id:  220 Catchment area:  1.62762117
# Node id:  200 Catchment area:  1.60203991
# Node id:  180 Catchment area:  1.04939439
# Node id:  159 Catchment area:  2.21365546
# Node id:  138 Catchment area:  1.33081659
# Node id:  117 Catchment area:  1.17047847
# max ca:  3.66142457
# Node id:  220 Catchment area:  0.02116945
# Node id:  219 Catchment area:  0.01638584
# Node id:  218 Catchment area:  0.01681494
# Node id:  217 Catchment area:  3.62163506
# max ca:  2.16453852
# Node id:  220 Catchment area:  1.08775002
# max ca:  3.63743768
# Node id:  220 Catchment area:  0.11139486
# Node id:  219 Catchment area:  0.1925794
# Node id:  218 Catchment area:  0.13904407
# Node id:  238 Catchment area:  0.27510574
# Node id:  237 Catchment area:  0.18968398
# Node id:  257 Catchment area:  0.24625764
# max ca:  2.15127323
# Node id:  220 Catchment area:  0.62387554
# Node id:  199 Catchment area:  0.61067834
# Node id:  179 Catchment area:  0.7854914
# max ca:  1.11685171
# Node id:  220 Catchment area:  0.10837789
# Node id:  241 Catchment area:  0.32259252
# Node id:  262 Catchment area:  0.66721426
# Node id:  283 Catchment area:  0.66059753
# max ca:  1.38631714
# Node id:  220 Catchment area:  0.52387027
# Node id:  199 Catchment area:  0.63124565
# Node id:  179 Catchment area:  0.56079659
# max ca:  0.20862873
# Node id:  220 Catchment area:  0.18087231
# max ca:  2.6509722
# Node id:  220 Catchment area:  0.18527108
# Node id:  240 Catchment area:  0.26155591
# max ca:  3.85965901
# Node id:  220 Catchment area:  3.33511171
# Node id:  200 Catchment area:  2.14956235
# Node id:  180 Catchment area:  2.82540703
# max ca:  1.25826029
# Node id:  220 Catchment area:  0.09514983
# Node id:  219 Catchment area:  0.12339953
# Node id:  218 Catchment area:  0.20360026
# max ca:  4.56554659
# Node id:  220 Catchment area:  0.22657952
# max ca:  1.97573461
# Node id:  220 Catchment area:  0.08961777
# Node id:  198 Catchment area:  0.07075095
# Node id:  197 Catchment area:  0.08241414
# Node id:  196 Catchment area:  0.05272371
# Node id:  195 Catchment area:  0.45970034
# max ca:  0.53744938
# Node id:  220 Catchment area:  0.14881912
# Node id:  240 Catchment area:  0.20384458
# Node id:  260 Catchment area:  0.17948959
# Node id:  280 Catchment area:  0.29001413
# Node id:  300 Catchment area:  0.42993148
# Node id:  299 Catchment area:  0.30636627
# Node id:  319 Catchment area:  0.5346319
# max ca:  12.30146413
# Node id:  220 Catchment area:  2.74279709
# Node id:  219 Catchment area:  4.09093794
# max ca:  3.9449872
# Node id:  220 Catchment area:  0.04832753
# Node id:  241 Catchment area:  0.07391873
# Node id:  262 Catchment area:  0.06664474
# Node id:  261 Catchment area:  0.09925989
# Node id:  260 Catchment area:  0.0607317
# Node id:  281 Catchment area:  0.10220967
# max ca:  3.9403307
# Node id:  220 Catchment area:  1.5403396
# Node id:  240 Catchment area:  2.0783535
# Node id:  260 Catchment area:  2.49834867
# Node id:  280 Catchment area:  3.78928539
# max ca:  16.76335803
# Node id:  220 Catchment area:  16.75278306
# Node id:  240 Catchment area:  12.68841958
# max ca:  22.50789912
# Node id:  220 Catchment area:  1.79244613
# Node id:  219 Catchment area:  1.34296757
# Node id:  239 Catchment area:  1.62493125
# Node id:  259 Catchment area:  1.18570359
# Node id:  280 Catchment area:  21.45735678
# Node id:  300 Catchment area:  15.74116957
# max ca:  19.04810283
# Node id:  220 Catchment area:  15.59796194
# max ca:  18.93879265
# Node id:  220 Catchment area:  16.76414742
# max ca:  19.00140537
# Node id:  220 Catchment area:  18.95163612
# max ca:  0.88429693
# Node id:  220 Catchment area:  0.5647735
# max ca:  1.52765995
# Node id:  220 Catchment area:  0.07811593
# Node id:  200 Catchment area:  0.12270793
# max ca:  1.7425345
# Node id:  220 Catchment area:  0.41368215
# Node id:  199 Catchment area:  0.40388099
# Node id:  178 Catchment area:  0.26107827
# Node id:  157 Catchment area:  1.05915004
# max ca:  2.57403969
# Node id:  220 Catchment area:  0.12263397
# max ca:  1.84992924
# Node id:  220 Catchment area:  0.05630443
# Node id:  199 Catchment area:  0.06541776
# Node id:  178 Catchment area:  0.06682226
# Node id:  157 Catchment area:  0.13891131
# max ca:  1.7161455
# Node id:  220 Catchment area:  0.27430204
# Node id:  199 Catchment area:  0.27675273
# max ca:  0.82632648
# Node id:  220 Catchment area:  0.12530533
# Node id:  198 Catchment area:  0.16883728
# Node id:  197 Catchment area:  0.15877536
# Node id:  175 Catchment area:  0.1821545
# max ca:  13.10238794
# Node id:  198 Catchment area:  0.70257148
# Node id:  197 Catchment area:  0.63431345
# Node id:  196 Catchment area:  0.594418
# max ca:  11.67884522
# Node id:  220 Catchment area:  11.65157982
# Node id:  219 Catchment area:  6.82607844
# max ca:  0.46194359
# Node id:  220 Catchment area:  0.21346665
# Node id:  219 Catchment area:  0.25001944
# Node id:  239 Catchment area:  0.42391328
# max ca:  11.67104385
# Node id:  220 Catchment area:  9.65200057
# Node id:  199 Catchment area:  7.64797307
# max ca:  0.22896938
# Node id:  220 Catchment area:  0.22389246
# max ca:  0.60280264
# Node id:  220 Catchment area:  0.53568099
# Node id:  219 Catchment area:  0.47238493
# Node id:  197 Catchment area:  0.37352537
# max ca:  9.88716685
# Node id:  220 Catchment area:  9.33728525
# Node id:  198 Catchment area:  7.09474151
# max ca:  9.30058234
# Node id:  220 Catchment area:  9.29667174
# max ca:  3.41139855
# Node id:  220 Catchment area:  3.19479682
# Node id:  198 Catchment area:  2.11083312
# Node id:  197 Catchment area:  2.98685756
# max ca:  5.19850597
# Node id:  220 Catchment area:  5.07110409
# Node id:  240 Catchment area:  3.66656859
# max ca:  4.55604168
# Node id:  220 Catchment area:  0.17769523
# Node id:  219 Catchment area:  0.13664118
# Node id:  197 Catchment area:  0.40398599
# Node id:  196 Catchment area:  0.26991243
# max ca:  4.18606012
# Node id:  220 Catchment area:  0.0495806
# Node id:  199 Catchment area:  2.82507573
# max ca:  4.41840397
# Node id:  220 Catchment area:  0.33788852
# max ca:  3.31908593
# Node id:  220 Catchment area:  3.26556209
# max ca:  2.44285613
# Node id:  220 Catchment area:  1.77928235
# max ca:  2.25770367
# Node id:  220 Catchment area:  0.18310824
# Node id:  240 Catchment area:  0.34719622
# Node id:  239 Catchment area:  0.19310355
# Node id:  238 Catchment area:  0.17556579
# Node id:  259 Catchment area:  0.28108105
# max ca:  0.26563549
# Node id:  220 Catchment area:  0.17465003
# Node id:  241 Catchment area:  0.19591212
# max ca:  0.98984062
# Node id:  220 Catchment area:  0.10115345
# Node id:  241 Catchment area:  0.10150629
# Node id:  263 Catchment area:  0.11711756
# Node id:  284 Catchment area:  0.1370937
# Node id:  305 Catchment area:  0.10247884
# Node id:  326 Catchment area:  0.29157129
# max ca:  0.5225678
# Node id:  220 Catchment area:  0.11188669
# max ca:  0.75078201
# Node id:  220 Catchment area:  0.56404626
# max ca:  1.01958301
# Node id:  220 Catchment area:  0.53987882
# max ca:  1.53882643
# Node id:  220 Catchment area:  0.60528735
# max ca:  1.01958301
# Node id:  220 Catchment area:  0.16775732
# max ca:  2.19097274
# Node id:  220 Catchment area:  0.96148885
# Node id:  221 Catchment area:  1.26253779
# Node id:  222 Catchment area:  1.422464
# max ca:  2.16633864
# Node id:  220 Catchment area:  0.16041485
# Node id:  221 Catchment area:  0.12512819
# max ca:  2.16534894
# Node id:  220 Catchment area:  0.11753113
# Node id:  221 Catchment area:  0.13516419
# Node id:  222 Catchment area:  0.12868204
# Node id:  202 Catchment area:  0.07744478
# Node id:  182 Catchment area:  0.16041485
# Node id:  183 Catchment area:  0.12512819
# max ca:  0.18384603
# Node id:  220 Catchment area:  0.08224033
# Node id:  221 Catchment area:  0.1232719

# %% [markdown]
# # Create a list of all gully head nodes that had a valid convergence point.

# %%
def get_keys(value_list, my_dict):
    gh_node_list = []
    for node_value in value_list:   
        for key, value in my_dict.items(): 
             if node_value == value:
                    gh_node_list.append(key)
  
    return gh_node_list

# %%
gully_heads_to_keep = get_keys(catchment_area_node_list, catchment_area_dict)

# %%
len(gully_heads_to_keep)
# Out:
# 70

# %%
len(catchment_area_node_list)
# Out:
# 68

# %% [markdown]
# # Now move 5m downstream of the remaining gully heads - this will be the point from which to the look at the gully head steepness

# %%
downstream_5m_dict, downstream_5m_node_list = findPoint5mDownstream(gully_heads_to_keep, grid_nodes, input_DEM, catchment_area,
                                                                  input_DEM_resolution, 6, 0.9, 0.1)
# Out:
# max ca:  0.23283354
# Node id:  84 Catchment area:  0.11226898
# Node id:  97 Catchment area:  0.09268434
# Node id:  110 Catchment area:  0.14635211
# Node id:  123 Catchment area:  0.20442272
# Node id:  136 Catchment area:  0.21742352
# Node id:  149 Catchment area:  0.22402084
# 5
# max ca:  0.35060929
# Node id:  84 Catchment area:  0.30491547
# Node id:  96 Catchment area:  0.32478428
# Node id:  95 Catchment area:  0.2102262
# Node id:  107 Catchment area:  0.34819328
# Node id:  119 Catchment area:  0.35060929
# Node id:  131 Catchment area:  0.20614822
# 5
# max ca:  0.35872553
# Node id:  84 Catchment area:  0.11727363
# Node id:  96 Catchment area:  0.12675587
# Node id:  108 Catchment area:  0.0749894
# Node id:  107 Catchment area:  0.10833271
# Node id:  119 Catchment area:  0.06632081
# Node id:  132 Catchment area:  0.1165698
# 5
# max ca:  1.04557549
# Node id:  84 Catchment area:  0.58452598
# Node id:  98 Catchment area:  0.58599834
# Node id:  111 Catchment area:  0.58711975
# Node id:  125 Catchment area:  0.61384153
# Node id:  138 Catchment area:  0.71525584
# Node id:  151 Catchment area:  1.03902702
# 5
# max ca:  1.04557549
# Node id:  84 Catchment area:  0.21621121
# Node id:  96 Catchment area:  0.39192846
# Node id:  95 Catchment area:  0.43210703
# Node id:  94 Catchment area:  0.44057626
# Node id:  106 Catchment area:  0.44368884
# Node id:  118 Catchment area:  0.50536205
# 5
# max ca:  1.41595025
# Node id:  84 Catchment area:  0.76583295
# Node id:  96 Catchment area:  0.82834667
# Node id:  108 Catchment area:  1.23126722
# Node id:  120 Catchment area:  1.34305443
# Node id:  132 Catchment area:  1.37786997
# Node id:  144 Catchment area:  1.40530951
# 5
# max ca:  0.13143454
# Node id:  84 Catchment area:  0.1007065
# Node id:  97 Catchment area:  0.12124513
# Node id:  110 Catchment area:  0.12419932
# Node id:  123 Catchment area:  0.12612697
# Node id:  136 Catchment area:  0.12778046
# Node id:  149 Catchment area:  0.12962648
# 5
# max ca:  2.35431182
# Node id:  84 Catchment area:  0.59267971
# Node id:  97 Catchment area:  0.45405845
# Node id:  109 Catchment area:  0.85103343
# Node id:  122 Catchment area:  0.85153743
# Node id:  135 Catchment area:  2.08877018
# Node id:  134 Catchment area:  2.33903134
# 5
# max ca:  2.42929892
# Node id:  84 Catchment area:  0.11819419
# Node id:  96 Catchment area:  0.10005415
# Node id:  109 Catchment area:  0.08128381
# Node id:  122 Catchment area:  1.0466507
# Node id:  134 Catchment area:  2.31987165
# Node id:  146 Catchment area:  1.84719253
# 5
# max ca:  2.47189598
# Node id:  84 Catchment area:  0.43014091
# Node id:  96 Catchment area:  0.31624414
# Node id:  108 Catchment area:  0.3003327
# Node id:  120 Catchment area:  0.33168782
# Node id:  133 Catchment area:  0.43905565
# Node id:  146 Catchment area:  0.44041287
# 5
# max ca:  2.71902795
# Node id:  84 Catchment area:  1.73166318
# Node id:  71 Catchment area:  1.39321661
# Node id:  59 Catchment area:  2.42494949
# Node id:  46 Catchment area:  2.64480038
# Node id:  33 Catchment area:  2.71618562
# Node id:  19 Catchment area:  2.71760316
# 5
# max ca:  0.30570599
# Node id:  84 Catchment area:  0.25877403
# Node id:  97 Catchment area:  0.27836606
# Node id:  110 Catchment area:  0.1838795
# Node id:  122 Catchment area:  0.27425174
# Node id:  134 Catchment area:  0.30165379
# Node id:  146 Catchment area:  0.30570599
# 5
# max ca:  2.21365546
# Node id:  84 Catchment area:  1.62762117
# Node id:  72 Catchment area:  1.60203991
# Node id:  60 Catchment area:  1.04939439
# Node id:  47 Catchment area:  2.21365546
# Node id:  34 Catchment area:  1.33081659
# Node id:  21 Catchment area:  1.17047847
# 5
# max ca:  3.65394915
# Node id:  84 Catchment area:  0.02116945
# Node id:  83 Catchment area:  0.01638584
# Node id:  82 Catchment area:  0.01681494
# Node id:  81 Catchment area:  3.62163506
# Node id:  94 Catchment area:  3.6326372
# Node id:  107 Catchment area:  3.63743768
# 5
# max ca:  2.15105458
# Node id:  84 Catchment area:  1.08775002
# Node id:  98 Catchment area:  2.0473791
# Node id:  111 Catchment area:  1.9409005
# Node id:  124 Catchment area:  2.10016114
# Node id:  137 Catchment area:  2.14023285
# Node id:  150 Catchment area:  2.14694701
# 5
# max ca:  0.28312836
# Node id:  84 Catchment area:  0.11139486
# Node id:  83 Catchment area:  0.1925794
# Node id:  82 Catchment area:  0.13904407
# Node id:  94 Catchment area:  0.27510574
# Node id:  93 Catchment area:  0.18968398
# Node id:  105 Catchment area:  0.24625764
# 5
# max ca:  2.03948746
# Node id:  84 Catchment area:  0.62387554
# Node id:  71 Catchment area:  0.61067834
# Node id:  59 Catchment area:  0.7854914
# Node id:  60 Catchment area:  1.11764637
# Node id:  48 Catchment area:  0.72080054
# Node id:  49 Catchment area:  1.38631714
# 5
# max ca:  1.04517847
# Node id:  84 Catchment area:  0.10837789
# Node id:  97 Catchment area:  0.32259252
# Node id:  110 Catchment area:  0.66721426
# Node id:  123 Catchment area:  0.66059753
# Node id:  122 Catchment area:  0.99183218
# Node id:  134 Catchment area:  1.02322504
# 5
# max ca:  0.7850841
# Node id:  84 Catchment area:  0.52387027
# Node id:  71 Catchment area:  0.63124565
# Node id:  59 Catchment area:  0.56079659
# Node id:  47 Catchment area:  0.69357698
# Node id:  35 Catchment area:  0.73352332
# Node id:  22 Catchment area:  0.77797018
# 5
# max ca:  0.20359576
# Node id:  84 Catchment area:  0.18087231
# Node id:  97 Catchment area:  0.18692861
# Node id:  111 Catchment area:  0.18983225
# Node id:  124 Catchment area:  0.19389987
# Node id:  137 Catchment area:  0.11585258
# Node id:  151 Catchment area:  0.20073499
# 5
# max ca:  2.50746769
# Node id:  84 Catchment area:  0.18527108
# Node id:  96 Catchment area:  0.26155591
# Node id:  108 Catchment area:  0.3113265
# Node id:  107 Catchment area:  0.20003926
# Node id:  119 Catchment area:  0.23795511
# Node id:  131 Catchment area:  2.45884786
# 5
# max ca:  3.85965901
# Node id:  84 Catchment area:  3.33511171
# Node id:  72 Catchment area:  2.14956235
# Node id:  60 Catchment area:  2.82540703
# Node id:  48 Catchment area:  3.40543271
# Node id:  35 Catchment area:  3.85599558
# Node id:  23 Catchment area:  3.85965901
# 5
# max ca:  1.1708758
# Node id:  84 Catchment area:  0.09514983
# Node id:  83 Catchment area:  0.12339953
# Node id:  82 Catchment area:  0.20360026
# Node id:  81 Catchment area:  0.24626481
# Node id:  93 Catchment area:  0.28603593
# Node id:  105 Catchment area:  0.24560483
# 5
# max ca:  4.55284036
# Node id:  84 Catchment area:  0.22657952
# Node id:  96 Catchment area:  0.27793832
# Node id:  95 Catchment area:  0.28082953
# Node id:  94 Catchment area:  0.20650059
# Node id:  93 Catchment area:  0.2273753
# Node id:  92 Catchment area:  0.09695736
# 5
# max ca:  1.94951912
# Node id:  84 Catchment area:  0.08961777
# Node id:  70 Catchment area:  0.07075095
# Node id:  69 Catchment area:  0.08241414
# Node id:  68 Catchment area:  0.05272371
# Node id:  67 Catchment area:  0.45970034
# Node id:  66 Catchment area:  1.93919867
# 5
# max ca:  0.5346319
# Node id:  84 Catchment area:  0.14881912
# Node id:  96 Catchment area:  0.20384458
# Node id:  108 Catchment area:  0.17948959
# Node id:  120 Catchment area:  0.29001413
# Node id:  132 Catchment area:  0.42993148
# Node id:  131 Catchment area:  0.30636627
# 5
# max ca:  12.29496547
# Node id:  84 Catchment area:  2.74279709
# Node id:  83 Catchment area:  4.09093794
# Node id:  82 Catchment area:  9.51070302
# Node id:  81 Catchment area:  12.29336843
# Node id:  67 Catchment area:  9.31133224
# Node id:  66 Catchment area:  12.29496547
# 5
# max ca:  3.9403307
# Node id:  84 Catchment area:  0.04832753
# Node id:  97 Catchment area:  0.07391873
# Node id:  110 Catchment area:  0.06664474
# Node id:  109 Catchment area:  0.09925989
# Node id:  108 Catchment area:  0.0607317
# Node id:  121 Catchment area:  0.10220967
# 5
# max ca:  3.86873011
# Node id:  84 Catchment area:  1.5403396
# Node id:  96 Catchment area:  2.0783535
# Node id:  108 Catchment area:  2.49834867
# Node id:  120 Catchment area:  3.78928539
# Node id:  106 Catchment area:  3.79004538
# Node id:  92 Catchment area:  3.79227571
# 5
# max ca:  16.76032695
# Node id:  84 Catchment area:  16.75278306
# Node id:  72 Catchment area:  6.93965905
# Node id:  73 Catchment area:  16.75084294
# Node id:  74 Catchment area:  16.7491224
# Node id:  75 Catchment area:  16.74814471
# Node id:  63 Catchment area:  10.46589027
# 5
# max ca:  22.48530717
# Node id:  84 Catchment area:  1.79244613
# Node id:  83 Catchment area:  1.34296757
# Node id:  95 Catchment area:  1.62493125
# Node id:  107 Catchment area:  1.18570359
# Node id:  120 Catchment area:  21.45735678
# Node id:  133 Catchment area:  0.72354012
# 5
# max ca:  19.04383886
# Node id:  84 Catchment area:  15.59796194
# Node id:  70 Catchment area:  18.64604673
# Node id:  69 Catchment area:  19.04168093
# Node id:  55 Catchment area:  11.15477004
# Node id:  54 Catchment area:  19.04299206
# Node id:  53 Catchment area:  19.04337853
# 5
# max ca:  18.92461086
# Node id:  84 Catchment area:  16.76414742
# Node id:  96 Catchment area:  16.76465867
# Node id:  108 Catchment area:  12.69741968
# Node id:  121 Catchment area:  16.7656915
# Node id:  133 Catchment area:  12.69798896
# Node id:  145 Catchment area:  7.63068121
# 5
# max ca:  18.99022223
# Node id:  84 Catchment area:  18.95163612
# Node id:  96 Catchment area:  14.35353867
# Node id:  108 Catchment area:  12.79830402
# Node id:  107 Catchment area:  18.98294106
# Node id:  106 Catchment area:  18.98652608
# Node id:  105 Catchment area:  18.98874436
# 5
# max ca:  0.87253895
# Node id:  84 Catchment area:  0.5647735
# Node id:  71 Catchment area:  0.75717913
# Node id:  58 Catchment area:  0.77124259
# Node id:  44 Catchment area:  0.48757657
# Node id:  31 Catchment area:  0.68096643
# Node id:  17 Catchment area:  0.83799315
# 5
# max ca:  0.19080136
# Node id:  84 Catchment area:  0.07811593
# Node id:  72 Catchment area:  0.12270793
# Node id:  60 Catchment area:  0.12543995
# Node id:  47 Catchment area:  0.13149008
# Node id:  34 Catchment area:  0.07830109
# Node id:  22 Catchment area:  0.13678861
# 5
# max ca:  1.69002299
# Node id:  84 Catchment area:  0.41368215
# Node id:  71 Catchment area:  0.40388099
# Node id:  58 Catchment area:  0.26107827
# Node id:  45 Catchment area:  1.05915004
# Node id:  44 Catchment area:  1.34376385
# Node id:  43 Catchment area:  1.50665573
# 5
# max ca:  0.80191741
# Node id:  84 Catchment area:  0.12263397
# Node id:  72 Catchment area:  0.16347386
# Node id:  59 Catchment area:  0.096164
# Node id:  47 Catchment area:  0.35069092
# Node id:  34 Catchment area:  0.55389318
# Node id:  22 Catchment area:  0.80191741
# 5
# max ca:  0.55389318
# Node id:  84 Catchment area:  0.05630443
# Node id:  71 Catchment area:  0.06541776
# Node id:  58 Catchment area:  0.06682226
# Node id:  45 Catchment area:  0.13891131
# Node id:  32 Catchment area:  0.31856208
# Node id:  18 Catchment area:  0.35069092
# 5
# max ca:  0.54224416
# Node id:  84 Catchment area:  0.27430204
# Node id:  71 Catchment area:  0.27675273
# Node id:  57 Catchment area:  0.40562213
# Node id:  43 Catchment area:  0.49830332
# Node id:  29 Catchment area:  0.54224416
# Node id:  16 Catchment area:  0.39247352
# 5
# max ca:  0.56053937
# Node id:  84 Catchment area:  0.12530533
# Node id:  70 Catchment area:  0.16883728
# Node id:  69 Catchment area:  0.15877536
# Node id:  55 Catchment area:  0.1821545
# Node id:  42 Catchment area:  0.24941128
# Node id:  28 Catchment area:  0.24916548
# 5
# max ca:  13.10083614
# Node id:  84 Catchment area:  0.70257148
# Node id:  83 Catchment area:  0.63431345
# Node id:  82 Catchment area:  0.594418
# Node id:  81 Catchment area:  2.27467234
# Node id:  67 Catchment area:  13.0983265
# Node id:  54 Catchment area:  13.09871202
# 5
# max ca:  11.67104385
# Node id:  84 Catchment area:  11.65157982
# Node id:  83 Catchment area:  6.82607844
# Node id:  69 Catchment area:  9.66085488
# Node id:  56 Catchment area:  11.66083193
# Node id:  42 Catchment area:  11.6686667
# Node id:  29 Catchment area:  11.67104385
# 5
# max ca:  0.46194359
# Node id:  84 Catchment area:  0.21346665
# Node id:  83 Catchment area:  0.25001944
# Node id:  95 Catchment area:  0.42391328
# Node id:  94 Catchment area:  0.44468329
# Node id:  106 Catchment area:  0.46194359
# Node id:  105 Catchment area:  0.27538912
# 5
# max ca:  11.65069649
# Node id:  84 Catchment area:  9.65200057
# Node id:  71 Catchment area:  7.64797307
# Node id:  70 Catchment area:  11.64649311
# Node id:  56 Catchment area:  11.64739139
# Node id:  42 Catchment area:  8.82228928
# Node id:  41 Catchment area:  11.64959065
# 5
# max ca:  0.22593992
# Node id:  84 Catchment area:  0.22389246
# Node id:  83 Catchment area:  0.22415648
# Node id:  95 Catchment area:  0.22462193
# Node id:  94 Catchment area:  0.22511049
# Node id:  93 Catchment area:  0.22550323
# Node id:  92 Catchment area:  0.22593992
# 5
# max ca:  0.53568099
# Node id:  84 Catchment area:  0.53568099
# Node id:  83 Catchment area:  0.47238493
# Node id:  69 Catchment area:  0.37352537
# Node id:  68 Catchment area:  0.53321589
# Node id:  67 Catchment area:  0.29646421
# Node id:  66 Catchment area:  0.44101131
# 5
# max ca:  9.39282888
# Node id:  84 Catchment area:  9.33728525
# Node id:  70 Catchment area:  7.09474151
# Node id:  57 Catchment area:  9.38276026
# Node id:  44 Catchment area:  9.39141838
# Node id:  31 Catchment area:  9.39184826
# Node id:  18 Catchment area:  9.39235918
# 5
# max ca:  9.30058234
# Node id:  84 Catchment area:  9.29667174
# Node id:  98 Catchment area:  3.84453217
# Node id:  111 Catchment area:  9.27718751
# Node id:  124 Catchment area:  9.27464
# Node id:  138 Catchment area:  1.12677348
# Node id:  151 Catchment area:  3.83489845
# 5
# max ca:  3.25435153
# Node id:  84 Catchment area:  3.19479682
# Node id:  70 Catchment area:  2.11083312
# Node id:  69 Catchment area:  2.98685756
# Node id:  68 Catchment area:  3.23043591
# Node id:  67 Catchment area:  3.24161952
# Node id:  66 Catchment area:  3.24997578
# 5
# max ca:  5.19247947
# Node id:  84 Catchment area:  5.07110409
# Node id:  96 Catchment area:  3.66656859
# Node id:  95 Catchment area:  5.16581892
# Node id:  94 Catchment area:  5.18575823
# Node id:  93 Catchment area:  5.18831658
# Node id:  92 Catchment area:  5.19061777
# 5
# max ca:  0.48315406
# Node id:  84 Catchment area:  0.17769523
# Node id:  83 Catchment area:  0.13664118
# Node id:  69 Catchment area:  0.40398599
# Node id:  68 Catchment area:  0.26991243
# Node id:  54 Catchment area:  0.42151895
# Node id:  40 Catchment area:  0.47999834
# 5
# max ca:  4.1205203
# Node id:  84 Catchment area:  0.0495806
# Node id:  71 Catchment area:  2.82507573
# Node id:  70 Catchment area:  3.72570121
# Node id:  69 Catchment area:  4.01981644
# Node id:  55 Catchment area:  4.03607976
# Node id:  54 Catchment area:  4.07293906
# 5
# max ca:  3.54103271
# Node id:  84 Catchment area:  0.33788852
# Node id:  71 Catchment area:  0.44871755
# Node id:  58 Catchment area:  0.45126956
# Node id:  44 Catchment area:  0.2971993
# Node id:  31 Catchment area:  0.30059829
# Node id:  19 Catchment area:  0.17990256
# 5
# max ca:  3.31703706
# Node id:  84 Catchment area:  3.26556209
# Node id:  71 Catchment area:  3.31310282
# Node id:  57 Catchment area:  3.31391033
# Node id:  43 Catchment area:  2.51056564
# Node id:  29 Catchment area:  2.88529904
# Node id:  28 Catchment area:  3.31650024
# 5
# max ca:  2.42482604
# Node id:  84 Catchment area:  1.77928235
# Node id:  70 Catchment area:  2.06812659
# Node id:  57 Catchment area:  1.49240838
# Node id:  43 Catchment area:  2.37145286
# Node id:  29 Catchment area:  2.38618
# Node id:  15 Catchment area:  2.40710084
# 5
# max ca:  1.96554178
# Node id:  84 Catchment area:  0.18310824
# Node id:  96 Catchment area:  0.34719622
# Node id:  95 Catchment area:  0.19310355
# Node id:  94 Catchment area:  0.17556579
# Node id:  107 Catchment area:  0.28108105
# Node id:  119 Catchment area:  0.30194483
# 5
# max ca:  0.22430483
# Node id:  84 Catchment area:  0.17465003
# Node id:  97 Catchment area:  0.19591212
# Node id:  111 Catchment area:  0.22430483
# Node id:  125 Catchment area:  0.17383607
# Node id:  138 Catchment area:  0.19097293
# Node id:  152 Catchment area:  0.17471159
# 5
# max ca:  0.77090141
# Node id:  84 Catchment area:  0.10115345
# Node id:  97 Catchment area:  0.10150629
# Node id:  111 Catchment area:  0.11711756
# Node id:  124 Catchment area:  0.1370937
# Node id:  137 Catchment area:  0.10247884
# Node id:  150 Catchment area:  0.29157129
# 5
# max ca:  0.2785419
# Node id:  84 Catchment area:  0.11188669
# Node id:  72 Catchment area:  0.26141056
# Node id:  73 Catchment area:  0.23654327
# Node id:  74 Catchment area:  0.2785419
# Node id:  75 Catchment area:  0.21177231
# Node id:  76 Catchment area:  0.15165527
# 5
# max ca:  0.69473491
# Node id:  84 Catchment area:  0.56404626
# Node id:  85 Catchment area:  0.63429347
# Node id:  99 Catchment area:  0.65978036
# Node id:  100 Catchment area:  0.63961011
# Node id:  114 Catchment area:  0.68497456
# Node id:  115 Catchment area:  0.69473491
# 5
# max ca:  1.00613059
# Node id:  84 Catchment area:  0.53987882
# Node id:  96 Catchment area:  0.68869152
# Node id:  108 Catchment area:  0.78493685
# Node id:  107 Catchment area:  0.98904322
# Node id:  106 Catchment area:  0.99420195
# Node id:  118 Catchment area:  0.99902179
# 5
# max ca:  1.46511192
# Node id:  84 Catchment area:  0.60528735
# Node id:  70 Catchment area:  1.43505639
# Node id:  56 Catchment area:  0.84725004
# Node id:  43 Catchment area:  1.46511192
# Node id:  29 Catchment area:  1.11924213
# Node id:  15 Catchment area:  0.65798744
# 5
# max ca:  0.99420195
# Node id:  84 Catchment area:  0.16775732
# Node id:  83 Catchment area:  0.23801777
# Node id:  82 Catchment area:  0.24063763
# Node id:  68 Catchment area:  0.15716355
# Node id:  67 Catchment area:  0.78493685
# Node id:  66 Catchment area:  0.98904322
# 5
# max ca:  2.18883434
# Node id:  84 Catchment area:  0.96148885
# Node id:  85 Catchment area:  1.26253779
# Node id:  86 Catchment area:  1.422464
# Node id:  87 Catchment area:  1.98112942
# Node id:  88 Catchment area:  2.1601098
# Node id:  89 Catchment area:  2.18807532
# 5
# max ca:  2.16534894
# Node id:  84 Catchment area:  0.16041485
# Node id:  85 Catchment area:  0.12512819
# Node id:  73 Catchment area:  0.19695488
# Node id:  61 Catchment area:  0.21239407
# Node id:  48 Catchment area:  0.16482679
# Node id:  36 Catchment area:  1.58409789
# 5
# max ca:  0.19695488
# Node id:  84 Catchment area:  0.11753113
# Node id:  85 Catchment area:  0.13516419
# Node id:  86 Catchment area:  0.12868204
# Node id:  74 Catchment area:  0.07744478
# Node id:  62 Catchment area:  0.16041485
# Node id:  63 Catchment area:  0.12512819
# 5
# max ca:  2.16534894
# Node id:  84 Catchment area:  0.16041485
# Node id:  85 Catchment area:  0.12512819
# Node id:  73 Catchment area:  0.19695488
# Node id:  61 Catchment area:  0.21239407
# Node id:  48 Catchment area:  0.16482679
# Node id:  36 Catchment area:  1.58409789
# 5
# max ca:  0.19695488
# Node id:  84 Catchment area:  0.11753113
# Node id:  85 Catchment area:  0.13516419
# Node id:  86 Catchment area:  0.12868204
# Node id:  74 Catchment area:  0.07744478
# Node id:  62 Catchment area:  0.16041485
# Node id:  63 Catchment area:  0.12512819
# 5
# max ca:  0.16952391
# Node id:  84 Catchment area:  0.08224033
# Node id:  85 Catchment area:  0.1232719
# Node id:  86 Catchment area:  0.14650952
# Node id:  87 Catchment area:  0.15085218
# Node id:  75 Catchment area:  0.15381433
# Node id:  76 Catchment area:  0.12507167
# 5

# %%
len(downstream_5m_node_list)
# Out:
# 70

# %% [markdown]
# # Can collect catchment area at this stage but need a reliable estimate of it

# %%
outlet_ids = np.isin(grid_nodes,downstream_5m_node_list).astype('uint8')

# %% [markdown]
# # Remove any gully head candidates that have drainage area < given threshold estimated by multiple-direction algorithm.

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('fann_downstream_5m.tif', input_geotiff, outlet_ids, grid_nodes_float.dtype)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
