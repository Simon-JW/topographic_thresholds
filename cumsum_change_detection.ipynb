# %% [markdown]
# ## Import required libraries.

# %%
# %%capture
import operator
import seaborn as sns; sns.set()
from jupyterthemes import jtplot
jtplot.style()
import numpy as np
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy.signal import medfilt
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from landlab.plot.imshow import imshow_grid 

# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure

# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120) 
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Setup input data
# Define spatial resolution: Specify the resolution of the input DEM and also the desired working resolution (can be same as input DEM resolution).

# %%
def roundup(x):
    return int(math.ceil(x / 10.0)) * 10

input_DEM_resolution = 1
working_resolution = 1
location = (r'C:\PhD\junk')
os.chdir(location)
input_geotiff = gdal.Open('namadgi.tif')
x = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())
empty_grid_rows = roundup(x.shape[0])
empty_grid_cols = roundup(x.shape[1])
input_DEM = np.zeros([empty_grid_rows,empty_grid_cols])
input_DEM[:x.shape[0], :x.shape[1]] = x

input_outlets = gdal.Open('namadgi_downstream_5m.tif')
o = np.array(input_outlets.GetRasterBand(1).ReadAsArray())
outlets= o
#outlets = 1 - o

# %% [markdown]
# ## Visualise the DEM.

# %%
plt.figure(figsize=(12,12))
plt.imshow(input_DEM, cmap="terrain_r", vmin = np.percentile(input_DEM, 5));
plt.colorbar();

# %% [markdown]
# ## Define required function.

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def differenceFromMeanElevation(elev):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = elev[central_value]                        
    mean = np.nanmean(elev)#Count number of values greater than centroid value
    diff = centroid - mean
    return diff
def PCTL(x):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = x[central_value]                        
    y = np.sum(x < centroid)/num_values#Count number of values greater than centroid value
    return y
def flow_dir_dataset(flow_rec_prop, catchment_area, grid_resolution, outlet_node):
    """ Create an xarray Dataset containing eight arrays each representing the
    amount of water flowing in the given direction.
        1 . flow_rec_prop == the flow receiver proportion array created by LandLab flow routing.
        2 . catchment_area == the corresponding catchment area array from the landLab flow accumulation.
        surface.        
    The resulting Dataset is used to calculate specific catchment area."""
    array_direction = xr.Dataset()
    for i in range(0,8):
        rows = catchment_area.shape[0]; cols = catchment_area.shape[1];
        direction = np.flip(flow_rec_prop[:,i].reshape(rows,cols), 0);
        # Above needs to be flipped because during reshape it organises data top down
        # rather than bottom up as per ModelGrid order (catchment_area is mg arrangement).
        zero_outlet = outlet_node != 1
        remove_outlet = zero_outlet * catchment_area
        weighted_direction = xr.DataArray((remove_outlet * direction),
                                          dims = ['lat', 'lon']);
        array_direction[direction_list[i]] = weighted_direction
        
    E, N, W, S, NE, NW, SW, SE = (array_direction['East'], array_direction['North'],
                             array_direction['West'], array_direction['South'],
                             array_direction['North East'], array_direction['North West'],
                             array_direction['South West'], array_direction['South East'])

    flow_dirs = xr.concat([E, N, W, S, NE, NW, SW, SE], 'direction')
    flow_dirs.name = 'flow_directions'
    flow_dirs.attrs['grid cell resolution'] = grid_resolution
    flow_directions = flow_dirs.assign_coords(direction=(['East','North','West','South',
                                   'North East', 'North West','South West', 'South East']))
    return flow_directions
def profileCurvature(DEM, cellsize):
    """This process is taken from Change (2014, Introduction to Geographic Information
       systems, Page 284)."""
    Z1 = DEM[0]; Z2 = DEM[1]; Z3 = DEM[2]
    Z4 = DEM[3]; Z0 = DEM[4]; Z5 = DEM[5]
    Z6 = DEM[6]; Z7 = DEM[7]; Z8 = DEM[8]
    D = (((Z4 + Z5)/2) - Z0) / cellsize**2
    E = (((Z2 + Z7)/2) - Z0) / cellsize**2
    F = (Z3 - Z1 + Z6 - Z8)/ (4 * cellsize**2)
    G = (Z5 - Z4) / (2 * cellsize)
    H = (Z2 - Z7) / (2 * cellsize)
    profile_curvature = (-2 * (D*(G**2) + E*(H**2) + (F*G*H))) / (G**2 + H**2)
    return profile_curvature
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def closest(lst, K): 
     angle_list = lst
     idx = (np.abs(angle_list - K)).argmin() 
     return angle_list[idx]  
def data_range(data):
    data_min = np.amin(data); data_max = np.amax(data)
    value_range = data_max - data_min
    return value_range
def checkGullyHead(catchment_area_list, step_size, comparison_distance, minimum_depth, elevation_of_gh):
    
    """ """
    
    max_value_length = len(catchment_area_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = catchment_area_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptreat_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = catchment_area_list[start_of_upstream_nodes:end_of_usptreat_nodes]
        
        min_downstream = np.min(downstream_nodes)
        mean_upstream = np.mean(upstream_nodes)
        std_upstream = np.std(upstream_nodes)
        elevation_difference = min_downstream - mean_upstream
        print('minimum downstream value: ', min_downstream)
        print('mean upstream value: ', mean_upstream)
        print('std upstream value: ', std_upstream)
      
        if min_downstream <= minimum_depth and mean_upstream > elevation_of_gh and std_upstream < 0.1 and elevation_difference <= -0.2:
            keep_gully = 'yes'
            gully_head_location = end_of_downstream_nodes + np.round(comparison_distance/2) - 1
            break
        else:
            keep_gully = 'no'
            gully_head_location = 'none'

    return keep_gully
def upstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, import_drainage_area, 
                         import_dfme, catchment_outlet_ids, step_size_m, comparison_distance_m,  
                         slope_above_head, min_depth, gh_elevation):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        
        #da_subset_copy = np.copy(import_drainage_area)
        import_da_subset = import_drainage_area[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        flattened_import_da = import_da_subset.reshape(da.shape)
        
        #dfme_subset_copy = np.copy(import_dfme)
        import_dfme_subset = import_dfme[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        flattened_import_dfme = import_dfme_subset.reshape(da.shape)
        
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.

        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        print(central_node)
        print(mg1.shape)
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)
        

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        node_dfme_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            upstream_dfme_dict = {};
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_import_da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})
                        node_dfme = np.amin(np.multiply(isolate_candidate_grid_cells, flattened_import_dfme))
                        upstream_dfme_dict.update({node_id_value:node_dfme})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    print(primary_flow_direction_id)
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    node_dfme_dict[primary_flow_direction_id] = upstream_dfme_dict[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        print(target_distance, ' ', target_distance * input_DEM_resolution)
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        dfme_along_central_drainage_line = []
        for key, value in node_dfme_dict.items():
            dfme_along_central_drainage_line.append(value)
        median_dfme_along_central_drainage_line = ndimage.median_filter(dfme_along_central_drainage_line, size=step_size_m)

        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_dfme_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            print('node: ',i,)
            divergence_occuring = checkGullyHead(dfme_along_central_drainage_line, 
                                                    step_size, comparison_distance, min_depth, gh_elevation)
            upslope_divergence_dict[i] = divergence_occuring
            
    return upslope_divergence_dict, slope_dict, slope_at_head
def slopeWindowMperM(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_m_per_m = rise_run
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_m_per_m

# %%
#################################################################################################
flow_acc_surf = np.copy(input_DEM).astype('float64');
#################################################################################################
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

sfb = SinkFillerBarnes(mg, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();
fa = FlowAccumulator(mg,
                    surface = 'topographic__elevation',
                    flow_director = 'FlowDirectorMFD',
                    diagonals = True);
#(flow_acc, q) = fa.accumulate_flow();
fa.run_one_step()
fd = FlowDirectorMFD(mg, 'topographic__elevation', diagonals = True);
fd.run_one_step()

da = np.array(mg.at_node['drainage_area'].round(4));
catchment_area_ha = np.divide(da.reshape(mg.shape), (100/working_resolution)**2)
frn = mg.at_node['flow__receiver_node'];
drainage_area = np.flip(da.reshape(mg.shape), 0);
frp = np.array(mg.at_node['flow__receiver_proportions']);
ns = np.flip(mg.status_at_node.reshape(mg.shape), 0);
flow_rec_surf_rows = cols * rows;
flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);

tss = mg.at_node['topographic__steepest_slope'];
steepest_slope = tss.reshape(flow_rec_surf_rows,8);
all_receiver_proportions = np.copy(frp);

# %% [markdown]
# # For all nodes

# %%
# Must be larger than 'line_length' (specified later).
size_of_edge = 30

# %%
grid_nodes = np.array(mg.nodes.reshape(mg.shape))
find_nodes = np.multiply(outlets, grid_nodes);

gully_head_edge_mask = np.zeros([grid_nodes.shape[0], grid_nodes.shape[1]])
gully_head_mask_centre = np.ones([grid_nodes.shape[0] - size_of_edge*2, grid_nodes.shape[1] - size_of_edge*2])
gully_head_edge_mask[size_of_edge:-1*(size_of_edge), size_of_edge:-1*(size_of_edge)] = gully_head_mask_centre

remaining_gully_heads = find_nodes * gully_head_edge_mask
gh_array = np.unique(remaining_gully_heads);
gh_list = gh_array.tolist();
gh_list.remove(0);
len(gh_list)
# Out:
# 90

# %% [markdown]
# # For one node

# %%
#grid_nodes = np.array(mg.nodes.reshape(mg.shape))
#find_outlet_ids = grid_nodes * outlets
#outlet_id = np.unique(find_outlet_ids)[1]

# %%
radius = 9
central_value = find_median_value(circleWindow(radius))
num_values = number_of_values(circleWindow(radius))
dfme = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(radius), mode='nearest');
dfme[dfme > 5.0] = 5.0
dfme[dfme < -5.0] = -5.0

# %%
slope = generic_filter(input_DEM, slopeWindowDegrees,
                  footprint= rectangleWindow(3,3),
                  mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

# %%
shape = 9
central_value = find_median_value(circleWindow(shape))
num_values = number_of_values(circleWindow(shape))

# %%
DFME = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(shape), mode='nearest');

# %%
# Specific the size of the area to be checked. This represents a physical distance from the 
# outlet but has no unit of measure.
distance_from_outlet = 20

# %%
outlet_id = 1841218
outlet_id
# Out:
# 1841218

# %%
divergence_dict, slope_dict, slope_area_data = upstreamDrainageLine(20, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_ha, DFME,gh_list, 3, 3, 10, -0.2, -0.2)
# Out:
# 840
# (41, 41)
# 839
# 797
# 796
# 795
# 794
# 793
# 792
# 750
# 749
# 748
# 747
# 10   10
# 746
# 786
# 785
# 825
# 824
# 823
# 822
# 821
# 780
# node:  66788.0
# minimum downstream value:  -0.452900159029
# mean upstream value:  -1.43358603014
# std upstream value:  0.260617285836
# minimum downstream value:  -0.65129963871
# mean upstream value:  -1.68916523849
# std upstream value:  0.136566102481
# minimum downstream value:  -0.832030767509
# mean upstream value:  -1.84978275023
# std upstream value:  0.11939021647
# minimum downstream value:  -1.00503962219
# mean upstream value:  -2.01332898448
# std upstream value:  0.141971613687
# minimum downstream value:  -1.08161582494
# mean upstream value:  -2.0403533252
# std upstream value:  0.112693650961
# minimum downstream value:  -1.51486218117
# mean upstream value:  -2.02522722126
# std upstream value:  0.120322987303
# minimum downstream value:  -1.7042800843
# mean upstream value:  -1.79789772084
# std upstream value:  0.201700835502
# minimum downstream value:  -1.84835345001
# mean upstream value:  -1.66924799541
# std upstream value:  0.199856086365
# minimum downstream value:  -1.99671471637
# mean upstream value:  -1.53401467546
# std upstream value:  0.0149349499863
# minimum downstream value:  -2.19491878706
# mean upstream value:  -1.46678674268
# std upstream value:  0.109987101444
# minimum downstream value:  -2.19491878706
# mean upstream value:  -1.30261616462
# std upstream value:  0.202040726053
# 840
# (41, 41)
# 881
# 921
# 961
# 1002
# 1043
# 1084
# 1125
# 1166
# 1207
# 1248
# 1289
# 10   10
# 1329
# 1369
# 1409
# 1450
# 1490
# 1532
# 1573
# 1614
# 1613
# node:  82534.0
# minimum downstream value:  -0.374487111691
# mean upstream value:  -0.186674296463
# std upstream value:  0.0309219762373
# minimum downstream value:  -0.374487111691
# mean upstream value:  -0.195431675364
# std upstream value:  0.0361181580992
# minimum downstream value:  -0.374487111691
# mean upstream value:  -0.225204930161
# std upstream value:  0.00660947834685
# minimum downstream value:  -0.329807447351
# mean upstream value:  -0.208536623024
# std upstream value:  0.0291283045744
# minimum downstream value:  -0.245607881207
# mean upstream value:  -0.214688709445
# std upstream value:  0.0333973070928
# minimum downstream value:  -0.197806015316
# mean upstream value:  -0.231364253953
# std upstream value:  0.0480525810116
# minimum downstream value:  -0.217732425735
# mean upstream value:  -0.280896012177
# std upstream value:  0.0301953720593
# minimum downstream value:  -0.22407815202
# mean upstream value:  -0.311082601233
# std upstream value:  0.0204501600992
# minimum downstream value:  -0.233804212729
# mean upstream value:  -0.311504459507
# std upstream value:  0.0198889974676
# minimum downstream value:  -0.233804212729
# mean upstream value:  -0.313303187274
# std upstream value:  0.02047869023
# minimum downstream value:  -0.242534411283
# mean upstream value:  -0.256560917428
# std upstream value:  0.0679174175302
# 840
# (41, 41)
# 839
# 838
# 837
# 795
# 753
# 711
# 710
# 709
# 667
# 625
# 624
# 10   10
# 582
# 540
# 498
# 497
# 496
# 454
# 453
# 452
# 411
# node:  84806.0
# minimum downstream value:  -1.18285360826
# mean upstream value:  -0.126275224648
# std upstream value:  0.0940659687008
# 840
# (41, 41)
# 880
# 838
# 878
# 877
# 917
# 957
# 956
# 997
# 1037
# 1078
# 1119
# 10   10
# 1160
# 1201
# 1243
# 1283
# 1323
# 1322
# 1280
# 1238
# 1278
# node:  84998.0
# minimum downstream value:  -0.418728191391
# mean upstream value:  -0.294955166903
# std upstream value:  0.0063450091961
# minimum downstream value:  -0.437791907269
# mean upstream value:  -0.290480702919
# std upstream value:  0.00386500172669
# minimum downstream value:  -0.437791907269
# mean upstream value:  -0.312454484982
# std upstream value:  0.0286075360082
# minimum downstream value:  -0.437791907269
# mean upstream value:  -0.296184715703
# std upstream value:  0.0434645332933
# minimum downstream value:  -0.302259121017
# mean upstream value:  -0.269190932765
# std upstream value:  0.0611820904296
# minimum downstream value:  -0.302259121017
# mean upstream value:  -0.191373440588
# std upstream value:  0.0534399630418
# minimum downstream value:  -0.302259121017
# mean upstream value:  -0.146454138875
# std upstream value:  0.0435106822971
# minimum downstream value:  -0.295817378953
# mean upstream value:  -0.121594576025
# std upstream value:  0.00874121760643
# minimum downstream value:  -0.352710346931
# mean upstream value:  -0.134186152884
# std upstream value:  0.0182936842613
# 840
# (41, 41)
# 881
# 922
# 921
# 961
# 1001
# 1000
# 999
# 1039
# 1038
# 1037
# 1077
# 10   10
# 1076
# 1075
# 1074
# 1073
# 1113
# 1153
# 1152
# 1151
# 1191
# node:  86957.0
# minimum downstream value:  -0.744999942101
# mean upstream value:  -0.40278925035
# std upstream value:  0.0455721809086
# minimum downstream value:  -0.703438136889
# mean upstream value:  -0.42607347893
# std upstream value:  0.0127042027044
# minimum downstream value:  -0.514458335907
# mean upstream value:  -0.395373519073
# std upstream value:  0.0372635211375
# minimum downstream value:  -0.317911140532
# mean upstream value:  -0.400944364244
# std upstream value:  0.0432685870576
# minimum downstream value:  -0.338373598845
# mean upstream value:  -0.404607438601
# std upstream value:  0.0441854646328
# minimum downstream value:  -0.436786877779
# mean upstream value:  -0.422019586576
# std upstream value:  0.0217263418314
# minimum downstream value:  -0.436786877779
# mean upstream value:  -0.435600914032
# std upstream value:  0.039984784349
# minimum downstream value:  -0.436786877779
# mean upstream value:  -0.496278544188
# std upstream value:  0.0835097439018
# minimum downstream value:  -0.433207274426
# mean upstream value:  -0.594340891078
# std upstream value:  0.0819776561952
# minimum downstream value:  -0.449919809937
# mean upstream value:  -0.641155097167
# std upstream value:  0.0373678171879
# minimum downstream value:  -0.449919809937
# mean upstream value:  -0.635209195385
# std upstream value:  0.0440638614209
# 840
# (41, 41)
# 798
# 797
# 796
# 754
# 753
# 752
# 792
# 833
# 873
# 872
# 871
# 10   10
# 870
# 869
# 827
# 826
# 866
# 906
# 905
# 904
# 944
# node:  96463.0
# minimum downstream value:  -0.42105186975
# mean upstream value:  -0.391102023118
# std upstream value:  0.0428152992272
# minimum downstream value:  -0.549021604033
# mean upstream value:  -0.365034301919
# std upstream value:  0.0147265761982
# minimum downstream value:  -0.609288634048
# mean upstream value:  -0.380857605865
# std upstream value:  0.00922048198233
# minimum downstream value:  -0.609288634048
# mean upstream value:  -0.396409749671
# std upstream value:  0.0233428497645
# minimum downstream value:  -0.609288634048
# mean upstream value:  -0.42419160182
# std upstream value:  0.0248868463245
# minimum downstream value:  -0.586964724092
# mean upstream value:  -0.461257552598
# std upstream value:  0.0319192106183
# minimum downstream value:  -0.448171261271
# mean upstream value:  -0.455012023685
# std upstream value:  0.0390886957434
# minimum downstream value:  -0.380090283782
# mean upstream value:  -0.345926036005
# std upstream value:  0.160305858264
# minimum downstream value:  -0.392514436141
# mean upstream value:  -0.220303139668
# std upstream value:  0.132729274416
# minimum downstream value:  -0.426746715199
# mean upstream value:  -0.159860161139
# std upstream value:  0.047250699546
# 840
# (41, 41)
# 839
# 838
# 837
# 836
# 835
# 793
# 833
# 832
# 831
# 830
# 829
# 10   10
# 828
# 868
# 867
# 907
# 906
# 946
# 986
# 985
# 1026
# node:  104469.0
# minimum downstream value:  -0.634875633029
# mean upstream value:  -0.171228461586
# std upstream value:  0.0721504867043
# 840
# (41, 41)
# 839
# 879
# 919
# 960
# 1000
# 999
# 1039
# 1079
# 1119
# 1159
# 1200
# 10   10
# 1241
# 1281
# 1321
# 1320
# 1360
# 1359
# 1399
# 1439
# 1480
# node:  110978.0
# minimum downstream value:  -0.389952889544
# mean upstream value:  -0.173316844995
# std upstream value:  0.0227257642647
# 840
# (41, 41)
# 798
# 756
# 714
# 673
# 631
# 590
# 549
# 508
# 466
# 425
# 384
# 10   10
# 343
# 301
# 260
# 219
# 178
# 136
# 95
# 53
# 52
# node:  150219.0
# minimum downstream value:  -1.07135516382
# mean upstream value:  -0.86921557199
# std upstream value:  0.05319039624
# minimum downstream value:  -1.07135516382
# mean upstream value:  -0.967476061996
# std upstream value:  0.113893785113
# minimum downstream value:  -1.06314798589
# mean upstream value:  -1.02243938622
# std upstream value:  0.0718231410135
# minimum downstream value:  -1.04660335737
# mean upstream value:  -1.0104908095
# std upstream value:  0.0855982584917
# minimum downstream value:  -1.04660335737
# mean upstream value:  -0.946012755785
# std upstream value:  0.0431522410586
# minimum downstream value:  -1.04660335737
# mean upstream value:  -0.930991352468
# std upstream value:  0.0223924891075
# minimum downstream value:  -0.943645009881
# mean upstream value:  -0.957474659554
# std upstream value:  0.0259951747182
# minimum downstream value:  -1.11734720464
# mean upstream value:  -0.959114969326
# std upstream value:  0.0238961806002
# minimum downstream value:  -1.11734720464
# mean upstream value:  -0.99607589782
# std upstream value:  0.0588382593445
# minimum downstream value:  -1.11734720464
# mean upstream value:  -1.00022178519
# std upstream value:  0.0585075084505
# minimum downstream value:  -1.00632594414
# mean upstream value:  -0.94574738554
# std upstream value:  0.130903267437
# 840
# (41, 41)
# 798
# 797
# 837
# 795
# 753
# 752
# 751
# 791
# 790
# 830
# 870
# 10   10
# 869
# 909
# 908
# 907
# 906
# 905
# 904
# 903
# 944
# node:  196322.0
# minimum downstream value:  -0.707363686543
# mean upstream value:  -0.679864735157
# std upstream value:  0.0336743705477
# minimum downstream value:  -0.707363686543
# mean upstream value:  -0.621337729795
# std upstream value:  0.101170037982
# minimum downstream value:  -0.707363686543
# mean upstream value:  -0.545194965106
# std upstream value:  0.131148821801
# minimum downstream value:  -0.643001752409
# mean upstream value:  -0.473421802948
# std upstream value:  0.0370836534771
# minimum downstream value:  -0.660637776371
# mean upstream value:  -0.60312352036
# std upstream value:  0.19503439761
# minimum downstream value:  -0.660637776371
# mean upstream value:  -0.81304891433
# std upstream value:  0.22513179293
# minimum downstream value:  -0.727210003397
# mean upstream value:  -0.963427637877
# std upstream value:  0.0730493970114
# minimum downstream value:  -0.727210003397
# mean upstream value:  -0.944675450583
# std upstream value:  0.0968883824929
# minimum downstream value:  -0.727210003397
# mean upstream value:  -0.854469349576
# std upstream value:  0.0781124456922
# minimum downstream value:  -0.511890516922
# mean upstream value:  -0.813942166656
# std upstream value:  0.0242366065111
# minimum downstream value:  -0.874161912519
# mean upstream value:  -0.836650783051
# std upstream value:  0.0424119377265
# 840
# (41, 41)
# 881
# 921
# 961
# 1001
# 1041
# 1081
# 1080
# 1121
# 1162
# 1203
# 1244
# 10   10
# 1284
# 1324
# 1364
# 1404
# 1444
# 1484
# 1524
# 1523
# 1563
# node:  222954.0
# minimum downstream value:  -0.37734153054
# mean upstream value:  -0.129742085855
# std upstream value:  0.0231317133981
# 840
# (41, 41)
# 880
# 920
# 960
# 959
# 999
# 1039
# 1079
# 1121
# 1162
# 1203
# 1244
# 10   10
# 1286
# 1327
# 1368
# 1410
# 1451
# 1491
# 1531
# 1573
# 1614
# node:  250944.0
# minimum downstream value:  -0.432244221684
# mean upstream value:  -0.308994378654
# std upstream value:  0.143746859557
# minimum downstream value:  -0.432244221684
# mean upstream value:  -0.292892516366
# std upstream value:  0.120998423205
# minimum downstream value:  -0.432244221684
# mean upstream value:  -0.309911273057
# std upstream value:  0.109836045133
# minimum downstream value:  -0.319179610301
# mean upstream value:  -0.287489578187
# std upstream value:  0.131677709926
# minimum downstream value:  -0.512110050488
# mean upstream value:  -0.194271283659
# std upstream value:  0.0429741122094
# 840
# (41, 41)
# 880
# 920
# 960
# 1001
# 1042
# 1082
# 1122
# 1162
# 1161
# 1201
# 1241
# 10   10
# 1281
# 1321
# 1362
# 1402
# 1401
# 1400
# 1440
# 1480
# 1520
# node:  276435.0
# minimum downstream value:  -0.413590140965
# mean upstream value:  -0.225861440063
# std upstream value:  0.0259019641939
# minimum downstream value:  -0.397729685184
# mean upstream value:  -0.217387283587
# std upstream value:  0.0369660026094
# minimum downstream value:  -0.37954072613
# mean upstream value:  -0.187040668231
# std upstream value:  0.0508642080372
# minimum downstream value:  -0.348923754786
# mean upstream value:  -0.140257019928
# std upstream value:  0.0212071473383
# 840
# (41, 41)
# 881
# 922
# 963
# 1004
# 1045
# 1086
# 1127
# 1169
# 1210
# 1252
# 1293
# 10   10
# 1334
# 1375
# 1416
# 1457
# 1498
# 1539
# 1580
# 1621
# 1622
# node:  310459.0
# minimum downstream value:  -1.38151459826
# mean upstream value:  -0.84347546242
# std upstream value:  0.0783418567572
# minimum downstream value:  -1.32309309767
# mean upstream value:  -0.77335917557
# std upstream value:  0.0393853172859
# minimum downstream value:  -1.13417167814
# mean upstream value:  -0.743081234818
# std upstream value:  0.00937672143807
# minimum downstream value:  -1.01520764498
# mean upstream value:  -0.668237980175
# std upstream value:  0.0964777735871
# minimum downstream value:  -0.980050912488
# mean upstream value:  -0.640355448164
# std upstream value:  0.0841843789238
# minimum downstream value:  -0.980050912488
# mean upstream value:  -0.625833262568
# std upstream value:  0.0685766961631
# minimum downstream value:  -0.94629629987
# mean upstream value:  -0.677974494864
# std upstream value:  0.0182773807911
# minimum downstream value:  -0.827801248302
# mean upstream value:  -0.68961717206
# std upstream value:  0.00270613235075
# minimum downstream value:  -0.756328839087
# mean upstream value:  -0.681457439116
# std upstream value:  0.00887342765889
# minimum downstream value:  -0.736967426044
# mean upstream value:  -0.671663347126
# std upstream value:  0.0117501322578
# minimum downstream value:  -0.736967426044
# mean upstream value:  -0.694597447814
# std upstream value:  0.0436340285779
# 840
# (41, 41)
# 880
# 921
# 961
# 1001
# 1000
# 999
# 1040
# 1080
# 1120
# 1160
# 1200
# 10   10
# 1240
# 1280
# 1279
# 1320
# 1361
# 1401
# 1441
# 1482
# 1523
# node:  584844.0
# minimum downstream value:  -0.794979773962
# mean upstream value:  -0.395670412086
# std upstream value:  0.0429253539035
# minimum downstream value:  -0.794979773962
# mean upstream value:  -0.403274314991
# std upstream value:  0.0491189755695
# minimum downstream value:  -0.491194050303
# mean upstream value:  -0.422231882771
# std upstream value:  0.0232718577585
# minimum downstream value:  -0.491194050303
# mean upstream value:  -0.371978639143
# std upstream value:  0.0718629805042
# minimum downstream value:  -0.442522252501
# mean upstream value:  -0.336492043396
# std upstream value:  0.047555436463
# minimum downstream value:  -0.42555303159
# mean upstream value:  -0.296089825737
# std upstream value:  0.0324629720269
# minimum downstream value:  -0.426490994781
# mean upstream value:  -0.350850181931
# std upstream value:  0.0694374076261
# minimum downstream value:  -0.448364740304
# mean upstream value:  -0.365612969882
# std upstream value:  0.0706634301466
# minimum downstream value:  -0.448364740304
# mean upstream value:  -0.365537057909
# std upstream value:  0.0707654723693
# minimum downstream value:  -0.448364740304
# mean upstream value:  -0.281614280972
# std upstream value:  0.0812002053399
# minimum downstream value:  -0.391839913229
# mean upstream value:  -0.255373506207
# std upstream value:  0.0498212807248
# 840
# (41, 41)
# 882
# 923
# 965
# 1006
# 1046
# 1087
# 1128
# 1169
# 1210
# 1251
# 1291
# 10   10
# 1332
# 1373
# 1414
# 1454
# 1495
# 1536
# 1578
# 1620
# 1621
# node:  606823.0
# minimum downstream value:  -0.70600836833
# mean upstream value:  -0.191700087234
# std upstream value:  0.00627015690444
# 840
# (41, 41)
# 839
# 879
# 920
# 960
# 1001
# 1042
# 1083
# 1124
# 1166
# 1207
# 1248
# 10   10
# 1288
# 1328
# 1368
# 1409
# 1449
# 1490
# 1531
# 1572
# 1613
# node:  644821.0
# minimum downstream value:  -0.482386653131
# mean upstream value:  -0.362222342309
# std upstream value:  0.0667064873778
# minimum downstream value:  -0.460010151618
# mean upstream value:  -0.458119268003
# std upstream value:  0.102246094046
# minimum downstream value:  -0.470353318769
# mean upstream value:  -0.563809964025
# std upstream value:  0.0822439823887
# minimum downstream value:  -0.470353318769
# mean upstream value:  -0.622853878458
# std upstream value:  0.0278695573276
# minimum downstream value:  -0.470353318769
# mean upstream value:  -0.637761252985
# std upstream value:  0.0101097346632
# minimum downstream value:  -0.351759356472
# mean upstream value:  -0.617473778203
# std upstream value:  0.0185979146667
# minimum downstream value:  -0.454063445683
# mean upstream value:  -0.581587518785
# std upstream value:  0.0440080611527
# minimum downstream value:  -0.585323288507
# mean upstream value:  -0.552072396863
# std upstream value:  0.0286096667724
# minimum downstream value:  -0.652043157887
# mean upstream value:  -0.539148705122
# std upstream value:  0.0119041368353
# minimum downstream value:  -0.652043157887
# mean upstream value:  -0.547971702847
# std upstream value:  0.00468023243621
# minimum downstream value:  -0.652043157887
# mean upstream value:  -0.501781358078
# std upstream value:  0.0699060553023
# 840
# (41, 41)
# 881
# 922
# 963
# 1005
# 1045
# 1086
# 1127
# 1167
# 1208
# 1249
# 1290
# 10   10
# 1331
# 1330
# 1329
# 1287
# 1286
# 1285
# 1325
# 1365
# 1406
# node:  678815.0
# minimum downstream value:  -0.402929012012
# mean upstream value:  -0.131229767529
# std upstream value:  0.0173308134085
# 840
# (41, 41)
# 839
# 838
# 837
# 836
# 835
# 876
# 917
# 957
# 956
# 955
# 995
# 10   10
# 994
# 993
# 992
# 1032
# 1031
# 1071
# 1112
# 1152
# 1192
# node:  930426.0
# minimum downstream value:  -1.02125808656
# mean upstream value:  -0.706836805984
# std upstream value:  0.0135085609806
# minimum downstream value:  -1.16389555799
# mean upstream value:  -0.736557147563
# std upstream value:  0.0504304890412
# minimum downstream value:  -1.30866708869
# mean upstream value:  -0.770606723228
# std upstream value:  0.0588033819713
# minimum downstream value:  -1.30866708869
# mean upstream value:  -0.762494274436
# std upstream value:  0.0702422148968
# minimum downstream value:  -1.30866708869
# mean upstream value:  -0.746637356925
# std upstream value:  0.0636971102575
# minimum downstream value:  -0.851579387197
# mean upstream value:  -0.724804140676
# std upstream value:  0.0434828662791
# minimum downstream value:  -0.71683257936
# mean upstream value:  -0.794857060328
# std upstream value:  0.0557032100739
# minimum downstream value:  -0.805993604095
# mean upstream value:  -0.911679153543
# std upstream value:  0.147935828904
# minimum downstream value:  -0.818086767385
# mean upstream value:  -1.13348557544
# std upstream value:  0.222948238462
# minimum downstream value:  -0.818086767385
# mean upstream value:  -1.21098655329
# std upstream value:  0.146389669421
# minimum downstream value:  -0.818086767385
# mean upstream value:  -1.16694618999
# std upstream value:  0.185207606842
# 840
# (41, 41)
# 799
# 758
# 717
# 716
# 715
# 673
# 631
# 630
# 629
# 587
# 586
# 10   10
# 544
# 502
# 460
# 419
# 377
# 335
# 334
# 333
# 291
# node:  970466.0
# minimum downstream value:  -0.886803668478
# mean upstream value:  -0.774228142498
# std upstream value:  0.0681037523766
# minimum downstream value:  -0.926200052495
# mean upstream value:  -0.853869612823
# std upstream value:  0.0640890190438
# minimum downstream value:  -0.926200052495
# mean upstream value:  -0.893188476563
# std upstream value:  0.0294691521611
# minimum downstream value:  -0.926200052495
# mean upstream value:  -0.897655381516
# std upstream value:  0.0243838639223
# minimum downstream value:  -0.863049171659
# mean upstream value:  -0.911223520875
# std upstream value:  0.0429573732141
# minimum downstream value:  -0.773362231349
# mean upstream value:  -0.99401951967
# std upstream value:  0.110723222462
# minimum downstream value:  -0.858067448431
# mean upstream value:  -1.04764907696
# std upstream value:  0.0697648969518
# minimum downstream value:  -0.930179158689
# mean upstream value:  -1.03168858464
# std upstream value:  0.0884705930228
# minimum downstream value:  -0.930179158689
# mean upstream value:  -0.946370121047
# std upstream value:  0.0628778713562
# minimum downstream value:  -0.930179158689
# mean upstream value:  -0.925933717268
# std upstream value:  0.0356987602917
# minimum downstream value:  -0.970883576766
# mean upstream value:  -0.966509149323
# std upstream value:  0.0657968811472
# 840
# (41, 41)
# 839
# 879
# 919
# 960
# 1001
# 1000
# 999
# 998
# 956
# 955
# 995
# 10   10
# 1035
# 1075
# 1033
# 1073
# 1114
# 1154
# 1194
# 1234
# 1233
# node:  986133.0
# minimum downstream value:  -0.625789355855
# mean upstream value:  -0.592156491889
# std upstream value:  0.05233387756
# minimum downstream value:  -0.808145998024
# mean upstream value:  -0.653413594162
# std upstream value:  0.117973430068
# minimum downstream value:  -0.971245927773
# mean upstream value:  -0.697506066525
# std upstream value:  0.0769045228287
# minimum downstream value:  -0.971245927773
# mean upstream value:  -0.745739762177
# std upstream value:  0.0679032608615
# minimum downstream value:  -0.971245927773
# mean upstream value:  -0.771931966146
# std upstream value:  0.0955784168323
# minimum downstream value:  -0.866611887815
# mean upstream value:  -0.899269636755
# std upstream value:  0.103567295066
# minimum downstream value:  -0.635760522171
# mean upstream value:  -0.965737806479
# std upstream value:  0.0613866067673
# minimum downstream value:  -0.805916405478
# mean upstream value:  -0.964707526608
# std upstream value:  0.0627522763351
# minimum downstream value:  -0.805916405478
# mean upstream value:  -0.893802366395
# std upstream value:  0.06579527497
# minimum downstream value:  -0.805916405478
# mean upstream value:  -0.860578494267
# std upstream value:  0.0285994298978
# minimum downstream value:  -0.884493017385
# mean upstream value:  -0.932201440784
# std upstream value:  0.118577095031
# 840
# (41, 41)
# 798
# 756
# 796
# 795
# 794
# 793
# 792
# 791
# 831
# 872
# 913
# 10   10
# 954
# 995
# 1035
# 1034
# 1033
# 1073
# 1113
# 1112
# 1152
# node:  992375.0
# minimum downstream value:  -0.380451669806
# mean upstream value:  -0.242473617373
# std upstream value:  0.0328941970796
# minimum downstream value:  -0.380451669806
# mean upstream value:  -0.260201475523
# std upstream value:  0.0123041388218
# minimum downstream value:  -0.380451669806
# mean upstream value:  -0.286973634099
# std upstream value:  0.0501650280801
# minimum downstream value:  -0.320183192317
# mean upstream value:  -0.386458847991
# std upstream value:  0.12335935293
# minimum downstream value:  -0.24981810076
# mean upstream value:  -0.51188263623
# std upstream value:  0.113451345242
# minimum downstream value:  -0.277600917892
# mean upstream value:  -0.601823045331
# std upstream value:  0.0368017431706
# minimum downstream value:  -0.277600917892
# mean upstream value:  -0.691837275609
# std upstream value:  0.0904977482745
# minimum downstream value:  -0.277600917892
# mean upstream value:  -0.707856631876
# std upstream value:  0.0815861946184
# minimum downstream value:  -0.35791739362
# mean upstream value:  -0.689325103961
# std upstream value:  0.101550778032
# minimum downstream value:  -0.549777667984
# mean upstream value:  -0.636688192214
# std upstream value:  0.0460012505127
# minimum downstream value:  -0.627952847085
# mean upstream value:  -0.62966536973
# std upstream value:  0.0407730561051
# 840
# (41, 41)
# 880
# 920
# 960
# 959
# 917
# 916
# 915
# 914
# 913
# 912
# 911
# 10   10
# 910
# 950
# 949
# 948
# 988
# 1028
# 1068
# 1067
# 1026
# node:  1000120.0
# minimum downstream value:  -1.09627101732
# mean upstream value:  -0.885746851583
# std upstream value:  0.0458201746975
# minimum downstream value:  -1.12931202523
# mean upstream value:  -0.954375778419
# std upstream value:  0.0692890199879
# minimum downstream value:  -1.12931202523
# mean upstream value:  -1.01526120152
# std upstream value:  0.0485812457511
# minimum downstream value:  -1.12931202523
# mean upstream value:  -1.03682213181
# std upstream value:  0.0186042192483
# minimum downstream value:  -0.975357236598
# mean upstream value:  -1.01303289562
# std upstream value:  0.0346259319837
# minimum downstream value:  -0.950838955966
# mean upstream value:  -1.01142957685
# std upstream value:  0.0326494853423
# minimum downstream value:  -0.946994947351
# mean upstream value:  -1.03644192863
# std upstream value:  0.0482663296294
# minimum downstream value:  -1.04268649256
# mean upstream value:  -1.09468651572
# std upstream value:  0.0390942589783
# minimum downstream value:  -1.05610216465
# mean upstream value:  -1.14436832875
# std upstream value:  0.0464016211623
# minimum downstream value:  -1.05610216465
# mean upstream value:  -1.25035270118
# std upstream value:  0.111345127217
# minimum downstream value:  -1.05610216465
# mean upstream value:  -1.32024591619
# std upstream value:  0.0871097808203
# 840
# (41, 41)
# 880
# 920
# 919
# 918
# 917
# 875
# 874
# 914
# 955
# 995
# 994
# 10   10
# 952
# 951
# 992
# 1032
# 1031
# 1071
# 1111
# 1151
# 1191
# node:  1006672.0
# minimum downstream value:  -0.531760958344
# mean upstream value:  -0.501415147141
# std upstream value:  0.0235323529094
# minimum downstream value:  -0.544915120121
# mean upstream value:  -0.517740885417
# std upstream value:  0.0405261192294
# minimum downstream value:  -0.593900537302
# mean upstream value:  -0.517949000021
# std upstream value:  0.0405268650246
# minimum downstream value:  -0.593900537302
# mean upstream value:  -0.531655775229
# std upstream value:  0.0255477457072
# minimum downstream value:  -0.593900537302
# mean upstream value:  -0.532732374269
# std upstream value:  0.0270551979458
# minimum downstream value:  -0.586142076334
# mean upstream value:  -0.501934307837
# std upstream value:  0.0593115465767
# minimum downstream value:  -0.518429239748
# mean upstream value:  -0.444997593976
# std upstream value:  0.0957465635592
# minimum downstream value:  -0.567406454576
# mean upstream value:  -0.369788932549
# std upstream value:  0.0397725960833
# minimum downstream value:  -0.567406454576
# mean upstream value:  -0.319174463727
# std upstream value:  0.0320096864521
# minimum downstream value:  -0.567406454576
# mean upstream value:  -0.312516404706
# std upstream value:  0.0292681689852
# minimum downstream value:  -0.570636251698
# mean upstream value:  -0.296226692451
# std upstream value:  0.0181301908223
# 840
# (41, 41)
# 839
# 797
# 755
# 713
# 672
# 631
# 630
# 629
# 587
# 586
# 585
# 10   10
# 584
# 583
# 582
# 622
# 621
# 620
# 619
# 659
# 658
# node:  1012208.0
# minimum downstream value:  -0.959022009326
# mean upstream value:  -1.05930445976
# std upstream value:  0.110257278652
# minimum downstream value:  -1.20181889591
# mean upstream value:  -0.933527970345
# std upstream value:  0.0680784087943
# minimum downstream value:  -1.23602222548
# mean upstream value:  -0.889444986979
# std upstream value:  0.0601899456578
# minimum downstream value:  -1.29503622545
# mean upstream value:  -0.822287819602
# std upstream value:  0.0361549117615
# minimum downstream value:  -1.29503622545
# mean upstream value:  -0.768028611094
# std upstream value:  0.074349295113
# minimum downstream value:  -1.29503622545
# mean upstream value:  -0.66688523525
# std upstream value:  0.0895695819158
# minimum downstream value:  -1.21498319
# mean upstream value:  -0.600659115355
# std upstream value:  0.0531286777557
# minimum downstream value:  -0.989087493052
# mean upstream value:  -0.60026861902
# std upstream value:  0.0525832526258
# minimum downstream value:  -0.973842696239
# mean upstream value:  -0.635336090611
# std upstream value:  0.0440217658369
# minimum downstream value:  -0.856838542953
# mean upstream value:  -0.620684758162
# std upstream value:  0.0646030233933
# minimum downstream value:  -0.856838542953
# mean upstream value:  -0.533856739954
# std upstream value:  0.100222468968
# 840
# (41, 41)
# 881
# 922
# 964
# 1006
# 1048
# 1089
# 1131
# 1172
# 1213
# 1254
# 1295
# 10   10
# 1336
# 1377
# 1418
# 1460
# 1501
# 1542
# 1583
# 1624
# 1625
# node:  1018960.0
# minimum downstream value:  -0.268277254972
# mean upstream value:  -0.223488225924
# std upstream value:  0.0463060038091
# minimum downstream value:  -0.268277254972
# mean upstream value:  -0.267448334826
# std upstream value:  0.0234494441633
# minimum downstream value:  -0.268277254972
# mean upstream value:  -0.24744102669
# std upstream value:  0.0508731656965
# minimum downstream value:  -0.211560878829
# mean upstream value:  -0.210589784564
# std upstream value:  0.0587655687067
# minimum downstream value:  -0.211560878829
# mean upstream value:  -0.167651914011
# std upstream value:  0.00633489532793
# minimum downstream value:  -0.236519191576
# mean upstream value:  -0.171642921659
# std upstream value:  0.0119411442964
# minimum downstream value:  -0.272551645875
# mean upstream value:  -0.191248957819
# std upstream value:  0.023090771157
# minimum downstream value:  -0.293274167027
# mean upstream value:  -0.209532163517
# std upstream value:  0.0149056764062
# minimum downstream value:  -0.293274167027
# mean upstream value:  -0.219508798069
# std upstream value:  0.000996210429354
# minimum downstream value:  -0.293274167027
# mean upstream value:  -0.229857272624
# std upstream value:  0.01556373854
# minimum downstream value:  -0.176497267169
# mean upstream value:  -0.223890784544
# std upstream value:  0.0209591558079
# 840
# (41, 41)
# 839
# 838
# 878
# 919
# 960
# 1001
# 1042
# 1084
# 1124
# 1164
# 1204
# 10   10
# 1245
# 1287
# 1327
# 1367
# 1366
# 1406
# 1446
# 1445
# 1444
# node:  1024654.0
# minimum downstream value:  -0.64118468997
# mean upstream value:  -0.226016963109
# std upstream value:  0.0618958131321
# minimum downstream value:  -0.666792918571
# mean upstream value:  -0.245325945426
# std upstream value:  0.077942209281
# minimum downstream value:  -0.666792918571
# mean upstream value:  -0.311824190444
# std upstream value:  0.0270821271143
# minimum downstream value:  -0.666792918571
# mean upstream value:  -0.347650460104
# std upstream value:  0.0251269339991
# minimum downstream value:  -0.586179228168
# mean upstream value:  -0.304261942626
# std upstream value:  0.0809824242658
# minimum downstream value:  -0.434044396924
# mean upstream value:  -0.241946575984
# std upstream value:  0.100498265233
# minimum downstream value:  -0.274573284647
# mean upstream value:  -0.226488357162
# std upstream value:  0.0790332263883
# minimum downstream value:  -0.322739914001
# mean upstream value:  -0.286855906209
# std upstream value:  0.097160296646
# minimum downstream value:  -0.338159372684
# mean upstream value:  -0.381135681715
# std upstream value:  0.0405063121227
# minimum downstream value:  -0.382052093626
# mean upstream value:  -0.410202086679
# std upstream value:  0.0262270399865
# minimum downstream value:  -0.382052093626
# mean upstream value:  -0.40782887254
# std upstream value:  0.029537866884
# 840
# (41, 41)
# 839
# 879
# 878
# 877
# 917
# 916
# 915
# 955
# 954
# 994
# 993
# 10   10
# 1033
# 1032
# 1072
# 1071
# 1111
# 1110
# 1150
# 1190
# 1231
# node:  1030219.0
# minimum downstream value:  -0.469853457726
# mean upstream value:  -0.106176403986
# std upstream value:  0.0857357314498
# 840
# (41, 41)
# 798
# 756
# 714
# 713
# 712
# 670
# 628
# 586
# 545
# 503
# 461
# 10   10
# 419
# 418
# 377
# 335
# 293
# 251
# 209
# 167
# 126
# node:  1062528.0
# minimum downstream value:  -1.22262247561
# mean upstream value:  -1.04156325269
# std upstream value:  0.026760005084
# minimum downstream value:  -1.44784654459
# mean upstream value:  -1.07323060771
# std upstream value:  0.0537441807532
# minimum downstream value:  -1.44784654459
# mean upstream value:  -1.11083437551
# std upstream value:  0.0278752636024
# minimum downstream value:  -1.44784654459
# mean upstream value:  -1.20406537565
# std upstream value:  0.105335632531
# minimum downstream value:  -1.40143377131
# mean upstream value:  -1.27256290401
# std upstream value:  0.107669929265
# minimum downstream value:  -1.16664141629
# mean upstream value:  -1.24786384995
# std upstream value:  0.142587695617
# minimum downstream value:  -1.07294207788
# mean upstream value:  -1.09890397264
# std upstream value:  0.183018912684
# minimum downstream value:  -1.13919730808
# mean upstream value:  -0.978292713995
# std upstream value:  0.057454115278
# minimum downstream value:  -1.13919730808
# mean upstream value:  -1.07691346421
# std upstream value:  0.190158741884
# minimum downstream value:  -1.35263507828
# mean upstream value:  -1.15143119802
# std upstream value:  0.147504295505
# minimum downstream value:  -1.35263507828
# mean upstream value:  -1.23453197052
# std upstream value:  0.0868996840895
# 840
# (41, 41)
# 839
# 838
# 878
# 919
# 959
# 999
# 1040
# 1080
# 1121
# 1120
# 1078
# 10   10
# 1077
# 1117
# 1157
# 1156
# 1114
# 1113
# 1112
# 1070
# 1069
# node:  1094587.0
# minimum downstream value:  -0.694654864285
# mean upstream value:  -0.195785824018
# std upstream value:  0.136653678854
# minimum downstream value:  -0.574845023777
# mean upstream value:  -0.333504296103
# std upstream value:  0.0654887286701
# minimum downstream value:  -0.574845023777
# mean upstream value:  -0.337479542367
# std upstream value:  0.0611168305142
# minimum downstream value:  -0.366994020967
# mean upstream value:  -0.265165829062
# std upstream value:  0.128410572441
# minimum downstream value:  -0.247264274024
# mean upstream value:  -0.177865130157
# std upstream value:  0.0698090919064
# minimum downstream value:  -0.259909889915
# mean upstream value:  -0.205353466733
# std upstream value:  0.10747423874
# minimum downstream value:  -0.321607989285
# mean upstream value:  -0.304032598403
# std upstream value:  0.10561495208
# minimum downstream value:  -0.418995009109
# mean upstream value:  -0.370466832901
# std upstream value:  0.0213981778406
# minimum downstream value:  -0.418995009109
# mean upstream value:  -0.387674726202
# std upstream value:  0.0222201012516
# minimum downstream value:  -0.418995009109
# mean upstream value:  -0.435016456172
# std upstream value:  0.0788028651449
# minimum downstream value:  -0.271835628706
# mean upstream value:  -0.476297451416
# std upstream value:  0.0559199394158
# 840
# (41, 41)
# 881
# 922
# 964
# 1005
# 1045
# 1086
# 1126
# 1125
# 1124
# 1123
# 1164
# 10   10
# 1204
# 1245
# 1285
# 1325
# 1366
# 1407
# 1448
# 1489
# 1530
# node:  1166619.0
# minimum downstream value:  -0.442591731256
# mean upstream value:  -0.408540386456
# std upstream value:  0.00562501176958
# minimum downstream value:  -0.442591731256
# mean upstream value:  -0.414049151073
# std upstream value:  0.0133847824224
# minimum downstream value:  -0.442591731256
# mean upstream value:  -0.421968764153
# std upstream value:  0.0118317691315
# minimum downstream value:  -0.401319420856
# mean upstream value:  -0.424134989501
# std upstream value:  0.00884391049951
# minimum downstream value:  -0.416420435246
# mean upstream value:  -0.397709259717
# std upstream value:  0.031766961506
# minimum downstream value:  -0.416420435246
# mean upstream value:  -0.388308076519
# std upstream value:  0.025046928395
# minimum downstream value:  -0.416420435246
# mean upstream value:  -0.403187144886
# std upstream value:  0.0421474613653
# minimum downstream value:  -0.432946729095
# mean upstream value:  -0.436757928298
# std upstream value:  0.0265652762556
# minimum downstream value:  -0.432946729095
# mean upstream value:  -0.418721275681
# std upstream value:  0.0520648399734
# minimum downstream value:  -0.432946729095
# mean upstream value:  -0.3436253564
# std upstream value:  0.0910413322328
# minimum downstream value:  -0.427415930707
# mean upstream value:  -0.272157772099
# std upstream value:  0.0516986613547
# 840
# (41, 41)
# 880
# 921
# 962
# 1002
# 1042
# 1083
# 1123
# 1163
# 1203
# 1243
# 1242
# 10   10
# 1241
# 1281
# 1321
# 1320
# 1319
# 1359
# 1358
# 1357
# 1356
# node:  1252599.0
# minimum downstream value:  -0.38442691607
# mean upstream value:  -0.0904825685524
# std upstream value:  0.0399152950238
# 840
# (41, 41)
# 839
# 879
# 919
# 959
# 958
# 998
# 1038
# 1078
# 1077
# 1117
# 1157
# 10   10
# 1197
# 1237
# 1277
# 1317
# 1357
# 1397
# 1437
# 1477
# 1518
# node:  1398237.0
# minimum downstream value:  -0.896695706213
# mean upstream value:  -0.27553681988
# std upstream value:  0.0355182922203
# minimum downstream value:  -1.1474498402
# mean upstream value:  -0.263652575346
# std upstream value:  0.0517914447225
# minimum downstream value:  -1.1474498402
# mean upstream value:  -0.22983089643
# std upstream value:  0.0585980416016
# minimum downstream value:  -1.1474498402
# mean upstream value:  -0.199901636096
# std upstream value:  0.0164567029174
# 840
# (41, 41)
# 882
# 923
# 964
# 1006
# 1048
# 1049
# 1091
# 1133
# 1175
# 1217
# 1218
# 10   10
# 1260
# 1302
# 1344
# 1385
# 1427
# 1468
# 1509
# 1550
# 1591
# node:  1534540.0
# minimum downstream value:  -1.12426950809
# mean upstream value:  -1.22897769089
# std upstream value:  0.0364529232081
# minimum downstream value:  -1.21861683239
# mean upstream value:  -1.24072458622
# std upstream value:  0.0348783484985
# minimum downstream value:  -1.21861683239
# mean upstream value:  -1.23375821522
# std upstream value:  0.0278008712289
# minimum downstream value:  -1.21861683239
# mean upstream value:  -1.28336186466
# std upstream value:  0.0429433164112
# minimum downstream value:  -1.21245011039
# mean upstream value:  -1.2937815871
# std upstream value:  0.0363029529733
# minimum downstream value:  -1.27953040082
# mean upstream value:  -1.32553659472
# std upstream value:  0.0332004423126
# minimum downstream value:  -1.27953040082
# mean upstream value:  -1.32095501765
# std upstream value:  0.0312607587037
# minimum downstream value:  -1.27953040082
# mean upstream value:  -1.37371512552
# std upstream value:  0.0459577049733
# minimum downstream value:  -1.25863128783
# mean upstream value:  -1.35517040951
# std upstream value:  0.0594558005279
# minimum downstream value:  -1.34376350976
# mean upstream value:  -1.30166613914
# std upstream value:  0.109324496053
# minimum downstream value:  -1.34376350976
# mean upstream value:  -1.04811516361
# std upstream value:  0.267923861914
# 840
# (41, 41)
# 881
# 922
# 963
# 1004
# 1045
# 1086
# 1126
# 1166
# 1206
# 1247
# 1288
# 10   10
# 1328
# 1368
# 1408
# 1448
# 1489
# 1530
# 1570
# 1612
# 1613
# node:  1664483.0
# minimum downstream value:  -0.904468641922
# mean upstream value:  -0.660042382041
# std upstream value:  0.0698262400071
# minimum downstream value:  -0.894350798234
# mean upstream value:  -0.604164093379
# std upstream value:  0.0208422346977
# minimum downstream value:  -0.894350798234
# mean upstream value:  -0.579839613441
# std upstream value:  0.0136397179651
# minimum downstream value:  -0.894350798234
# mean upstream value:  -0.582944606133
# std upstream value:  0.0165479438704
# minimum downstream value:  -0.841331753335
# mean upstream value:  -0.61325262218
# std upstream value:  0.0491837547444
# minimum downstream value:  -0.841331753335
# mean upstream value:  -0.68711851017
# std upstream value:  0.0745379189872
# minimum downstream value:  -0.755661553545
# mean upstream value:  -0.805437130733
# std upstream value:  0.11394402561
# minimum downstream value:  -0.633593653502
# mean upstream value:  -0.846958406672
# std upstream value:  0.0769903933118
# minimum downstream value:  -0.590871939075
# mean upstream value:  -0.782071682775
# std upstream value:  0.150830024202
# minimum downstream value:  -0.60018691715
# mean upstream value:  -0.78338840168
# std upstream value:  0.152344792054
# minimum downstream value:  -0.678950735703
# mean upstream value:  -0.726930158412
# std upstream value:  0.165261691416
# 840
# (41, 41)
# 839
# 879
# 919
# 918
# 958
# 999
# 1039
# 1080
# 1120
# 1161
# 1201
# 10   10
# 1242
# 1282
# 1323
# 1363
# 1403
# 1444
# 1484
# 1524
# 1565
# node:  1745068.0
# minimum downstream value:  -0.592198307806
# mean upstream value:  -0.403265308486
# std upstream value:  0.0237701778557
# minimum downstream value:  -0.592198307806
# mean upstream value:  -0.359421640831
# std upstream value:  0.0387135521626
# minimum downstream value:  -0.592198307806
# mean upstream value:  -0.342452419919
# std upstream value:  0.0361356746424
# minimum downstream value:  -0.581758642385
# mean upstream value:  -0.297236386024
# std upstream value:  0.0313223089997
# minimum downstream value:  -0.529260205657
# mean upstream value:  -0.282485821187
# std upstream value:  0.0344859913497
# minimum downstream value:  -0.436460713624
# mean upstream value:  -0.242708429832
# std upstream value:  0.0219276304853
# minimum downstream value:  -0.436460713624
# mean upstream value:  -0.227805397727
# std upstream value:  0.0232475825855
# minimum downstream value:  -0.391258993639
# mean upstream value:  -0.221440693449
# std upstream value:  0.0142485096401
# minimum downstream value:  -0.391258993639
# mean upstream value:  -0.221652667984
# std upstream value:  0.0141080882549
# minimum downstream value:  -0.331168555459
# mean upstream value:  -0.225789388021
# std upstream value:  0.0120131744953
# minimum downstream value:  -0.331168555459
# mean upstream value:  -0.219849276134
# std upstream value:  0.00521956356457
# 840
# (41, 41)
# 882
# 923
# 963
# 1003
# 1002
# 960
# 1001
# 1041
# 1082
# 1123
# 1164
# 10   10
# 1204
# 1245
# 1286
# 1326
# 1366
# 1407
# 1447
# 1488
# 1530
# node:  1776472.0
# minimum downstream value:  -0.861627269639
# mean upstream value:  -0.689911813447
# std upstream value:  0.0654236174799
# minimum downstream value:  -0.809525440804
# mean upstream value:  -0.636368943769
# std upstream value:  0.0366532542455
# minimum downstream value:  -0.809525440804
# mean upstream value:  -0.575436075686
# std upstream value:  0.0495194717614
# minimum downstream value:  -0.809525440804
# mean upstream value:  -0.584005122128
# std upstream value:  0.056591268135
# minimum downstream value:  -0.770879330842
# mean upstream value:  -0.594098358757
# std upstream value:  0.0627385413961
# minimum downstream value:  -0.770879330842
# mean upstream value:  -0.616436100132
# std upstream value:  0.0311716377763
# minimum downstream value:  -0.770879330842
# mean upstream value:  -0.606267434021
# std upstream value:  0.0278080911099
# minimum downstream value:  -0.688203954885
# mean upstream value:  -0.633974821671
# std upstream value:  0.0648642036041
# minimum downstream value:  -0.610652154613
# mean upstream value:  -0.685936888844
# std upstream value:  0.0566594924533
# minimum downstream value:  -0.636359293941
# mean upstream value:  -0.73946464046
# std upstream value:  0.0191663532462
# minimum downstream value:  -0.640530431695
# mean upstream value:  -0.741883208786
# std upstream value:  0.0173943386164
# 840
# (41, 41)
# 839
# 838
# 837
# 795
# 794
# 752
# 751
# 750
# 708
# 707
# 706
# 10   10
# 705
# 704
# 703
# 702
# 701
# 659
# 658
# 657
# 616
# node:  1817177.0
# minimum downstream value:  -1.45821190634
# mean upstream value:  -1.45754060004
# std upstream value:  0.0728663825377
# minimum downstream value:  -1.45821190634
# mean upstream value:  -1.47564785722
# std upstream value:  0.0899749273267
# minimum downstream value:  -1.42155366076
# mean upstream value:  -1.57589653327
# std upstream value:  0.0630582357179
# minimum downstream value:  -1.59958525043
# mean upstream value:  -1.61471457098
# std upstream value:  0.0347378343245
# minimum downstream value:  -1.59958525043
# mean upstream value:  -1.62410401356
# std upstream value:  0.0235841859625
# minimum downstream value:  -1.59958525043
# mean upstream value:  -1.54067755939
# std upstream value:  0.0960253552581
# minimum downstream value:  -1.51636321177
# mean upstream value:  -1.4227643924
# std upstream value:  0.137210349298
# minimum downstream value:  -1.57068498333
# mean upstream value:  -1.28378822618
# std upstream value:  0.0922556440071
# minimum downstream value:  -1.65560056664
# mean upstream value:  -1.24221644948
# std upstream value:  0.0431606932759
# minimum downstream value:  -1.65560056664
# mean upstream value:  -1.2366571841
# std upstream value:  0.0410016570848
# minimum downstream value:  -1.65560056664
# mean upstream value:  -1.27222017431
# std upstream value:  0.0178239959465
# 840
# (41, 41)
# 798
# 797
# 755
# 713
# 753
# 752
# 751
# 709
# 667
# 666
# 665
# 10   10
# 664
# 663
# 621
# 579
# 578
# 577
# 576
# 575
# 534
# node:  1843219.0
# minimum downstream value:  -0.779545840539
# mean upstream value:  -0.69192315907
# std upstream value:  0.0437822426597
# minimum downstream value:  -0.791234193583
# mean upstream value:  -0.611913065351
# std upstream value:  0.0787898607028
# minimum downstream value:  -0.791234193583
# mean upstream value:  -0.531731687201
# std upstream value:  0.0781020595648
# minimum downstream value:  -0.791234193583
# mean upstream value:  -0.464917249516
# std upstream value:  0.0290389420957
# minimum downstream value:  -0.755534175828
# mean upstream value:  -0.440035331234
# std upstream value:  0.00907940606289
# minimum downstream value:  -0.755534175828
# mean upstream value:  -0.457571157825
# std upstream value:  0.0335394630121
# minimum downstream value:  -0.745118152483
# mean upstream value:  -0.561962665462
# std upstream value:  0.136810679167
# minimum downstream value:  -0.692767358109
# mean upstream value:  -0.713719705976
# std upstream value:  0.157668075601
# minimum downstream value:  -0.637883966619
# mean upstream value:  -0.855406508615
# std upstream value:  0.076261998364
# minimum downstream value:  -0.505087871325
# mean upstream value:  -0.935153322886
# std upstream value:  0.0426784648798
# minimum downstream value:  -0.45222322366
# mean upstream value:  -0.9935063097
# std upstream value:  0.0534943012305
# 840
# (41, 41)
# 880
# 920
# 960
# 1000
# 1041
# 1082
# 1124
# 1165
# 1206
# 1247
# 1287
# 10   10
# 1286
# 1285
# 1284
# 1324
# 1364
# 1404
# 1403
# 1443
# 1483
# node:  1854461.0
# minimum downstream value:  -0.472385089859
# mean upstream value:  -0.0988975394227
# std upstream value:  0.0275082702957
# 840
# (41, 41)
# 882
# 923
# 964
# 1004
# 1045
# 1086
# 1126
# 1167
# 1209
# 1250
# 1291
# 10   10
# 1332
# 1374
# 1375
# 1416
# 1457
# 1497
# 1539
# 1580
# 1621
# node:  1860463.0
# minimum downstream value:  -0.618851612679
# mean upstream value:  -0.292352447711
# std upstream value:  0.0758697374617
# minimum downstream value:  -0.618851612679
# mean upstream value:  -0.339504397748
# std upstream value:  0.0293843230165
# minimum downstream value:  -0.618851612679
# mean upstream value:  -0.329109925683
# std upstream value:  0.0421146630307
# minimum downstream value:  -0.474282728354
# mean upstream value:  -0.271328369462
# std upstream value:  0.0533347226382
# minimum downstream value:  -0.286203738729
# mean upstream value:  -0.251930608737
# std upstream value:  0.0337010640908
# minimum downstream value:  -0.306115674407
# mean upstream value:  -0.267667868392
# std upstream value:  0.0485288601182
# minimum downstream value:  -0.377624270473
# mean upstream value:  -0.319203734869
# std upstream value:  0.0336660488606
# minimum downstream value:  -0.377624270473
# mean upstream value:  -0.3594177809
# std upstream value:  0.0306527886278
# minimum downstream value:  -0.377624270473
# mean upstream value:  -0.391549935925
# std upstream value:  0.024681426226
# minimum downstream value:  -0.334773248363
# mean upstream value:  -0.397236579021
# std upstream value:  0.0173886742048
# minimum downstream value:  -0.276579966187
# mean upstream value:  -0.407004455647
# std upstream value:  0.0222014874099
# 840
# (41, 41)
# 839
# 797
# 796
# 795
# 836
# 876
# 875
# 874
# 873
# 872
# 912
# 10   10
# 870
# 869
# 868
# 867
# 825
# 783
# 782
# 781
# 780
# node:  1879337.0
# minimum downstream value:  -1.24907023916
# mean upstream value:  -0.86769733253
# std upstream value:  0.0378557736904
# minimum downstream value:  -1.24907023916
# mean upstream value:  -0.786794629807
# std upstream value:  0.0805857221319
# minimum downstream value:  -1.24499704715
# mean upstream value:  -0.761680954844
# std upstream value:  0.063752426524
# minimum downstream value:  -1.1640123209
# mean upstream value:  -0.752005716558
# std upstream value:  0.0549262419249
# minimum downstream value:  -0.991116851686
# mean upstream value:  -0.783480396698
# std upstream value:  0.0112436702614
# minimum downstream value:  -0.917321729095
# mean upstream value:  -0.769692241282
# std upstream value:  0.0215955297878
# minimum downstream value:  -0.917321729095
# mean upstream value:  -0.757539892385
# std upstream value:  0.0105396279812
# minimum downstream value:  -0.860282083745
# mean upstream value:  -0.713759270267
# std upstream value:  0.054201573298
# minimum downstream value:  -0.825488184752
# mean upstream value:  -0.642111716691
# std upstream value:  0.0945086134437
# minimum downstream value:  -0.796462469893
# mean upstream value:  -0.55387128546
# std upstream value:  0.0608164650304
# minimum downstream value:  -0.796462469893
# mean upstream value:  -0.488028424531
# std upstream value:  0.0364789808303
# 840
# (41, 41)
# 839
# 797
# 796
# 754
# 753
# 752
# 710
# 709
# 749
# 748
# 747
# 10   10
# 746
# 704
# 703
# 702
# 701
# 741
# 740
# 739
# 780
# node:  1943428.0
# minimum downstream value:  -0.543658230145
# mean upstream value:  -0.596279219676
# std upstream value:  0.0677422869216
# minimum downstream value:  -0.600807401031
# mean upstream value:  -0.543706157619
# std upstream value:  0.0726319886991
# minimum downstream value:  -0.600807401031
# mean upstream value:  -0.473163187582
# std upstream value:  0.028178728735
# minimum downstream value:  -0.600807401031
# mean upstream value:  -0.452263752934
# std upstream value:  0.0229113752145
# minimum downstream value:  -0.642324334548
# mean upstream value:  -0.45662145401
# std upstream value:  0.0290650735256
# minimum downstream value:  -0.646012498456
# mean upstream value:  -0.479935275393
# std upstream value:  0.029915677795
# minimum downstream value:  -0.646012498456
# mean upstream value:  -0.503819723217
# std upstream value:  0.00482144970038
# minimum downstream value:  -0.646012498456
# mean upstream value:  -0.507763768373
# std upstream value:  0.00243164119031
# minimum downstream value:  -0.500500826025
# mean upstream value:  -0.506021492095
# std upstream value:  0.00489554065909
# minimum downstream value:  -0.484605148376
# mean upstream value:  -0.535162200727
# std upstream value:  0.0438461887729
# minimum downstream value:  -0.497678251606
# mean upstream value:  -0.597899908134
# std upstream value:  0.0810916529148
# 840
# (41, 41)
# 798
# 797
# 755
# 754
# 795
# 835
# 875
# 915
# 914
# 873
# 831
# 10   10
# 830
# 788
# 787
# 786
# 745
# 703
# 661
# 619
# 577
# node:  1961452.0
# minimum downstream value:  -0.423605213995
# mean upstream value:  -0.261967876369
# std upstream value:  0.0751623345516
# minimum downstream value:  -0.469978905478
# mean upstream value:  -0.313705102571
# ...
# mean upstream value:  -0.566830842391
# std upstream value:  0.169466401373
# minimum downstream value:  -0.826762444417
# mean upstream value:  -0.536032775959
# std upstream value:  0.126160725384
# minimum downstream value:  -0.846095872962
# mean upstream value:  -0.577410269475
# std upstream value:  0.116612217193
# minimum downstream value:  -0.846095872962
# mean upstream value:  -0.640070778265
# std upstream value:  0.0526696652834
# minimum downstream value:  -0.846095872962
# mean upstream value:  -0.61226544487
# std upstream value:  0.016136785697
# minimum downstream value:  -0.805472030941
# mean upstream value:  -0.664280746922
# std upstream value:  0.0586174994053
# minimum downstream value:  -0.805472030941
# mean upstream value:  -0.737901850965
# std upstream value:  0.0849704622926
# minimum downstream value:  -0.713077831645
# mean upstream value:  -0.790638316761
# std upstream value:  0.0369575017919
# minimum downstream value:  -0.713077831645
# mean upstream value:  -0.728825062788
# std upstream value:  0.12010201076
# minimum downstream value:  -0.713077831645
# mean upstream value:  -0.559674852293
# std upstream value:  0.187022425016
# 840
# (41, 41)
# 799
# 757
# 716
# 675
# 633
# 591
# 550
# 508
# 466
# 425
# 384
# 10   10
# 343
# 302
# 261
# 220
# 180
# 140
# 100
# 59
# 60
# node:  3136452.0
# minimum downstream value:  -0.522218244349
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 880
# 920
# 919
# 959
# 999
# 1040
# 1080
# 1122
# 1163
# 1203
# 1244
# 10   10
# 1285
# 1326
# 1367
# 1407
# 1448
# 1489
# 1530
# 1571
# 1611
# node:  3164147.0
# minimum downstream value:  -0.144392774981
# mean upstream value:  -0.206042303555
# std upstream value:  0.0306458179531
# minimum downstream value:  -0.144392774981
# mean upstream value:  -0.203253503531
# std upstream value:  0.0267776536888
# minimum downstream value:  -0.172880994473
# mean upstream value:  -0.219347324296
# std upstream value:  0.0293144357676
# minimum downstream value:  -0.217003381299
# mean upstream value:  -0.234682025331
# std upstream value:  0.00762936708916
# minimum downstream value:  -0.248655296597
# mean upstream value:  -0.205505129848
# std upstream value:  0.0378630098221
# minimum downstream value:  -0.248655296597
# mean upstream value:  -0.162416561162
# std upstream value:  0.0467556374357
# minimum downstream value:  -0.248655296597
# mean upstream value:  -0.142830307148
# std upstream value:  0.0233464432401
# minimum downstream value:  -0.240288896523
# mean upstream value:  -0.134404078146
# std upstream value:  0.0227980155986
# minimum downstream value:  -0.240288896523
# mean upstream value:  -0.135641829298
# std upstream value:  0.0215378057893
# minimum downstream value:  -0.240288896523
# mean upstream value:  -0.112153346045
# std upstream value:  0.0134804822539
# minimum downstream value:  -0.239861891675
# mean upstream value:  -0.0935960852581
# std upstream value:  0.0173678878947
# 840
# (41, 41)
# 798
# 756
# 714
# 672
# 631
# 589
# 588
# 546
# 545
# 544
# 502
# 10   10
# 460
# 418
# 376
# 335
# 293
# 251
# 210
# 209
# 167
# node:  3270516.0
# minimum downstream value:  -0.824702206336
# mean upstream value:  -0.894656697752
# std upstream value:  0.018072828658
# minimum downstream value:  -0.925699708961
# mean upstream value:  -0.857867857841
# std upstream value:  0.0650587365076
# minimum downstream value:  -0.925699708961
# mean upstream value:  -0.825726857141
# std upstream value:  0.0481039368392
# minimum downstream value:  -0.925699708961
# mean upstream value:  -0.813382476686
# std upstream value:  0.0337154330806
# minimum downstream value:  -0.91869924191
# mean upstream value:  -0.838296561059
# std upstream value:  0.0107904776436
# minimum downstream value:  -0.919856256176
# mean upstream value:  -0.88289082443
# std upstream value:  0.0526126848453
# minimum downstream value:  -0.919856256176
# mean upstream value:  -0.882311513144
# std upstream value:  0.052993909989
# minimum downstream value:  -0.919856256176
# mean upstream value:  -0.808750238029
# std upstream value:  0.139476052508
# minimum downstream value:  -0.885755214767
# mean upstream value:  -0.715110406888
# std upstream value:  0.0958424704262
# minimum downstream value:  -0.8487220734
# mean upstream value:  -0.638889961092
# std upstream value:  0.0264941968822
# minimum downstream value:  -0.8487220734
# mean upstream value:  -0.661138441566
# std upstream value:  0.0307022595801
# 840
# (41, 41)
# 839
# 797
# 796
# 795
# 754
# 712
# 711
# 670
# 628
# 627
# 585
# 10   10
# 584
# 583
# 541
# 499
# 457
# 416
# 374
# 333
# 291
# node:  3324543.0
# minimum downstream value:  -0.874724979928
# mean upstream value:  -0.577453050375
# std upstream value:  0.136163189227
# minimum downstream value:  -0.874724979928
# mean upstream value:  -0.648829765471
# std upstream value:  0.137828944788
# minimum downstream value:  -0.874724979928
# mean upstream value:  -0.735616932745
# std upstream value:  0.0227532976609
# minimum downstream value:  -0.720130890254
# mean upstream value:  -0.737080650681
# std upstream value:  0.0248062200623
# minimum downstream value:  -0.509273483819
# mean upstream value:  -0.768457063416
# std upstream value:  0.0415455816925
# minimum downstream value:  -0.509273483819
# mean upstream value:  -0.848204038517
# std upstream value:  0.0779059986532
# minimum downstream value:  -0.767505268806
# mean upstream value:  -0.949497147511
# std upstream value:  0.105503844368
# minimum downstream value:  -0.767505268806
# mean upstream value:  -1.04220384037
# std upstream value:  0.0620659245711
# minimum downstream value:  -0.767505268806
# mean upstream value:  -1.03368207808
# std upstream value:  0.0740308358847
# minimum downstream value:  -0.771896422616
# mean upstream value:  -1.01400784981
# std upstream value:  0.0678114604888
# minimum downstream value:  -0.817532867311
# mean upstream value:  -0.982460635139
# std upstream value:  0.0379143367916
# 840
# (41, 41)
# 798
# 756
# 714
# 672
# 671
# 670
# 669
# 627
# 585
# 543
# 501
# 10   10
# 459
# 417
# 376
# 334
# 294
# 252
# 210
# 209
# 168
# node:  3374614.0
# minimum downstream value:  -0.498559763309
# mean upstream value:  -0.457905845994
# std upstream value:  0.0576236053321
# minimum downstream value:  -0.510389003829
# mean upstream value:  -0.508951983747
# std upstream value:  0.0469331359191
# minimum downstream value:  -0.541256870677
# mean upstream value:  -0.53098639889
# std upstream value:  0.0164800978878
# minimum downstream value:  -0.541256870677
# mean upstream value:  -0.525669183342
# std upstream value:  0.0169866571156
# minimum downstream value:  -0.541256870677
# mean upstream value:  -0.524951075377
# std upstream value:  0.0159999552401
# minimum downstream value:  -0.443096899704
# mean upstream value:  -0.500443892045
# std upstream value:  0.0472146641159
# minimum downstream value:  -0.534709463006
# mean upstream value:  -0.490006799911
# std upstream value:  0.0454400931028
# minimum downstream value:  -0.549049588531
# mean upstream value:  -0.418288159276
# std upstream value:  0.0647456730174
# minimum downstream value:  -0.549049588531
# mean upstream value:  -0.459802197845
# std upstream value:  0.0953033442293
# minimum downstream value:  -0.549049588531
# mean upstream value:  -0.560854382823
# std upstream value:  0.187330878247
# minimum downstream value:  -0.546895264637
# mean upstream value:  -0.719934837934
# std upstream value:  0.113183879772
# 840
# (41, 41)
# 799
# 758
# 717
# 675
# 674
# 633
# 592
# 550
# 508
# 467
# 427
# 10   10
# 386
# 344
# 303
# 261
# 220
# 180
# 139
# 98
# 57
# node:  3436627.0
# minimum downstream value:  -0.349782589396
# mean upstream value:  -0.233476601099
# std upstream value:  0.0629697345952
# minimum downstream value:  -0.51124832093
# mean upstream value:  -0.266787964993
# std upstream value:  0.041440779055
# minimum downstream value:  -0.51124832093
# mean upstream value:  -0.246738519279
# std upstream value:  0.0674377139937
# minimum downstream value:  -0.51124832093
# mean upstream value:  -0.200313522882
# std upstream value:  0.0475867487762
# minimum downstream value:  -0.391910839458
# mean upstream value:  -0.215294396924
# std upstream value:  0.0684996373904
# minimum downstream value:  -0.289032103045
# mean upstream value:  -0.307233124382
# std upstream value:  0.103505129555
# minimum downstream value:  -0.317755295825
# mean upstream value:  -0.410105910069
# std upstream value:  0.0734071512874
# minimum downstream value:  -0.317755295825
# mean upstream value:  -0.461822871634
# std upstream value:  0.0227644318103
# minimum downstream value:  -0.317755295825
# mean upstream value:  -0.43350464993
# std upstream value:  0.0617723213223
# minimum downstream value:  -0.26635935184
# mean upstream value:  -0.404079271399
# std upstream value:  0.0489231765224
# minimum downstream value:  -0.311301973969
# mean upstream value:  -0.421790403183
# std upstream value:  0.0723205311569
# 840
# (41, 41)
# 799
# 758
# 757
# 756
# 755
# 713
# 712
# 711
# 669
# 627
# 585
# 10   10
# 544
# 502
# 461
# 420
# 379
# 378
# 336
# 335
# 293
# node:  3462641.0
# minimum downstream value:  -0.417778648407
# mean upstream value:  -0.201188923028
# std upstream value:  0.0954904785781
# minimum downstream value:  -0.397171925179
# mean upstream value:  -0.118606989563
# std upstream value:  0.0556845002137
# 840
# (41, 41)
# 839
# 838
# 837
# 836
# 794
# 753
# 712
# 670
# 628
# 588
# 547
# 10   10
# 506
# 466
# 424
# 383
# 382
# 340
# 299
# 258
# 217
# node:  3514652.0
# minimum downstream value:  -0.583728654583
# mean upstream value:  -0.177080277555
# std upstream value:  0.0385783395142
# 840
# (41, 41)
# 799
# 758
# 716
# 715
# 673
# 631
# 590
# 549
# 508
# 467
# 426
# 10   10
# 386
# 346
# 305
# 264
# 222
# 181
# 139
# 98
# 57
# node:  3611462.0
# minimum downstream value:  -0.61517020365
# mean upstream value:  -0.0635885004941
# std upstream value:  0.0259909671716
# 840
# (41, 41)
# 800
# 760
# 719
# 679
# 637
# 636
# 594
# 553
# 512
# 471
# 429
# 10   10
# 389
# 348
# 306
# 264
# 223
# 181
# 180
# 179
# 137
# node:  3658691.0
# minimum downstream value:  -1.33212340585
# mean upstream value:  -0.855808263083
# std upstream value:  0.0699438621433
# minimum downstream value:  -1.18467163568
# mean upstream value:  -0.768867020236
# std upstream value:  0.0790618021841
# minimum downstream value:  -0.981894994442
# mean upstream value:  -0.735411713089
# std upstream value:  0.0433566751503
# minimum downstream value:  -0.981894994442
# mean upstream value:  -0.754322157547
# std upstream value:  0.0608937686306
# minimum downstream value:  -0.981894994442
# mean upstream value:  -0.842698168849
# std upstream value:  0.0717735149212
# minimum downstream value:  -0.934936040946
# mean upstream value:  -0.924896682518
# std upstream value:  0.0791606864052
# minimum downstream value:  -0.934936040946
# mean upstream value:  -0.959286736248
# std upstream value:  0.0390525632132
# minimum downstream value:  -0.867647796751
# mean upstream value:  -0.95394121454
# std upstream value:  0.0423859495981
# minimum downstream value:  -0.767281875309
# mean upstream value:  -1.0232922701
# std upstream value:  0.140459902669
# minimum downstream value:  -0.821572284925
# mean upstream value:  -1.09162639472
# std upstream value:  0.124897788314
# minimum downstream value:  -0.939240346313
# mean upstream value:  -1.03007674186
# std upstream value:  0.20954446749
# 840
# (41, 41)
# 799
# 758
# 759
# 719
# 720
# 680
# 640
# 599
# 558
# 518
# 478
# 10   10
# 437
# 397
# 356
# 316
# 275
# 235
# 195
# 196
# 155
# node:  3680854.0
# minimum downstream value:  -0.836681984159
# mean upstream value:  -0.928323336112
# std upstream value:  0.0625733373977
# minimum downstream value:  -0.836681984159
# mean upstream value:  -0.905387787951
# std upstream value:  0.0301387459415
# minimum downstream value:  -0.836681984159
# mean upstream value:  -0.863044025084
# std upstream value:  0.0796070734883
# minimum downstream value:  -0.929157724494
# mean upstream value:  -0.79618712816
# std upstream value:  0.111373163889
# minimum downstream value:  -1.0168138587
# mean upstream value:  -0.747134805511
# std upstream value:  0.048186996773
# minimum downstream value:  -1.0168138587
# mean upstream value:  -0.841234772573
# std upstream value:  0.147688673367
# minimum downstream value:  -1.0168138587
# mean upstream value:  -0.910800697618
# std upstream value:  0.0980243717161
# minimum downstream value:  -0.948007214211
# mean upstream value:  -0.96964823807
# std upstream value:  0.0599517824356
# minimum downstream value:  -0.948007214211
# mean upstream value:  -1.00066825052
# std upstream value:  0.0990693905698
# minimum downstream value:  -0.948007214211
# mean upstream value:  -1.08130268806
# std upstream value:  0.0734830402775
# minimum downstream value:  -0.800850246264
# mean upstream value:  -1.17142676553
# std upstream value:  0.0539898367781
# 840
# (41, 41)
# 799
# 758
# 716
# 675
# 634
# 593
# 552
# 511
# 469
# 428
# 386
# 10   10
# 345
# 304
# 262
# 221
# 180
# 139
# 97
# 56
# 55
# node:  3747244.0
# minimum downstream value:  -0.62163558779
# mean upstream value:  -0.413115047812
# std upstream value:  0.107751054781
# minimum downstream value:  -0.65206583498
# mean upstream value:  -0.535871945508
# std upstream value:  0.103416834326
# minimum downstream value:  -0.65206583498
# mean upstream value:  -0.633037340971
# std upstream value:  0.0609052836093
# minimum downstream value:  -0.65206583498
# mean upstream value:  -0.646188125309
# std upstream value:  0.0432452291564
# minimum downstream value:  -0.382519145257
# mean upstream value:  -0.621741896719
# std upstream value:  0.0513750369061
# minimum downstream value:  -0.402759657547
# mean upstream value:  -0.506907507051
# std upstream value:  0.111171393694
# minimum downstream value:  -0.549955224802
# mean upstream value:  -0.414571045887
# std upstream value:  0.119061302428
# minimum downstream value:  -0.654900954175
# mean upstream value:  -0.285151103426
# std upstream value:  0.0667131765825
# minimum downstream value:  -0.694255843935
# mean upstream value:  -0.184183676095
# std upstream value:  0.108601020898
# minimum downstream value:  -0.694255843935
# mean upstream value:  -0.0800509446537
# std upstream value:  0.082333330236
# 840
# (41, 41)
# 798
# 757
# 716
# 675
# 676
# 677
# 637
# 597
# 557
# 516
# 475
# 10   10
# 433
# 391
# 349
# 307
# 306
# 305
# 265
# 224
# 182
# node:  3749275.0
# minimum downstream value:  -1.618331487
# mean upstream value:  -0.212206613091
# std upstream value:  0.26549420452
# minimum downstream value:  -1.54396412966
# mean upstream value:  -0.0240357892787
# std upstream value:  0.0204860642506
# 840
# (41, 41)
# 841
# 801
# 760
# 719
# 678
# 637
# 596
# 555
# 514
# 473
# 432
# 10   10
# 391
# 350
# 309
# 268
# 228
# 187
# 147
# 107
# 66
# node:  3751282.0
# minimum downstream value:  -1.06788701596
# mean upstream value:  -0.0235267609004
# std upstream value:  0.0332718643441
# 840
# (41, 41)
# 880
# 920
# 919
# 959
# 999
# 998
# 997
# 1037
# 1036
# 1076
# 1116
# 10   10
# 1157
# 1156
# 1114
# 1154
# 1194
# 1234
# 1275
# 1316
# 1356
# node:  3756638.0
# minimum downstream value:  -0.927157315341
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 799
# 758
# 757
# 716
# 674
# 634
# 593
# 553
# 513
# 472
# 430
# 10   10
# 388
# 347
# 307
# 266
# 226
# 185
# 143
# 102
# 61
# node:  3788798.0
# minimum downstream value:  -0.663798577229
# mean upstream value:  -0.572564126318
# std upstream value:  0.0287191210637
# minimum downstream value:  -0.663798577229
# mean upstream value:  -0.593698051764
# std upstream value:  0.0384294263472
# minimum downstream value:  -0.549316888741
# mean upstream value:  -0.649447515234
# std upstream value:  0.0420917985032
# minimum downstream value:  -0.480452345294
# mean upstream value:  -0.732962426147
# std upstream value:  0.0957747186423
# minimum downstream value:  -0.566856414433
# mean upstream value:  -0.761345784184
# std upstream value:  0.0703835533977
# minimum downstream value:  -0.566856414433
# mean upstream value:  -0.685804203722
# std upstream value:  0.156366399968
# minimum downstream value:  -0.610242519454
# mean upstream value:  -0.563051970109
# std upstream value:  0.107831130314
# minimum downstream value:  -0.630258190773
# mean upstream value:  -0.457604449728
# std upstream value:  0.0416500273309
# minimum downstream value:  -0.707841835474
# mean upstream value:  -0.485186550457
# std upstream value:  0.0675191973322
# minimum downstream value:  -0.860787252192
# mean upstream value:  -0.522964658473
# std upstream value:  0.0892642023276
# minimum downstream value:  -0.860787252192
# mean upstream value:  -0.592869292449
# std upstream value:  0.0204741632032
# 840
# (41, 41)
# 841
# 801
# 760
# 719
# 678
# 637
# 596
# 597
# 557
# 517
# 476
# 10   10
# 435
# 394
# 353
# 312
# 271
# 230
# 189
# 148
# 107
# node:  3841312.0
# minimum downstream value:  -0.928322049469
# mean upstream value:  -0.32738003335
# std upstream value:  0.297279363313
# minimum downstream value:  -0.830916694973
# mean upstream value:  -0.087547412817
# std upstream value:  0.123810738556
# minimum downstream value:  -0.765432003458
# mean upstream value:  0.0
# std upstream value:  0.0

# %%
def get_key(val, my_dict):
    gullies_to_keep = []
    for key, value in my_dict.items(): 
         if val == value:
                gullies_to_keep.append(key)
    return gullies_to_keep

# %%
gullies_to_keep_node_list = get_key('yes', divergence_dict)

# %%
len(gullies_to_keep_node_list)
# Out:
# 40

# %%
outlet_ids = np.isin(grid_nodes,gullies_to_keep_node_list).astype('uint8')

# %%
pd.DataFrame.from_dict(divergence_dict, orient='index')
# Out:
#              0
# 66788.0     no
# 82534.0     no
# 84806.0    yes
# 84998.0    yes
# 86957.0     no
# ...        ...
# 3749275.0  yes
# 3751282.0  yes
# 3756638.0  yes
# 3788798.0   no
# 3841312.0  yes
#
# [90 rows x 1 columns]

# %%
distance_from_outlet = 20
# This value is used to initialise the search.
catchment_outlet_id = 1745068
# Initate an outer loop that iterates through every distance interval from the outlet.
watershed_grid_cells = []
node_location = mg.nodes.reshape(da.shape)
ordered_node_list = []

for i in range(0, distance_from_outlet):
    # Create a list initially containing only the outlet grid cell.
    if i == 0:
        candidate_gridcells = [catchment_outlet_id];
    else:
        candidate_gridcells = list(set(upstream_nodes));
    # Empty the list of upsteam nodes.
    upstream_nodes = {};
    # Intiate a new loop to check every gridcell at the current interval distance.
    print(candidate_gridcells)
    for grid_cell in candidate_gridcells:
        # Check each flow direction of the current grid cell.The second dimension of the 
        # flow__receiver_node object will always be size == 8.
        for i in range(frn.shape[1]):
            # Return all rows (grid nodes) that send any flow to the target grid cell.
            # Note: This can only be one grid cell because the prgram is looping through
            # each direction one at a time so only one grid cell can be sending flow from any
            # one given direction.
            flow_from_whole_grid_cell = frn[np.where(frn[:,i] == grid_cell)];
            # Check if the current direction contributes flow. If not, do nothing. 
            # Else, append to list.
            if flow_from_whole_grid_cell.shape[0] == 0:
                pass
            else:
                # Below variable finds the row position of the flow_from_direction gridcell
                # in the flow__receiver_node array. This corresponds to the contributing
                # cell's node id.
                node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                #Find the proportion of flow leaving the donor node and heading toward 
                # the current grid cell.
                proportion_of_flow = frp[node_id_value, i]
                # Create a boolean array to use as mask on drainage area.
                isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, da))
                node_directional_drainage_area = node_drainage_area * proportion_of_flow
                upstream_nodes.update({node_id_value:node_directional_drainage_area});
        if len(upstream_nodes) == 0:
            print ("dictionary empty")
        else:
            primary_flow_direction_id = max(upstream_nodes.items(), key=operator.itemgetter(1))[0]
            upstream_nodes = []
            upstream_nodes.append(primary_flow_direction_id);
            ordered_node_list.append(primary_flow_direction_id);
            watershed_grid_cells.append(primary_flow_direction_id)
            

preliminary_width = np.isin(node_location,watershed_grid_cells)
flow_width = (preliminary_width * da).reshape(mg.shape)

flow_width[flow_width==0] = np.nan

flow_grid_nodes = (preliminary_width * da).reshape(mg.shape)

drainage_mask = flow_width > 0

drainage_slope = np.copy(slope).astype('float32')
drainage_slope[~drainage_mask] = np.nan

drainage_dfme = np.copy(dfme).astype('float32')
drainage_dfme[~drainage_mask] = np.nan

drainage_area = np.copy(catchment_area_ha).astype('float32')
drainage_area[~drainage_mask] = np.nan

drainage_nodes = np.copy(grid_nodes).astype('float32')
drainage_nodes[~drainage_mask] = np.nan

lat = grid_nodes.shape[0]
lon = grid_nodes.shape[1]
nodes_1d = np.squeeze(grid_nodes.reshape(1, lat * lon))
drainage_dfme_1d = np.squeeze(drainage_dfme.reshape(1, lat * lon))
drainage_slope_1d = np.squeeze(drainage_slope.reshape(1, lat * lon))
drainage_area_1d = np.squeeze(drainage_area.reshape(1, lat * lon))

node_drainage_dfme_dict = {}
for A, B in zip(nodes_1d, drainage_dfme_1d):
    node_drainage_dfme_dict[A] = B

dfme_from_gully_unordered = { key:value for key, value in node_drainage_dfme_dict.items() if ~np.isnan(value)}

# This just reorders the dictionary to reflect the actual node order along the flow line.
# The step above creates a dictionary where the keys are ordered from highest to lowest and this is not always
# going to reflect the node order (only if the flow line is moving south to north).
dfme_from_gully = {k: dfme_from_gully_unordered[k] for k in ordered_node_list}


node_drainage_slope_dict = {}
for A, B in zip(nodes_1d, drainage_slope_1d):
    node_drainage_slope_dict[A] = B

slope_from_gully_unordered = { key:value for key, value in node_drainage_slope_dict.items() if ~np.isnan(value) }
slope_from_gully = {k: slope_from_gully_unordered[k] for k in ordered_node_list}

node_drainage_area_dict = {}
for A, B in zip(nodes_1d, drainage_area_1d):
    node_drainage_area_dict[A] = B

area_from_gully_unordered = { key:value for key, value in node_drainage_area_dict.items() if ~np.isnan(value) }
area_from_gully = {k: area_from_gully_unordered[k] for k in ordered_node_list}


ds = [dfme_from_gully, slope_from_gully, area_from_gully]
d = {}
for k in dfme_from_gully.keys():
    d[k] = tuple(d[k] for d in ds)
d_ordered = {k: d[k] for k in ordered_node_list}

drainage_parameters = pd.DataFrame.from_dict(d_ordered)

drainage_parameters.rename(index={0:'DFME', 1: 'Slope', 2: 'Area'}, inplace=True)

drainage_parameters_transpose = drainage_parameters.T

drainage_parameters_transpose.insert(0, "Distance", 0);

for i in range(0, distance_from_outlet):
    drainage_parameters_transpose.iloc[i,0] = i

drainage_parameters_transpose['Node ID'] = drainage_parameters_transpose.index

dCDFMEdx = np.gradient(drainage_parameters_transpose.loc[:,'DFME'].values)
d2CDFMEdx2 = np.gradient(dCDFMEdx)

dCSdx = np.gradient(drainage_parameters_transpose.loc[:,'Slope'].values)
d2CSdx2 = np.gradient(dCSdx)

dCAdx = np.gradient(drainage_parameters_transpose.loc[:,'Area'].values)
d2CAdx2 = np.gradient(dCAdx)


drainage_parameters_transpose['dCDFMEdx'] = dCDFMEdx

drainage_parameters_transpose['dCSdx'] = dCSdx
drainage_parameters_transpose['dCAdx'] = dCAdx


drainage_parameters_transpose['d2CDFMEdx2'] = d2CDFMEdx2

drainage_parameters_transpose['d2CSdx2'] = d2CSdx2
drainage_parameters_transpose['d2CAdx2'] = d2CAdx2


cumulative_drainage_parameters = drainage_parameters_transpose.cumsum()
drainage_parameters_transpose['Cumulative DFME'] = cumulative_drainage_parameters.iloc[:,1]

get_median_slope = drainage_parameters_transpose.loc[:,'Slope'].values
get_median_dfme = drainage_parameters_transpose.loc[:,'DFME'].values

median_slope = ndimage.median_filter(get_median_slope, size=3)
median_dfme = ndimage.median_filter(get_median_dfme, size=3)

drainage_parameters_transpose['MedianSlope'] = median_slope
drainage_parameters_transpose['MedianDFME'] = median_dfme

dfme_list = drainage_parameters_transpose.loc[:,'MedianDFME'].values.tolist()
# Out:
# [1745068]
# [1745067]
# [1747066]
# [1749065]
# [1749064]
# [1751063]
# [1753063]
# [1755062]
# [1757062]
# [1759061]
# [1761061]
# [1763060]
# [1765060]
# [1767059]
# [1769059]
# [1771058]
# [1773057]
# [1775057]
# [1777056]
# [1779055]
# C:\Users\sjwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:62: RuntimeWarning: invalid value encountered in greater

# %%
drainage_parameters_transpose
# Out:
#          Distance      DFME     Slope      Area  Node ID  dCDFMEdx     dCSdx  \
# 1745067         0 -0.543919  8.543198  4.173244  1745067  0.014645 -4.094602
# 1747066         1 -0.529275  4.448596  4.997729  1747066 -0.024140 -0.864544
# 1749065         2 -0.592198  6.814110  3.911884  1749065 -0.026242  1.985452
# 1749064         3 -0.581759  8.419500  3.104597  1749064  0.031469  0.708285
# 1751063         4 -0.529260  8.230680  2.465562  1751063  0.084805 -0.192997
# 1753063         5 -0.412149  8.033506  2.345508  1753063  0.046400 -1.039597
# 1755062         6 -0.436461  6.151486  2.555057  1755062  0.015037 -0.225323
# 1757062         7 -0.382076  7.582861  2.818154  1757062  0.022601  1.030925
# 1759061         8 -0.391259  8.213335  2.944001  1759061  0.038573 -0.103980
# 1761061         9 -0.304930  7.374901  2.834751  1761061  0.030045 -0.198800
# 1763060        10 -0.331169  7.815736  2.975104  1763060  0.024659  0.470236
# 1765060        11 -0.255611  8.315373  3.066234  1765060  0.035245 -0.445163
# 1767059        12 -0.260678  6.925410  3.242463  1767059  0.021887 -0.694536
# 1769059        13 -0.211836  6.926301  3.404785  1769059  0.024888 -0.338008
# 1771058        14 -0.210902  6.249395  4.430811  1771058 -0.014874 -0.876663
# 1773057        15 -0.241584  5.172975  3.555149  1773057 -0.000785 -0.529479
# 1775057        16 -0.212472  5.190436  3.975701  1775057  0.009136 -0.161659
# 1777056        17 -0.223312  4.849657  4.095396  1777056 -0.005646 -0.137043
# 1779055        18 -0.223764  4.916349  3.304328  1779055  0.029414  0.066999
# 1781055        19 -0.164484  4.983655  3.271796  1781055  0.059279  0.067306
#
#             dCAdx  d2CDFMEdx2   d2CSdx2   d2CAdx2  Cumulative DFME  \
# 1745067  0.824485   -0.038784  3.230058 -0.955166        -0.543919
# 1747066 -0.130680   -0.020443  3.040027 -0.885526        -1.073194
# 1749065 -0.946566    0.027804  0.786414 -0.296240        -1.665392
# 1749064 -0.723161    0.055523 -1.089225  0.283511        -2.247151
# 1751063 -0.379544    0.007465 -0.873941  0.383954        -2.776411
# 1753063  0.044747   -0.034884 -0.016163  0.307934        -3.188561
# 1755062  0.236323   -0.011899  1.035261  0.074862        -3.625021
# 1757062  0.194472    0.011768  0.060671 -0.114012        -4.007097
# 1759061  0.008298    0.003722 -0.614862 -0.089460        -4.398356
# 1761061  0.015552   -0.006957  0.287108  0.053722        -4.703286
# 1763060  0.115742    0.002600 -0.123182  0.059064        -5.034455
# 1765060  0.133679   -0.001386 -0.582386  0.026767        -5.290066
# 1767059  0.169276   -0.005179  0.053578  0.230248        -5.550744
# 1769059  0.594174   -0.018381 -0.091064 -0.047047        -5.762580
# 1771058  0.075182   -0.012837 -0.095736 -0.410865        -5.973482
# 1773057 -0.227555    0.012005  0.357502  0.097471        -6.215066
# 1775057  0.270124   -0.002430  0.196218 -0.054065        -6.427538
# 1777056 -0.335686    0.010139  0.114329 -0.340962        -6.650850
# 1779055 -0.411800    0.032463  0.102175  0.151577        -6.874614
# 1781055 -0.032532    0.029865  0.000307  0.379268        -7.039098
#
#          MedianSlope  MedianDFME
# 1745067     8.543198   -0.543919
# 1747066     6.814110   -0.543919
# 1749065     6.814110   -0.581759
# 1749064     8.230680   -0.581759
# 1751063     8.230680   -0.529260
# 1753063     8.033506   -0.436461
# 1755062     7.582861   -0.412149
# 1757062     7.582861   -0.391259
# 1759061     7.582861   -0.382076
# 1761061     7.815736   -0.331169
# 1763060     7.815736   -0.304930
# 1765060     7.815736   -0.260678
# 1767059     6.926301   -0.255611
# 1769059     6.925410   -0.211836
# 1771058     6.249395   -0.211836
# 1773057     5.190436   -0.212472
# 1775057     5.172975   -0.223312
# 1777056     4.916349   -0.223312
# 1779055     4.916349   -0.223312
# 1781055     4.983655   -0.164484

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
y1 = "DFME"
y2 = "Cumulative DFME"

sns.lineplot(data = drainage_parameters_transpose,x = "Distance",y = y1, color = 'xkcd:cobalt blue')
ax1.set_ylabel(y1, fontsize=15)
#ax1.lines[0].set_linestyle("--")
#ax1.set_ylim(-0.5, 0.5)
ax1.set_xlabel('Distance upstream of convergence point (m)', fontsize = 15)
ax1.legend([y1],bbox_to_anchor=(0.3, 0.21, 0.53, 0.6))
ax2 = ax1.twinx()

#ax2.set_ylim(-0.3,0.3)
sns.lineplot(data=drainage_parameters_transpose,x = "Distance",y=y2,color='xkcd:pumpkin',ax = ax2)
ax2.set_ylabel(y2, fontsize = 15)
ax2.legend([y2],bbox_to_anchor=(0.3, 0.5, 0.5, 0.4))
plt.axvline(x=17, color = 'xkcd:merlot', linestyle = 'dotted')
plt.axvline(x=20, color = 'xkcd:merlot', linestyle = 'dotted')
#ax1.text(18, -0.8, r'Gully head', fontsize=15, rotation = 90)
plt.title('Change in upstream values for DFME and PC', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Change in upstream values for DFME and PC')

# %%
getcumsum = drainage_parameters_transpose.loc[:,'DFME'].values

# %%
original_cumsum = getcumsum.cumsum()

# %%
cumsum_list = [0]
xbar = np.mean(getcumsum)
for i in range(0, len(getcumsum)):
    x = getcumsum[i]
    diff = x - xbar
    cumsum_iter = cumsum_list[i] + diff
    cumsum_list.append(cumsum_iter)
    
new_cumsum = np.array(cumsum_list)

# %%
min_val = np.min(new_cumsum)
max_val = np.max(new_cumsum)
diff_val =  max_val - min_val
diff_val
# Out:
# 1.2307624608278278

# %%
scs = np.copy(getcumsum)

# %%
for i in range(0,10):
    np.random.shuffle(scs)
    cumsum_list = [0]
    xbar = np.mean(scs)
    for i in range(0, len(scs)):
        x = scs[i]
        diff = x - xbar
        cumsum_iter = cumsum_list[i] + diff
        cumsum_list.append(cumsum_iter)

    rand_cumsum = np.array(cumsum_list)

    min_val = np.min(rand_cumsum)
    max_val = np.max(rand_cumsum)
    diff_val =  max_val - min_val
    print(diff_val)
# Out:
# 0.984743371606
# 0.595459723473
# 0.772921457887
# 0.356078857183
# 0.63821965754
# 0.607306930423
# 0.620704939961
# 0.84945486784
# 0.814839848876
# 0.839832168818

# %%
np.random.shuffle(scs)
new_cumsum = scs.cumsum()
min_val = np.min(new_cumsum)
max_val = np.max(new_cumsum)
diff_val =  max_val - min_val
diff_val
# Out:
# 40.01032010540365

# %%
plt.plot(new_cumsum)

# %%
algorithm_end_point = drainage_parameters_transpose['Distance'].max()
algorithm_start_point = drainage_parameters_transpose['Distance'].min()

gh = drainage_parameters_transpose.loc[drainage_parameters_transpose['Distance'] == algorithm_end_point,
                                                  'Node ID'].values[0]

cp = drainage_parameters_transpose.loc[drainage_parameters_transpose['Distance'] == algorithm_start_point,
                                                  'Node ID'].values[0]

node_length = np.abs(cp - gh)
length = node_length/mg.shape[0]

gh_lat = np.where(grid_nodes == gh)[0][0]
cp_lat = np.where(grid_nodes == cp)[0][0]
gh_lon = np.where(grid_nodes == gh)[1][0]
cp_lon = np.where(grid_nodes == cp)[1][0]

lat_displacement = cp_lat - gh_lat
lon_displacement = gh_lon - cp_lon

if lat_displacement > 0 and lon_displacement > 0:
    angle_max = 90
    angle_min = 0
    quadrant = 1
    print('Quadrant = Q1', 'min angle', str(angle_min), 'max angle', str(angle_max))
elif lat_displacement > 0 and lon_displacement < 0:
    angle_max = 360
    angle_min = 270
    quadrant = 2
    print('Quadrant = Q2', 'min angle', str(angle_min), 'max angle', str(angle_max))
elif lat_displacement < 0 and lon_displacement < 0:
    angle_max = 270
    angle_min = 180
    quadrant = 3
    print('Quadrant = Q3', 'min angle', str(angle_min), 'max angle', str(angle_max))
else:
    angle_max = 180
    angle_min = 90
    quadrant = 4
    print('Quadrant = Q4', 'min angle', str(angle_min), 'max angle', str(angle_max))

theta_a = np.degrees(np.arctan(np.abs(lat_displacement)/np.abs(lon_displacement)))

if quadrant == 1:
    gully_orientation = angle_max - theta_a
elif quadrant == 2:
    gully_orientation = angle_min + theta_a
elif quadrant == 3:
    gully_orientation = angle_max - theta_a
else:
    gully_orientation = angle_min + theta_a

class GullyOrientation:
    """Convention for first direction to take (d1) in cross section method 
    follows directional convention used in Landlab."""
    possible_angles = np.array([90, 0, 270, 180, 45, 315, 225, 135, 360])
    def __init__(self, angle, outlet, grid_shape):
        self.angle = angle
        self.outlet = outlet
        self.grid_shape = grid_shape
        idx = (np.abs(self.possible_angles - self.angle)).argmin() 
        find_angle_from_list = self.possible_angles[idx]
        self.closest_angle = find_angle_from_list

    def cross_section(self, line_length):
        cross_section_nodes_d1 = [self.outlet]
        cross_section_nodes_d2 = [self.outlet]
        if self.closest_angle == 90 or self.closest_angle == 270:
            print('east-west gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - self.grid_shape[1]
                next_node_d2 = current_node_d2 + self.grid_shape[1]
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        elif self.closest_angle == 0 or self.closest_angle == 180 or self.closest_angle == 360:
            print('north-south gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 + 1
                next_node_d2 = current_node_d2 - 1
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        elif self.closest_angle == 45 or self.closest_angle == 225:
            print('northeast-southwest gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - (self.grid_shape[1] + 1)
                next_node_d2 = current_node_d2 + (self.grid_shape[1] + 1)
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)
        else:
            print('northwest-southeast gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - (self.grid_shape[1] - 1)
                next_node_d2 = current_node_d2 + (self.grid_shape[1] - 1)
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        cross_section_nodes = np.array(list(set(cross_section_nodes_d1 + cross_section_nodes_d2)))
        return cross_section_nodes

gully_and_cross_section = GullyOrientation(gully_orientation, catchment_outlet_id, mg.shape)

line_length = 20

cross_section_nodes = gully_and_cross_section.cross_section(line_length)

cross_section_mask = np.isin(node_location,cross_section_nodes).reshape(mg.shape)
cross_section_image = cross_section_mask.astype('uint8')

cross_section_slope = np.copy(slope).astype('float32')
cross_section_slope[~cross_section_mask] = np.nan

cross_section_dfme = np.copy(dfme).astype('float32')
cross_section_dfme[~cross_section_mask] = np.nan

cross_section_area = np.copy(catchment_area_ha).astype('float32')
cross_section_area[~cross_section_mask] = np.nan

cross_section_nodes = np.copy(grid_nodes).astype('float32')
cross_section_nodes[~cross_section_mask] = np.nan

cross_section_elevation_prep = np.copy(input_DEM).astype('float32')
cross_section_elevation_prep[~cross_section_mask] = np.nan
cross_section_elevation = cross_section_elevation_prep - np.nanmin(cross_section_elevation_prep)

cross_section_dfme_line = cross_section_elevation_prep - np.nanmean(cross_section_elevation_prep)

lat = grid_nodes.shape[0]
lon = grid_nodes.shape[1]
nodes_1d = np.squeeze(grid_nodes.reshape(1, lat * lon))
cross_section_dfme_1d = np.squeeze(cross_section_dfme.reshape(1, lat * lon))
cross_section_slope_1d = np.squeeze(cross_section_slope.reshape(1, lat * lon))

cross_section_area_1d = np.squeeze(cross_section_area.reshape(1, lat * lon))

cross_section_elevation_1d = np.squeeze(cross_section_elevation.reshape(1, lat * lon))
cross_section_dfme_line_1d = np.squeeze(cross_section_dfme_line.reshape(1, lat * lon))

node_cross_section_dfme_dict = {}
for A, B in zip(nodes_1d, cross_section_dfme_1d):
    node_cross_section_dfme_dict[A] = B

dfme_cross_section_unordered = { key:value for key, value in node_cross_section_dfme_dict.items() if ~np.isnan(value) }

node_cross_section_slope_dict = {}
for A, B in zip(nodes_1d, cross_section_slope_1d):
    node_cross_section_slope_dict[A] = B

slope_cross_section_unordered = { key:value for key, value in node_cross_section_slope_dict.items() if ~np.isnan(value)}

node_cross_section_area_dict = {}
for A, B in zip(nodes_1d, cross_section_area_1d):
    node_cross_section_area_dict[A] = B

area_cross_section_unordered = { key:value for key, value in node_cross_section_area_dict.items() if ~np.isnan(value) }

node_cross_section_elevation_dict = {}
for A, B in zip(nodes_1d, cross_section_elevation_1d):
    node_cross_section_elevation_dict[A] = B

elevation_cross_section_unordered = { key:value for key, 
                                     value in node_cross_section_elevation_dict.items() if ~np.isnan(value) }

node_cross_section_dfme_line_dict = {}
for A, B in zip(nodes_1d, cross_section_dfme_line_1d):
    node_cross_section_dfme_line_dict[A] = B

dfme_line_cross_section_unordered = { key:value for key, 
                                     value in node_cross_section_dfme_line_dict.items() if ~np.isnan(value) }

ds = [dfme_cross_section_unordered,  
      slope_cross_section_unordered, area_cross_section_unordered, 
     elevation_cross_section_unordered, dfme_line_cross_section_unordered]
d = {}
for k in dfme_cross_section_unordered.keys():
    d[k] = tuple(d[k] for d in ds)

cross_section_parameters = pd.DataFrame.from_dict(d)

cross_section_parameters.rename(index={0:'DFME', 1: 'Slope', 
                                       2: 'Area', 3: 'Elevation', 4: 'DFME Line'}, inplace=True)

cross_section_parameters_transpose = cross_section_parameters.T

cross_section_parameters_transpose.insert(0, "Distance", 0)

for i in range(0, (line_length * 2)+1):
    if i < line_length:
        cross_section_parameters_transpose.iloc[i,0] = -line_length + i
    else:
        cross_section_parameters_transpose.iloc[i,0] = i - line_length

cumulative_cross_section_parameters = cross_section_parameters_transpose.cumsum()

cross_section_parameters_transpose['Cumulative DFME'] = cumulative_cross_section_parameters.iloc[:,1]

cross_section_parameters_transpose['Cumulative S'] = cumulative_cross_section_parameters.iloc[:,3]
cross_section_parameters_transpose['Cumulative A'] = cumulative_cross_section_parameters.iloc[:,4]


extract_slope = cross_section_parameters_transpose['Slope'].values

cross_section_parameters_transpose['Slope Range'] = generic_filter(extract_slope, data_range, 
                                                                       footprint= (1, 3), mode='nearest');

extract_dfme = cross_section_parameters_transpose['DFME'].values

cross_section_parameters_transpose['DFME Range'] = generic_filter(extract_dfme, data_range, 
                                                                       footprint= (1, 3), mode='nearest');


gully_head, distance_upstream = checkGullyHead(dfme_list,3,3, -0.2, -0.1)    

gully_heads_dict.update({catchment_outlet_id:gully_head});

# %%
gully_heads_dict

# %%
for name, age in mydict.items():
    if age == search_age:
        print name

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
y1 = "DFME"
y2 = "MedianDFME"

sns.lineplot(data = drainage_parameters_transpose,x = "Distance",y = y1, color = 'xkcd:cobalt blue')
ax1.set_ylabel(y1, fontsize=15)
#ax1.lines[0].set_linestyle("--")
#ax1.set_ylim(-0.5, 0.5)
ax1.set_xlabel('Distance upstream of convergence point (m)', fontsize = 15)
ax1.legend([y1],bbox_to_anchor=(0.3, 0.21, 0.53, 0.6))
ax2 = ax1.twinx()

#ax2.set_ylim(-0.3,0.3)
sns.lineplot(data=drainage_parameters_transpose,x = "Distance",y=y2,color='xkcd:pumpkin',ax = ax2)
ax2.set_ylabel(y2, fontsize = 15)
ax2.legend([y2],bbox_to_anchor=(0.3, 0.5, 0.5, 0.4))
plt.axvline(x=17, color = 'xkcd:merlot', linestyle = 'dotted')
plt.axvline(x=20, color = 'xkcd:merlot', linestyle = 'dotted')
#ax1.text(18, -0.8, r'Gully head', fontsize=15, rotation = 90)
plt.title('Change in upstream values for DFME and PC', fontsize = 20)

# %%
gully_head, distance_upstream = checkGullyHead(dfme_list,3,3)

# %%
gully_head

# %%
dfme_list

# %%
gully_head

# %%
distance_upstream

# %% [markdown]
# To find the endpoints of the line at the head of the gully, all i need to do is move n units in the direction of the gully orientation from the end points of the cross section line. Can use same rules from the GullOrientation class.

# %% [markdown]
# Note: Method below requires that the outlet_id (A) is at least 10 grid cells from the edge of the DEM. In the paper can just say gullies near edges were not used because it risks moving window values being affected.

# %% [markdown]
# ## Scheme for finding all grid cells along the desired line.
#
# Four possible line:
#
# (1) north-south, north direction == outlet_id - mg.shape[1], south direction == outlet_id + mg.shape[1]
#
# (2) east-west, east = outlet_id + 1, west == outlet_id - 1
#
# (3) northeast-southwest, northeast == outlet_id - (mg.shape[1] - 1), southwest == outlet_id + (mg.shape[1] - 1)
#
# (4) northwest-southeast, northwest == outlet_id - (mg.shape[1] + 1), southeast == outlet_id + (mg.shape[1] + 1)

# %% [markdown]
# # Calculate the cumulative summary of each variable.

# %%
dCDFMEdx = np.gradient(cross_section_parameters_transpose.loc[:,'DFME'].values)
d2CDFMEdx2 = np.gradient(dCDFMEdx)
 
dCPCdx = np.gradient(cross_section_parameters_transpose.loc[:,'PC'].values)
d2CPCdx2 = np.gradient(dCPCdx)

dCSdx = np.gradient(cross_section_parameters_transpose.loc[:,'Slope'].values)
d2CSdx2 = np.gradient(dCSdx)

dCAdx = np.gradient(cross_section_parameters_transpose.loc[:,'Area'].values)
d2CAdx2 = np.gradient(dCAdx)

dPCTLdx = np.gradient(cross_section_parameters_transpose.loc[:,'PCTL'].values)
d2PCTLdx2 = np.gradient(dPCTLdx)

cross_section_parameters_transpose['dCDFMEdx'] = dCDFMEdx
cross_section_parameters_transpose['dCPCdx'] = dCPCdx
cross_section_parameters_transpose['dCSdx'] = dCSdx
cross_section_parameters_transpose['dCAdx'] = dCAdx
cross_section_parameters_transpose['dPCTLdx'] = dPCTLdx

cross_section_parameters_transpose['d2CDFMEdx2'] = d2CDFMEdx2
cross_section_parameters_transpose['d2CPCdx2'] = d2CPCdx2
cross_section_parameters_transpose['d2CSdx2'] = d2CSdx2
cross_section_parameters_transpose['d2CAdx2'] = d2CAdx2
cross_section_parameters_transpose['d2PCTLdx2'] = d2PCTLdx2

# %%
cross_section_parameters_transpose_spline = pd.DataFrame(np.arange(-100,100)/(100.0/line_length), columns = ['Distance'])

# %%
spline_smoothness = np.linspace(-line_length,line_length, 200)
spline_input_distance = cross_section_parameters_transpose.loc[:,'Distance'].values

spline_input_dfme = cross_section_parameters_transpose.loc[:,'DFME'].values
dfme_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme)
dfme_spline = dfme_spline_setup(spline_smoothness)

spline_input_dfme = cross_section_parameters_transpose.loc[:,'Cumulative DFME'].values
cdfme_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme)
cdfme_spline = cdfme_spline_setup(spline_smoothness)

spline_input_pc = cross_section_parameters_transpose.loc[:,'PC'].values
pc_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_pc)
pc_spline = pc_spline_setup(spline_smoothness)

spline_input_slope = cross_section_parameters_transpose.loc[:,'Slope'].values
slope_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_slope)
slope_spline = slope_spline_setup(spline_smoothness)

spline_input_slope_range = cross_section_parameters_transpose.loc[:,'Slope Range'].values
slope_range_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_slope_range)
slope_range_spline = slope_range_spline_setup(spline_smoothness)

spline_input_area = cross_section_parameters_transpose.loc[:,'Area'].values
area_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_area)
area_spline = area_spline_setup(spline_smoothness)

spline_input_dfme_range = cross_section_parameters_transpose.loc[:,'DFME Range'].values
dfme_range_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme_range)
dfme_range_spline = dfme_range_spline_setup(spline_smoothness)

spline_input_dfme_line = cross_section_parameters_transpose.loc[:,'DFME Line'].values
dfme_line_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme_line)
dfme_line_spline = dfme_line_spline_setup(spline_smoothness)

spline_input_elevation_range = cross_section_parameters_transpose.loc[:,'Elevation'].values
elevation_range_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_elevation_range)
elevation_range_spline = elevation_range_spline_setup(spline_smoothness)

spline_input_d2CDFMEdx2 = cross_section_parameters_transpose.loc[:,'d2CDFMEdx2'].values
d2CDFMEdx2_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_d2CDFMEdx2)
d2CDFMEdx2_spline = d2CDFMEdx2_spline_setup(spline_smoothness)

spline_input_d2CPCdx2 = cross_section_parameters_transpose.loc[:,'d2CPCdx2'].values
d2CPCdx2_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_d2CPCdx2)
d2CPCdx2_spline = d2CPCdx2_spline_setup(spline_smoothness)

spline_input_dCDFMEdx = cross_section_parameters_transpose.loc[:,'dCDFMEdx'].values
dCDFMEdx_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dCDFMEdx)
dCDFMEdx_spline = dCDFMEdx_spline_setup(spline_smoothness)

spline_input_dCPCdx = cross_section_parameters_transpose.loc[:,'dCPCdx'].values
dCPCdx_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dCPCdx)
dCPCdx_spline = dCPCdx_spline_setup(spline_smoothness)

spline_input_dCSdx = cross_section_parameters_transpose.loc[:,'dCSdx'].values
dCSdx_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dCSdx)
dCSdx_spline = dCSdx_spline_setup(spline_smoothness)

cross_section_parameters_transpose_spline['DFMEL Spline'] = dfme_line_spline
cross_section_parameters_transpose_spline['Elevation Spline'] = elevation_range_spline
cross_section_parameters_transpose_spline['DFMER Spline'] = dfme_range_spline
cross_section_parameters_transpose_spline['DFME Spline'] = dfme_spline
cross_section_parameters_transpose_spline['Cumulative DFME Spline'] = cdfme_spline
cross_section_parameters_transpose_spline['PC Spline'] = pc_spline
cross_section_parameters_transpose_spline['A Spline'] = area_spline
cross_section_parameters_transpose_spline['Slope Spline'] = slope_spline
cross_section_parameters_transpose_spline['SR Spline'] = slope_range_spline
cross_section_parameters_transpose_spline['d2CDFMEdx2 Spline'] = d2CDFMEdx2_spline
cross_section_parameters_transpose_spline['d2CPCdx2 Spline'] = d2CPCdx2_spline
cross_section_parameters_transpose_spline['dCDFMEdx Spline'] = dCDFMEdx_spline
cross_section_parameters_transpose_spline['dCPCdx Spline'] = dCPCdx_spline
cross_section_parameters_transpose_spline['dCSdx Spline'] = dCSdx_spline

# %% [markdown]
# # Possible rules
# 1. Find peak in second derivative of DFME and then the first point it cross the x-axis.
# 2. Find point that PC goes from large negative to positive and then point that it crosses x-axis.
# 3. Some combination of 1 & 2. E.g. condition 1 only if first part of condition 2 is also met.
#
# Probably just the first is best but can still talk about considering PC and show graph.

# %% [markdown]
# ## Can use DFME together with one of slope, pc, area and then use a sum of squares approach to test which of the three models works best on all ~30 gullies.

# %% [markdown]
# # Three possible rules:
#
# Just have set maximum distance same as flow line. For edges can be 15m in each direction. The the edge will always just be the maximum DFME or rate of change of DFME (second derivative?).
#
# 1. Find peak DFME.
#
# 2. Combination DFME and Slope Range. Just look for peak DFME followed by sections of low slope range (<5?) and DFME is within delta of the 0 line.
#
# 3. Combined DFME, PC and Slope. Look for DFME peak precded by clear - to + PC change and followed by low slope range (<5?) and DFME is within delta of the 0 line.
#
# Increasing complexity, least squares will see if complexity is needed or not.
#
# Then digitise edges for sample of 30 and do least squares assessment of the three methods.

# %% [markdown]
# # Maybe the simplest rule is to find spots where slope is low and DFME is 0.
# # Or just find peak in DFME.

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (15, 8))
x_value = "Distance"
y1_value = "DFME Spline"
y2_value = "Slope Spline"
sns.lineplot(data = cross_section_parameters_transpose_spline, x = x_value, y = y1_value, 
             color = 'xkcd:royal purple')
ax1.set_ylabel('Slope (Degrees)', fontsize=20)
#ax1.annotate('Thalweg', arrowprops = dict(facecolor = 'black'), xy = (0, -23), xytext = (1, -29))
#ax1.lines[0].set_linestyle("--")
ax1.set_ylim(-1, 1)
ax1.set_xlabel('Distance from thalwag (m)', fontsize = 20)
ax1.legend([y1_value],bbox_to_anchor=(0.375, 0.6, 0.5, 0.4))
ax2 = ax1.twinx()
ax2.set_ylim(-45, 45)
sns.lineplot(data = cross_section_parameters_transpose_spline, x = x_value, y = y2_value
             , color = 'xkcd:forest green', ax = ax2)
ax2.lines[0].set_linestyle("--")
#ax2.set_ylabel(y2_value, fontsize = 15)
ax2.set_ylabel('DFME (m)', fontsize = 20)
ax2.legend([y2_value],bbox_to_anchor=(0.375, 0.55, 0.5, 0.4))
plt.axvline(x=11, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axvline(x=-12, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axvline(x=0, color = 'xkcd:cobalt blue', linewidth = 1, alpha = 0.5, linestyle = 'dotted')
plt.axhline(y=0, color = 'xkcd:cobalt blue', linewidth = 1, alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=0, color = 'xkcd:cobalt blue', alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=11, color = 'xkcd:pumpkin', linestyle = 'dotted')
ax1.text(-12.5, -0.5, r'Left Edge', fontsize=15, rotation = 90)
ax1.text(10.5, -0.5, r'Right Edge', fontsize=15, rotation = 90)
plt.title('Gully cross section DFME and slope', fontsize = 25)

# %% [markdown]
# #

# %% [markdown]
# ## Second derivative works best because the highest rate is the middle of the wall going up and the point that then crosses the x-axis when the increase stops being positive (immediately after passing up over the edge of the gully) - straight from graph theory.

# %% [markdown]
# ## First derivative.

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "d2CDFMEdx2 Spline", 
             color = 'xkcd:royal purple')
ax1.set_ylabel('DFME (m)', fontsize=15)
#ax1.annotate('Transition', arrowprops = dict(facecolor = 'black'), xy = (15.5, 0), xytext = (7, 0.06))
#ax1.lines[0].set_linestyle("--")
#ax1.set_ylim(-0.5, 0.5)
ax1.set_xlabel('Distance downstream (m)', fontsize = 15)
ax1.legend(['DFME'],bbox_to_anchor=(0.4, 0.6, 0.5, 0.4))
ax2 = ax1.twinx()
#ax2.set_ylim(-0.2, 0.2)
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "S Spline", 
             color = 'xkcd:forest green', ax = ax2)
ax2.lines[0].set_linestyle("--")
ax2.set_ylabel('PC (rad / 100m)', fontsize = 15)
ax2.legend(['PC'],bbox_to_anchor=(0.375, 0.5, 0.5, 0.4))
plt.axvline(x=7, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axhline(y=0, color = 'xkcd:cobalt blue', alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=6.5, color = 'xkcd:pumpkin', linestyle = 'dotted')
ax1.text(11.5, -0.075, r'Gully head', fontsize=15, rotation = 90)
plt.title('Second derivative of DFME and PC cumulative upstream sum', fontsize = 20)

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "S Spline", 
             color = 'xkcd:forest green')
ax1.set_ylabel('DFME (m)', fontsize=15)
#ax1.annotate('Transition', arrowprops = dict(facecolor = 'black'), xy = (15.5, 0), xytext = (7, 0.06))
ax1.lines[0].set_linestyle("--")
#ax1.set_ylim(-0.4, 0.4)
ax1.set_xlabel('Distance downstream (m)', fontsize = 15)
ax1.legend(['DFME'],bbox_to_anchor=(0.4, 0.6, 0.5, 0.4))
ax2 = ax1.twinx()
ax2.set_ylim(-0.6, 0.6)
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "d2CDFMEdx2 Spline", 
             color = 'xkcd:royal purple', ax = ax2)
#ax2.lines[0].set_linestyle("--")
ax2.set_ylabel('PC (rad / 100m)', fontsize = 15)
ax2.legend(['PC'],bbox_to_anchor=(0.375, 0.5, 0.5, 0.4))
plt.axvline(x=3, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axvline(x=-4, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axhline(y=0, color = 'xkcd:cobalt blue', alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=6.5, color = 'xkcd:pumpkin', linestyle = 'dotted')
ax1.text(-4.5, 35, r'L. edge', fontsize=15, rotation = 90)
ax1.text(2.5, 35, r'R. edge', fontsize=15, rotation = 90)
plt.title('Second derivative of DFME and PC cumulative upstream sum', fontsize = 20)

# %%
# Extract the data we're interested in
dfme, dist = cross_section_parameters_transpose['DFME'], cross_section_parameters_transpose['Distance']
pc, slope = cross_section_parameters_transpose['PC'], cross_section_parameters_transpose['Slope']

# Scatter the points, using size and color but no label
plt.scatter(dist, dfme, label=None,
            c=pc, cmap='viridis',
            s=slope, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('Distance')
plt.ylabel('Difference from mean elevation')
plt.colorbar(label='slope')
plt.clim(-0.1, 0.1)

# Here we create a legend:

# we'll plot empty lists with the desired size and label
for slope in [1, 2, 5]:
    plt.scatter([], [], c='k', alpha=0.3, s=slope,
                label=str(slope) + ' ha')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='Gully plot')

plt.title('California Cities: Area and Population');

# %%
cross_section_parameters_transpose_spline.head()

# %%
cross_section_parameters_transpose['PC'].nunique()

# %%
sns.set(style="white")

f = sns.relplot(x="Distance", y="DFME", hue="PC", size="Slope",
            sizes=(20, 200), alpha=.5, height=6, data=cross_section_parameters_transpose)

plt.axhline(y=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')
plt.axvline(x=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')
f.set(ylim = (-0.5, 0.5))

# %% [markdown]
# ## Organise one field of the dataframe into categories so that I can use the palettes in below plot. n_colors below refers to the number of categories assigned to 'name'.

# %%
bins = [-0.2, -0.1, -0.05, -0.01, 0, 0.01, 0.05, 0.1, 0.2]
names = ['- 0.2','- 0.1', '- 0.05', '- 0.01', '0.01', '0.05','0.1', '0.2']

cross_section_parameters_transpose['Profile Curvature'] = pd.cut(cross_section_parameters_transpose['PC'], 
                                                                 bins, labels=names)

# %%
filtered_pc = np.copy(cross_section_parameters_transpose['PC'].values)
filtered_pc[filtered_pc < 0] = np.nan
cross_section_parameters_transpose['PC Filtered'] = filtered_pc

# %%
filtered_dfme = np.copy(cross_section_parameters_transpose['DFME'].values)
filtered_dfme[filtered_dfme < 0.05] = np.nan
cross_section_parameters_transpose['DFME Filtered'] = filtered_dfme

# %%
filtered_slope = np.copy(cross_section_parameters_transpose['Slope'].values)
filtered_slope[filtered_slope < 10] = np.nan
cross_section_parameters_transpose['Slope Filtered'] = filtered_slope

# %% [markdown]
# ### Three simple models are:
#
# 1. Just DFME peak near thalweg.
# 2. DFME peak plus positive PC.
# 3. DFME peak, positive PC and low slope range.

# %%
# Load the example planets dataset
#palette = sns.diverging_palette(10, 220, sep=1, n=8)
palette = sns.color_palette('RdBu')
sns.set(style = 'ticks')
fig, ax = plt.subplots(figsize =(12,9))
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
f = sns.scatterplot(x="Distance", y="DFME Filtered",
                     hue="PC", size="Slope",
                     palette=cmap, sizes=(20, 200),
                     data=cross_section_parameters_transpose)
f.set(ylim = (-1, 1))
f.set(xlim = (-30, 30))
plt.axhline(y=0, color = 'xkcd:merlot', alpha = 0.2, linestyle = '--')
plt.axvline(x=0, color = 'xkcd:merlot', alpha = 0.2, linestyle = '--')

# %%
cross_section_parameters_transpose.drop(columns=['PC Filtered', 'DFME Filtered', 'Slope Filtered']);

# %%
#sns.set(style="whitegrid")
sns.set(style = 'ticks')
#palette = sns.color_palette("RdBu", n_colors = 6)
palette = sns.diverging_palette(10, 220, sep=1, n=8)
# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="Distance", y="DFME", hue="Profile Curvature", size="Slope", palette = palette, sizes = (20, 200),
             alpha=.8, height=6, data=cross_section_parameters_transpose)
#f.set(ylim = (-0.3, 0.3))
plt.axhline(y=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')
plt.axvline(x=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('namadgi_gn.tif', input_geotiff, grid_nodes, drainage_area.dtype)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
