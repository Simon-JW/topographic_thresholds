# %% [markdown]
# ## Import required libraries.

# %%
# %%capture
import operator
import seaborn as sns; sns.set()
from jupyterthemes import jtplot
jtplot.style()
import numpy as np
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy.signal import medfilt
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from landlab.plot.imshow import imshow_grid 

# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure

# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120) 
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Setup input data
# Define spatial resolution: Specify the resolution of the input DEM and also the desired working resolution (can be same as input DEM resolution).

# %%
def roundup(x):
    return int(math.ceil(x / 10.0)) * 10

input_DEM_resolution = 1
working_resolution = 1
location = (r'C:\PhD\junk')
os.chdir(location)
input_geotiff = gdal.Open('wean_sub.tif')
x = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())
empty_grid_rows = roundup(x.shape[0])
empty_grid_cols = roundup(x.shape[1])
input_DEM = np.zeros([empty_grid_rows,empty_grid_cols])
input_DEM[:x.shape[0], :x.shape[1]] = x

input_outlets = gdal.Open('wean_downstream_5m.tif')
o = np.array(input_outlets.GetRasterBand(1).ReadAsArray())
outlets= o
#outlets = 1 - o

# %% [markdown]
# ## Visualise the DEM.

# %%
plt.figure(figsize=(12,12))
plt.imshow(input_DEM, cmap="terrain_r", vmin = np.percentile(input_DEM, 5));
plt.colorbar();

# %% [markdown]
# ## Define required function.

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def differenceFromMeanElevation(elev):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = elev[central_value]                        
    mean = np.nanmean(elev)#Count number of values greater than centroid value
    diff = centroid - mean
    return diff
def PCTL(x):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = x[central_value]                        
    y = np.sum(x < centroid)/num_values#Count number of values greater than centroid value
    return y
def flow_dir_dataset(flow_rec_prop, catchment_area, grid_resolution, outlet_node):
    """ Create an xarray Dataset containing eight arrays each representing the
    amount of water flowing in the given direction.
        1 . flow_rec_prop == the flow receiver proportion array created by LandLab flow routing.
        2 . catchment_area == the corresponding catchment area array from the landLab flow accumulation.
        surface.        
    The resulting Dataset is used to calculate specific catchment area."""
    array_direction = xr.Dataset()
    for i in range(0,8):
        rows = catchment_area.shape[0]; cols = catchment_area.shape[1];
        direction = np.flip(flow_rec_prop[:,i].reshape(rows,cols), 0);
        # Above needs to be flipped because during reshape it organises data top down
        # rather than bottom up as per ModelGrid order (catchment_area is mg arrangement).
        zero_outlet = outlet_node != 1
        remove_outlet = zero_outlet * catchment_area
        weighted_direction = xr.DataArray((remove_outlet * direction),
                                          dims = ['lat', 'lon']);
        array_direction[direction_list[i]] = weighted_direction
        
    E, N, W, S, NE, NW, SW, SE = (array_direction['East'], array_direction['North'],
                             array_direction['West'], array_direction['South'],
                             array_direction['North East'], array_direction['North West'],
                             array_direction['South West'], array_direction['South East'])

    flow_dirs = xr.concat([E, N, W, S, NE, NW, SW, SE], 'direction')
    flow_dirs.name = 'flow_directions'
    flow_dirs.attrs['grid cell resolution'] = grid_resolution
    flow_directions = flow_dirs.assign_coords(direction=(['East','North','West','South',
                                   'North East', 'North West','South West', 'South East']))
    return flow_directions
def profileCurvature(DEM, cellsize):
    """This process is taken from Change (2014, Introduction to Geographic Information
       systems, Page 284)."""
    Z1 = DEM[0]; Z2 = DEM[1]; Z3 = DEM[2]
    Z4 = DEM[3]; Z0 = DEM[4]; Z5 = DEM[5]
    Z6 = DEM[6]; Z7 = DEM[7]; Z8 = DEM[8]
    D = (((Z4 + Z5)/2) - Z0) / cellsize**2
    E = (((Z2 + Z7)/2) - Z0) / cellsize**2
    F = (Z3 - Z1 + Z6 - Z8)/ (4 * cellsize**2)
    G = (Z5 - Z4) / (2 * cellsize)
    H = (Z2 - Z7) / (2 * cellsize)
    profile_curvature = (-2 * (D*(G**2) + E*(H**2) + (F*G*H))) / (G**2 + H**2)
    return profile_curvature
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def closest(lst, K): 
     angle_list = lst
     idx = (np.abs(angle_list - K)).argmin() 
     return angle_list[idx]  
def data_range(data):
    data_min = np.amin(data); data_max = np.amax(data)
    value_range = data_max - data_min
    return value_range
def checkGullyHead(catchment_area_list, step_size, comparison_distance, minimum_depth, elevation_of_gh):
    
    """ """
    
    max_value_length = len(catchment_area_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = catchment_area_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptreat_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = catchment_area_list[start_of_upstream_nodes:end_of_usptreat_nodes]
        
        min_downstream = np.min(downstream_nodes)
        mean_upstream = np.mean(upstream_nodes)
        std_upstream = np.std(upstream_nodes)
        elevation_difference = min_downstream - mean_upstream
        print('minimum downstream value: ', min_downstream)
        print('mean upstream value: ', mean_upstream)
        print('std upstream value: ', std_upstream)
      
        if min_downstream <= minimum_depth and mean_upstream > elevation_of_gh and std_upstream < 0.1 and elevation_difference <= -0.2:
            keep_gully = 'yes'
            gully_head_location = end_of_downstream_nodes + np.round(comparison_distance/2) - 1
            break
        else:
            keep_gully = 'no'
            gully_head_location = 'none'

    return keep_gully
def upstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, import_drainage_area, 
                         import_dfme, catchment_outlet_ids, step_size_m, comparison_distance_m,  
                         slope_above_head, min_depth, gh_elevation):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        
        #da_subset_copy = np.copy(import_drainage_area)
        import_da_subset = import_drainage_area[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        flattened_import_da = import_da_subset.reshape(da.shape)
        
        #dfme_subset_copy = np.copy(import_dfme)
        import_dfme_subset = import_dfme[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        flattened_import_dfme = import_dfme_subset.reshape(da.shape)
        
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.

        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        print(central_node)
        print(mg1.shape)
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)
        

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        node_dfme_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            upstream_dfme_dict = {};
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_import_da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})
                        node_dfme = np.amin(np.multiply(isolate_candidate_grid_cells, flattened_import_dfme))
                        upstream_dfme_dict.update({node_id_value:node_dfme})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    print(primary_flow_direction_id)
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    node_dfme_dict[primary_flow_direction_id] = upstream_dfme_dict[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        print(target_distance, ' ', target_distance * input_DEM_resolution)
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        dfme_along_central_drainage_line = []
        for key, value in node_dfme_dict.items():
            dfme_along_central_drainage_line.append(value)
        median_dfme_along_central_drainage_line = ndimage.median_filter(dfme_along_central_drainage_line, size=step_size_m)

        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_dfme_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            print('node: ',i,)
            divergence_occuring = checkGullyHead(dfme_along_central_drainage_line, 
                                                    step_size, comparison_distance, min_depth, gh_elevation)
            upslope_divergence_dict[i] = divergence_occuring
            
    return upslope_divergence_dict, slope_dict, slope_at_head
def slopeWindowMperM(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_m_per_m = rise_run
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_m_per_m

# %%
#################################################################################################
flow_acc_surf = np.copy(input_DEM).astype('float64');
#################################################################################################
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

sfb = SinkFillerBarnes(mg, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();
fa = FlowAccumulator(mg,
                    surface = 'topographic__elevation',
                    flow_director = 'FlowDirectorMFD',
                    diagonals = True);
#(flow_acc, q) = fa.accumulate_flow();
fa.run_one_step()
fd = FlowDirectorMFD(mg, 'topographic__elevation', diagonals = True);
fd.run_one_step()

da = np.array(mg.at_node['drainage_area'].round(4));
catchment_area_ha = np.divide(da.reshape(mg.shape), (100/working_resolution)**2)
frn = mg.at_node['flow__receiver_node'];
drainage_area = np.flip(da.reshape(mg.shape), 0);
frp = np.array(mg.at_node['flow__receiver_proportions']);
ns = np.flip(mg.status_at_node.reshape(mg.shape), 0);
flow_rec_surf_rows = cols * rows;
flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);

tss = mg.at_node['topographic__steepest_slope'];
steepest_slope = tss.reshape(flow_rec_surf_rows,8);
all_receiver_proportions = np.copy(frp);

# %% [markdown]
# # For all nodes

# %%
# Must be larger than 'line_length' (specified later).
size_of_edge = 30

# %%
grid_nodes = np.array(mg.nodes.reshape(mg.shape))
find_nodes = np.multiply(outlets, grid_nodes);

gully_head_edge_mask = np.zeros([grid_nodes.shape[0], grid_nodes.shape[1]])
gully_head_mask_centre = np.ones([grid_nodes.shape[0] - size_of_edge*2, grid_nodes.shape[1] - size_of_edge*2])
gully_head_edge_mask[size_of_edge:-1*(size_of_edge), size_of_edge:-1*(size_of_edge)] = gully_head_mask_centre

remaining_gully_heads = find_nodes * gully_head_edge_mask
gh_array = np.unique(remaining_gully_heads);
gh_list = gh_array.tolist();
gh_list.remove(0);
len(gh_list)
# Out:
# 61

# %% [markdown]
# # For one node

# %%
#grid_nodes = np.array(mg.nodes.reshape(mg.shape))
#find_outlet_ids = grid_nodes * outlets
#outlet_id = np.unique(find_outlet_ids)[1]

# %%
radius = 9
central_value = find_median_value(circleWindow(radius))
num_values = number_of_values(circleWindow(radius))
dfme = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(radius), mode='nearest');
dfme[dfme > 5.0] = 5.0
dfme[dfme < -5.0] = -5.0

# %%
slope = generic_filter(input_DEM, slopeWindowDegrees,
                  footprint= rectangleWindow(3,3),
                  mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

# %%
shape = 9
central_value = find_median_value(circleWindow(shape))
num_values = number_of_values(circleWindow(shape))

# %%
DFME = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(shape), mode='nearest');

# %%
# Specific the size of the area to be checked. This represents a physical distance from the 
# outlet but has no unit of measure.
distance_from_outlet = 20

# %%
outlet_id = 1841218
outlet_id
# Out:
# 1841218

# %%
divergence_dict, slope_dict, slope_area_data = upstreamDrainageLine(20, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_ha, DFME,gh_list, 3, 3, 10, -0.2, -0.2)
# Out:
# 840
# (41, 41)
# 841
# 842
# 884
# 885
# 886
# 887
# 888
# 930
# 931
# 973
# 1015
# 10   10
# 1016
# 1058
# 1059
# 1060
# 1102
# 1144
# 1145
# 1187
# 1228
# node:  27349.0
# minimum downstream value:  -0.520902128559
# mean upstream value:  -0.239591897555
# std upstream value:  0.0325004167786
# minimum downstream value:  -0.231552304958
# mean upstream value:  -0.254258468688
# std upstream value:  0.0213616515177
# minimum downstream value:  -0.237043056563
# mean upstream value:  -0.264355082757
# std upstream value:  0.0141458306253
# minimum downstream value:  -0.237043056563
# mean upstream value:  -0.252922369714
# std upstream value:  0.00625167184371
# minimum downstream value:  -0.237043056563
# mean upstream value:  -0.231385362949
# std upstream value:  0.0340363241465
# minimum downstream value:  -0.231473658867
# mean upstream value:  -0.207841513813
# std upstream value:  0.0289250829497
# minimum downstream value:  -0.282829917938
# mean upstream value:  -0.184496410908
# std upstream value:  0.00517795671722
# minimum downstream value:  -0.282829917938
# mean upstream value:  -0.175924228271
# std upstream value:  0.0135894392069
# minimum downstream value:  -0.282829917938
# mean upstream value:  -0.15169258771
# std upstream value:  0.0249399558036
# minimum downstream value:  -0.261763501073
# mean upstream value:  -0.126336179389
# std upstream value:  0.0234221243447
# minimum downstream value:  -0.261763501073
# mean upstream value:  -0.098168414572
# std upstream value:  0.0185342043558
# 840
# (41, 41)
# 882
# 883
# 925
# 967
# 968
# 1010
# 1011
# 1012
# 1054
# 1096
# 1097
# 10   10
# 1139
# 1181
# 1182
# 1142
# 1102
# 1144
# 1186
# 1146
# 1187
# node:  28156.0
# minimum downstream value:  -0.282829917938
# mean upstream value:  -0.175924228271
# std upstream value:  0.0135894392069
# minimum downstream value:  -0.282829917938
# mean upstream value:  -0.15169258771
# std upstream value:  0.0249399558036
# minimum downstream value:  -0.261763501073
# mean upstream value:  -0.126336179389
# std upstream value:  0.0234221243447
# minimum downstream value:  -0.261763501073
# mean upstream value:  -0.098168414572
# std upstream value:  0.0185342043558
# minimum downstream value:  -0.248531778811
# mean upstream value:  -0.0759494062783
# std upstream value:  0.0207409795691
# minimum downstream value:  -0.191131953665
# mean upstream value:  -0.0684914168005
# std upstream value:  0.0121032458664
# minimum downstream value:  -0.191131953665
# mean upstream value:  -0.0710926081038
# std upstream value:  0.0136678777147
# minimum downstream value:  -0.178496470093
# mean upstream value:  -0.0838364914001
# std upstream value:  0.00440328712901
# minimum downstream value:  -0.158144261055
# mean upstream value:  -0.0997315659353
# std upstream value:  0.0201103646678
# minimum downstream value:  -0.118437031983
# mean upstream value:  -0.128357737746
# std upstream value:  0.0315652836023
# minimum downstream value:  -0.102427245129
# mean upstream value:  -0.14506130696
# std upstream value:  0.0165333828941
# 840
# (41, 41)
# 882
# 923
# 965
# 1007
# 1048
# 1090
# 1131
# 1172
# 1214
# 1256
# 1297
# 10   10
# 1339
# 1381
# 1423
# 1464
# 1506
# 1548
# 1590
# 1591
# 1592
# node:  36941.0
# minimum downstream value:  -0.578687343673
# mean upstream value:  -0.163429471344
# std upstream value:  0.0354036862831
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 594
# 553
# 512
# 471
# 429
# 388
# 10   10
# 347
# 306
# 265
# 225
# 183
# 142
# 102
# 60
# 59
# node:  91894.0
# minimum downstream value:  -0.62144560682
# mean upstream value:  -0.101373001521
# std upstream value:  0.00504793241676
# 840
# (41, 41)
# 799
# 798
# 756
# 714
# 673
# 631
# 590
# 549
# 508
# 467
# 426
# 10   10
# 385
# 344
# 303
# 262
# 221
# 180
# 138
# 97
# 56
# node:  97498.0
# minimum downstream value:  -0.721385488397
# mean upstream value:  -0.621256228963
# std upstream value:  0.01289387565
# minimum downstream value:  -0.683173379408
# mean upstream value:  -0.615749957219
# std upstream value:  0.0200457064011
# minimum downstream value:  -0.683173379408
# mean upstream value:  -0.583096590909
# std upstream value:  0.0339065329827
# minimum downstream value:  -0.683173379408
# mean upstream value:  -0.565912178854
# std upstream value:  0.0205487330906
# minimum downstream value:  -0.65382644593
# mean upstream value:  -0.564049882851
# std upstream value:  0.0185403813377
# minimum downstream value:  -0.65382644593
# mean upstream value:  -0.595482706867
# std upstream value:  0.0272860633042
# minimum downstream value:  -0.636952396438
# mean upstream value:  -0.441144096364
# std upstream value:  0.237243538375
# minimum downstream value:  -0.636952396438
# mean upstream value:  -0.28090875799
# std upstream value:  0.249177944338
# minimum downstream value:  -0.62144560682
# mean upstream value:  -0.101373001521
# std upstream value:  0.00504793241676
# 840
# (41, 41)
# 798
# 756
# 714
# 673
# 632
# 590
# 549
# 508
# 466
# 425
# 383
# 10   10
# 382
# 340
# 298
# 257
# 215
# 174
# 133
# 92
# 51
# node:  105504.0
# minimum downstream value:  -0.536413260599
# mean upstream value:  -0.603150901744
# std upstream value:  0.0363302281573
# minimum downstream value:  -0.572605781404
# mean upstream value:  -0.617963104851
# std upstream value:  0.043594808322
# minimum downstream value:  -0.572605781404
# mean upstream value:  -0.672939737795
# std upstream value:  0.0343862686264
# minimum downstream value:  -0.591498936589
# mean upstream value:  -0.672694994056
# std upstream value:  0.0345858721642
# minimum downstream value:  -0.607938140749
# mean upstream value:  -0.661116206756
# std upstream value:  0.0439873476129
# minimum downstream value:  -0.607938140749
# mean upstream value:  -0.648378837093
# std upstream value:  0.0269076881711
# minimum downstream value:  -0.645058974918
# mean upstream value:  -0.637146518793
# std upstream value:  0.0326715069488
# minimum downstream value:  -0.652374750069
# mean upstream value:  -0.649209204713
# std upstream value:  0.0297960273248
# minimum downstream value:  -0.721385488397
# mean upstream value:  -0.623274972787
# std upstream value:  0.0217095013312
# minimum downstream value:  -0.721385488397
# mean upstream value:  -0.632049842
# std upstream value:  0.0200834343838
# minimum downstream value:  -0.721385488397
# mean upstream value:  -0.621256228963
# std upstream value:  0.01289387565
# 840
# (41, 41)
# 798
# 757
# 716
# 674
# 633
# 592
# 551
# 510
# 469
# 428
# 387
# 10   10
# 346
# 305
# 265
# 224
# 183
# 143
# 102
# 103
# 104
# node:  126306.0
# minimum downstream value:  -0.431161511086
# mean upstream value:  -0.487146751997
# std upstream value:  0.0303792815233
# minimum downstream value:  -0.431161511086
# mean upstream value:  -0.512397776165
# std upstream value:  0.0243893073209
# minimum downstream value:  -0.447663197875
# mean upstream value:  -0.53486217152
# std upstream value:  0.00751702319126
# minimum downstream value:  -0.472805942943
# mean upstream value:  -0.554730361315
# std upstream value:  0.0240178553299
# minimum downstream value:  -0.472805942943
# mean upstream value:  -0.57163114887
# std upstream value:  0.0187395613874
# minimum downstream value:  -0.477951471985
# mean upstream value:  -0.599885118809
# std upstream value:  0.0215023104036
# minimum downstream value:  -0.528089078519
# mean upstream value:  -0.595961257874
# std upstream value:  0.0242655722121
# minimum downstream value:  -0.531152777992
# mean upstream value:  -0.585196152035
# std upstream value:  0.0335305933726
# minimum downstream value:  -0.545344658049
# mean upstream value:  -0.555195925264
# std upstream value:  0.015155282444
# minimum downstream value:  -0.587693647905
# mean upstream value:  -0.531538047338
# std upstream value:  0.0191937487106
# minimum downstream value:  -0.587693647905
# mean upstream value:  -0.499645127609
# std upstream value:  0.0354003184918
# 840
# (41, 41)
# 799
# 758
# 716
# 675
# 633
# 632
# 672
# 671
# 629
# 587
# 546
# 10   10
# 504
# 464
# 424
# 383
# 343
# 303
# 263
# 222
# 181
# node:  139587.0
# minimum downstream value:  -0.362311804247
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 759
# 718
# 677
# 636
# 595
# 553
# 512
# 471
# 430
# 389
# 10   10
# 349
# 308
# 267
# 225
# 185
# 145
# 104
# 62
# 61
# node:  140403.0
# minimum downstream value:  -0.481294533952
# mean upstream value:  -0.00971785835598
# std upstream value:  0.0130832279406
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 595
# 554
# 513
# 471
# 431
# 389
# 10   10
# 348
# 308
# 267
# 226
# 184
# 144
# 145
# 187
# 188
# node:  142306.0
# minimum downstream value:  -1.12377411009
# mean upstream value:  -0.224782227527
# std upstream value:  0.0278478562289
# minimum downstream value:  -1.12377411009
# mean upstream value:  -0.249335086707
# std upstream value:  0.0222445722876
# minimum downstream value:  -1.12377411009
# mean upstream value:  -0.265999976197
# std upstream value:  0.00301492596886
# minimum downstream value:  -1.04031926935
# mean upstream value:  -0.261756826609
# std upstream value:  0.0090155258578
# minimum downstream value:  -0.314903651302
# mean upstream value:  -0.265195823941
# std upstream value:  0.0122088957059
# minimum downstream value:  -0.218096706707
# mean upstream value:  -0.268396550959
# std upstream value:  0.0137143056475
# minimum downstream value:  -0.261736481557
# mean upstream value:  -0.274064658345
# std upstream value:  0.00570379871956
# minimum downstream value:  -0.268172071856
# mean upstream value:  -0.265297790447
# std upstream value:  0.0104246298786
# minimum downstream value:  -0.268172071856
# mean upstream value:  -0.262637252707
# std upstream value:  0.00754128801121
# minimum downstream value:  -0.268172071856
# mean upstream value:  -0.257156593212
# std upstream value:  0.0089421289893
# minimum downstream value:  -0.278489063851
# mean upstream value:  -0.215652164263
# std upstream value:  0.0627502666636
# 840
# (41, 41)
# 799
# 758
# 716
# 675
# 635
# 594
# 553
# 512
# 470
# 429
# 387
# 10   10
# 386
# 426
# 425
# 383
# 341
# 300
# 258
# 218
# 178
# node:  144387.0
# minimum downstream value:  -1.00039178298
# mean upstream value:  -0.323717763144
# std upstream value:  0.0416523279736
# minimum downstream value:  -1.15889477636
# mean upstream value:  -0.29897431988
# std upstream value:  0.044801449532
# minimum downstream value:  -1.15889477636
# mean upstream value:  -0.312152163942
# std upstream value:  0.03850071498
# minimum downstream value:  -1.15889477636
# mean upstream value:  -0.247670370914
# std upstream value:  0.0577004439241
# minimum downstream value:  -0.829563186103
# mean upstream value:  -0.158093921124
# std upstream value:  0.124917752503
# minimum downstream value:  -0.622057647102
# mean upstream value:  -0.0562888083879
# std upstream value:  0.079604396232
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 595
# 555
# 515
# 475
# 434
# 393
# 10   10
# 353
# 313
# 314
# 274
# 316
# 275
# 235
# 194
# 153
# node:  147303.0
# minimum downstream value:  -0.290340498973
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 799
# 758
# 717
# 675
# 633
# 592
# 551
# 510
# 468
# 427
# 387
# 10   10
# 346
# 305
# 264
# 222
# 181
# 139
# 138
# 178
# 177
# node:  149189.0
# minimum downstream value:  -1.151325452
# mean upstream value:  -0.965200029657
# std upstream value:  0.0273961402122
# minimum downstream value:  -1.151325452
# mean upstream value:  -1.03095194097
# std upstream value:  0.0944928184956
# minimum downstream value:  -1.151325452
# mean upstream value:  -0.996283248479
# std upstream value:  0.13448044251
# minimum downstream value:  -1.09789110267
# mean upstream value:  -0.870171869853
# std upstream value:  0.22103593182
# minimum downstream value:  -0.961639042428
# mean upstream value:  -0.598193504122
# std upstream value:  0.199370452896
# minimum downstream value:  -0.961639042428
# mean upstream value:  -0.410299710763
# std upstream value:  0.153006137859
# minimum downstream value:  -1.00039178298
# mean upstream value:  -0.323717763144
# std upstream value:  0.0416523279736
# minimum downstream value:  -1.15889477636
# mean upstream value:  -0.29897431988
# std upstream value:  0.044801449532
# minimum downstream value:  -1.15889477636
# mean upstream value:  -0.312152163942
# std upstream value:  0.03850071498
# minimum downstream value:  -1.15889477636
# mean upstream value:  -0.247670370914
# std upstream value:  0.0577004439241
# minimum downstream value:  -0.829563186103
# mean upstream value:  -0.158093921124
# std upstream value:  0.124917752503
# 840
# (41, 41)
# 798
# 797
# 755
# 713
# 712
# 711
# 710
# 668
# 626
# 584
# 543
# 10   10
# 502
# 461
# 420
# 380
# 339
# 298
# 257
# 217
# 176
# node:  149986.0
# minimum downstream value:  -0.805215224918
# mean upstream value:  -0.105785988065
# std upstream value:  0.149603979031
# minimum downstream value:  -0.754373542876
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 799
# 757
# 716
# 675
# 634
# 594
# 553
# 511
# 471
# 430
# 389
# 10   10
# 349
# 308
# 266
# 225
# 185
# 144
# 103
# 62
# 63
# node:  152403.0
# minimum downstream value:  -0.98044836474
# mean upstream value:  -0.599205087453
# std upstream value:  0.142777877204
# minimum downstream value:  -1.04735725011
# mean upstream value:  -0.514476429332
# std upstream value:  0.0910466177018
# minimum downstream value:  -1.06938551349
# mean upstream value:  -0.453800206442
# std upstream value:  0.0371999871972
# minimum downstream value:  -1.06938551349
# mean upstream value:  -0.45125558725
# std upstream value:  0.040230170744
# minimum downstream value:  -1.06938551349
# mean upstream value:  -0.442096896165
# std upstream value:  0.0295412151942
# minimum downstream value:  -0.880948032786
# mean upstream value:  -0.46912155855
# std upstream value:  0.0525557865163
# minimum downstream value:  -0.755314762884
# mean upstream value:  -0.526488051584
# std upstream value:  0.0413844440463
# minimum downstream value:  -0.632058366014
# mean upstream value:  -0.529035324479
# std upstream value:  0.038163822755
# minimum downstream value:  -0.501128788522
# mean upstream value:  -0.474880535141
# std upstream value:  0.0842492527064
# minimum downstream value:  -0.501128788522
# mean upstream value:  -0.399477268867
# std upstream value:  0.0584349624129
# minimum downstream value:  -0.473652715268
# mean upstream value:  -0.340080572839
# std upstream value:  0.0274085640289
# 840
# (41, 41)
# 798
# 756
# 714
# 673
# 632
# 592
# 551
# 509
# 468
# 426
# 384
# 10   10
# 342
# 301
# 260
# 218
# 177
# 135
# 94
# 52
# 51
# node:  155572.0
# minimum downstream value:  -0.383197166232
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 883
# 884
# 885
# 886
# 887
# 888
# 889
# 890
# 850
# 810
# 10   10
# 770
# 730
# 731
# 691
# 650
# 610
# 570
# 528
# 487
# node:  157208.0
# minimum downstream value:  -0.395003126544
# mean upstream value:  -0.0058791571455
# std upstream value:  0.00831438377049
# 840
# (41, 41)
# 798
# 757
# 716
# 676
# 634
# 592
# 550
# 509
# 468
# 428
# 387
# 10   10
# 345
# 304
# 262
# 220
# 178
# 137
# 96
# 54
# 53
# node:  158772.0
# minimum downstream value:  -0.43110518022
# mean upstream value:  -0.306061796206
# std upstream value:  0.114673847368
# minimum downstream value:  -0.386322986467
# mean upstream value:  -0.178329407462
# std upstream value:  0.161480176488
# minimum downstream value:  -0.369281512475
# mean upstream value:  -0.0479838857538
# std upstream value:  0.0678594620083
# 840
# (41, 41)
# 841
# 842
# 802
# 803
# 804
# 846
# 888
# 889
# 931
# 973
# 1015
# 10   10
# 1057
# 1098
# 1140
# 1141
# 1183
# 1224
# 1266
# 1307
# 1349
# node:  159108.0
# minimum downstream value:  -0.87197851852
# mean upstream value:  -0.121274282182
# std upstream value:  0.00412808016616
# 840
# (41, 41)
# 800
# 759
# 718
# 676
# 634
# 593
# 552
# 511
# 470
# 429
# 387
# 10   10
# 346
# 304
# 262
# 220
# 179
# 138
# 97
# 56
# 57
# node:  160108.0
# minimum downstream value:  -0.278687005929
# mean upstream value:  -0.113689598516
# std upstream value:  0.00674868579634
# minimum downstream value:  -0.279167567317
# mean upstream value:  -0.106779236724
# std upstream value:  0.0132542600695
# minimum downstream value:  -0.34881471174
# mean upstream value:  -0.105392998857
# std upstream value:  0.0116092601847
# 840
# (41, 41)
# 798
# 757
# 715
# 674
# 633
# 592
# 550
# 508
# 467
# 426
# 385
# 10   10
# 343
# 302
# 261
# 220
# 179
# 137
# 96
# 55
# 54
# node:  170981.0
# minimum downstream value:  -0.336313240142
# mean upstream value:  -0.181843713652
# std upstream value:  0.0138440846738
# minimum downstream value:  -0.336313240142
# mean upstream value:  -0.168391412426
# std upstream value:  0.0100867225348
# minimum downstream value:  -0.336313240142
# mean upstream value:  -0.167425786397
# std upstream value:  0.0105202123986
# minimum downstream value:  -0.304462538406
# mean upstream value:  -0.170264001577
# std upstream value:  0.0145062712857
# minimum downstream value:  -0.22232646716
# mean upstream value:  -0.171183831136
# std upstream value:  0.0137869412985
# minimum downstream value:  -0.198638071656
# mean upstream value:  -0.165678001675
# std upstream value:  0.0188057790261
# minimum downstream value:  -0.198638071656
# mean upstream value:  -0.150074955032
# std upstream value:  0.00777649295865
# minimum downstream value:  -0.182161474416
# mean upstream value:  -0.144153057194
# std upstream value:  0.000857940158876
# minimum downstream value:  -0.182161474416
# mean upstream value:  -0.153903644547
# std upstream value:  0.0146146048575
# minimum downstream value:  -0.190676119959
# mean upstream value:  -0.149070649279
# std upstream value:  0.0189028216384
# minimum downstream value:  -0.190676119959
# mean upstream value:  -0.140613058339
# std upstream value:  0.0244624904724
# 840
# (41, 41)
# 800
# 842
# 843
# 844
# 845
# 805
# 806
# 807
# 767
# 768
# 728
# 10   10
# 688
# 689
# 690
# 691
# 692
# 693
# 653
# 654
# 613
# node:  193220.0
# minimum downstream value:  -0.460879118546
# mean upstream value:  -0.109634459725
# std upstream value:  0.00887055821954
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 594
# 553
# 512
# 471
# 431
# 390
# 10   10
# 349
# 308
# 267
# 227
# 186
# 145
# 104
# 63
# 64
# node:  199415.0
# minimum downstream value:  -0.430938238212
# mean upstream value:  -0.133213008031
# std upstream value:  0.0196136053144
# 840
# (41, 41)
# 800
# 760
# 719
# 678
# 638
# 597
# 556
# 516
# 475
# 434
# 393
# 10   10
# 352
# 311
# 270
# 230
# 189
# 148
# 107
# 66
# 67
# node:  199594.0
# minimum downstream value:  -1.37760895137
# mean upstream value:  -1.43643988608
# std upstream value:  0.0615343617142
# minimum downstream value:  -1.23254298033
# mean upstream value:  -1.5095010187
# std upstream value:  0.0639541011398
# minimum downstream value:  -1.3256558505
# mean upstream value:  -1.5711274681
# std upstream value:  0.0410079205507
# minimum downstream value:  -1.37022514494
# mean upstream value:  -1.5947666897
# std upstream value:  0.0130643326326
# minimum downstream value:  -1.37022514494
# mean upstream value:  -1.60120043045
# std upstream value:  0.0110977667134
# minimum downstream value:  -1.42833362926
# mean upstream value:  -1.54955978293
# std upstream value:  0.0649307474488
# minimum downstream value:  -1.51552922547
# mean upstream value:  -1.60593527893
# std upstream value:  0.121373197227
# minimum downstream value:  -1.58464020137
# mean upstream value:  -1.62897404004
# std upstream value:  0.125304230252
# minimum downstream value:  -1.61321297747
# mean upstream value:  -1.69648033011
# std upstream value:  0.0420831986707
# minimum downstream value:  -1.61321297747
# mean upstream value:  -1.63343523551
# std upstream value:  0.0476372742468
# minimum downstream value:  -1.61321297747
# mean upstream value:  -1.58009706279
# std upstream value:  0.0610937868144
# 840
# (41, 41)
# 799
# 758
# 718
# 677
# 636
# 595
# 553
# 512
# 471
# 429
# 388
# 10   10
# 347
# 306
# 266
# 226
# 185
# 145
# 104
# 63
# 62
# node:  199805.0
# minimum downstream value:  -0.648314585328
# mean upstream value:  -0.637328216995
# std upstream value:  0.0805268945351
# minimum downstream value:  -0.663278572173
# mean upstream value:  -0.645683439353
# std upstream value:  0.0855926075382
# minimum downstream value:  -0.671306866431
# mean upstream value:  -0.617489579795
# std upstream value:  0.073499003973
# minimum downstream value:  -0.671306866431
# mean upstream value:  -0.694430666636
# std upstream value:  0.0543726828595
# minimum downstream value:  -0.679331542004
# mean upstream value:  -0.725275373899
# std upstream value:  0.0739865578443
# minimum downstream value:  -0.70799804205
# mean upstream value:  -0.709993666497
# std upstream value:  0.0951537074296
# minimum downstream value:  -0.70799804205
# mean upstream value:  -0.615944923934
# std upstream value:  0.134866636554
# minimum downstream value:  -0.70799804205
# mean upstream value:  -0.465114427649
# std upstream value:  0.0953527541158
# minimum downstream value:  -0.704397209077
# mean upstream value:  -0.385920146394
# std upstream value:  0.0618362936098
# minimum downstream value:  -0.755478327453
# mean upstream value:  -0.332111182734
# std upstream value:  0.0144028852357
# minimum downstream value:  -0.796931330866
# mean upstream value:  -0.31199909356
# std upstream value:  0.0228150208288
# 840
# (41, 41)
# 798
# 757
# 716
# 675
# 634
# 593
# 552
# 511
# 470
# 429
# 387
# 10   10
# 346
# 304
# 262
# 221
# 180
# 138
# 97
# 56
# 55
# node:  201003.0
# minimum downstream value:  -0.504067643358
# mean upstream value:  -0.184374340595
# std upstream value:  0.0058329703187
# 840
# (41, 41)
# 799
# 757
# 716
# 674
# 673
# 631
# 590
# 548
# 507
# 465
# 424
# 10   10
# 382
# 340
# 299
# 257
# 215
# 174
# 133
# 91
# 132
# node:  205732.0
# minimum downstream value:  -0.63206753335
# mean upstream value:  -0.671614173216
# std upstream value:  0.0705893852309
# minimum downstream value:  -0.640547198269
# mean upstream value:  -0.713003246523
# std upstream value:  0.0254949397799
# minimum downstream value:  -0.640547198269
# mean upstream value:  -0.683024329787
# std upstream value:  0.0624719766921
# minimum downstream value:  -0.651797811033
# mean upstream value:  -0.664580173015
# std upstream value:  0.0466671872914
# minimum downstream value:  -0.651797811033
# mean upstream value:  -0.685909024969
# std upstream value:  0.0684544182848
# minimum downstream value:  -0.688731438558
# mean upstream value:  -0.743000377308
# std upstream value:  0.0354669118349
# minimum downstream value:  -0.748229136109
# mean upstream value:  -0.76419300587
# std upstream value:  0.00570071489857
# minimum downstream value:  -0.748229136109
# mean upstream value:  -0.74236316706
# std upstream value:  0.0300853708132
# minimum downstream value:  -0.748229136109
# mean upstream value:  -0.725024599018
# std upstream value:  0.023358752347
# minimum downstream value:  -0.702049164904
# mean upstream value:  -0.679252694875
# std upstream value:  0.0430896427281
# minimum downstream value:  -0.766035720765
# mean upstream value:  -0.678209106284
# std upstream value:  0.0425963864391
# 840
# (41, 41)
# 800
# 760
# 720
# 680
# 640
# 599
# 559
# 519
# 479
# 480
# 440
# 10   10
# 441
# 442
# 402
# 362
# 321
# 280
# 240
# 200
# 201
# node:  225216.0
# minimum downstream value:  -0.842909982553
# mean upstream value:  -0.140044482486
# std upstream value:  0.0145103606997
# 840
# (41, 41)
# 799
# 757
# 716
# 676
# 635
# 594
# 553
# 512
# 471
# 430
# 389
# 10   10
# 348
# 307
# 266
# 225
# 184
# 143
# 102
# 60
# 59
# node:  238095.0
# minimum downstream value:  -0.747960509048
# mean upstream value:  -0.0878069529577
# std upstream value:  0.0282879457225
# 840
# (41, 41)
# 799
# 758
# 716
# 675
# 635
# 594
# 553
# 512
# 471
# 430
# 389
# 10   10
# 348
# 307
# 266
# 225
# 184
# 143
# 102
# 61
# 60
# node:  238895.0
# minimum downstream value:  -0.785877092083
# mean upstream value:  -0.132762682768
# std upstream value:  0.0499797869157
# 840
# (41, 41)
# 800
# 801
# 761
# 721
# 722
# 682
# 683
# 643
# 603
# 604
# 605
# 10   10
# 565
# 566
# 567
# 527
# 528
# 529
# 489
# 449
# 408
# node:  239628.0
# minimum downstream value:  -0.432191630126
# mean upstream value:  -0.272262432516
# std upstream value:  0.0696041965536
# minimum downstream value:  -0.468897521731
# mean upstream value:  -0.209201938393
# std upstream value:  0.0782925045558
# minimum downstream value:  -0.468897521731
# mean upstream value:  -0.112026973518
# std upstream value:  0.0626315441604
# 840
# (41, 41)
# 798
# 757
# 717
# 676
# 635
# 594
# 553
# 512
# 471
# 430
# 388
# 10   10
# 348
# 308
# 267
# 226
# 186
# 144
# 103
# 63
# 62
# node:  266098.0
# minimum downstream value:  -0.626154360564
# mean upstream value:  -0.561722907467
# std upstream value:  0.144543964344
# minimum downstream value:  -0.675419984599
# mean upstream value:  -0.423563317662
# std upstream value:  0.181927935666
# minimum downstream value:  -0.675419984599
# mean upstream value:  -0.290498796345
# std upstream value:  0.0491066150365
# minimum downstream value:  -0.675419984599
# mean upstream value:  -0.274321223122
# std upstream value:  0.0276831662374
# minimum downstream value:  -0.655713228369
# mean upstream value:  -0.314097770118
# std upstream value:  0.0360354077955
# minimum downstream value:  -0.671933984568
# mean upstream value:  -0.339893124949
# std upstream value:  0.0222642373815
# minimum downstream value:  -0.671933984568
# mean upstream value:  -0.366556843593
# std upstream value:  0.0164181319058
# minimum downstream value:  -0.671933984568
# mean upstream value:  -0.379865925303
# std upstream value:  0.0215476805557
# minimum downstream value:  -0.357521509465
# mean upstream value:  -0.395364271322
# std upstream value:  0.00478285760795
# minimum downstream value:  -0.308988789796
# mean upstream value:  -0.405621635427
# std upstream value:  0.0101158321117
# minimum downstream value:  -0.360564099941
# mean upstream value:  -0.422060397303
# std upstream value:  0.0217744024089
# 840
# (41, 41)
# 798
# 797
# 796
# 795
# 794
# 834
# 874
# 873
# 872
# 871
# 870
# 10   10
# 869
# 868
# 867
# 866
# 865
# 823
# 822
# 821
# 780
# node:  273714.0
# minimum downstream value:  -0.469134786855
# mean upstream value:  -0.0826639167876
# std upstream value:  0.00430777612318
# 840
# (41, 41)
# 799
# 758
# 759
# 719
# 679
# 639
# 598
# 557
# 516
# 475
# 434
# 10   10
# 392
# 351
# 310
# 269
# 228
# 186
# 146
# 147
# 148
# node:  279341.0
# minimum downstream value:  -0.55087943699
# mean upstream value:  -0.430837598557
# std upstream value:  0.029751439801
# minimum downstream value:  -0.547300677997
# mean upstream value:  -0.454306661533
# std upstream value:  0.00750815722193
# minimum downstream value:  -0.508255909554
# mean upstream value:  -0.438026398067
# std upstream value:  0.0207489918214
# minimum downstream value:  -0.372353414302
# mean upstream value:  -0.446052199453
# std upstream value:  0.0255048553952
# minimum downstream value:  -0.38971176449
# mean upstream value:  -0.457349211802
# std upstream value:  0.0349795256013
# minimum downstream value:  -0.459096071748
# mean upstream value:  -0.487105981477
# std upstream value:  0.0138481555159
# minimum downstream value:  -0.459096071748
# mean upstream value:  -0.513500550362
# std upstream value:  0.0237705872355
# minimum downstream value:  -0.460118953418
# mean upstream value:  -0.530744067608
# std upstream value:  0.0220804660312
# minimum downstream value:  -0.460118953418
# mean upstream value:  -0.537716107877
# std upstream value:  0.0122250852913
# minimum downstream value:  -0.46778236359
# mean upstream value:  -0.495466430825
# std upstream value:  0.0542024656917
# minimum downstream value:  -0.494009990466
# mean upstream value:  -0.393525818434
# std upstream value:  0.116067811186
# 840
# (41, 41)
# 800
# 759
# 718
# 677
# 637
# 596
# 555
# 514
# 474
# 433
# 392
# 10   10
# 351
# 309
# 268
# 227
# 186
# 145
# 104
# 63
# 62
# node:  286930.0
# minimum downstream value:  -0.464144378783
# mean upstream value:  -0.156524577788
# std upstream value:  0.0162205038092
# 840
# (41, 41)
# 799
# 759
# 718
# 677
# 637
# 596
# 555
# 513
# 472
# 432
# 391
# 10   10
# 350
# 309
# 268
# 228
# 188
# 147
# 106
# 65
# 66
# node:  291122.0
# minimum downstream value:  -0.308498457958
# mean upstream value:  -0.0249130791826
# std upstream value:  0.0279245959986
# 840
# (41, 41)
# 800
# 760
# 761
# 762
# 804
# 805
# 847
# 848
# 849
# 850
# 892
# 10   10
# 934
# 935
# 977
# 1019
# 1061
# 1062
# 1063
# 1022
# 982
# node:  297459.0
# minimum downstream value:  -0.444598412796
# mean upstream value:  -0.364513171049
# std upstream value:  0.0440623014709
# minimum downstream value:  -0.444598412796
# mean upstream value:  -0.282313290321
# std upstream value:  0.0743138818172
# minimum downstream value:  -0.444587436118
# mean upstream value:  -0.222942970487
# std upstream value:  0.069498003146
# minimum downstream value:  -0.444587436118
# mean upstream value:  -0.183558005432
# std upstream value:  0.0141798256301
# 840
# (41, 41)
# 841
# 801
# 802
# 803
# 804
# 764
# 765
# 807
# 808
# 850
# 891
# 10   10
# 932
# 933
# 934
# 894
# 936
# 977
# 1018
# 1019
# 1061
# node:  300562.0
# minimum downstream value:  -0.389671717708
# mean upstream value:  -0.383089128376
# std upstream value:  0.0206246322444
# minimum downstream value:  -0.389671717708
# mean upstream value:  -0.360608690184
# std upstream value:  0.0240292959361
# minimum downstream value:  -0.375743639799
# mean upstream value:  -0.336511503881
# std upstream value:  0.0451182747665
# minimum downstream value:  -0.403645149804
# mean upstream value:  -0.285715336856
# std upstream value:  0.0386631778665
# minimum downstream value:  -0.403645149804
# mean upstream value:  -0.251685744375
# std upstream value:  0.0217675000227
# minimum downstream value:  -0.403645149804
# mean upstream value:  -0.235462776757
# std upstream value:  0.00339675801767
# minimum downstream value:  -0.402188146538
# mean upstream value:  -0.248656100749
# std upstream value:  0.0220406097176
# minimum downstream value:  -0.392631078426
# mean upstream value:  -0.249602949823
# std upstream value:  0.0213842477665
# minimum downstream value:  -0.392631078426
# mean upstream value:  -0.235756332538
# std upstream value:  0.0358751600812
# minimum downstream value:  -0.334746831962
# mean upstream value:  -0.198312068331
# std upstream value:  0.0281268346346
# minimum downstream value:  -0.282156601254
# mean upstream value:  -0.178049079985
# std upstream value:  0.0102603915027
# 840
# (41, 41)
# 800
# 801
# 761
# 720
# 679
# 639
# 599
# 559
# 517
# 476
# 436
# 10   10
# 396
# 354
# 313
# 272
# 231
# 190
# 149
# 109
# 68
# node:  303562.0
# minimum downstream value:  -0.921227979095
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 924
# 966
# 967
# 968
# 928
# 929
# 930
# 931
# 891
# 892
# 10   10
# 893
# 894
# 854
# 814
# 815
# 774
# 734
# 694
# 695
# node:  307000.0
# minimum downstream value:  -0.499061795563
# mean upstream value:  -0.191602905434
# std upstream value:  0.0328244403085
# 840
# (41, 41)
# 799
# 758
# 717
# 675
# 634
# 592
# 550
# 508
# 466
# 424
# 383
# 10   10
# 343
# 302
# 261
# 220
# 180
# 139
# 99
# 59
# 60
# node:  308964.0
# minimum downstream value:  -0.489997833614
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 801
# 761
# 721
# 680
# 639
# 598
# 557
# 516
# 474
# 433
# 10   10
# 392
# 351
# 311
# 270
# 230
# 189
# 148
# 107
# 67
# node:  311853.0
# minimum downstream value:  -0.360671333645
# mean upstream value:  -0.200919330984
# std upstream value:  0.0527052212332
# minimum downstream value:  -0.360671333645
# mean upstream value:  -0.3187444031
# std upstream value:  0.120697960278
# minimum downstream value:  -0.360671333645
# mean upstream value:  -0.336766983052
# std upstream value:  0.105949443267
# minimum downstream value:  -0.336244243878
# mean upstream value:  -0.351471630795
# std upstream value:  0.0972033445443
# minimum downstream value:  -0.327547940341
# mean upstream value:  -0.262337344123
# std upstream value:  0.0353390022546
# minimum downstream value:  -0.207985014784
# mean upstream value:  -0.278939590153
# std upstream value:  0.0423162448423
# minimum downstream value:  -0.261646255674
# mean upstream value:  -0.252094133098
# std upstream value:  0.0423320056901
# minimum downstream value:  -0.486601938843
# mean upstream value:  -0.322973922307
# std upstream value:  0.0847153983463
# minimum downstream value:  -0.486601938843
# mean upstream value:  -0.360411753296
# std upstream value:  0.0956435090481
# minimum downstream value:  -0.486601938843
# mean upstream value:  -0.444655547814
# std upstream value:  0.0237534630878
# minimum downstream value:  -0.305760198902
# mean upstream value:  -0.447936770473
# std upstream value:  0.0223975071411
# 840
# (41, 41)
# 799
# 758
# 718
# 678
# 679
# 639
# 599
# 558
# 517
# 476
# 435
# 10   10
# 394
# 353
# 312
# 270
# 229
# 187
# 146
# 105
# 64
# node:  313188.0
# minimum downstream value:  -0.424600834903
# mean upstream value:  -0.0264390787117
# std upstream value:  0.0142593595586
# 840
# (41, 41)
# 800
# 760
# 720
# 680
# 640
# 599
# 559
# 518
# 477
# 435
# 395
# 10   10
# 354
# 313
# 272
# 231
# 190
# 150
# 109
# 69
# 70
# node:  314727.0
# minimum downstream value:  -0.354250218086
# mean upstream value:  -0.0115900454314
# std upstream value:  0.00550181048243
# 840
# (41, 41)
# 799
# 757
# 716
# 675
# 634
# 593
# 551
# 510
# 469
# 428
# 387
# 10   10
# 345
# 304
# 263
# 222
# 181
# 140
# 99
# 139
# 138
# node:  321760.0
# minimum downstream value:  -0.546179006222
# mean upstream value:  -0.413945576262
# std upstream value:  0.0400541296294
# minimum downstream value:  -0.497153421636
# mean upstream value:  -0.364647504683
# std upstream value:  0.0537381833734
# minimum downstream value:  -0.462459157107
# mean upstream value:  -0.315483605909
# std upstream value:  0.0308863179818
# minimum downstream value:  -0.389618523036
# mean upstream value:  -0.378687078303
# std upstream value:  0.119726179734
# minimum downstream value:  -0.450226312569
# mean upstream value:  -0.440982059685
# std upstream value:  0.112172293153
# minimum downstream value:  -0.450226312569
# mean upstream value:  -0.516564692119
# std upstream value:  0.0240458191227
# minimum downstream value:  -0.450226312569
# mean upstream value:  -0.496636673396
# std upstream value:  0.0113946583573
# minimum downstream value:  -0.433478555189
# mean upstream value:  -0.528842528975
# std upstream value:  0.0415495048185
# minimum downstream value:  -0.358131861027
# mean upstream value:  -0.534444977329
# std upstream value:  0.0401079826877
# minimum downstream value:  -0.547742278208
# mean upstream value:  -0.500069197302
# std upstream value:  0.084664489182
# minimum downstream value:  -0.547742278208
# mean upstream value:  -0.397986491207
# std upstream value:  0.102467082139
# 840
# (41, 41)
# 798
# 757
# 717
# 676
# 635
# 595
# 554
# 513
# 473
# 432
# 392
# 10   10
# 352
# 353
# 313
# 273
# 232
# 192
# 151
# 110
# 68
# node:  346791.0
# minimum downstream value:  -0.72537388255
# mean upstream value:  -0.684719844612
# std upstream value:  0.100317871688
# minimum downstream value:  -0.72537388255
# mean upstream value:  -0.657001600906
# std upstream value:  0.0663122419703
# minimum downstream value:  -0.794869404065
# mean upstream value:  -0.655756773214
# std upstream value:  0.0661084172897
# minimum downstream value:  -0.794869404065
# mean upstream value:  -0.659640949234
# std upstream value:  0.0611356933665
# minimum downstream value:  -0.814651670192
# mean upstream value:  -0.495543428403
# std upstream value:  0.184420134773
# minimum downstream value:  -0.814651670192
# mean upstream value:  -0.273759080487
# std upstream value:  0.238883131369
# minimum downstream value:  -0.814651670192
# mean upstream value:  -0.0797347921942
# std upstream value:  0.112762024514
# minimum downstream value:  -0.731496939075
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 881
# 923
# 964
# 1006
# 1007
# 1049
# 1050
# 1051
# 1052
# 1094
# 1135
# 10   10
# 1176
# 1217
# 1218
# 1219
# 1261
# 1303
# 1345
# 1346
# 1388
# node:  346997.0
# minimum downstream value:  -0.584072550295
# mean upstream value:  -0.365990358536
# std upstream value:  0.032923315095
# minimum downstream value:  -0.56847070988
# mean upstream value:  -0.340641991737
# std upstream value:  0.0132149602933
# minimum downstream value:  -0.56847070988
# mean upstream value:  -0.340942503435
# std upstream value:  0.0136371910733
# minimum downstream value:  -0.522674439924
# mean upstream value:  -0.36405737755
# std upstream value:  0.0269284657673
# minimum downstream value:  -0.462973613513
# mean upstream value:  -0.401569874076
# std upstream value:  0.0350240518244
# minimum downstream value:  -0.456806409029
# mean upstream value:  -0.418990747102
# std upstream value:  0.0197237218715
# minimum downstream value:  -0.409274979542
# mean upstream value:  -0.415044570943
# std upstream value:  0.0240675195908
# minimum downstream value:  -0.359205645535
# mean upstream value:  -0.402735613394
# std upstream value:  0.011222082864
# minimum downstream value:  -0.360107180629
# mean upstream value:  -0.408968034626
# std upstream value:  0.0179919400646
# minimum downstream value:  -0.398835072875
# mean upstream value:  -0.427357388422
# std upstream value:  0.0138550914417
# minimum downstream value:  -0.445767368724
# mean upstream value:  -0.426234108343
# std upstream value:  0.0153651029195
# 840
# (41, 41)
# 800
# 801
# 761
# 721
# 680
# 638
# 597
# 556
# 515
# 475
# 434
# 10   10
# 393
# 352
# 311
# 269
# 228
# 187
# 146
# 105
# 64
# node:  353065.0
# minimum downstream value:  -0.260529408813
# mean upstream value:  -0.188384286029
# std upstream value:  0.00940074801396
# minimum downstream value:  -0.302937624483
# mean upstream value:  -0.192334402534
# std upstream value:  0.0149167313704
# minimum downstream value:  -0.302937624483
# mean upstream value:  -0.202917046227
# std upstream value:  0.0165388216735
# minimum downstream value:  -0.302937624483
# mean upstream value:  -0.217165699432
# std upstream value:  0.00380392783987
# minimum downstream value:  -0.293026648962
# mean upstream value:  -0.222038098161
# std upstream value:  0.00489085328445
# minimum downstream value:  -0.201412758808
# mean upstream value:  -0.231429912984
# std upstream value:  0.0092321578181
# minimum downstream value:  -0.201412758808
# mean upstream value:  -0.244002471642
# std upstream value:  0.0131297826848
# minimum downstream value:  -0.213263108325
# mean upstream value:  -0.252986259611
# std upstream value:  0.00664317873124
# minimum downstream value:  -0.21591041776
# mean upstream value:  -0.255050679283
# std upstream value:  0.00398837936233
# minimum downstream value:  -0.222323572212
# mean upstream value:  -0.257598153216
# std upstream value:  0.00736974254554
# minimum downstream value:  -0.22788030451
# mean upstream value:  -0.265655879447
# std upstream value:  0.0118145611399
# 840
# (41, 41)
# 841
# 883
# 884
# 885
# 886
# 887
# 888
# 848
# 849
# 850
# 810
# 10   10
# 811
# 771
# 731
# 732
# 733
# 693
# 652
# 610
# 568
# node:  373495.0
# minimum downstream value:  -0.639392355214
# mean upstream value:  -0.573758372833
# std upstream value:  0.0605262081469
# minimum downstream value:  -0.649666646724
# mean upstream value:  -0.534506454769
# std upstream value:  0.0052194831322
# minimum downstream value:  -0.690971404667
# mean upstream value:  -0.502911513659
# std upstream value:  0.046154803931
# minimum downstream value:  -0.690971404667
# mean upstream value:  -0.475853881032
# std upstream value:  0.0466464959528
# minimum downstream value:  -0.690971404667
# mean upstream value:  -0.419375292711
# std upstream value:  0.0336468233063
# minimum downstream value:  -0.659328777328
# mean upstream value:  -0.383952305408
# std upstream value:  0.0481630519419
# minimum downstream value:  -0.659328777328
# mean upstream value:  -0.351124478266
# std upstream value:  0.0165227413613
# minimum downstream value:  -0.541573023136
# mean upstream value:  -0.343893581385
# std upstream value:  0.00858430149101
# minimum downstream value:  -0.541573023136
# mean upstream value:  -0.336565181044
# std upstream value:  0.0189431737862
# minimum downstream value:  -0.541573023136
# mean upstream value:  -0.320886503881
# std upstream value:  0.0211148780068
# minimum downstream value:  -0.447953054556
# mean upstream value:  -0.302011884405
# std upstream value:  0.00652274376042
# 840
# (41, 41)
# 799
# 757
# 715
# 673
# 632
# 591
# 590
# 589
# 547
# 546
# 505
# 10   10
# 463
# 422
# 380
# 339
# 298
# 256
# 215
# 174
# 132
# node:  378784.0
# minimum downstream value:  -0.361349233997
# mean upstream value:  -0.248766189193
# std upstream value:  0.0142709834935
# minimum downstream value:  -0.361349233997
# mean upstream value:  -0.235843341812
# std upstream value:  0.00400470562085
# minimum downstream value:  -0.276331724385
# mean upstream value:  -0.186215366771
# std upstream value:  0.068259663148
# minimum downstream value:  -0.276331724385
# mean upstream value:  -0.137794866549
# std upstream value:  0.0653425202279
# minimum downstream value:  -0.276331724385
# mean upstream value:  -0.0610682471154
# std upstream value:  0.0432066777483
# 840
# (41, 41)
# 881
# 882
# 883
# 884
# 926
# 927
# 928
# 970
# 1012
# 1013
# 1054
# 10   10
# 1096
# 1138
# 1179
# 1180
# 1181
# 1182
# 1183
# 1184
# 1185
# node:  391060.0
# minimum downstream value:  -0.596152083205
# mean upstream value:  -0.435525283512
# std upstream value:  0.00654954273176
# minimum downstream value:  -0.485785201604
# mean upstream value:  -0.449123337335
# std upstream value:  0.0188948351947
# minimum downstream value:  -0.434121595541
# mean upstream value:  -0.450362978245
# std upstream value:  0.0175931266334
# minimum downstream value:  -0.434121595541
# mean upstream value:  -0.451284737769
# std upstream value:  0.0173255116832
# minimum downstream value:  -0.433477348961
# mean upstream value:  -0.457249094846
# std upstream value:  0.0254071467536
# minimum downstream value:  -0.433477348961
# mean upstream value:  -0.469811842847
# std upstream value:  0.0183836258871
# minimum downstream value:  -0.444372244974
# mean upstream value:  -0.469317892323
# std upstream value:  0.0189959379544
# minimum downstream value:  -0.47427151043
# mean upstream value:  -0.442361180804
# std upstream value:  0.0241336077566
# minimum downstream value:  -0.47427151043
# mean upstream value:  -0.396644521922
# std upstream value:  0.047150276201
# minimum downstream value:  -0.47427151043
# mean upstream value:  -0.38065101915
# std upstream value:  0.0341615702099
# minimum downstream value:  -0.492164581661
# mean upstream value:  -0.376249853644
# std upstream value:  0.0305944406493
# 840
# (41, 41)
# 798
# 757
# 716
# 675
# 633
# 592
# 551
# 509
# 468
# 427
# 385
# 10   10
# 343
# 301
# 260
# 219
# 178
# 136
# 95
# 54
# 53
# node:  395288.0
# minimum downstream value:  -0.911737494789
# mean upstream value:  -0.0713522688674
# std upstream value:  0.016600858629
# 840
# (41, 41)
# 841
# 883
# 924
# 965
# 925
# 967
# 968
# 1010
# 1052
# 1094
# 1095
# 10   10
# 1096
# 1097
# 1098
# 1140
# 1181
# 1223
# 1265
# 1306
# 1307
# node:  413905.0
# minimum downstream value:  -0.212040354612
# mean upstream value:  -0.153600639977
# std upstream value:  0.0115273889867
# minimum downstream value:  -0.184492028278
# mean upstream value:  -0.142818124241
# std upstream value:  0.00848388121378
# minimum downstream value:  -0.18029266478
# mean upstream value:  -0.142467433442
# std upstream value:  0.00799859262181
# minimum downstream value:  -0.170878534732
# mean upstream value:  -0.150088947281
# std upstream value:  0.0112971260371
# minimum downstream value:  -0.170878534732
# mean upstream value:  -0.156350116956
# std upstream value:  0.00391476582899
# minimum downstream value:  -0.170878534732
# mean upstream value:  -0.165644347903
# std upstream value:  0.0116405521277
# minimum downstream value:  -0.167207378644
# mean upstream value:  -0.165539204996
# std upstream value:  0.0116753969971
# minimum downstream value:  -0.1545731013
# mean upstream value:  -0.164287139933
# std upstream value:  0.0130091898918
# minimum downstream value:  -0.153521028903
# mean upstream value:  -0.15862739573
# std upstream value:  0.00628915583815
# minimum downstream value:  -0.161885981503
# mean upstream value:  -0.163980958961
# std upstream value:  0.0113308214364
# minimum downstream value:  -0.161885981503
# mean upstream value:  -0.176856522189
# std upstream value:  0.00984967983014
# 840
# (41, 41)
# 841
# 801
# 761
# 721
# 722
# 682
# 683
# 643
# 644
# 645
# 604
# 10   10
# 564
# 524
# 525
# 485
# 486
# 487
# 447
# 407
# 367
# node:  419349.0
# minimum downstream value:  -0.344363849625
# mean upstream value:  -0.361048641883
# std upstream value:  0.00872459805837
# minimum downstream value:  -0.344363849625
# mean upstream value:  -0.372466920393
# std upstream value:  0.0204786073461
# minimum downstream value:  -0.344363849625
# mean upstream value:  -0.376877856349
# std upstream value:  0.0158583165481
# minimum downstream value:  -0.354967803352
# mean upstream value:  -0.378854784256
# std upstream value:  0.0151648049142
# minimum downstream value:  -0.364661295895
# mean upstream value:  -0.368170415303
# std upstream value:  0.00544032336104
# minimum downstream value:  -0.364661295895
# mean upstream value:  -0.366048096668
# std upstream value:  0.00798132958642
# minimum downstream value:  -0.369459431162
# mean upstream value:  -0.371979041219
# std upstream value:  0.0156482906008
# minimum downstream value:  -0.398916131423
# mean upstream value:  -0.357130249184
# std upstream value:  0.0289443532178
# minimum downstream value:  -0.398916131423
# mean upstream value:  -0.355256574427
# std upstream value:  0.0291451643975
# minimum downstream value:  -0.398916131423
# mean upstream value:  -0.342978013834
# std upstream value:  0.0148189637764
# minimum downstream value:  -0.375390214882
# mean upstream value:  -0.342835558262
# std upstream value:  0.0150176205786
# 840
# (41, 41)
# 799
# 757
# 716
# 675
# 634
# 593
# 553
# 512
# 471
# 429
# 387
# 10   10
# 346
# 304
# 262
# 221
# 179
# 138
# 97
# 55
# 54
# node:  420841.0
# minimum downstream value:  -0.385156804865
# mean upstream value:  -0.0367596089761
# std upstream value:  0.0428113117959
# 840
# (41, 41)
# 882
# 923
# 964
# 1005
# 1047
# 1088
# 1129
# 1170
# 1211
# 1252
# 1294
# 10   10
# 1335
# 1376
# 1417
# 1459
# 1500
# 1541
# 1583
# 1625
# 1585
# node:  425109.0
# minimum downstream value:  -0.362451364872
# mean upstream value:  -0.336862596756
# std upstream value:  0.0455682639833
# minimum downstream value:  -0.360969995793
# mean upstream value:  -0.328958423398
# std upstream value:  0.0559815206889
# minimum downstream value:  -0.360969995793
# mean upstream value:  -0.288076609334
# std upstream value:  0.0724988111207
# minimum downstream value:  -0.360969995793
# mean upstream value:  -0.263079737486
# std upstream value:  0.0383251289321
# minimum downstream value:  -0.277874007998
# mean upstream value:  -0.294475610705
# std upstream value:  0.0536677254318
# minimum downstream value:  -0.34388558007
# mean upstream value:  -0.303428076944
# std upstream value:  0.0415841539605
# minimum downstream value:  -0.388828202199
# mean upstream value:  -0.31468202694
# std upstream value:  0.0470833393588
# minimum downstream value:  -0.388828202199
# mean upstream value:  -0.309919113541
# std upstream value:  0.044062509623
# minimum downstream value:  -0.388828202199
# mean upstream value:  -0.325439855201
# std upstream value:  0.0224556929965
# minimum downstream value:  -0.313837586655
# mean upstream value:  -0.30384450719
# std upstream value:  0.0219063578298
# minimum downstream value:  -0.348349107584
# mean upstream value:  -0.245111276981
# std upstream value:  0.0618847560301
# 840
# (41, 41)
# 841
# 842
# 843
# 885
# 886
# 887
# 888
# 889
# 931
# 932
# 892
# 10   10
# 934
# 935
# 977
# 978
# 979
# 1021
# 1022
# 1064
# 1105
# node:  430675.0
# minimum downstream value:  -0.583612856658
# mean upstream value:  -0.12601411641
# std upstream value:  0.0231465627241
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 804
# 764
# 765
# 766
# 767
# 768
# 769
# 10   10
# 770
# 771
# 772
# 773
# 733
# 775
# 776
# 777
# 736
# node:  443243.0
# minimum downstream value:  -0.268067733101
# mean upstream value:  -0.229292637118
# std upstream value:  0.0103859964375
# minimum downstream value:  -0.268067733101
# mean upstream value:  -0.236075460361
# std upstream value:  0.0135187061989
# minimum downstream value:  -0.268067733101
# mean upstream value:  -0.244044770051
# std upstream value:  0.00312022048442
# minimum downstream value:  -0.254527095749
# mean upstream value:  -0.248019292578
# std upstream value:  0.00546087545076
# minimum downstream value:  -0.246711580178
# mean upstream value:  -0.240104222957
# std upstream value:  0.0122241613777
# minimum downstream value:  -0.228030118075
# mean upstream value:  -0.239248323503
# std upstream value:  0.0122102491013
# minimum downstream value:  -0.242597014536
# mean upstream value:  -0.245101546739
# std upstream value:  0.0199096585991
# minimum downstream value:  -0.248378587806
# mean upstream value:  -0.274562187346
# std upstream value:  0.030434232781
# minimum downstream value:  -0.248378587806
# mean upstream value:  -0.297198470245
# std upstream value:  0.0179593322202
# minimum downstream value:  -0.254520582116
# mean upstream value:  -0.311915743178
# std upstream value:  0.00404851907697
# minimum downstream value:  -0.254520582116
# mean upstream value:  -0.292101713037
# std upstream value:  0.0275319587607
# 840
# (41, 41)
# 882
# 924
# 925
# 926
# 927
# 928
# 929
# 930
# 890
# 891
# 933
# 10   10
# 974
# 1014
# 1055
# 1097
# node:  448619.0
# minimum downstream value:  -1.42645372232
# mean upstream value:  -1.29565904137
# std upstream value:  0.153336443946
# minimum downstream value:  -1.42645372232
# mean upstream value:  -1.22474218075
# std upstream value:  0.126422810737
# minimum downstream value:  -1.42242962381
# mean upstream value:  -1.19708718361
# std upstream value:  0.0921842734813
# minimum downstream value:  -1.41431182741
# mean upstream value:  -0.951525500955
# std upstream value:  0.432206704951
# minimum downstream value:  -1.41966157091
# mean upstream value:  -0.549221837945
# std upstream value:  0.552280794236
# minimum downstream value:  -1.41966157091
# mean upstream value:  -0.114303005857
# std upstream value:  0.161648861103
# 840
# (41, 41)
# 881
# 922
# 963
# 1004
# 1044
# 1085
# 1125
# 1166
# 1207
# 1248
# 1289
# 10   10
# 1331
# 1372
# 1413
# 1454
# 1495
# 1537
# 1579
# 1621
# 1581
# node:  461116.0
# minimum downstream value:  -1.11648993813
# mean upstream value:  -0.951048638667
# std upstream value:  0.0718962324364
# minimum downstream value:  -1.11648993813
# mean upstream value:  -0.869438885072
# std upstream value:  0.127671430577
# minimum downstream value:  -1.11648993813
# mean upstream value:  -0.737417188401
# std upstream value:  0.0912952824844
# minimum downstream value:  -0.984896452531
# mean upstream value:  -0.694918586017
# std upstream value:  0.0421669594959
# minimum downstream value:  -0.984896452531
# mean upstream value:  -0.679553206573
# std upstream value:  0.0386101941793
# minimum downstream value:  -1.03162670512
# mean upstream value:  -0.73168044662
# std upstream value:  0.0483624328165
# minimum downstream value:  -1.03162670512
# mean upstream value:  -0.759622727144
# std upstream value:  0.061498180252
# minimum downstream value:  -1.03162670512
# mean upstream value:  -0.780212844627
# std upstream value:  0.0329378075898
# minimum downstream value:  -0.857056870291
# mean upstream value:  -0.774550607553
# std upstream value:  0.0318775687339
# minimum downstream value:  -0.729561063141
# mean upstream value:  -0.728931854208
# std upstream value:  0.04043392811
# minimum downstream value:  -0.729561063141
# mean upstream value:  -0.634944991161
# std upstream value:  0.134549426738
# 840
# (41, 41)
# 881
# 923
# 964
# 1006
# 1047
# 1089
# 1130
# 1171
# 1213
# 1254
# 1295
# 10   10
# 1336
# 1377
# 1418
# 1459
# 1501
# 1543
# 1585
# 1586
# 1628
# node:  462060.0
# minimum downstream value:  -1.21762229708
# mean upstream value:  -1.2728596764
# std upstream value:  0.0701022906218
# minimum downstream value:  -1.22327709575
# mean upstream value:  -1.28813651868
# std upstream value:  0.0828743087148
# minimum downstream value:  -1.26513840747
# mean upstream value:  -1.34601320611
# std upstream value:  0.0180030139072
# minimum downstream value:  -1.36589442317
# mean upstream value:  -1.3651804968
# std upstream value:  0.0137507209282
# minimum downstream value:  -1.36589442317
# mean upstream value:  -1.28123914394
# std upstream value:  0.117963568256
# minimum downstream value:  -1.36589442317
# mean upstream value:  -1.22204585823
# std upstream value:  0.114436884189
# minimum downstream value:  -1.32332360792
# mean upstream value:  -1.080473205
# std upstream value:  0.0906847731783
# minimum downstream value:  -1.36736047315
# mean upstream value:  -1.09521102403
# std upstream value:  0.0984461537084
# minimum downstream value:  -1.36736047315
# mean upstream value:  -0.9810798253
# std upstream value:  0.136832741187
# minimum downstream value:  -1.38082547998
# mean upstream value:  -0.912067639498
# std upstream value:  0.178031877324
# minimum downstream value:  -1.38082547998
# mean upstream value:  -0.71898798886
# std upstream value:  0.103005119364

# %%
def get_key(val, my_dict):
    gullies_to_keep = []
    for key, value in my_dict.items(): 
         if val == value:
                gullies_to_keep.append(key)
    return gullies_to_keep

# %%
gullies_to_keep_node_list = get_key('yes', divergence_dict)

# %%
len(gullies_to_keep_node_list)
# Out:
# 34

# %%
outlet_ids = np.isin(grid_nodes,gullies_to_keep_node_list).astype('uint8')

# %%
pd.DataFrame.from_dict(divergence_dict, orient='index')
# Out:
#             0
# 27349.0    no
# 28156.0    no
# 36941.0   yes
# 91894.0   yes
# 97498.0   yes
# ...       ...
# 430675.0  yes
# 443243.0   no
# 448619.0   no
# 461116.0   no
# 462060.0   no
#
# [61 rows x 1 columns]

# %%
# easiest option here is to take a subset of the node grid and get the nodes from the watershed grid cells

# %%
def singleUpstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, import_drainage_area, 
                         import_dfme, catchment_outlet_ids, step_size_m, comparison_distance_m,  
                         slope_above_head, min_depth, gh_elevation):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        
        #da_subset_copy = np.copy(import_drainage_area)
        import_da_subset = import_drainage_area[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        flattened_import_da = import_da_subset.reshape(da.shape)
        
        #dfme_subset_copy = np.copy(import_dfme)
        import_dfme_subset = import_dfme[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        flattened_import_dfme = import_dfme_subset.reshape(da.shape)
                
        grid_nodes_subset = grid_nodes[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        
        flattened_grid_nodes_subset = grid_nodes_subset.reshape(da.shape)
        
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.

        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        print(central_node)
        print(mg1.shape)
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)
        

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        node_dfme_dict = {}
        original_node_id_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            upstream_dfme_dict = {};
            upstream_original_node_id = {}
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_import_da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})
                        original_node_id = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_grid_nodes_subset))
                        upstream_original_node_id.update({node_id_value:original_node_id})
                        node_dfme = np.amin(np.multiply(isolate_candidate_grid_cells, flattened_import_dfme))
                        upstream_dfme_dict.update({node_id_value:node_dfme})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    node_dfme_dict[primary_flow_direction_id] = upstream_dfme_dict[primary_flow_direction_id]
                    original_node_id_dict[primary_flow_direction_id] = upstream_original_node_id[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        dfme_along_central_drainage_line = []
        for key, value in node_dfme_dict.items():
            dfme_along_central_drainage_line.append(value)
        median_dfme_along_central_drainage_line = ndimage.median_filter(dfme_along_central_drainage_line, size=step_size_m)

        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        original_node_id_along_central_drainage_line = []
        for key, value in original_node_id_dict.items():
            original_node_id_along_central_drainage_line.append(value)
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_dfme_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            divergence_occuring = checkGullyHead(dfme_along_central_drainage_line, 
                                                    step_size, comparison_distance, min_depth, gh_elevation)
            upslope_divergence_dict[i] = divergence_occuring
    

    
    return original_node_id_along_central_drainage_line, slope_along_central_drainage_line,dfme_along_central_drainage_line

# %%
start_time = timeit.default_timer()
catchment_outlet_id = [291122]
node_drainage_line, slope_values, dfme_values = singleUpstreamDrainageLine(20, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_ha, DFME,catchment_outlet_id, 3, 3, 10, -0.2, -0.2)
timeit.default_timer() - start_time
# Out:
# 840
# (41, 41)
# minimum downstream value:  -0.308498457958
# mean upstream value:  -0.0249130791826
# std upstream value:  0.0279245959986
# 0.15674700000090525

# %%
node_location = mg.nodes.reshape(da.shape)

# %%
preliminary_width = np.isin(node_location,node_drainage_line).reshape(mg.shape)

# %%
gully_drainage_values_dict = dict(zip(node_drainage_line, slope_values))

# %%
slope_drainage_values_dict = dict(zip(node_drainage_line, slope_values))
dfme_drainage_values_dict = dict(zip(node_drainage_line, dfme_values))

ds = [slope_drainage_values_dict, dfme_drainage_values_dict]
d = {}
for k in slope_drainage_values_dict.keys():
    d[k] = tuple(d[k] for d in ds) 

new_drainage_parameters = pd.DataFrame.from_dict(d, orient='index')
new_drainage_parameters.rename(columns={0:'Slope', 1:'DFME'}, inplace=True)
new_drainage_parameters.insert(0, "Distance", 0);
for i in range(0, distance_from_outlet):
    new_drainage_parameters.iloc[i,0] = i
new_drainage_parameters['Node ID'] = new_drainage_parameters.index

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
data = new_drainage_parameters

y1 = "DFME"
y2 = "Slope"

sns.lineplot(data = data,x = "Distance",y = y1, color = 'xkcd:cobalt blue')
ax1.set_ylabel(y1, fontsize=15)
#ax1.lines[0].set_linestyle("--")
ax1.set_ylim(-0.5, 0.5)
ax1.set_xlabel('Distance upstream of convergence point (m)', fontsize = 15)
ax1.legend([y1],bbox_to_anchor=(0.3, 0.21, 0.53, 0.6))
ax2 = ax1.twinx()

ax2.set_ylim(-0.0,0.15)
sns.lineplot(data=data,x = "Distance",y=y2,color='xkcd:forest green',ax = ax2)
ax2.set_ylabel(y2, fontsize = 15)
ax2.lines[0].set_linestyle("--")
ax2.legend([y2],bbox_to_anchor=(0.3, 0.5, 0.5, 0.4))
plt.axvline(x=17, color = 'xkcd:merlot', linestyle = 'dotted')
plt.axvline(x=20, color = 'xkcd:merlot', linestyle = 'dotted')
#ax1.text(18, -0.8, r'Gully head', fontsize=15, rotation = 90)
plt.title('Change in upstream values for DFME and PC', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Change in upstream values for DFME and PC')

# %%
algorithm_end_point = new_drainage_parameters['Distance'].max()
algorithm_start_point = new_drainage_parameters['Distance'].min()

# %%
gh = new_drainage_parameters.loc[new_drainage_parameters['Distance'] == algorithm_end_point,
                                                  'Node ID'].values[0]


cp = new_drainage_parameters.loc[new_drainage_parameters['Distance'] == algorithm_start_point,
                                                  'Node ID'].values[0]

# %%
cp
# Out:
# 139604

# %% [markdown]
# # GH needs to be changed to the point the kernel decides the head is at rather than just the maximum distance. Need to collect this at the time the kernel is deciding whether to keep the guilly head or not.
#
# # or maybe 5m upstream of gully head because this will give a better approximation of gully orientation.

# %% [markdown]
# # Get node values from subset and then map them back to node values for larger dem (easy becauise the difference in (x,y) coordinates is the same.

# %%
gh_lat = np.where(grid_nodes == gh)[0][0]
cp_lat = np.where(grid_nodes == cp)[0][0]
gh_lon = np.where(grid_nodes == gh)[1][0]
cp_lon = np.where(grid_nodes == cp)[1][0]

lat_displacement = cp_lat - gh_lat
lon_displacement = gh_lon - cp_lon

# %%
# a^2 + b^2 = c^2
gully_length = np.sqrt(lat_displacement**2 + lon_displacement**2)
gully_length
# Out:
# 18.027756377319946

# %%
if lat_displacement > 0 and lon_displacement > 0:
    angle_max = 90
    angle_min = 0
    quadrant = 1
    print('Quadrant = Q1', 'min angle', str(angle_min), 'max angle', str(angle_max))
elif lat_displacement > 0 and lon_displacement < 0:
    angle_max = 360
    angle_min = 270
    quadrant = 2
    print('Quadrant = Q2', 'min angle', str(angle_min), 'max angle', str(angle_max))
elif lat_displacement < 0 and lon_displacement < 0:
    angle_max = 270
    angle_min = 180
    quadrant = 3
    print('Quadrant = Q3', 'min angle', str(angle_min), 'max angle', str(angle_max))
else:
    angle_max = 180
    angle_min = 90
    quadrant = 4
    print('Quadrant = Q4', 'min angle', str(angle_min), 'max angle', str(angle_max))

theta_a = np.degrees(np.arctan(np.abs(lat_displacement)/np.abs(lon_displacement)))

if quadrant == 1:
    gully_orientation = angle_max - theta_a
elif quadrant == 2:
    gully_orientation = angle_min + theta_a
elif quadrant == 3:
    gully_orientation = angle_max - theta_a
else:
    gully_orientation = angle_min + theta_a
# Out:
# Quadrant = Q2 min angle 270 max angle 360

# %%
gully_orientation
# Out:
# 356.82016988013578

# %%
class GullyOrientation:
    """Convention for first direction to take (d1) in cross section method 
    follows directional convention used in Landlab."""
    possible_angles = np.array([90, 0, 270, 180, 45, 315, 225, 135, 360])
    def __init__(self, angle, outlet, grid_shape):
        self.angle = angle
        self.outlet = outlet
        self.grid_shape = grid_shape
        idx = (np.abs(self.possible_angles - self.angle)).argmin() 
        find_angle_from_list = self.possible_angles[idx]
        self.closest_angle = find_angle_from_list

    def cross_section(self, line_length):
        cross_section_nodes_d1 = [self.outlet]
        cross_section_nodes_d2 = [self.outlet]
        if self.closest_angle == 90 or self.closest_angle == 270:
            print('east-west gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - self.grid_shape[1]
                next_node_d2 = current_node_d2 + self.grid_shape[1]
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        elif self.closest_angle == 0 or self.closest_angle == 180 or self.closest_angle == 360:
            print('north-south gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]
                print(current_node_d1)
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 + 1
                next_node_d2 = current_node_d2 - 1
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        elif self.closest_angle == 45 or self.closest_angle == 225:
            print('northeast-southwest gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - (self.grid_shape[1] + 1)
                next_node_d2 = current_node_d2 + (self.grid_shape[1] + 1)
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)
        else:
            print('northwest-southeast gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - (self.grid_shape[1] - 1)
                next_node_d2 = current_node_d2 + (self.grid_shape[1] - 1)
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        cross_section_nodes = np.array(list(set(cross_section_nodes_d1 + cross_section_nodes_d2)))
        return cross_section_nodes

# %%
gully_outlet_id = catchment_outlet_id[0]

# %%
# need to just use subset dem here to make the next steps fast
# gully_outlet_id also needs to be the id from the dem subset and not the larger dem

# %%
gully_and_cross_section = GullyOrientation(gully_orientation, gully_outlet_id, mg.shape)

# %%
line_length = 20

cross_section_nodes = gully_and_cross_section.cross_section(line_length)
# Out:
# north-south gully
# 140403
# 140404
# 140405
# 140406
# 140407
# 140408
# 140409
# 140410
# 140411
# 140412
# 140413
# 140414
# 140415
# 140416
# 140417
# 140418
# 140419
# 140420
# 140421
# 140422

# %%
cross_section_mask = np.isin(node_location,cross_section_nodes).reshape(mg.shape)
cross_section_image = cross_section_mask.astype('uint8')

cross_section_slope = np.copy(slope).astype('float32')
cross_section_slope[~cross_section_mask] = np.nan

cross_section_dfme = np.copy(dfme).astype('float32')
cross_section_dfme[~cross_section_mask] = np.nan

cross_section_area = np.copy(catchment_area_ha).astype('float32')
cross_section_area[~cross_section_mask] = np.nan

cross_section_nodes = np.copy(grid_nodes).astype('float32')
cross_section_nodes[~cross_section_mask] = np.nan

cross_section_elevation_prep = np.copy(input_DEM).astype('float32')
cross_section_elevation_prep[~cross_section_mask] = np.nan
cross_section_elevation = cross_section_elevation_prep - np.nanmin(cross_section_elevation_prep)

cross_section_dfme_line = cross_section_elevation_prep - np.nanmean(cross_section_elevation_prep)

lat = grid_nodes.shape[0]
lon = grid_nodes.shape[1]
nodes_1d = np.squeeze(grid_nodes.reshape(1, lat * lon))
cross_section_dfme_1d = np.squeeze(cross_section_dfme.reshape(1, lat * lon))
cross_section_slope_1d = np.squeeze(cross_section_slope.reshape(1, lat * lon))

cross_section_area_1d = np.squeeze(cross_section_area.reshape(1, lat * lon))

cross_section_elevation_1d = np.squeeze(cross_section_elevation.reshape(1, lat * lon))
cross_section_dfme_line_1d = np.squeeze(cross_section_dfme_line.reshape(1, lat * lon))

node_cross_section_dfme_dict = {}
for A, B in zip(nodes_1d, cross_section_dfme_1d):
    node_cross_section_dfme_dict[A] = B

dfme_cross_section_unordered = { key:value for key, value in node_cross_section_dfme_dict.items() if ~np.isnan(value) }

node_cross_section_slope_dict = {}
for A, B in zip(nodes_1d, cross_section_slope_1d):
    node_cross_section_slope_dict[A] = B

slope_cross_section_unordered = { key:value for key, value in node_cross_section_slope_dict.items() if ~np.isnan(value)}

node_cross_section_area_dict = {}
for A, B in zip(nodes_1d, cross_section_area_1d):
    node_cross_section_area_dict[A] = B

area_cross_section_unordered = { key:value for key, value in node_cross_section_area_dict.items() if ~np.isnan(value) }

node_cross_section_elevation_dict = {}
for A, B in zip(nodes_1d, cross_section_elevation_1d):
    node_cross_section_elevation_dict[A] = B

elevation_cross_section_unordered = { key:value for key, 
                                     value in node_cross_section_elevation_dict.items() if ~np.isnan(value) }

node_cross_section_dfme_line_dict = {}
for A, B in zip(nodes_1d, cross_section_dfme_line_1d):
    node_cross_section_dfme_line_dict[A] = B

dfme_line_cross_section_unordered = { key:value for key, 
                                     value in node_cross_section_dfme_line_dict.items() if ~np.isnan(value) }

ds = [dfme_cross_section_unordered,  
      slope_cross_section_unordered, area_cross_section_unordered, 
     elevation_cross_section_unordered, dfme_line_cross_section_unordered]
d = {}
for k in dfme_cross_section_unordered.keys():
    d[k] = tuple(d[k] for d in ds)

cross_section_parameters = pd.DataFrame.from_dict(d)

cross_section_parameters.rename(index={0:'DFME', 1: 'Slope', 
                                       2: 'Area', 3: 'Elevation', 4: 'DFME Line'}, inplace=True)

cross_section_parameters_transpose = cross_section_parameters.T

cross_section_parameters_transpose.insert(0, "Distance", 0)

for i in range(0, (line_length * 2)+1):
    if i < line_length:
        cross_section_parameters_transpose.iloc[i,0] = -line_length + i
    else:
        cross_section_parameters_transpose.iloc[i,0] = i - line_length

cumulative_cross_section_parameters = cross_section_parameters_transpose.cumsum()

cross_section_parameters_transpose['Cumulative DFME'] = cumulative_cross_section_parameters.iloc[:,1]

cross_section_parameters_transpose['Cumulative S'] = cumulative_cross_section_parameters.iloc[:,3]
cross_section_parameters_transpose['Cumulative A'] = cumulative_cross_section_parameters.iloc[:,4]


extract_slope = cross_section_parameters_transpose['Slope'].values

cross_section_parameters_transpose['Slope Range'] = generic_filter(extract_slope, data_range, 
                                                                       footprint= (1, 3), mode='nearest');

extract_dfme = cross_section_parameters_transpose['DFME'].values

cross_section_parameters_transpose['DFME Range'] = generic_filter(extract_dfme, data_range, 
                                                                       footprint= (1, 3), mode='nearest');

# %% [markdown]
# To find the endpoints of the line at the head of the gully, all i need to do is move n units in the direction of the gully orientation from the end points of the cross section line. Can use same rules from the GullOrientation class.

# %% [markdown]
# Note: Method below requires that the outlet_id (A) is at least 10 grid cells from the edge of the DEM. In the paper can just say gullies near edges were not used because it risks moving window values being affected.

# %% [markdown]
# ## Scheme for finding all grid cells along the desired line.
#
# Four possible line:
#
# (1) north-south, north direction == outlet_id - mg.shape[1], south direction == outlet_id + mg.shape[1]
#
# (2) east-west, east = outlet_id + 1, west == outlet_id - 1
#
# (3) northeast-southwest, northeast == outlet_id - (mg.shape[1] - 1), southwest == outlet_id + (mg.shape[1] - 1)
#
# (4) northwest-southeast, northwest == outlet_id - (mg.shape[1] + 1), southeast == outlet_id + (mg.shape[1] + 1)

# %% [markdown]
# # Calculate the cumulative summary of each variable.

# %%
dCDFMEdx = np.gradient(cross_section_parameters_transpose.loc[:,'DFME'].values)
d2CDFMEdx2 = np.gradient(dCDFMEdx)
 
dCSdx = np.gradient(cross_section_parameters_transpose.loc[:,'Slope'].values)
d2CSdx2 = np.gradient(dCSdx)

dCAdx = np.gradient(cross_section_parameters_transpose.loc[:,'Area'].values)
d2CAdx2 = np.gradient(dCAdx)

cross_section_parameters_transpose['dCDFMEdx'] = dCDFMEdx
cross_section_parameters_transpose['dCSdx'] = dCSdx
cross_section_parameters_transpose['dCAdx'] = dCAdx


cross_section_parameters_transpose['d2CDFMEdx2'] = d2CDFMEdx2
cross_section_parameters_transpose['d2CSdx2'] = d2CSdx2
cross_section_parameters_transpose['d2CAdx2'] = d2CAdx2

# %%
cross_section_parameters_transpose_spline = pd.DataFrame(np.arange(-100,100)/(100.0/line_length), columns = ['Distance'])

# %%
spline_smoothness = np.linspace(-line_length,line_length, 200)
spline_input_distance = cross_section_parameters_transpose.loc[:,'Distance'].values

spline_input_dfme = cross_section_parameters_transpose.loc[:,'DFME'].values
dfme_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme)
dfme_spline = dfme_spline_setup(spline_smoothness)

spline_input_dfme = cross_section_parameters_transpose.loc[:,'Cumulative DFME'].values
cdfme_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme)
cdfme_spline = cdfme_spline_setup(spline_smoothness)

spline_input_slope = cross_section_parameters_transpose.loc[:,'Slope'].values
slope_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_slope)
slope_spline = slope_spline_setup(spline_smoothness)

spline_input_slope_range = cross_section_parameters_transpose.loc[:,'Slope Range'].values
slope_range_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_slope_range)
slope_range_spline = slope_range_spline_setup(spline_smoothness)

spline_input_area = cross_section_parameters_transpose.loc[:,'Area'].values
area_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_area)
area_spline = area_spline_setup(spline_smoothness)

spline_input_dfme_range = cross_section_parameters_transpose.loc[:,'DFME Range'].values
dfme_range_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme_range)
dfme_range_spline = dfme_range_spline_setup(spline_smoothness)

spline_input_dfme_line = cross_section_parameters_transpose.loc[:,'DFME Line'].values
dfme_line_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dfme_line)
dfme_line_spline = dfme_line_spline_setup(spline_smoothness)

spline_input_elevation_range = cross_section_parameters_transpose.loc[:,'Elevation'].values
elevation_range_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_elevation_range)
elevation_range_spline = elevation_range_spline_setup(spline_smoothness)

spline_input_d2CDFMEdx2 = cross_section_parameters_transpose.loc[:,'d2CDFMEdx2'].values
d2CDFMEdx2_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_d2CDFMEdx2)
d2CDFMEdx2_spline = d2CDFMEdx2_spline_setup(spline_smoothness)

spline_input_dCDFMEdx = cross_section_parameters_transpose.loc[:,'dCDFMEdx'].values
dCDFMEdx_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dCDFMEdx)
dCDFMEdx_spline = dCDFMEdx_spline_setup(spline_smoothness)

spline_input_dCSdx = cross_section_parameters_transpose.loc[:,'dCSdx'].values
dCSdx_spline_setup = InterpolatedUnivariateSpline(spline_input_distance, spline_input_dCSdx)
dCSdx_spline = dCSdx_spline_setup(spline_smoothness)

cross_section_parameters_transpose_spline['DFMEL Spline'] = dfme_line_spline
cross_section_parameters_transpose_spline['Elevation Spline'] = elevation_range_spline
cross_section_parameters_transpose_spline['DFMER Spline'] = dfme_range_spline
cross_section_parameters_transpose_spline['DFME Spline'] = dfme_spline
cross_section_parameters_transpose_spline['Cumulative DFME Spline'] = cdfme_spline

cross_section_parameters_transpose_spline['A Spline'] = area_spline
cross_section_parameters_transpose_spline['Slope Spline'] = slope_spline
cross_section_parameters_transpose_spline['SR Spline'] = slope_range_spline
cross_section_parameters_transpose_spline['d2CDFMEdx2 Spline'] = d2CDFMEdx2_spline

cross_section_parameters_transpose_spline['dCDFMEdx Spline'] = dCDFMEdx_spline

cross_section_parameters_transpose_spline['dCSdx Spline'] = dCSdx_spline

# %% [markdown]
# # Possible rules
# 1. Find peak in second derivative of DFME and then the first point it cross the x-axis.
# 2. Find point that PC goes from large negative to positive and then point that it crosses x-axis.
# 3. Some combination of 1 & 2. E.g. condition 1 only if first part of condition 2 is also met.
#
# Probably just the first is best but can still talk about considering PC and show graph.

# %% [markdown]
# ## Can use DFME together with one of slope, pc, area and then use a sum of squares approach to test which of the three models works best on all ~30 gullies.

# %% [markdown]
# # Three possible rules:
#
# Just have set maximum distance same as flow line. For edges can be 15m in each direction. The the edge will always just be the maximum DFME or rate of change of DFME (second derivative?).
#
# 1. Find peak DFME.
#
# 2. Combination DFME and Slope Range. Just look for peak DFME followed by sections of low slope range (<5?) and DFME is within delta of the 0 line.
#
# 3. Combined DFME, PC and Slope. Look for DFME peak precded by clear - to + PC change and followed by low slope range (<5?) and DFME is within delta of the 0 line.
#
# Increasing complexity, least squares will see if complexity is needed or not.
#
# Then digitise edges for sample of 30 and do least squares assessment of the three methods.

# %% [markdown]
# # Maybe the simplest rule is to find spots where slope is low and DFME is 0.
# # Or just find peak in DFME.

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (15, 8))
x_value = "Distance"
y1_value = "DFME Spline"
y2_value = "SR Spline"
sns.lineplot(data = cross_section_parameters_transpose_spline, x = x_value, y = y1_value, 
             color = 'xkcd:royal purple')
ax1.set_ylabel(y1_value, fontsize=20)
#ax1.annotate('Thalweg', arrowprops = dict(facecolor = 'black'), xy = (0, -23), xytext = (1, -29))
#ax1.lines[0].set_linestyle("--")
ax1.set_ylim(-1, 1)
ax1.set_xlabel('Distance from thalwag (m)', fontsize = 20)
ax1.legend([y1_value],bbox_to_anchor=(0.375, 0.6, 0.5, 0.4))
ax2 = ax1.twinx()
ax2.set_ylim(-10, 10)
sns.lineplot(data = cross_section_parameters_transpose_spline, x = x_value, y = y2_value
             , color = 'xkcd:forest green', ax = ax2)
ax2.lines[0].set_linestyle("--")
#ax2.set_ylabel(y2_value, fontsize = 15)
ax2.set_ylabel(y2_value, fontsize = 20)
ax2.legend([y2_value],bbox_to_anchor=(0.375, 0.55, 0.5, 0.4))
plt.axvline(x=11, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axvline(x=-12, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axvline(x=0, color = 'xkcd:cobalt blue', linewidth = 1, alpha = 0.5, linestyle = 'dotted')
plt.axhline(y=0, color = 'xkcd:cobalt blue', linewidth = 1, alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=0, color = 'xkcd:cobalt blue', alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=11, color = 'xkcd:pumpkin', linestyle = 'dotted')
ax1.text(-12.5, -0.5, r'Left Edge', fontsize=15, rotation = 90)
ax1.text(10.5, -0.5, r'Right Edge', fontsize=15, rotation = 90)
plt.title('Gully cross section DFME and slope', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'Gully cross section DFME and slope')

# %% [markdown]
# #

# %% [markdown]
# ## Second derivative works best because the highest rate is the middle of the wall going up and the point that then crosses the x-axis when the increase stops being positive (immediately after passing up over the edge of the gully) - straight from graph theory.

# %% [markdown]
# ## First derivative.

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "d2CDFMEdx2 Spline", 
             color = 'xkcd:royal purple')
ax1.set_ylabel('DFME (m)', fontsize=15)
#ax1.annotate('Transition', arrowprops = dict(facecolor = 'black'), xy = (15.5, 0), xytext = (7, 0.06))
#ax1.lines[0].set_linestyle("--")
#ax1.set_ylim(-0.5, 0.5)
ax1.set_xlabel('Distance downstream (m)', fontsize = 15)
ax1.legend(['DFME'],bbox_to_anchor=(0.4, 0.6, 0.5, 0.4))
ax2 = ax1.twinx()
#ax2.set_ylim(-0.2, 0.2)
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "S Spline", 
             color = 'xkcd:forest green', ax = ax2)
ax2.lines[0].set_linestyle("--")
ax2.set_ylabel('PC (rad / 100m)', fontsize = 15)
ax2.legend(['PC'],bbox_to_anchor=(0.375, 0.5, 0.5, 0.4))
plt.axvline(x=7, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axhline(y=0, color = 'xkcd:cobalt blue', alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=6.5, color = 'xkcd:pumpkin', linestyle = 'dotted')
ax1.text(11.5, -0.075, r'Gully head', fontsize=15, rotation = 90)
plt.title('Second derivative of DFME and PC cumulative upstream sum', fontsize = 20)

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "S Spline", 
             color = 'xkcd:forest green')
ax1.set_ylabel('DFME (m)', fontsize=15)
#ax1.annotate('Transition', arrowprops = dict(facecolor = 'black'), xy = (15.5, 0), xytext = (7, 0.06))
ax1.lines[0].set_linestyle("--")
#ax1.set_ylim(-0.4, 0.4)
ax1.set_xlabel('Distance downstream (m)', fontsize = 15)
ax1.legend(['DFME'],bbox_to_anchor=(0.4, 0.6, 0.5, 0.4))
ax2 = ax1.twinx()
ax2.set_ylim(-0.6, 0.6)
sns.lineplot(data = cross_section_parameters_transpose_spline, x = "Distance", y = "d2CDFMEdx2 Spline", 
             color = 'xkcd:royal purple', ax = ax2)
#ax2.lines[0].set_linestyle("--")
ax2.set_ylabel('PC (rad / 100m)', fontsize = 15)
ax2.legend(['PC'],bbox_to_anchor=(0.375, 0.5, 0.5, 0.4))
plt.axvline(x=3, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axvline(x=-4, color = 'xkcd:apricot', linewidth = 14, alpha = 0.5)
plt.axhline(y=0, color = 'xkcd:cobalt blue', alpha = 0.5, linestyle = 'dotted')
#plt.axvline(x=6.5, color = 'xkcd:pumpkin', linestyle = 'dotted')
ax1.text(-4.5, 35, r'L. edge', fontsize=15, rotation = 90)
ax1.text(2.5, 35, r'R. edge', fontsize=15, rotation = 90)
plt.title('Second derivative of DFME and PC cumulative upstream sum', fontsize = 20)

# %%
# Extract the data we're interested in
dfme, dist = cross_section_parameters_transpose['DFME'], cross_section_parameters_transpose['Distance']
pc, slope = cross_section_parameters_transpose['PC'], cross_section_parameters_transpose['Slope']

# Scatter the points, using size and color but no label
plt.scatter(dist, dfme, label=None,
            c=pc, cmap='viridis',
            s=slope, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('Distance')
plt.ylabel('Difference from mean elevation')
plt.colorbar(label='slope')
plt.clim(-0.1, 0.1)

# Here we create a legend:

# we'll plot empty lists with the desired size and label
for slope in [1, 2, 5]:
    plt.scatter([], [], c='k', alpha=0.3, s=slope,
                label=str(slope) + ' ha')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='Gully plot')

plt.title('California Cities: Area and Population');

# %%
cross_section_parameters_transpose_spline.head()

# %%
cross_section_parameters_transpose['PC'].nunique()

# %%
sns.set(style="white")

f = sns.relplot(x="Distance", y="DFME", hue="PC", size="Slope",
            sizes=(20, 200), alpha=.5, height=6, data=cross_section_parameters_transpose)

plt.axhline(y=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')
plt.axvline(x=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')
f.set(ylim = (-0.5, 0.5))

# %% [markdown]
# ## Organise one field of the dataframe into categories so that I can use the palettes in below plot. n_colors below refers to the number of categories assigned to 'name'.

# %%
bins = [-0.2, -0.1, -0.05, -0.01, 0, 0.01, 0.05, 0.1, 0.2]
names = ['- 0.2','- 0.1', '- 0.05', '- 0.01', '0.01', '0.05','0.1', '0.2']

cross_section_parameters_transpose['Profile Curvature'] = pd.cut(cross_section_parameters_transpose['PC'], 
                                                                 bins, labels=names)

# %%
filtered_pc = np.copy(cross_section_parameters_transpose['PC'].values)
filtered_pc[filtered_pc < 0] = np.nan
cross_section_parameters_transpose['PC Filtered'] = filtered_pc

# %%
filtered_dfme = np.copy(cross_section_parameters_transpose['DFME'].values)
filtered_dfme[filtered_dfme < 0.05] = np.nan
cross_section_parameters_transpose['DFME Filtered'] = filtered_dfme

# %%
filtered_slope = np.copy(cross_section_parameters_transpose['Slope'].values)
filtered_slope[filtered_slope < 10] = np.nan
cross_section_parameters_transpose['Slope Filtered'] = filtered_slope

# %% [markdown]
# ### Three simple models are:
#
# 1. Just DFME peak near thalweg.
# 2. DFME peak plus positive PC.
# 3. DFME peak, positive PC and low slope range.

# %%
# Load the example planets dataset
#palette = sns.diverging_palette(10, 220, sep=1, n=8)
palette = sns.color_palette('RdBu')
sns.set(style = 'ticks')
fig, ax = plt.subplots(figsize =(12,9))
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
f = sns.scatterplot(x="Distance", y="DFME Filtered",
                     hue="PC", size="Slope",
                     palette=cmap, sizes=(20, 200),
                     data=cross_section_parameters_transpose)
f.set(ylim = (-1, 1))
f.set(xlim = (-30, 30))
plt.axhline(y=0, color = 'xkcd:merlot', alpha = 0.2, linestyle = '--')
plt.axvline(x=0, color = 'xkcd:merlot', alpha = 0.2, linestyle = '--')

# %%
cross_section_parameters_transpose.drop(columns=['PC Filtered', 'DFME Filtered', 'Slope Filtered']);

# %%
#sns.set(style="whitegrid")
sns.set(style = 'ticks')
#palette = sns.color_palette("RdBu", n_colors = 6)
palette = sns.diverging_palette(10, 220, sep=1, n=8)
# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="Distance", y="DFME", hue="Profile Curvature", size="Slope", palette = palette, sizes = (20, 200),
             alpha=.8, height=6, data=cross_section_parameters_transpose)
#f.set(ylim = (-0.3, 0.3))
plt.axhline(y=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')
plt.axvline(x=0, color = 'xkcd:black', alpha = 0.2, linestyle = '--')

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('wpw4.tif', input_geotiff, preliminary_width, drainage_area.dtype)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
