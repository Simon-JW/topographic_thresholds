# %%
# %%capture
#from jupyterthemes import jtplot
#jtplot.style()
import numpy as np
import operator
import seaborn as sns; sns.set()
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
from scipy import stats
from scipy.stats import sem
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from pylab import show, figure
from landlab.plot.imshow import imshow_grid 

# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure
from matplotlib.lines import Line2D
# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120)
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()
from statsmodels.formula.api import ols
from scipy.stats import t
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def slopeWindowMperM(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_m_per_m = rise_run
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_m_per_m
def catchmentDicts(area_grid, gn, gh_nodes):
    """Creates a dictionary of node ID:catcment area values."""
    area_dict = {}
    nodes = gh_nodes
    x_axis_length = gn.shape[1]
    for i in nodes:
        row = int(np.floor(i / x_axis_length))
        col = int(i - (row*x_axis_length))
        area = area_grid[row,col]
        area_dict[i] = area
    return area_dict
def upslopeDivergence(catchment_area_list, change_detection_factor, step_size, comparison_distance):
    
    """"Looks at whether catchment area is increasing at any point upstream of a gully head.
    
    - 'catchment_area_list' is an ordered list of node catchment areas moving upstream.
    
    - 'change_detection_factor' is the percentage increase required for the function to consider the change
    to represent a point of divergent flow.
    
    - 'step_size' is the number of grid cells to be compared in downstream to upstream groups. E.g. step_size == 1 
    will compare node 1 and node 2, but step_size == 2 will compare node 1 and 2 to node 3 and 4.
    
    - 'comparison_distance' is the distance between the downstream nodes being compared to upstream nodes."""
    
    max_value_length = len(catchment_area_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = catchment_area_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptreat_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = catchment_area_list[start_of_upstream_nodes:end_of_usptreat_nodes]
        
        required_catchment_area_increase = max(downstream_nodes) + (max(downstream_nodes) * change_detection_factor)
        
        if all(nodes >= required_catchment_area_increase for nodes in upstream_nodes):
            divergence = 1
            break
        else:
            divergence = 0
    return divergence
def findGullyHeadNode(gully_heads, grid_nodes, DEM, ca, input_DEM_resolution, 
                      distance_from_node, contributing_fraction, required_ca):
    
    catchment_area_dict = {}
    catchment_area_node_list = []
    distance_from_node = int(np.ceil(distance_from_node/input_DEM_resolution))

    for i in gully_heads:

        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset = DEM[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        #################################################################################################
        ca_subset = ca[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        print('max ca: ', np.amax(ca_subset))
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');

        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');
        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);
        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        for j in range(0, distance_from_node):
            # Begin at the point (node) digitized as the intersection between the central flow line and the gully head.
            if j == 0:
                candidate_gridcell = catchment_outlet_id;
            else:
                candidate_gridcell = next_cell_downstream;
            # Get all receiver nodes of the current node.
            grid_cell_receiver_nodes = frp[candidate_gridcell,:];
            # Check if there is a node that receives >= 'contributing_fraction' from the current node.
            candidate_gridcell_list = [candidate_gridcell]
            node_ca_int = catchmentDicts(ca_subset, grid_nodes_sub, candidate_gridcell_list) # Find the node's contributing area.
            node_ca = node_ca_int[candidate_gridcell]
            print('Node id: ', candidate_gridcell, 'Catchment area: ', node_ca)
            if np.amax(grid_cell_receiver_nodes) < contributing_fraction or node_ca < required_ca:
                # Check if this is the last possible grid cell in the subset that could meet the criteria. If so, then there
                # is no suitable grid cell (node).
                if j == distance_from_node - 1:
                    catchment_area_dict[i] = 'No grid cell found'
                else:
                    # Otherwise, find the next downslope grid cell receiving the highest proportion of flow and check that 
                    # in the next iteration.
                    index_next_cell_downstream = np.where(grid_cell_receiver_nodes == np.amax(grid_cell_receiver_nodes))[0][0];
                    next_cell_downstream = frn[candidate_gridcell, index_next_cell_downstream];
            else:
                # Find the position of the gridcell (node) that meets the criteria both in the subset and in the whole DEM
                # and record the node ID.
                final_node_index_lat =  np.where(grid_nodes_sub == candidate_gridcell)[0][0]
                final_node_index_lon =  np.where(grid_nodes_sub == candidate_gridcell)[1][0]
                
                # Find the offest between the index position of the node the loop ends on, and the index position of
                # the node that it started on. 
                final_lat_offset = final_node_index_lat - node_lat
                final_lon_offset = final_node_index_lon - node_lon
                # Then apply this offest to the index position of the starting node with respect top the whole DEM to find the 
                # node ID of the grid cell that met the criteria above.
                final_row_index = row_index + final_lat_offset
                final_col_index = col_index + final_lon_offset
                node_of_area_record = grid_nodes[final_row_index, final_col_index] # - this range is more than 1
                catchment_area_dict[i] = node_of_area_record
                catchment_area_node_list.append(node_of_area_record)
                break
                             
    return catchment_area_dict, catchment_area_node_list
def upstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, catchment_outlet_ids, 
                         step_size_m, comparison_distance_m, change_detection_factor, slope_above_head):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        print(target_distance, ' ', target_distance * input_DEM_resolution)
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        area_along_central_drainage_line = []
        for key, value in node_area_dict.items():
            area_along_central_drainage_line.append(value)
        median_area_along_central_drainage_line = ndimage.median_filter(area_along_central_drainage_line, size=step_size_m)
        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_area_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            divergence_occuring = upslopeDivergence(median_area_along_central_drainage_line, change_detection_factor, 
                                                    step_size, comparison_distance)
            upslope_divergence_dict[i] = divergence_occuring
            
    return upslope_divergence_dict, slope_dict, slope_at_head
def roundup(x):
    return int(math.ceil(x / 10.0)) * 10
def findPoint5mDownstream(gully_heads, grid_nodes, DEM, ca, input_DEM_resolution, 
                      distance_from_node, contributing_fraction, required_ca):
    
    catchment_area_dict = {}
    catchment_area_node_list = []
    distance_from_node = int(np.ceil(distance_from_node/input_DEM_resolution))

    for i in gully_heads:

        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset = DEM[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        #################################################################################################
        ca_subset = ca[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        print('max ca: ', np.amax(ca_subset))
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');

        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');
        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);
        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.
        drainage_area = da.reshape(mg1.shape);
        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        for j in range(0, distance_from_node):
            # Begin at the point (node) digitized as the intersection between the central flow line and the gully head.
            if j == 0:
                candidate_gridcell = catchment_outlet_id;
            else:
                candidate_gridcell = next_cell_downstream;
            # Get all receiver nodes of the current node.
            grid_cell_receiver_nodes = frp[candidate_gridcell,:];
            # Check if there is a node that receives >= 'contributing_fraction' from the current node.
            candidate_gridcell_list = [candidate_gridcell]
            node_ca_int = catchmentDicts(ca_subset, grid_nodes_sub, candidate_gridcell_list) # Find the node's contributing area.
            node_ca = node_ca_int[candidate_gridcell]
            print('Node id: ', candidate_gridcell, 'Catchment area: ', node_ca)
            if j + 1 < distance_from_node:
                
                # Otherwise, find the next downslope grid cell receiving the highest proportion of flow and check that 
                # in the next iteration.
                index_next_cell_downstream = np.where(grid_cell_receiver_nodes == np.amax(grid_cell_receiver_nodes))[0][0];
                next_cell_downstream = frn[candidate_gridcell, index_next_cell_downstream];
            else:
                print(j)
                # Find the position of the gridcell (node) that meets the criteria both in the subset and in the whole DEM
                # and record the node ID.
                final_node_index_lat =  np.where(grid_nodes_sub == candidate_gridcell)[0][0]
                final_node_index_lon =  np.where(grid_nodes_sub == candidate_gridcell)[1][0]
                
                # Find the offest between the index position of the node the loop ends on, and the index position of
                # the node that it started on. 
                final_lat_offset = final_node_index_lat - node_lat
                final_lon_offset = final_node_index_lon - node_lon
                # Then apply this offest to the index position of the starting node with respect top the whole DEM to find the 
                # node ID of the grid cell that met the criteria above.
                final_row_index = row_index + final_lat_offset
                final_col_index = col_index + final_lon_offset
                node_of_area_record = grid_nodes[final_row_index, final_col_index] # - this range is more than 1
                catchment_area_dict[i] = node_of_area_record
                catchment_area_node_list.append(node_of_area_record)
                break
                             
    return catchment_area_dict, catchment_area_node_list

# %%
input_DEM_resolution = 1
working_resolution = 1

location = (r'C:\PhD\junk')
os.chdir(location)

input_geotiff = gdal.Open('fann_sub.tif')
x = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())
empty_grid_rows = roundup(x.shape[0])
empty_grid_cols = roundup(x.shape[1])
input_DEM = np.zeros([empty_grid_rows,empty_grid_cols])
input_DEM[:x.shape[0], :x.shape[1]] = x

gully_head_layer = gdal.Open('fann_first_gullies.tif')
gh = np.array(gully_head_layer.GetRasterBand(1).ReadAsArray()).astype('uint8')

#input_ca_grid = gdal.Open('wean_t_M8.tif')
#ca_grid = np.array(input_ca_grid.GetRasterBand(1).ReadAsArray())

# %%
flow_acc_surf = np.copy(input_DEM).astype('float64');
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

# %%
grid_nodes = np.array(mg.nodes.reshape(mg.shape))

# %%
grid_nodes_float = grid_nodes.astype('float64')

# %% [markdown]
# ## Isolate all gully head nodes

# %%
find_nodes = np.multiply(gh, grid_nodes);

# %% [markdown]
# ## Create array of only gully head nodes

# %%
gh_array = np.unique(find_nodes);

# %% [markdown]
# ## Turn gully head node array into a list and remove the value 0

# %%
gh_list = gh_array.tolist();
gh_list.remove(0);

# %%
len(gh_list)
# Out:
# 84

# %% [markdown]
# # Run multiple-direction flow routing algorithm

# %%
flow_acc_surf = np.copy(input_DEM).astype('float64');
#################################################################################################
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

sfb = SinkFillerBarnes(mg, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();
fa = FlowAccumulator(mg,
                    surface = 'topographic__elevation',
                    flow_director = 'FlowDirectorMFD',
                    diagonals = True);
fa.run_one_step();
fd = FlowDirectorMFD(mg, 'topographic__elevation', diagonals = True);
fd.run_one_step();

da = np.array(mg.at_node['drainage_area'].round(4))
frn = mg.at_node['flow__receiver_node']
drainage_area = np.flip(da.reshape(mg.shape), 0);
frp = np.array(mg.at_node['flow__receiver_proportions']);
ns = np.flip(mg.status_at_node.reshape(mg.shape), 0)
flow_rec_surf_rows = cols * rows;
flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);

# %%
catchment_area = da.reshape(mg.shape) / (10000 * (1/working_resolution**2))

# %%
plt.figure(figsize=(20,10));
plt.imshow(catchment_area, cmap="gist_earth_r", vmax = 1);
plt.colorbar();

# %% [markdown]
# ### The final variable in the function below sets the threshold catchment area at the point of convergence required to keep the gully head as a candidate. Default set to 0.1 ha.

# %% [markdown]
# ## Work through list finding index positions of each node

# %%
catchment_area_dict, catchment_area_node_list = findGullyHeadNode(gh_list, grid_nodes, input_DEM, catchment_area,
                                                                  input_DEM_resolution, 10, 0.9, 0.1)
# Out:
# max ca:  3.65648347
# Node id:  31 Catchment area:  0.0933974
# Node id:  32 Catchment area:  0.08106677
# Node id:  33 Catchment area:  0.03132792
# Node id:  34 Catchment area:  3.54611183
# max ca:  0.52808658
# Node id:  136 Catchment area:  0.38421774
# Node id:  135 Catchment area:  0.36052781
# max ca:  0.50246575
# Node id:  220 Catchment area:  0.35255183
# Node id:  199 Catchment area:  0.30996469
# Node id:  177 Catchment area:  0.45637822
# max ca:  6.23902207
# Node id:  220 Catchment area:  0.1024091
# Node id:  219 Catchment area:  0.07517685
# Node id:  239 Catchment area:  0.08923097
# Node id:  238 Catchment area:  0.05827129
# Node id:  237 Catchment area:  0.07763689
# Node id:  236 Catchment area:  0.04950791
# Node id:  235 Catchment area:  0.03467515
# Node id:  234 Catchment area:  4.10635547
# Node id:  233 Catchment area:  4.26473655
# max ca:  0.15023029
# Node id:  220 Catchment area:  0.12883921
# max ca:  1.16153837
# Node id:  220 Catchment area:  0.08971981
# Node id:  241 Catchment area:  0.11992408
# max ca:  3.05362491
# Node id:  220 Catchment area:  0.29649912
# max ca:  5.6366411
# Node id:  220 Catchment area:  0.28177259
# Node id:  199 Catchment area:  0.3622248
# max ca:  2.94324158
# Node id:  220 Catchment area:  0.1957894
# max ca:  2.90061656
# Node id:  220 Catchment area:  0.89697893
# Node id:  199 Catchment area:  0.54364661
# max ca:  0.44199118
# Node id:  220 Catchment area:  0.08083179
# Node id:  219 Catchment area:  0.08975857
# Node id:  239 Catchment area:  0.0818705
# Node id:  259 Catchment area:  0.05408843
# Node id:  258 Catchment area:  0.12461489
# Node id:  257 Catchment area:  0.33853268
# max ca:  1.56983993
# Node id:  220 Catchment area:  0.33963255
# Node id:  219 Catchment area:  0.50813055
# Node id:  197 Catchment area:  0.58700398
# Node id:  175 Catchment area:  0.60884741
# Node id:  153 Catchment area:  0.91000117
# max ca:  4.2186646
# Node id:  220 Catchment area:  0.39638405
# max ca:  0.44199118
# Node id:  220 Catchment area:  0.10943555
# Node id:  199 Catchment area:  0.13491326
# Node id:  177 Catchment area:  0.19060335
# max ca:  4.2069128
# Node id:  220 Catchment area:  0.52448521
# max ca:  0.74684382
# Node id:  220 Catchment area:  0.42926189
# Node id:  199 Catchment area:  0.57772611
# Node id:  179 Catchment area:  0.55197917
# max ca:  2.08814586
# Node id:  220 Catchment area:  0.8637849
# Node id:  198 Catchment area:  1.60202748
# max ca:  0.5478007
# Node id:  220 Catchment area:  0.41210737
# max ca:  0.54093604
# Node id:  220 Catchment area:  0.49798828
# max ca:  0.46783682
# Node id:  220 Catchment area:  0.26188651
# max ca:  1.06450156
# Node id:  220 Catchment area:  0.30120161
# max ca:  0.81728002
# Node id:  220 Catchment area:  0.22521042
# Node id:  199 Catchment area:  0.37909144
# max ca:  0.36715581
# Node id:  220 Catchment area:  0.17396272
# max ca:  0.29268769
# Node id:  220 Catchment area:  0.12084728
# Node id:  241 Catchment area:  0.1163091
# Node id:  263 Catchment area:  0.17533564
# Node id:  284 Catchment area:  0.20347512
# Node id:  305 Catchment area:  0.22587296
# max ca:  0.20868251
# Node id:  220 Catchment area:  0.10411693
# Node id:  241 Catchment area:  0.09215291
# Node id:  261 Catchment area:  0.17024639
# max ca:  0.20379528
# Node id:  220 Catchment area:  0.13701652
# max ca:  0.47873511
# Node id:  220 Catchment area:  0.24643771
# Node id:  219 Catchment area:  0.31698267
# Node id:  218 Catchment area:  0.27872252
# Node id:  238 Catchment area:  0.31878452
# Node id:  237 Catchment area:  0.24481843
# max ca:  0.71003526
# Node id:  220 Catchment area:  0.29790197
# Node id:  241 Catchment area:  0.44841017
# max ca:  0.69715653
# Node id:  220 Catchment area:  0.36354799
# Node id:  241 Catchment area:  0.55949925
# max ca:  0.79083468
# Node id:  220 Catchment area:  0.33456415
# Node id:  242 Catchment area:  0.35692275
# max ca:  0.69715653
# Node id:  220 Catchment area:  0.17863093
# Node id:  241 Catchment area:  0.16879734
# Node id:  262 Catchment area:  0.20724423
# Node id:  282 Catchment area:  0.27545884
# max ca:  2.25543466
# Node id:  220 Catchment area:  0.04327824
# Node id:  219 Catchment area:  0.03408287
# Node id:  239 Catchment area:  0.05575755
# Node id:  259 Catchment area:  0.10973552
# max ca:  0.87741893
# Node id:  220 Catchment area:  0.11626007
# Node id:  241 Catchment area:  0.20516347
# Node id:  261 Catchment area:  0.16287064
# max ca:  5.62056987
# Node id:  220 Catchment area:  0.02316423
# Node id:  241 Catchment area:  0.02918124
# Node id:  263 Catchment area:  0.03201365
# Node id:  284 Catchment area:  0.0227565
# Node id:  305 Catchment area:  5.59588144
# Node id:  325 Catchment area:  4.24283308
# max ca:  0.72828008
# Node id:  220 Catchment area:  0.0548612
# Node id:  240 Catchment area:  0.05945943
# Node id:  239 Catchment area:  0.05313351
# Node id:  259 Catchment area:  0.06206517
# Node id:  279 Catchment area:  0.04581279
# Node id:  278 Catchment area:  0.03907692
# Node id:  277 Catchment area:  0.04026263
# Node id:  297 Catchment area:  0.05597677
# Node id:  296 Catchment area:  0.04214398
# Node id:  316 Catchment area:  0.09996231
# max ca:  0.89694714
# Node id:  220 Catchment area:  0.1742356
# max ca:  1.36863428
# Node id:  220 Catchment area:  1.35371061
# max ca:  0.76897681
# Node id:  220 Catchment area:  0.26129815
# Node id:  219 Catchment area:  0.1893863
# Node id:  218 Catchment area:  0.17956901
# max ca:  0.96527415
# Node id:  220 Catchment area:  0.3229425
# Node id:  219 Catchment area:  0.41258939
# Node id:  218 Catchment area:  0.4113661
# Node id:  196 Catchment area:  0.66447911
# max ca:  0.74659841
# Node id:  220 Catchment area:  0.39517227
# max ca:  12.43914435
# Node id:  220 Catchment area:  0.13589936
# Node id:  241 Catchment area:  0.17377988
# max ca:  0.38953159
# Node id:  220 Catchment area:  0.06818095
# Node id:  240 Catchment area:  0.13340891
# Node id:  239 Catchment area:  0.20334271
# Node id:  238 Catchment area:  0.20474288
# Node id:  258 Catchment area:  0.22284086
# max ca:  0.29002906
# Node id:  220 Catchment area:  0.17924358
# max ca:  0.61919253
# Node id:  220 Catchment area:  0.35515078
# Node id:  240 Catchment area:  0.36461277
# Node id:  260 Catchment area:  0.33159234
# max ca:  12.81393721
# Node id:  220 Catchment area:  0.18169128
# Node id:  219 Catchment area:  0.18906132
# max ca:  16.74436243
# Node id:  220 Catchment area:  0.0820412
# Node id:  219 Catchment area:  0.10651035
# Node id:  218 Catchment area:  0.10509637
# max ca:  0.38896968
# Node id:  220 Catchment area:  0.12803315
# Node id:  219 Catchment area:  0.15228101
# Node id:  239 Catchment area:  0.25697499
# Node id:  238 Catchment area:  0.15284256
# Node id:  237 Catchment area:  0.33134434
# max ca:  33.54251522
# Node id:  220 Catchment area:  0.42152125
# Node id:  242 Catchment area:  0.41374433
# max ca:  34.86388949
# Node id:  220 Catchment area:  0.01645964
# Node id:  198 Catchment area:  0.01811228
# Node id:  197 Catchment area:  20.44974928
# max ca:  16.30887271
# Node id:  220 Catchment area:  9.1792411
# Node id:  240 Catchment area:  9.38481241
# Node id:  260 Catchment area:  9.45657391
# max ca:  0.99921252
# Node id:  220 Catchment area:  0.46738145
# Node id:  241 Catchment area:  0.35033585
# max ca:  0.49566887
# Node id:  220 Catchment area:  0.27727096
# Node id:  241 Catchment area:  0.37720148
# max ca:  0.65789048
# Node id:  220 Catchment area:  0.42699514
# Node id:  240 Catchment area:  0.41799233
# max ca:  0.49962698
# Node id:  220 Catchment area:  0.25807246
# Node id:  198 Catchment area:  0.28318574
# max ca:  1.16380335
# Node id:  220 Catchment area:  1.10230258
# Node id:  199 Catchment area:  0.64804553
# max ca:  14.39179933
# Node id:  220 Catchment area:  0.16867149
# Node id:  198 Catchment area:  0.14494147
# Node id:  176 Catchment area:  0.16510111
# Node id:  154 Catchment area:  0.56982144
# max ca:  1.22889424
# Node id:  220 Catchment area:  0.87046182
# max ca:  0.57021905
# Node id:  220 Catchment area:  0.1332199
# Node id:  199 Catchment area:  0.18225969
# Node id:  178 Catchment area:  0.18177658
# Node id:  157 Catchment area:  0.33969287
# max ca:  11.53284368
# Node id:  220 Catchment area:  0.20541687
# Node id:  219 Catchment area:  0.19063969
# Node id:  218 Catchment area:  0.14068449
# Node id:  217 Catchment area:  0.09902067
# Node id:  195 Catchment area:  0.18677268
# Node id:  173 Catchment area:  0.18329955
# Node id:  151 Catchment area:  0.14069527
# Node id:  150 Catchment area:  0.17936244
# max ca:  0.67694893
# Node id:  220 Catchment area:  0.11250168
# Node id:  199 Catchment area:  0.14545928
# Node id:  179 Catchment area:  0.12676874
# Node id:  158 Catchment area:  0.10096835
# Node id:  137 Catchment area:  0.08352279
# Node id:  116 Catchment area:  0.13028826
# Node id:  95 Catchment area:  0.30316831
# Node id:  73 Catchment area:  0.24261952
# max ca:  0.50466443
# Node id:  220 Catchment area:  0.26182223
# Node id:  199 Catchment area:  0.22907423
# max ca:  1.64084051
# Node id:  220 Catchment area:  0.65337288
# Node id:  240 Catchment area:  0.72013757
# max ca:  0.43182269
# Node id:  220 Catchment area:  0.30035848
# Node id:  199 Catchment area:  0.31018738
# max ca:  0.42203825
# Node id:  220 Catchment area:  0.08133003
# Node id:  198 Catchment area:  0.1598637
# Node id:  197 Catchment area:  0.17240305
# max ca:  11.41958864
# Node id:  220 Catchment area:  0.17380777
# Node id:  199 Catchment area:  0.20361782
# Node id:  178 Catchment area:  0.20720414
# max ca:  7.41828062
# Node id:  220 Catchment area:  0.61965466
# Node id:  198 Catchment area:  0.50080922
# Node id:  176 Catchment area:  0.45996542
# max ca:  0.28065469
# Node id:  220 Catchment area:  0.07434826
# Node id:  200 Catchment area:  0.07949636
# Node id:  180 Catchment area:  0.21759889
# max ca:  0.66545596
# Node id:  220 Catchment area:  0.55180887
# Node id:  241 Catchment area:  0.33843274
# max ca:  0.30219573
# Node id:  220 Catchment area:  0.09290475
# Node id:  198 Catchment area:  0.12498443
# Node id:  177 Catchment area:  0.20476187
# Node id:  156 Catchment area:  0.16524082
# max ca:  5.70961313
# Node id:  220 Catchment area:  0.07983853
# Node id:  240 Catchment area:  0.07927697
# Node id:  261 Catchment area:  0.0340182
# Node id:  260 Catchment area:  3.23562134
# max ca:  0.68568867
# Node id:  220 Catchment area:  0.50176034
# max ca:  1.41500916
# Node id:  220 Catchment area:  0.65936711
# max ca:  6.48786522
# Node id:  220 Catchment area:  0.20964592
# Node id:  199 Catchment area:  0.35830463
# max ca:  0.45295164
# Node id:  220 Catchment area:  0.18606369
# Node id:  199 Catchment area:  0.17606061
# Node id:  177 Catchment area:  0.37840224
# max ca:  5.23316625
# Node id:  220 Catchment area:  0.06298492
# Node id:  240 Catchment area:  0.0525304
# Node id:  239 Catchment area:  0.05439467
# Node id:  238 Catchment area:  3.06427937
# max ca:  0.64095025
# Node id:  220 Catchment area:  0.49890321
# max ca:  5.05236434
# Node id:  220 Catchment area:  0.05618796
# Node id:  221 Catchment area:  0.04966677
# Node id:  222 Catchment area:  1.21590991
# max ca:  1.99153803
# Node id:  220 Catchment area:  1.27867146
# Node id:  219 Catchment area:  0.94822822
# Node id:  218 Catchment area:  1.62658545
# max ca:  0.33889534
# Node id:  220 Catchment area:  0.10459305
# Node id:  199 Catchment area:  0.14661326
# Node id:  178 Catchment area:  0.20144293
# max ca:  0.96277143
# Node id:  220 Catchment area:  0.11544163
# Node id:  199 Catchment area:  0.11821096
# max ca:  0.23426547
# Node id:  220 Catchment area:  0.16050325
# Node id:  199 Catchment area:  0.14840385
# Node id:  178 Catchment area:  0.09905283
# Node id:  158 Catchment area:  0.21328033
# max ca:  0.60642001
# Node id:  220 Catchment area:  0.32626929
# Node id:  198 Catchment area:  0.19433568
# max ca:  0.12774531
# Node id:  220 Catchment area:  0.06636028
# Node id:  199 Catchment area:  0.06058373
# Node id:  177 Catchment area:  0.07941614
# Node id:  155 Catchment area:  0.04767538
# Node id:  154 Catchment area:  0.07261198
# Node id:  133 Catchment area:  0.09753396
# Node id:  111 Catchment area:  0.10510994
# max ca:  0.01139166
# Node id:  170 Catchment area:  0.00146751
# Node id:  154 Catchment area:  0.00234013
# Node id:  138 Catchment area:  0.00300203
# Node id:  122 Catchment area:  0.00373976
# Node id:  106 Catchment area:  0.00452072
# Node id:  90 Catchment area:  0.00541999
# Node id:  74 Catchment area:  0.00636371
# Node id:  58 Catchment area:  0.0074703
# Node id:  42 Catchment area:  0.00873809
# Node id:  26 Catchment area:  0.01014811

# %% [markdown]
# # Create a list of all gully head nodes that had a valid convergence point.

# %%
def get_keys(value_list, my_dict):
    gh_node_list = []
    for node_value in value_list:   
        for key, value in my_dict.items(): 
             if node_value == value:
                    gh_node_list.append(key)
  
    return gh_node_list

# %%
gully_heads_to_keep = get_keys(catchment_area_node_list, catchment_area_dict)

# %%
len(gully_heads_to_keep)
# Out:
# 82

# %%
len(catchment_area_node_list)
# Out:
# 82

# %% [markdown]
# # Now move 5m downstream of the remaining gully heads - this will be the point from which to the look at the gully head steepness

# %%
downstream_5m_dict, downstream_5m_node_list = findPoint5mDownstream(gully_heads_to_keep, grid_nodes, input_DEM, catchment_area,
                                                                  input_DEM_resolution, 6, 0.9, 0.1)
# Out:
# max ca:  3.65648347
# Node id:  19 Catchment area:  0.0933974
# Node id:  20 Catchment area:  0.08106677
# Node id:  21 Catchment area:  0.03132792
# Node id:  22 Catchment area:  3.54611183
# Node id:  9 Catchment area:  3.65648347
# Node id:  9 Catchment area:  3.65648347
# 5
# max ca:  0.52583249
# Node id:  84 Catchment area:  0.38421774
# Node id:  83 Catchment area:  0.36052781
# Node id:  69 Catchment area:  0.45499547
# Node id:  55 Catchment area:  0.52292894
# Node id:  54 Catchment area:  0.52382333
# Node id:  53 Catchment area:  0.52502647
# 5
# max ca:  0.50246575
# Node id:  84 Catchment area:  0.35255183
# Node id:  71 Catchment area:  0.30996469
# Node id:  57 Catchment area:  0.45637822
# Node id:  43 Catchment area:  0.49242633
# Node id:  30 Catchment area:  0.50021684
# Node id:  16 Catchment area:  0.50246575
# 5
# max ca:  6.22889757
# Node id:  84 Catchment area:  0.1024091
# Node id:  83 Catchment area:  0.07517685
# Node id:  95 Catchment area:  0.08923097
# Node id:  94 Catchment area:  0.05827129
# Node id:  93 Catchment area:  0.07763689
# Node id:  92 Catchment area:  0.04950791
# 5
# max ca:  0.14624503
# Node id:  84 Catchment area:  0.12883921
# Node id:  83 Catchment area:  0.13756549
# Node id:  82 Catchment area:  0.13870402
# Node id:  81 Catchment area:  0.13995142
# Node id:  80 Catchment area:  0.1416252
# Node id:  79 Catchment area:  0.1438203
# 5
# max ca:  0.12330876
# Node id:  84 Catchment area:  0.08971981
# Node id:  97 Catchment area:  0.11992408
# Node id:  110 Catchment area:  0.12227582
# Node id:  123 Catchment area:  0.12330876
# Node id:  136 Catchment area:  0.06319116
# Node id:  149 Catchment area:  0.07942862
# 5
# max ca:  2.90862098
# Node id:  84 Catchment area:  0.29649912
# Node id:  85 Catchment area:  0.31150819
# Node id:  86 Catchment area:  0.31274712
# Node id:  87 Catchment area:  0.31362154
# Node id:  88 Catchment area:  0.1861241
# Node id:  89 Catchment area:  2.04004998
# 5
# max ca:  1.71362652
# Node id:  84 Catchment area:  0.28177259
# Node id:  71 Catchment area:  0.3622248
# Node id:  57 Catchment area:  0.53152937
# Node id:  45 Catchment area:  0.36625648
# Node id:  32 Catchment area:  0.5520946
# Node id:  19 Catchment area:  0.55266337
# 5
# max ca:  2.04004998
# Node id:  84 Catchment area:  0.1957894
# Node id:  85 Catchment area:  0.20247696
# Node id:  86 Catchment area:  0.20577133
# Node id:  87 Catchment area:  0.20903871
# Node id:  88 Catchment area:  0.20936388
# Node id:  89 Catchment area:  0.10192332
# 5
# max ca:  1.68619384
# Node id:  84 Catchment area:  0.89697893
# Node id:  71 Catchment area:  0.54364661
# Node id:  57 Catchment area:  0.91875007
# Node id:  44 Catchment area:  0.92211167
# Node id:  31 Catchment area:  0.92511501
# Node id:  17 Catchment area:  0.92673637
# 5
# max ca:  0.38841477
# Node id:  84 Catchment area:  0.08083179
# Node id:  83 Catchment area:  0.08975857
# Node id:  95 Catchment area:  0.0818705
# Node id:  107 Catchment area:  0.05408843
# Node id:  106 Catchment area:  0.12461489
# Node id:  105 Catchment area:  0.33853268
# 5
# max ca:  1.43553712
# Node id:  84 Catchment area:  0.33963255
# Node id:  83 Catchment area:  0.50813055
# Node id:  69 Catchment area:  0.58700398
# Node id:  55 Catchment area:  0.60884741
# Node id:  41 Catchment area:  0.91000117
# Node id:  28 Catchment area:  1.43270007
# 5
# max ca:  4.19673857
# Node id:  84 Catchment area:  0.39638405
# Node id:  72 Catchment area:  0.46797853
# Node id:  59 Catchment area:  0.52364984
# Node id:  47 Catchment area:  0.52773457
# Node id:  48 Catchment area:  1.70981493
# Node id:  49 Catchment area:  3.64494285
# 5
# max ca:  0.23438127
# Node id:  84 Catchment area:  0.10943555
# Node id:  71 Catchment area:  0.13491326
# Node id:  57 Catchment area:  0.19060335
# Node id:  43 Catchment area:  0.22656333
# Node id:  30 Catchment area:  0.23056971
# Node id:  16 Catchment area:  0.23438127
# 5
# max ca:  3.64494285
# Node id:  84 Catchment area:  0.52448521
# Node id:  71 Catchment area:  0.69781938
# Node id:  58 Catchment area:  0.72970124
# Node id:  45 Catchment area:  0.29832935
# Node id:  32 Catchment area:  3.4015754
# Node id:  31 Catchment area:  3.57596404
# 5
# max ca:  0.74198145
# Node id:  84 Catchment area:  0.42926189
# Node id:  71 Catchment area:  0.57772611
# Node id:  59 Catchment area:  0.55197917
# Node id:  47 Catchment area:  0.60548195
# Node id:  35 Catchment area:  0.49168656
# Node id:  22 Catchment area:  0.70752759
# 5
# max ca:  2.05199175
# Node id:  84 Catchment area:  0.8637849
# Node id:  70 Catchment area:  1.60202748
# Node id:  57 Catchment area:  1.87219248
# Node id:  44 Catchment area:  1.22970366
# Node id:  30 Catchment area:  2.04829387
# Node id:  16 Catchment area:  2.05199175
# 5
# max ca:  0.51738045
# Node id:  84 Catchment area:  0.41210737
# Node id:  71 Catchment area:  0.4494055
# Node id:  58 Catchment area:  0.46783682
# Node id:  46 Catchment area:  0.48057616
# Node id:  33 Catchment area:  0.49505896
# Node id:  20 Catchment area:  0.50101736
# 5
# max ca:  0.51883345
# Node id:  84 Catchment area:  0.49798828
# Node id:  83 Catchment area:  0.50340696
# Node id:  82 Catchment area:  0.50666567
# Node id:  68 Catchment area:  0.30108453
# Node id:  67 Catchment area:  0.51608681
# Node id:  66 Catchment area:  0.51883345
# 5
# max ca:  0.4253951
# Node id:  84 Catchment area:  0.26188651
# Node id:  71 Catchment area:  0.35091252
# Node id:  58 Catchment area:  0.37723995
# Node id:  45 Catchment area:  0.39376016
# Node id:  32 Catchment area:  0.40684514
# Node id:  19 Catchment area:  0.41822289
# 5
# max ca:  0.50791632
# Node id:  84 Catchment area:  0.30120161
# Node id:  70 Catchment area:  0.34696511
# Node id:  57 Catchment area:  0.25841776
# Node id:  43 Catchment area:  0.40742674
# Node id:  29 Catchment area:  0.47696209
# Node id:  16 Catchment area:  0.49993635
# 5
# max ca:  0.78542376
# Node id:  84 Catchment area:  0.22521042
# Node id:  71 Catchment area:  0.37909144
# Node id:  58 Catchment area:  0.48039655
# Node id:  45 Catchment area:  0.57886747
# Node id:  32 Catchment area:  0.60685519
# Node id:  20 Catchment area:  0.45265692
# 5
# max ca:  0.33226186
# Node id:  84 Catchment area:  0.17396272
# Node id:  96 Catchment area:  0.30337533
# Node id:  109 Catchment area:  0.31473029
# Node id:  122 Catchment area:  0.17637692
# Node id:  134 Catchment area:  0.32575276
# Node id:  147 Catchment area:  0.32929935
# 5
# max ca:  0.25650502
# Node id:  84 Catchment area:  0.12084728
# Node id:  97 Catchment area:  0.1163091
# Node id:  111 Catchment area:  0.17533564
# Node id:  124 Catchment area:  0.20347512
# Node id:  137 Catchment area:  0.22587296
# Node id:  150 Catchment area:  0.2476
# 5
# max ca:  0.18420293
# Node id:  84 Catchment area:  0.10411693
# Node id:  97 Catchment area:  0.09215291
# Node id:  109 Catchment area:  0.17024639
# Node id:  122 Catchment area:  0.18262506
# Node id:  135 Catchment area:  0.16634509
# Node id:  148 Catchment area:  0.18420293
# 5
# max ca:  0.19280941
# Node id:  84 Catchment area:  0.13701652
# Node id:  97 Catchment area:  0.15755581
# Node id:  110 Catchment area:  0.17459386
# Node id:  123 Catchment area:  0.18310634
# Node id:  136 Catchment area:  0.18823393
# Node id:  149 Catchment area:  0.19280941
# 5
# max ca:  0.39691294
# Node id:  84 Catchment area:  0.24643771
# Node id:  83 Catchment area:  0.31698267
# Node id:  82 Catchment area:  0.27872252
# Node id:  94 Catchment area:  0.31878452
# Node id:  93 Catchment area:  0.24481843
# Node id:  105 Catchment area:  0.37086213
# 5
# max ca:  0.64170262
# Node id:  84 Catchment area:  0.29790197
# Node id:  97 Catchment area:  0.44841017
# Node id:  110 Catchment area:  0.59631272
# Node id:  123 Catchment area:  0.62853399
# Node id:  136 Catchment area:  0.6330477
# Node id:  150 Catchment area:  0.64170262
# 5
# max ca:  0.68036602
# Node id:  84 Catchment area:  0.36354799
# Node id:  97 Catchment area:  0.55949925
# Node id:  110 Catchment area:  0.63892812
# Node id:  123 Catchment area:  0.65899895
# Node id:  136 Catchment area:  0.66788005
# Node id:  149 Catchment area:  0.67498511
# 5
# max ca:  0.71003526
# Node id:  84 Catchment area:  0.33456415
# Node id:  98 Catchment area:  0.35692275
# Node id:  111 Catchment area:  0.61938334
# Node id:  124 Catchment area:  0.71003526
# Node id:  138 Catchment area:  0.51472384
# Node id:  151 Catchment area:  0.65241213
# 5
# max ca:  0.31381433
# Node id:  84 Catchment area:  0.17863093
# Node id:  97 Catchment area:  0.16879734
# Node id:  110 Catchment area:  0.20724423
# Node id:  122 Catchment area:  0.27545884
# Node id:  135 Catchment area:  0.31381433
# Node id:  149 Catchment area:  0.25001447
# 5
# max ca:  2.18959024
# Node id:  84 Catchment area:  0.04327824
# Node id:  83 Catchment area:  0.03408287
# Node id:  95 Catchment area:  0.05575755
# Node id:  107 Catchment area:  0.10973552
# Node id:  120 Catchment area:  0.1111292
# Node id:  132 Catchment area:  0.11229489
# 5
# max ca:  0.32284655
# Node id:  84 Catchment area:  0.11626007
# Node id:  97 Catchment area:  0.20516347
# Node id:  109 Catchment area:  0.16287064
# Node id:  121 Catchment area:  0.24980048
# Node id:  133 Catchment area:  0.321455
# Node id:  146 Catchment area:  0.32230665
# 5
# max ca:  5.6092177
# Node id:  84 Catchment area:  0.02316423
# Node id:  97 Catchment area:  0.02918124
# Node id:  111 Catchment area:  0.03201365
# Node id:  124 Catchment area:  0.0227565
# Node id:  137 Catchment area:  5.59588144
# Node id:  149 Catchment area:  4.24283308
# 5
# max ca:  0.89694714
# Node id:  84 Catchment area:  0.1742356
# Node id:  70 Catchment area:  0.18389288
# Node id:  56 Catchment area:  0.13392539
# Node id:  42 Catchment area:  0.14422485
# Node id:  28 Catchment area:  0.13172444
# Node id:  14 Catchment area:  0.31122129
# 5
# max ca:  1.36059192
# Node id:  84 Catchment area:  1.35371061
# Node id:  97 Catchment area:  1.35487566
# Node id:  110 Catchment area:  1.35604765
# Node id:  124 Catchment area:  1.12872575
# Node id:  137 Catchment area:  0.8905057
# Node id:  151 Catchment area:  1.35963591
# 5
# max ca:  0.73756871
# Node id:  84 Catchment area:  0.26129815
# Node id:  83 Catchment area:  0.1893863
# Node id:  82 Catchment area:  0.17956901
# Node id:  68 Catchment area:  0.37254585
# Node id:  67 Catchment area:  0.44463078
# Node id:  66 Catchment area:  0.46274137
# 5
# max ca:  0.95609627
# Node id:  84 Catchment area:  0.3229425
# Node id:  83 Catchment area:  0.41258939
# Node id:  82 Catchment area:  0.4113661
# Node id:  68 Catchment area:  0.66447911
# Node id:  54 Catchment area:  0.8565571
# Node id:  41 Catchment area:  0.59536879
# 5
# max ca:  0.68972039
# Node id:  84 Catchment area:  0.39517227
# Node id:  70 Catchment area:  0.5580419
# Node id:  56 Catchment area:  0.42574642
# Node id:  55 Catchment area:  0.6831967
# Node id:  54 Catchment area:  0.68972039
# Node id:  40 Catchment area:  0.40492702
# 5
# max ca:  12.12236278
# Node id:  84 Catchment area:  0.13589936
# Node id:  97 Catchment area:  0.17377988
# Node id:  110 Catchment area:  0.20144849
# Node id:  123 Catchment area:  0.20258167
# Node id:  136 Catchment area:  0.20265883
# Node id:  149 Catchment area:  0.14202268
# 5
# max ca:  0.28114944
# Node id:  84 Catchment area:  0.06818095
# Node id:  96 Catchment area:  0.13340891
# Node id:  95 Catchment area:  0.20334271
# Node id:  94 Catchment area:  0.20474288
# Node id:  106 Catchment area:  0.22284086
# Node id:  105 Catchment area:  0.28114944
# 5
# max ca:  0.23824537
# Node id:  84 Catchment area:  0.17924358
# Node id:  83 Catchment area:  0.1936172
# Node id:  69 Catchment area:  0.19760427
# Node id:  68 Catchment area:  0.18122574
# Node id:  54 Catchment area:  0.1085897
# Node id:  41 Catchment area:  0.21827212
# 5
# max ca:  0.60439429
# Node id:  84 Catchment area:  0.35515078
# Node id:  96 Catchment area:  0.36461277
# Node id:  108 Catchment area:  0.33159234
# Node id:  120 Catchment area:  0.55502691
# Node id:  132 Catchment area:  0.35832754
# Node id:  145 Catchment area:  0.6030281
# 5
# max ca:  0.31751937
# Node id:  84 Catchment area:  0.18169128
# Node id:  83 Catchment area:  0.18906132
# Node id:  69 Catchment area:  0.28953017
# Node id:  68 Catchment area:  0.30608867
# Node id:  67 Catchment area:  0.31035611
# Node id:  66 Catchment area:  0.3143767
# 5
# max ca:  16.74191
# Node id:  84 Catchment area:  0.0820412
# Node id:  83 Catchment area:  0.10651035
# Node id:  82 Catchment area:  0.10509637
# Node id:  81 Catchment area:  0.12775342
# Node id:  80 Catchment area:  0.12094732
# Node id:  79 Catchment area:  0.10389661
# 5
# max ca:  0.36008232
# Node id:  84 Catchment area:  0.12803315
# Node id:  83 Catchment area:  0.15228101
# Node id:  95 Catchment area:  0.25697499
# Node id:  94 Catchment area:  0.15284256
# Node id:  93 Catchment area:  0.33134434
# Node id:  92 Catchment area:  0.35456882
# 5
# max ca:  26.79594649
# Node id:  84 Catchment area:  0.42152125
# Node id:  98 Catchment area:  0.41374433
# Node id:  112 Catchment area:  0.63744164
# Node id:  126 Catchment area:  0.4028954
# Node id:  139 Catchment area:  0.42227289
# Node id:  152 Catchment area:  0.20048089
# 5
# max ca:  34.8560741
# Node id:  84 Catchment area:  0.01645964
# Node id:  70 Catchment area:  0.01811228
# Node id:  69 Catchment area:  20.44974928
# Node id:  81 Catchment area:  25.84501794
# Node id:  93 Catchment area:  25.75543577
# Node id:  92 Catchment area:  34.36906181
# 5
# max ca:  15.61042506
# Node id:  84 Catchment area:  9.1792411
# Node id:  96 Catchment area:  9.38481241
# Node id:  108 Catchment area:  9.45657391
# Node id:  107 Catchment area:  15.05304649
# Node id:  119 Catchment area:  15.05472289
# Node id:  118 Catchment area:  15.19510931
# 5
# max ca:  0.65789048
# Node id:  84 Catchment area:  0.46738145
# Node id:  97 Catchment area:  0.35033585
# Node id:  109 Catchment area:  0.51293006
# Node id:  122 Catchment area:  0.31759156
# Node id:  134 Catchment area:  0.4546265
# Node id:  146 Catchment area:  0.5138941
# 5
# max ca:  0.47371327
# Node id:  84 Catchment area:  0.27727096
# Node id:  97 Catchment area:  0.37720148
# Node id:  110 Catchment area:  0.46295394
# Node id:  123 Catchment area:  0.46764263
# Node id:  136 Catchment area:  0.47371327
# Node id:  149 Catchment area:  0.26118113
# 5
# max ca:  0.57096552
# Node id:  84 Catchment area:  0.42699514
# Node id:  96 Catchment area:  0.41799233
# Node id:  95 Catchment area:  0.57034429
# Node id:  94 Catchment area:  0.57096552
# Node id:  106 Catchment area:  0.40700892
# Node id:  92 Catchment area:  0.53745972
# 5
# max ca:  0.49004077
# Node id:  84 Catchment area:  0.25807246
# Node id:  70 Catchment area:  0.28318574
# Node id:  57 Catchment area:  0.41401671
# Node id:  44 Catchment area:  0.47077495
# Node id:  30 Catchment area:  0.47859278
# Node id:  17 Catchment area:  0.48561414
# 5
# max ca:  1.14380132
# Node id:  84 Catchment area:  1.10230258
# Node id:  71 Catchment area:  0.64804553
# Node id:  59 Catchment area:  1.11559778
# Node id:  46 Catchment area:  1.12260352
# Node id:  33 Catchment area:  1.12981287
# Node id:  20 Catchment area:  0.71865477
# 5
# max ca:  14.36016073
# Node id:  84 Catchment area:  0.16867149
# Node id:  70 Catchment area:  0.14494147
# Node id:  56 Catchment area:  0.16510111
# Node id:  42 Catchment area:  0.56982144
# Node id:  28 Catchment area:  0.57021905
# Node id:  15 Catchment area:  0.3048697
# 5
# max ca:  1.22352642
# Node id:  84 Catchment area:  0.87046182
# Node id:  83 Catchment area:  1.1687587
# Node id:  82 Catchment area:  0.71753508
# Node id:  94 Catchment area:  1.21633623
# Node id:  93 Catchment area:  1.21951552
# Node id:  105 Catchment area:  1.10280484
# 5
# max ca:  0.3571327
# Node id:  84 Catchment area:  0.1332199
# Node id:  71 Catchment area:  0.18225969
# Node id:  58 Catchment area:  0.18177658
# Node id:  45 Catchment area:  0.33969287
# Node id:  32 Catchment area:  0.35511891
# Node id:  20 Catchment area:  0.3571327
# 5
# max ca:  0.20541687
# Node id:  84 Catchment area:  0.20541687
# Node id:  83 Catchment area:  0.19063969
# Node id:  82 Catchment area:  0.14068449
# Node id:  81 Catchment area:  0.09902067
# Node id:  67 Catchment area:  0.18677268
# Node id:  53 Catchment area:  0.18329955
# 5
# max ca:  0.39550325
# Node id:  84 Catchment area:  0.11250168
# Node id:  71 Catchment area:  0.14545928
# Node id:  59 Catchment area:  0.12676874
# Node id:  46 Catchment area:  0.10096835
# Node id:  33 Catchment area:  0.08352279
# Node id:  20 Catchment area:  0.13028826
# 5
# max ca:  0.50466443
# Node id:  84 Catchment area:  0.26182223
# Node id:  71 Catchment area:  0.22907423
# Node id:  57 Catchment area:  0.34773126
# Node id:  43 Catchment area:  0.39016258
# Node id:  29 Catchment area:  0.50466443
# Node id:  15 Catchment area:  0.37345999
# 5
# max ca:  0.92729129
# Node id:  84 Catchment area:  0.65337288
# Node id:  96 Catchment area:  0.72013757
# Node id:  108 Catchment area:  0.74075537
# Node id:  120 Catchment area:  0.58775817
# Node id:  119 Catchment area:  0.27391591
# Node id:  132 Catchment area:  0.52238083
# 5
# max ca:  0.43182269
# Node id:  84 Catchment area:  0.30035848
# Node id:  71 Catchment area:  0.31018738
# Node id:  57 Catchment area:  0.38538268
# Node id:  44 Catchment area:  0.25130861
# Node id:  30 Catchment area:  0.42203825
# Node id:  17 Catchment area:  0.43182269
# 5
# max ca:  0.30035848
# Node id:  84 Catchment area:  0.08133003
# Node id:  70 Catchment area:  0.1598637
# Node id:  69 Catchment area:  0.17240305
# Node id:  55 Catchment area:  0.21272358
# Node id:  41 Catchment area:  0.21597455
# Node id:  28 Catchment area:  0.26842129
# 5
# max ca:  0.54668747
# Node id:  84 Catchment area:  0.17380777
# Node id:  71 Catchment area:  0.20361782
# Node id:  58 Catchment area:  0.20720414
# Node id:  46 Catchment area:  0.40322789
# Node id:  33 Catchment area:  0.26654772
# Node id:  21 Catchment area:  0.43666382
# 5
# max ca:  7.39158027
# Node id:  84 Catchment area:  0.61965466
# Node id:  70 Catchment area:  0.50080922
# Node id:  56 Catchment area:  0.45996542
# Node id:  55 Catchment area:  0.62989746
# Node id:  54 Catchment area:  0.68363275
# Node id:  53 Catchment area:  0.70119545
# 5
# max ca:  0.26193406
# Node id:  84 Catchment area:  0.07434826
# Node id:  72 Catchment area:  0.07949636
# Node id:  60 Catchment area:  0.21759889
# Node id:  47 Catchment area:  0.24776871
# Node id:  34 Catchment area:  0.23424841
# Node id:  20 Catchment area:  0.26193406
# 5
# max ca:  0.60255179
# Node id:  84 Catchment area:  0.55180887
# Node id:  97 Catchment area:  0.33843274
# Node id:  109 Catchment area:  0.45193035
# Node id:  108 Catchment area:  0.59274401
# Node id:  120 Catchment area:  0.60255179
# Node id:  119 Catchment area:  0.41082163
# 5
# max ca:  0.30219573
# Node id:  84 Catchment area:  0.09290475
# Node id:  70 Catchment area:  0.12498443
# Node id:  57 Catchment area:  0.20476187
# Node id:  44 Catchment area:  0.16524082
# Node id:  30 Catchment area:  0.30035392
# Node id:  17 Catchment area:  0.30219573
# 5
# max ca:  5.55401139
# Node id:  84 Catchment area:  0.07983853
# Node id:  96 Catchment area:  0.07927697
# Node id:  109 Catchment area:  0.0340182
# Node id:  108 Catchment area:  3.23562134
# Node id:  107 Catchment area:  5.51445387
# Node id:  106 Catchment area:  4.91399475
# 5
# max ca:  0.67336813
# Node id:  84 Catchment area:  0.50176034
# Node id:  96 Catchment area:  0.64936017
# Node id:  108 Catchment area:  0.65446475
# Node id:  107 Catchment area:  0.38984241
# Node id:  106 Catchment area:  0.67158929
# Node id:  105 Catchment area:  0.67336813
# 5
# max ca:  0.71237418
# Node id:  84 Catchment area:  0.65936711
# Node id:  83 Catchment area:  0.69364939
# Node id:  82 Catchment area:  0.6998392
# Node id:  81 Catchment area:  0.64747343
# Node id:  67 Catchment area:  0.64296368
# Node id:  66 Catchment area:  0.69677588
# 5
# max ca:  6.46645547
# Node id:  84 Catchment area:  0.20964592
# Node id:  71 Catchment area:  0.35830463
# Node id:  58 Catchment area:  0.58303246
# Node id:  45 Catchment area:  0.61671644
# Node id:  32 Catchment area:  2.80344034
# Node id:  19 Catchment area:  4.71929765
# 5
# max ca:  0.4322559
# Node id:  84 Catchment area:  0.18606369
# Node id:  71 Catchment area:  0.17606061
# Node id:  57 Catchment area:  0.37840224
# Node id:  44 Catchment area:  0.39379851
# Node id:  30 Catchment area:  0.41094176
# Node id:  17 Catchment area:  0.38114511
# 5
# max ca:  5.21861397
# Node id:  84 Catchment area:  0.06298492
# Node id:  96 Catchment area:  0.0525304
# Node id:  95 Catchment area:  0.05439467
# Node id:  94 Catchment area:  3.06427937
# Node id:  80 Catchment area:  5.21861397
# Node id:  66 Catchment area:  3.95522923
# 5
# max ca:  0.64095025
# Node id:  84 Catchment area:  0.49890321
# Node id:  83 Catchment area:  0.59403458
# Node id:  82 Catchment area:  0.62347758
# Node id:  94 Catchment area:  0.3686342
# Node id:  93 Catchment area:  0.57885443
# Node id:  105 Catchment area:  0.62591481
# 5
# max ca:  2.86361236
# Node id:  84 Catchment area:  0.05618796
# Node id:  85 Catchment area:  0.04966677
# Node id:  86 Catchment area:  1.21590991
# Node id:  73 Catchment area:  1.24281867
# Node id:  61 Catchment area:  1.2499298
# Node id:  48 Catchment area:  1.84630132
# 5
# max ca:  1.98442324
# Node id:  84 Catchment area:  1.27867146
# Node id:  83 Catchment area:  0.94822822
# Node id:  82 Catchment area:  1.62658545
# Node id:  81 Catchment area:  1.97342118
# Node id:  80 Catchment area:  1.97747983
# Node id:  79 Catchment area:  1.98146592
# 5
# max ca:  0.30523159
# Node id:  84 Catchment area:  0.10459305
# Node id:  71 Catchment area:  0.14661326
# Node id:  58 Catchment area:  0.20144293
# Node id:  45 Catchment area:  0.2383547
# Node id:  31 Catchment area:  0.26344448
# Node id:  17 Catchment area:  0.20786711
# 5
# max ca:  0.7606995
# Node id:  84 Catchment area:  0.11544163
# Node id:  71 Catchment area:  0.11821096
# Node id:  57 Catchment area:  0.21552312
# Node id:  44 Catchment area:  0.22462401
# Node id:  31 Catchment area:  0.22958936
# Node id:  18 Catchment area:  0.23364866
# 5
# max ca:  0.22445285
# Node id:  84 Catchment area:  0.16050325
# Node id:  71 Catchment area:  0.14840385
# Node id:  58 Catchment area:  0.09905283
# Node id:  46 Catchment area:  0.21328033
# Node id:  33 Catchment area:  0.21700937
# Node id:  21 Catchment area:  0.18423086
# 5
# max ca:  0.38962676
# Node id:  84 Catchment area:  0.32626929
# Node id:  70 Catchment area:  0.19433568
# Node id:  69 Catchment area:  0.38763769
# Node id:  68 Catchment area:  0.38808231
# Node id:  67 Catchment area:  0.38849564
# Node id:  79 Catchment area:  0.38902834
# 5
# max ca:  0.11227231
# Node id:  84 Catchment area:  0.06636028
# Node id:  71 Catchment area:  0.06058373
# Node id:  57 Catchment area:  0.07941614
# Node id:  43 Catchment area:  0.04767538
# Node id:  42 Catchment area:  0.07261198
# Node id:  29 Catchment area:  0.09753396
# 5

# %%
len(downstream_5m_node_list)
# Out:
# 82

# %%
outlet_ids = np.isin(grid_nodes,downstream_5m_node_list).astype('uint8')

# %% [markdown]
# # Remove any gully head candidates that have drainage area < given threshold estimated by multiple-direction algorithm.

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('fann_downstream_5m.tif', input_geotiff, outlet_ids, grid_nodes_float.dtype)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
