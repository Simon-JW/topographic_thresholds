# %% [markdown]
# ## Import required libraries.

# %%
# %%capture
import operator
import seaborn as sns; sns.set()
from jupyterthemes import jtplot
jtplot.style()
import numpy as np
from landlab import FieldError
from landlab.utils import get_watershed_mask
import xarray as xr
import pandas as pd
import scipy
import gdal
from scipy import ndimage
from scipy.ndimage.filters import *
from scipy.interpolate import InterpolatedUnivariateSpline
from scipy.signal import medfilt
import os
import math
from osgeo import osr
from fractions import Fraction
import timeit
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
# %matplotlib inline
import random
# import plotting tools
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib as mpl
from landlab.plot.imshow import imshow_grid 

# import necessary landlab components
from landlab import RasterModelGrid, HexModelGrid
from landlab.components import FlowAccumulator, LakeMapperBarnes, SinkFillerBarnes
from landlab.components import(FlowDirectorD8, 
                               FlowDirectorDINF, 
                               FlowDirectorMFD, 
                               FlowDirectorSteepest)
from landlab.components import DepressionFinderAndRouter
# import landlab plotting functionality
from landlab.plot.drainage_plot import drainage_plot
from pylab import show, figure

# create a plotting routine to make a 3d plot of our surface. 
def surf_plot(mg, surface='topographic__elevation', 
              title='Surface plot of topography', colormap = cm.gray):
    
    fig = plt.figure()
    ax = fig.gca(projection='3d')

    # Plot the surface.
    Z = (mg.at_node[surface].reshape(mg.shape))#[y1:y2, x1:x2]
    color = colormap((Z-Z.min())/(Z.max()-Z.min()))
    surf = ax.plot_surface(mg.node_x.reshape(mg.shape),#[y1:y2, x1:x2]
                           mg.node_y.reshape(mg.shape),#[y1:y2, x1:x2]
                           Z,
                           rstride=1, cstride=1,
                           facecolors=color,
                           linewidth=0.,
                           antialiased=False)
    ax.view_init(elev=35, azim=-120) 
    ax.set_xlabel('X axis')
    ax.set_ylabel('Y axis')
    ax.set_zlabel('Elevation')
    plt.title(title)
    plt.show()

# %% [markdown]
# ## Setup input data
# Define spatial resolution: Specify the resolution of the input DEM and also the desired working resolution (can be same as input DEM resolution).

# %%
def roundup(x):
    return int(math.ceil(x / 10.0)) * 10

input_DEM_resolution = 1
working_resolution = 1
location = (r'C:\PhD\junk')
os.chdir(location)
input_geotiff = gdal.Open('fann_sub.tif')
x = np.array(input_geotiff.GetRasterBand(1).ReadAsArray())
empty_grid_rows = roundup(x.shape[0])
empty_grid_cols = roundup(x.shape[1])
input_DEM = np.zeros([empty_grid_rows,empty_grid_cols])
input_DEM[:x.shape[0], :x.shape[1]] = x

input_outlets = gdal.Open('fann_downstream_5m.tif')
o = np.array(input_outlets.GetRasterBand(1).ReadAsArray())
outlets= o
#outlets = 1 - o

# %% [markdown]
# ## Visualise the DEM.

# %%
plt.figure(figsize=(12,12))
plt.imshow(input_DEM, cmap="terrain_r", vmin = np.percentile(input_DEM, 5));
plt.colorbar();

# %% [markdown]
# ## Define required function.

# %%
def rectangleWindow(m, n):
    """Takes a value for number of rows (m) and number of columns (n) such that
       m and n are both positive real numbers and creates a rectangle of 
       boolian 'True' values."""
    rectangle = np.ones((m, n), dtype=bool) 
    return rectangle
def number_of_values(Window):
    """This funciton takes the shape function as an input and returns a number 
        of values present in the specified shape. 
        
        This can be different for a different window shape and to initialize
        requires the specification of the function for the given window type and 
        parameter values required for that input function.
        
        To initialize this function for shape == rectangle type 'number_of_values(rectangleWindow(m,n)) 
        where m and n are any positive real number as per the rectangleWindow function."""
    denominator = sum(sum(Window > 0))
    return denominator
def circleWindow(radius):
    """Takes a value for radius (r where r is any positive real number) and creates 
       a circular window using that radius."""
    y, x = np.ogrid[-radius: radius + 1, -radius: radius + 1]
    circle = x**2 + y**2 <= radius**2
    return circle
def find_median_value(Window):
    """This function takes the shape function and returns the median value 
        for all valid values (values that fall in the circle) arranged into a 
        1d array. The function also takes the number_of_values function as an input.
        To execute this function type 'find_median_value(shape(r)) where r is any integer.
        #Note: using median like this only gives the correct value for circles with odd 
        radius values."""
    no_values = number_of_values(Window)
    value_range = np.arange(0, no_values + 1)
    central_value = int(np.median(value_range))
    return central_value
def differenceFromMeanElevation(elev):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = elev[central_value]                        
    mean = np.nanmean(elev)#Count number of values greater than centroid value
    diff = centroid - mean
    return diff
def PCTL(x):
    """This function only works as an inside function to generic_filter function below. This
       is because generic_filter will take a 2d array and reshape it into a 1d array. Without this 
       step the 'central_value' variable will be outside of the array dimensions. 
       x = input DEM and r = radius of search window """
    centroid = x[central_value]                        
    y = np.sum(x < centroid)/num_values#Count number of values greater than centroid value
    return y
def flow_dir_dataset(flow_rec_prop, catchment_area, grid_resolution, outlet_node):
    """ Create an xarray Dataset containing eight arrays each representing the
    amount of water flowing in the given direction.
        1 . flow_rec_prop == the flow receiver proportion array created by LandLab flow routing.
        2 . catchment_area == the corresponding catchment area array from the landLab flow accumulation.
        surface.        
    The resulting Dataset is used to calculate specific catchment area."""
    array_direction = xr.Dataset()
    for i in range(0,8):
        rows = catchment_area.shape[0]; cols = catchment_area.shape[1];
        direction = np.flip(flow_rec_prop[:,i].reshape(rows,cols), 0);
        # Above needs to be flipped because during reshape it organises data top down
        # rather than bottom up as per ModelGrid order (catchment_area is mg arrangement).
        zero_outlet = outlet_node != 1
        remove_outlet = zero_outlet * catchment_area
        weighted_direction = xr.DataArray((remove_outlet * direction),
                                          dims = ['lat', 'lon']);
        array_direction[direction_list[i]] = weighted_direction
        
    E, N, W, S, NE, NW, SW, SE = (array_direction['East'], array_direction['North'],
                             array_direction['West'], array_direction['South'],
                             array_direction['North East'], array_direction['North West'],
                             array_direction['South West'], array_direction['South East'])

    flow_dirs = xr.concat([E, N, W, S, NE, NW, SW, SE], 'direction')
    flow_dirs.name = 'flow_directions'
    flow_dirs.attrs['grid cell resolution'] = grid_resolution
    flow_directions = flow_dirs.assign_coords(direction=(['East','North','West','South',
                                   'North East', 'North West','South West', 'South East']))
    return flow_directions
def profileCurvature(DEM, cellsize):
    """This process is taken from Change (2014, Introduction to Geographic Information
       systems, Page 284)."""
    Z1 = DEM[0]; Z2 = DEM[1]; Z3 = DEM[2]
    Z4 = DEM[3]; Z0 = DEM[4]; Z5 = DEM[5]
    Z6 = DEM[6]; Z7 = DEM[7]; Z8 = DEM[8]
    D = (((Z4 + Z5)/2) - Z0) / cellsize**2
    E = (((Z2 + Z7)/2) - Z0) / cellsize**2
    F = (Z3 - Z1 + Z6 - Z8)/ (4 * cellsize**2)
    G = (Z5 - Z4) / (2 * cellsize)
    H = (Z2 - Z7) / (2 * cellsize)
    profile_curvature = (-2 * (D*(G**2) + E*(H**2) + (F*G*H))) / (G**2 + H**2)
    return profile_curvature
def slopeWindowDegrees(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_percent = rise_run * 100
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_degrees
def closest(lst, K): 
     angle_list = lst
     idx = (np.abs(angle_list - K)).argmin() 
     return angle_list[idx]  
def data_range(data):
    data_min = np.amin(data); data_max = np.amax(data)
    value_range = data_max - data_min
    return value_range
def checkGullyHead(dfme_list, step_size, comparison_distance, minimum_depth, elevation_of_gh):
    
    """ """
    max_value_length = len(dfme_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = dfme_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptreat_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = dfme_list[start_of_upstream_nodes:end_of_usptreat_nodes]
        
        min_downstream = np.min(downstream_nodes)
        mean_upstream = np.mean(upstream_nodes)
        std_upstream = np.std(upstream_nodes)
        elevation_difference = min_downstream - mean_upstream
        print('minimum downstream value: ', min_downstream)
        print('mean upstream value: ', mean_upstream)
        print('std upstream value: ', std_upstream)
      
        if min_downstream <= minimum_depth and mean_upstream > elevation_of_gh and std_upstream < 0.1 and elevation_difference <= -0.2:
            keep_gully = 'yes'
            # below could use either floor or ceil instead of round 
            gully_head_location = int(end_of_downstream_nodes + np.round(comparison_distance/2))
            break
        else:
            keep_gully = 'no'
            gully_head_location = 'none'

    return keep_gully, gully_head_location
def checkGullyEdges(dfme_list, step_size, comparison_distance, minimum_depth, elevation_of_gh):
    
    """ """
    max_value_length = len(dfme_list) - step_size - comparison_distance - step_size
    for i in range(0, max_value_length):
                
        start_of_downstream_nodes = i
        end_of_downstream_nodes = i + step_size       
        downstream_nodes = dfme_list[start_of_downstream_nodes:end_of_downstream_nodes]
        
        start_of_upstream_nodes = i + step_size + comparison_distance
        end_of_usptream_nodes = start_of_upstream_nodes + step_size
        upstream_nodes = dfme_list[start_of_upstream_nodes:end_of_usptream_nodes]
        
        min_downstream = np.min(downstream_nodes)
        mean_upstream = np.mean(upstream_nodes)
        std_upstream = np.std(upstream_nodes)
        elevation_difference = min_downstream - mean_upstream
        #print('minimum downstream value: ', min_downstream)
        #print('mean upstream value: ', mean_upstream)
        #print('std upstream value: ', std_upstream)
      
        if min_downstream <= minimum_depth and mean_upstream > elevation_of_gh and std_upstream < 0.1 and elevation_difference <= -0.2:
            keep_gully = 'yes'
            # below could use either floor or ceil instead of round 
            gully_head_location = int(start_of_upstream_nodes)
            break
        else:
            keep_gully = 'no'
            gully_head_location = 'none'

    return keep_gully, gully_head_location
def upstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, import_drainage_area, 
                         import_dfme, catchment_outlet_ids, step_size_m, comparison_distance_m,  
                         slope_above_head, min_depth, gh_elevation):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    final_gully_head_position_dict = {}
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    is_gully_head = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    gully_head_node_dict = {}
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        
        #da_subset_copy = np.copy(import_drainage_area)
        import_da_subset = import_drainage_area[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        flattened_import_da = import_da_subset.reshape(da.shape)
        
        #dfme_subset_copy = np.copy(import_dfme)
        import_dfme_subset = import_dfme[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        flattened_import_dfme = import_dfme_subset.reshape(da.shape)
        
        grid_nodes_subset = grid_nodes[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        
        flattened_grid_nodes_subset = grid_nodes_subset.reshape(da.shape)
        
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.

        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        print(central_node)
        print(mg1.shape)
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)
        

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        node_dfme_dict = {}
        original_node_id_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            upstream_dfme_dict = {};
            upstream_original_node_id = {}
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_import_da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})
                        original_node_id = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_grid_nodes_subset))
                        upstream_original_node_id.update({node_id_value:original_node_id})
                        node_dfme = np.amin(np.multiply(isolate_candidate_grid_cells, flattened_import_dfme))
                        upstream_dfme_dict.update({node_id_value:node_dfme})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    print(primary_flow_direction_id)
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    node_dfme_dict[primary_flow_direction_id] = upstream_dfme_dict[primary_flow_direction_id]
                    original_node_id_dict[primary_flow_direction_id] = upstream_original_node_id[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        print(target_distance, ' ', target_distance * input_DEM_resolution)
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        dfme_along_central_drainage_line = []
        for key, value in node_dfme_dict.items():
            dfme_along_central_drainage_line.append(value)
        median_dfme_along_central_drainage_line = ndimage.median_filter(dfme_along_central_drainage_line, size=step_size_m)

        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        original_node_id_along_central_drainage_line = []
        for key, value in original_node_id_dict.items():
            original_node_id_along_central_drainage_line.append(value)
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_dfme_along_central_drainage_line) < required_number_of_grid_cells:
            is_gully_head[i] = 'not enough grid cells'
        else:
            print('node: ',i,)
            divergence_occuring, gully_head_node = checkGullyHead(dfme_along_central_drainage_line, 
                                                    step_size, comparison_distance, min_depth, gh_elevation)
            is_gully_head[i] = divergence_occuring
            gully_head_node_dict[i] = gully_head_node
            if isinstance(gully_head_node, str):
                pass
            else:
                final_gully_head_position_dict[i] = original_node_id_along_central_drainage_line[gully_head_node]
                
    return final_gully_head_position_dict, is_gully_head, slope_dict, slope_at_head
def slopeWindowMperM(DEM, x_cellsize, y_cellsize):
    """This function implements slope calculation using the same algorithm
       as ARCGIS (Outlined on the page 'How Slope Works').
       This particular example of the function is written such that it
       will only work if called within the ndimage generic_filter (as the first input).
       This is because the index arguments for a-e are given for the 1d array created
       by the generic_filter function after extracting values from the 3,3 rectangle window.
       NOTE: THIS FUNCTION ONLY WORKS WITH A 3x3 RECTANGLE WINDOW."""
    a = DEM[0]; b = DEM[1]; c = DEM[2]
    d = DEM[3]; e = DEM[4]; f = DEM[5]
    g = DEM[6]; h = DEM[7]; i = DEM[8]
    dzdx = ((c + (2*f) + i) - (a + (2*d) + g)) / (8 * x_cellsize)
    dzdy = ((g + (2*h) + i) - (a + (2*b) + c)) / (8 * y_cellsize)
    rise_run = np.sqrt(dzdx**2 + dzdy**2)
    slope_degrees = np.arctan(rise_run) * (180/math.pi)
    slope_m_per_m = rise_run
    #Can also ask it to return slope_degrees but asking for both causes it to throw and error.
    return slope_m_per_m

# %%
#################################################################################################
flow_acc_surf = np.copy(input_DEM).astype('float64');
#################################################################################################
rows = flow_acc_surf.shape[0];
cols = flow_acc_surf.shape[1];
mg = RasterModelGrid((rows,cols), 1);
z1 = mg.add_field('topographic__elevation', flow_acc_surf, at = 'node');

sfb = SinkFillerBarnes(mg, method = 'Steepest', ignore_overfill = True);
sfb.run_one_step();
fa = FlowAccumulator(mg,
                    surface = 'topographic__elevation',
                    flow_director = 'FlowDirectorMFD',
                    diagonals = True);
#(flow_acc, q) = fa.accumulate_flow();
fa.run_one_step()
fd = FlowDirectorMFD(mg, 'topographic__elevation', diagonals = True);
fd.run_one_step()

da = np.array(mg.at_node['drainage_area'].round(4));
catchment_area_ha = np.divide(da.reshape(mg.shape), (100/working_resolution)**2)
frn = mg.at_node['flow__receiver_node'];
drainage_area = np.flip(da.reshape(mg.shape), 0);
frp = np.array(mg.at_node['flow__receiver_proportions']);
ns = np.flip(mg.status_at_node.reshape(mg.shape), 0);
flow_rec_surf_rows = cols * rows;
flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);

tss = mg.at_node['topographic__steepest_slope'];
steepest_slope = tss.reshape(flow_rec_surf_rows,8);
all_receiver_proportions = np.copy(frp);

# %% [markdown]
# # For all nodes

# %%
# Must be larger than 'line_length' (specified later).
size_of_edge = 30

# %%
grid_nodes = np.array(mg.nodes.reshape(mg.shape))
find_nodes = np.multiply(outlets, grid_nodes);

gully_head_edge_mask = np.zeros([grid_nodes.shape[0], grid_nodes.shape[1]])
gully_head_mask_centre = np.ones([grid_nodes.shape[0] - size_of_edge*2, grid_nodes.shape[1] - size_of_edge*2])
gully_head_edge_mask[size_of_edge:-1*(size_of_edge), size_of_edge:-1*(size_of_edge)] = gully_head_mask_centre

remaining_gully_heads = find_nodes * gully_head_edge_mask
gh_array = np.unique(remaining_gully_heads).astype(int);
gh_list = gh_array.tolist();
gh_list.remove(0);
len(gh_list)
# Out:
# 77

# %%
#grid_nodes = np.array(mg.nodes.reshape(mg.shape))
#find_outlet_ids = grid_nodes * outlets
#outlet_id = np.unique(find_outlet_ids)[1]

# %%
radius = 9
central_value = find_median_value(circleWindow(radius))
num_values = number_of_values(circleWindow(radius))
dfme = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(radius), mode='nearest');
dfme[dfme > 5.0] = 5.0
dfme[dfme < -5.0] = -5.0

# %%
slope = generic_filter(input_DEM, slopeWindowDegrees,
                  footprint= rectangleWindow(3,3),
                  mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

# %%
shape = 9
central_value = find_median_value(circleWindow(shape))
num_values = number_of_values(circleWindow(shape))

# %%
DFME = generic_filter(input_DEM, differenceFromMeanElevation, 
                        footprint= circleWindow(shape), mode='nearest');

# %%
# Specific the size of the area to be checked. This represents a physical distance from the 
# outlet but has no unit of measure.
distance_from_outlet = 20

# %%
final_gully_heads, gully_head_dict, slope_dict, slope_area_data = upstreamDrainageLine(20, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_ha, DFME,gh_list, 3, 3, 10, -0.2, -0.2)
# Out:
# 840
# (41, 41)
# 841
# 883
# 843
# 803
# 804
# 805
# 806
# 766
# 767
# 768
# 769
# 10   10
# 770
# 771
# 731
# 773
# 774
# 734
# 735
# 695
# 654
# node:  30156
# minimum downstream value:  -0.364931491053
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 888
# 930
# 971
# 1011
# 10   10
# 1052
# 1092
# 1133
# 1175
# 1176
# 1177
# 1178
# 1179
# 1180
# node:  31230
# minimum downstream value:  -1.83454394435
# mean upstream value:  -1.79998220411
# std upstream value:  0.0701246224692
# minimum downstream value:  -1.83454394435
# mean upstream value:  -1.70551108057
# std upstream value:  0.0665960064676
# minimum downstream value:  -1.82768146982
# mean upstream value:  -1.67602145028
# std upstream value:  0.0491471092234
# minimum downstream value:  -1.82768146982
# mean upstream value:  -1.64438895526
# std upstream value:  0.0277098124665
# minimum downstream value:  -1.89700667189
# mean upstream value:  -1.68378361035
# std upstream value:  0.0380176679051
# minimum downstream value:  -1.89700667189
# mean upstream value:  -1.71186078741
# std upstream value:  0.0534135453381
# minimum downstream value:  -1.89700667189
# mean upstream value:  -1.79668103848
# std upstream value:  0.0696260140823
# minimum downstream value:  -1.76924308204
# mean upstream value:  -1.83648826388
# std upstream value:  0.0533829005263
# minimum downstream value:  -1.7336968584
# mean upstream value:  -1.82963161946
# std upstream value:  0.0626420142808
# minimum downstream value:  -1.68077419115
# mean upstream value:  -1.77836586773
# std upstream value:  0.0515407611673
# minimum downstream value:  -1.73177726655
# mean upstream value:  -1.72556559245
# std upstream value:  0.0232588773947
# 840
# (41, 41)
# 881
# 922
# 962
# 1004
# 1045
# 1086
# 1128
# 1169
# 1211
# 1253
# 1254
# 10   10
# 1296
# 1338
# 1379
# 1421
# 1463
# 1504
# 1544
# 1585
# 1625
# node:  39354
# minimum downstream value:  -0.691339063079
# mean upstream value:  -0.0264232369123
# std upstream value:  0.0373681000031
# 840
# (41, 41)
# 881
# 922
# 963
# 1004
# 1045
# 1086
# 1128
# 1169
# 1210
# 1251
# 1292
# 10   10
# 1334
# 1376
# 1418
# 1419
# 1460
# 1502
# 1503
# 1504
# 1505
# node:  42581
# minimum downstream value:  -0.566917449589
# mean upstream value:  -0.586691111287
# std upstream value:  0.0213918903132
# minimum downstream value:  -0.564079556069
# mean upstream value:  -0.604082833794
# std upstream value:  0.0432810751558
# minimum downstream value:  -0.604523187569
# mean upstream value:  -0.584263415833
# std upstream value:  0.0561077127487
# minimum downstream value:  -0.604523187569
# mean upstream value:  -0.548340768525
# std upstream value:  0.0871312320946
# minimum downstream value:  -0.609998016961
# mean upstream value:  -0.493793271433
# std upstream value:  0.0335285509322
# minimum downstream value:  -0.609998016961
# mean upstream value:  -0.48453804187
# std upstream value:  0.0241457961102
# minimum downstream value:  -0.609998016961
# mean upstream value:  -0.490698813136
# std upstream value:  0.0155030008676
# minimum downstream value:  -0.662173184482
# mean upstream value:  -0.450082530146
# std upstream value:  0.0538841740142
# minimum downstream value:  -0.662173184482
# mean upstream value:  -0.28191008838
# std upstream value:  0.20287577409
# minimum downstream value:  -0.662173184482
# mean upstream value:  -0.125560614745
# std upstream value:  0.177569524273
# minimum downstream value:  -0.532283013988
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 595
# 555
# 515
# 516
# 476
# 518
# 10   10
# 519
# 479
# 480
# 522
# 523
# 524
# 484
# 485
# 486
# node:  43106
# minimum downstream value:  -0.674468752895
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 923
# 964
# 1006
# 1047
# 1089
# 1131
# 1172
# 1214
# 1256
# 1297
# 10   10
# 1339
# 1380
# 1422
# 1464
# 1506
# 1548
# 1590
# 1632
# 1633
# node:  45345
# minimum downstream value:  -0.415179226238
# mean upstream value:  -0.054685529827
# std upstream value:  0.0773370179469
# 840
# (41, 41)
# 839
# 838
# 837
# 836
# 835
# 875
# 915
# 956
# 955
# 954
# 953
# 10   10
# 952
# 992
# 1032
# 1072
# 1112
# 1152
# 1192
# 1232
# 1231
# node:  46260
# minimum downstream value:  -0.34887502316
# mean upstream value:  -0.189084139737
# std upstream value:  0.121146672622
# minimum downstream value:  -0.363263035951
# mean upstream value:  -0.0745698026675
# std upstream value:  0.0500489199588
# 840
# (41, 41)
# 881
# 923
# 965
# 1007
# 1008
# 1049
# 1091
# 1092
# 1093
# 1094
# 1136
# 10   10
# 1178
# 1220
# 1261
# 1302
# 1344
# 1386
# 1428
# 1470
# 1512
# node:  51782
# minimum downstream value:  -0.532283013988
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 924
# 966
# 1007
# 1049
# 1050
# 1091
# 1132
# 1173
# 1213
# 1255
# 10   10
# 1297
# 1339
# 1381
# 1423
# 1465
# 1507
# 1549
# 1591
# 1632
# node:  55133
# minimum downstream value:  -1.21576024233
# mean upstream value:  -0.477040729347
# std upstream value:  0.328304587665
# minimum downstream value:  -1.21576024233
# mean upstream value:  -0.225022468014
# std upstream value:  0.306882773206
# minimum downstream value:  -1.21576024233
# mean upstream value:  -0.00538243229681
# std upstream value:  0.00761190875271
# 840
# (41, 41)
# 882
# 923
# 965
# 966
# 1007
# 1048
# 1089
# 1129
# 1171
# 1213
# 1255
# 10   10
# 1297
# 1339
# 1381
# 1423
# 1465
# 1507
# 1548
# 1590
# 1591
# node:  56975
# minimum downstream value:  -1.21576024233
# mean upstream value:  -0.00538243229681
# std upstream value:  0.00761190875271
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 889
# 890
# 932
# 933
# 10   10
# 934
# 976
# 936
# 978
# 979
# 939
# 980
# 1022
# 1023
# node:  58704
# minimum downstream value:  -0.927162984614
# mean upstream value:  -1.03556089942
# std upstream value:  0.0916004286607
# minimum downstream value:  -0.932173657323
# mean upstream value:  -0.976852718549
# std upstream value:  0.103819138758
# minimum downstream value:  -0.974806472718
# mean upstream value:  -0.852861004856
# std upstream value:  0.0717876332388
# minimum downstream value:  -1.12084008017
# mean upstream value:  -0.791944219818
# std upstream value:  0.0755543854698
# minimum downstream value:  -1.12084008017
# mean upstream value:  -0.733881652591
# std upstream value:  0.012548960046
# minimum downstream value:  -1.12352719514
# mean upstream value:  -0.707229634362
# std upstream value:  0.0252236560662
# minimum downstream value:  -1.12352719514
# mean upstream value:  -0.685245317904
# std upstream value:  0.0275098384055
# minimum downstream value:  -1.12352719514
# mean upstream value:  -0.657172965752
# std upstream value:  0.0133536904163
# minimum downstream value:  -0.909222387985
# mean upstream value:  -0.642160287488
# std upstream value:  0.0140009049112
# minimum downstream value:  -0.89780857252
# mean upstream value:  -0.612700249995
# std upstream value:  0.0291566685153
# minimum downstream value:  -0.751552054062
# mean upstream value:  -0.587306488801
# std upstream value:  0.0279926715378
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 845
# 846
# 888
# 889
# 931
# 932
# 933
# 10   10
# 975
# 935
# 977
# 978
# 938
# 939
# 981
# 1021
# 1022
# node:  58705
# minimum downstream value:  -0.932173657323
# mean upstream value:  -0.976852718549
# std upstream value:  0.103819138758
# minimum downstream value:  -0.974806472718
# mean upstream value:  -0.852861004856
# std upstream value:  0.0717876332388
# minimum downstream value:  -1.12084008017
# mean upstream value:  -0.791944219818
# std upstream value:  0.0755543854698
# minimum downstream value:  -1.12084008017
# mean upstream value:  -0.733881652591
# std upstream value:  0.012548960046
# minimum downstream value:  -1.12352719514
# mean upstream value:  -0.707229634362
# std upstream value:  0.0252236560662
# minimum downstream value:  -1.12352719514
# mean upstream value:  -0.685245317904
# std upstream value:  0.0275098384055
# minimum downstream value:  -1.12352719514
# mean upstream value:  -0.657172965752
# std upstream value:  0.0133536904163
# minimum downstream value:  -0.909222387985
# mean upstream value:  -0.642160287488
# std upstream value:  0.0140009049112
# minimum downstream value:  -0.89780857252
# mean upstream value:  -0.630141990772
# std upstream value:  0.00660464492852
# minimum downstream value:  -0.751552054062
# mean upstream value:  -0.622726902817
# std upstream value:  0.00402913390034
# minimum downstream value:  -0.726472032871
# mean upstream value:  -0.601615091558
# std upstream value:  0.0273109824712
# 840
# (41, 41)
# 881
# 921
# 961
# 1001
# 1042
# 1083
# 1123
# 1164
# 1205
# 1246
# 1288
# 10   10
# 1329
# 1371
# 1412
# 1454
# 1495
# 1536
# 1577
# 1618
# 1617
# node:  59138
# minimum downstream value:  -0.579919747213
# mean upstream value:  -0.121025638304
# std upstream value:  0.0160178819227
# 840
# (41, 41)
# 882
# 924
# 965
# 1006
# 1047
# 1089
# 1131
# 1173
# 1215
# 1256
# 1298
# 10   10
# 1299
# 1341
# 1383
# 1424
# 1466
# 1508
# 1550
# 1592
# 1634
# node:  66088
# minimum downstream value:  -0.907171558486
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 881
# 922
# 962
# 1003
# 1044
# 1085
# 1126
# 1167
# 1208
# 1249
# 1290
# 10   10
# 1331
# 1372
# 1413
# 1455
# 1496
# 1537
# 1578
# 1619
# 1620
# node:  90417
# minimum downstream value:  -0.385188649294
# mean upstream value:  -0.222858092216
# std upstream value:  0.0343068064242
# minimum downstream value:  -0.385342202168
# mean upstream value:  -0.249237744076
# std upstream value:  0.00316342191651
# minimum downstream value:  -0.385342202168
# mean upstream value:  -0.24884085473
# std upstream value:  0.00332821706419
# minimum downstream value:  -0.385342202168
# mean upstream value:  -0.251389132815
# std upstream value:  0.00303567577017
# minimum downstream value:  -0.285565282045
# mean upstream value:  -0.244039824515
# std upstream value:  0.00928587434255
# minimum downstream value:  -0.248286914448
# mean upstream value:  -0.223565384333
# std upstream value:  0.0282750032581
# minimum downstream value:  -0.248286914448
# mean upstream value:  -0.204399058627
# std upstream value:  0.0195942331174
# minimum downstream value:  -0.253499027297
# mean upstream value:  -0.199031583562
# std upstream value:  0.0122943567475
# minimum downstream value:  -0.253499027297
# mean upstream value:  -0.195867123811
# std upstream value:  0.0159913941884
# minimum downstream value:  -0.253572124738
# mean upstream value:  -0.181849785002
# std upstream value:  0.0253558760771
# minimum downstream value:  -0.253572124738
# mean upstream value:  -0.153165392568
# std upstream value:  0.0191498942641
# 840
# (41, 41)
# 881
# 922
# 963
# 1004
# 1045
# 1086
# 1128
# 1169
# 1210
# 1251
# 1292
# 10   10
# 1333
# 1374
# 1415
# 1456
# 1497
# 1538
# 1579
# 1620
# 1621
# node:  97776
# minimum downstream value:  -0.253499027297
# mean upstream value:  -0.195867123811
# std upstream value:  0.0159913941884
# minimum downstream value:  -0.253572124738
# mean upstream value:  -0.181849785002
# std upstream value:  0.0253558760771
# minimum downstream value:  -0.253572124738
# mean upstream value:  -0.153165392568
# std upstream value:  0.0191498942641
# minimum downstream value:  -0.253572124738
# mean upstream value:  -0.137742757483
# std upstream value:  0.0115132965309
# minimum downstream value:  -0.231451102396
# mean upstream value:  -0.125101282977
# std upstream value:  0.00637216289221
# minimum downstream value:  -0.215348677202
# mean upstream value:  -0.114406942536
# std upstream value:  0.013402743284
# minimum downstream value:  -0.215348677202
# mean upstream value:  -0.109076498682
# std upstream value:  0.00843604989384
# minimum downstream value:  -0.215348677202
# mean upstream value:  -0.109719619449
# std upstream value:  0.00900132383775
# minimum downstream value:  -0.176179546613
# mean upstream value:  -0.119333058635
# std upstream value:  0.00503854944035
# minimum downstream value:  -0.154021131191
# mean upstream value:  -0.125624142774
# std upstream value:  0.00603641806336
# minimum downstream value:  -0.129911641358
# mean upstream value:  -0.131534179366
# std upstream value:  0.00406025017835
# 840
# (41, 41)
# 881
# 923
# 965
# 1006
# 1048
# 1089
# 1131
# 1172
# 1213
# 1255
# 1297
# 10   10
# 1339
# 1381
# 1422
# 1463
# 1504
# 1546
# 1587
# 1629
# 1630
# node:  101491
# minimum downstream value:  -0.282285908937
# mean upstream value:  -0.0614640106483
# std upstream value:  0.0287568118912
# 840
# (41, 41)
# 880
# 921
# 962
# 1003
# 1044
# 1085
# 1126
# 1167
# 1208
# 1248
# 1288
# 10   10
# 1329
# 1370
# 1410
# 1451
# 1492
# 1533
# 1574
# 1614
# 1613
# node:  128377
# minimum downstream value:  -0.383706556479
# mean upstream value:  -0.104566692207
# std upstream value:  0.00740388973125
# 840
# (41, 41)
# 799
# 758
# 718
# 677
# 637
# 595
# 554
# 513
# 472
# 431
# 390
# 10   10
# 349
# 308
# 267
# 227
# 187
# 146
# 104
# 63
# 64
# node:  261673
# minimum downstream value:  -0.475620073763
# mean upstream value:  -0.211116785746
# std upstream value:  0.0433162465085
# minimum downstream value:  -0.408207708668
# mean upstream value:  -0.161594074234
# std upstream value:  0.0348169986665
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 593
# 552
# 511
# 470
# 429
# 388
# 10   10
# 347
# 306
# 265
# 224
# 183
# 143
# 103
# 62
# 63
# node:  263448
# minimum downstream value:  -0.309565246341
# mean upstream value:  -0.114882317142
# std upstream value:  0.0149292889561
# minimum downstream value:  -0.293244735054
# mean upstream value:  -0.100273805802
# std upstream value:  0.012170956596
# minimum downstream value:  -0.26065123788
# mean upstream value:  -0.0895339101357
# std upstream value:  0.0045579308638
# minimum downstream value:  -0.26065123788
# mean upstream value:  -0.0828545812876
# std upstream value:  0.00531369239765
# minimum downstream value:  -0.21588195077
# mean upstream value:  -0.0794570380049
# std upstream value:  0.00385197633667
# minimum downstream value:  -0.16438757855
# mean upstream value:  -0.0757466392869
# std upstream value:  0.00181460536161
# minimum downstream value:  -0.132049319301
# mean upstream value:  -0.0765442377023
# std upstream value:  0.00208757034138
# minimum downstream value:  -0.116942876884
# mean upstream value:  -0.0801226348274
# std upstream value:  0.00637254785442
# minimum downstream value:  -0.0956547552418
# mean upstream value:  -0.0829230548522
# std upstream value:  0.00444038225697
# minimum downstream value:  -0.0882237852798
# mean upstream value:  -0.0850957536258
# std upstream value:  0.00279413012715
# minimum downstream value:  -0.0847231898854
# mean upstream value:  -0.0826285742959
# std upstream value:  0.00136714578893
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 636
# 596
# 556
# 515
# 474
# 434
# 393
# 10   10
# 353
# 312
# 271
# 231
# 190
# 149
# 109
# 68
# 69
# node:  268066
# minimum downstream value:  -0.405969793146
# mean upstream value:  -0.119749046597
# std upstream value:  0.00873444388953
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 594
# 553
# 512
# 471
# 430
# 389
# 10   10
# 348
# 307
# 267
# 227
# 228
# 229
# 188
# 148
# 149
# node:  270845
# minimum downstream value:  -0.5363894979
# mean upstream value:  -0.107027759979
# std upstream value:  0.0240616303364
# 840
# (41, 41)
# 800
# 801
# 761
# 762
# 763
# 764
# 765
# 725
# 767
# 727
# 687
# 10   10
# 688
# 648
# 649
# 650
# 651
# 611
# 571
# 530
# 489
# node:  300413
# minimum downstream value:  -0.36498577133
# mean upstream value:  -0.0821048299315
# std upstream value:  0.01214559506
# 840
# (41, 41)
# 798
# 757
# 716
# 675
# 634
# 592
# 550
# 508
# 467
# 425
# 383
# 10   10
# 341
# 299
# 258
# 216
# 174
# 132
# 90
# 49
# 48
# node:  313914
# minimum downstream value:  -0.862843871588
# mean upstream value:  -0.161710837142
# std upstream value:  0.00625428695972
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 594
# 553
# 512
# 471
# 430
# 389
# 10   10
# 348
# 307
# 267
# 226
# 184
# 143
# 101
# 60
# 61
# node:  319505
# minimum downstream value:  -0.299411939538
# mean upstream value:  -0.151526932346
# std upstream value:  0.00861156238204
# minimum downstream value:  -0.279297357491
# mean upstream value:  -0.13625893574
# std upstream value:  0.0155394149025
# minimum downstream value:  -0.279297357491
# mean upstream value:  -0.120852825984
# std upstream value:  0.0142545811382
# minimum downstream value:  -0.279297357491
# mean upstream value:  -0.102197136961
# std upstream value:  0.013096137941
# minimum downstream value:  -0.230181426399
# mean upstream value:  -0.0872943863096
# std upstream value:  0.014793442709
# minimum downstream value:  -0.182140847911
# mean upstream value:  -0.0720201173162
# std upstream value:  0.00964223277758
# minimum downstream value:  -0.161315676723
# mean upstream value:  -0.0635838766186
# std upstream value:  0.00515671175793
# minimum downstream value:  -0.152907420524
# mean upstream value:  -0.0607060569391
# std upstream value:  0.00126577812791
# minimum downstream value:  -0.14035769979
# mean upstream value:  -0.0616892939029
# std upstream value:  0.00196234222386
# minimum downstream value:  -0.115511686906
# mean upstream value:  -0.0668564546407
# std upstream value:  0.00550493871021
# minimum downstream value:  -0.106689091256
# mean upstream value:  -0.0722439933043
# std upstream value:  0.00615291193139
# 840
# (41, 41)
# 799
# 757
# 716
# 675
# 633
# 632
# 590
# 548
# 506
# 465
# 424
# 10   10
# 383
# 342
# 300
# 258
# 216
# 175
# 133
# 91
# 49
# node:  320359
# minimum downstream value:  -0.72341352018
# mean upstream value:  -0.845041388108
# std upstream value:  0.0339337499941
# minimum downstream value:  -0.72341352018
# mean upstream value:  -0.854610639127
# std upstream value:  0.0206310171726
# minimum downstream value:  -0.717439794729
# mean upstream value:  -0.771366446072
# std upstream value:  0.104567582635
# minimum downstream value:  -0.783680188326
# mean upstream value:  -0.642611256073
# std upstream value:  0.143296164064
# minimum downstream value:  -0.797545421736
# mean upstream value:  -0.499082783937
# std upstream value:  0.0949681379987
# minimum downstream value:  -0.874734871001
# mean upstream value:  -0.353997151371
# std upstream value:  0.120749351458
# minimum downstream value:  -0.874734871001
# mean upstream value:  -0.249796589687
# std upstream value:  0.103681582638
# minimum downstream value:  -0.874734871001
# mean upstream value:  -0.173901423478
# std upstream value:  0.0113220978354
# 840
# (41, 41)
# 798
# 757
# 717
# 676
# 635
# 594
# 553
# 513
# 472
# 431
# 390
# 10   10
# 350
# 309
# 269
# 228
# 188
# 147
# 107
# 67
# 68
# node:  323193
# minimum downstream value:  -0.276105918432
# mean upstream value:  -0.245838391451
# std upstream value:  0.0120858094803
# minimum downstream value:  -0.276105918432
# mean upstream value:  -0.252351863896
# std upstream value:  0.00297594370855
# minimum downstream value:  -0.258210555367
# mean upstream value:  -0.235555374889
# std upstream value:  0.0216629794204
# minimum downstream value:  -0.213449953102
# mean upstream value:  -0.224947480816
# std upstream value:  0.0178404094705
# minimum downstream value:  -0.228792092546
# mean upstream value:  -0.189731241058
# std upstream value:  0.0339349630156
# minimum downstream value:  -0.255442261225
# mean upstream value:  -0.169576692644
# std upstream value:  0.0366932608129
# minimum downstream value:  -0.255442261225
# mean upstream value:  -0.140890933151
# std upstream value:  0.00395992523758
# minimum downstream value:  -0.255442261225
# mean upstream value:  -0.139709633487
# std upstream value:  0.00377308121578
# minimum downstream value:  -0.253280820583
# mean upstream value:  -0.136453661209
# std upstream value:  0.00191408426481
# minimum downstream value:  -0.248332509881
# mean upstream value:  -0.159503640236
# std upstream value:  0.0319012004176
# minimum downstream value:  -0.221457138363
# mean upstream value:  -0.166729470958
# std upstream value:  0.0287718933423
# 840
# (41, 41)
# 800
# 759
# 718
# 677
# 636
# 596
# 556
# 515
# 475
# 435
# 395
# 10   10
# 396
# 356
# 316
# 276
# 277
# 237
# 197
# 157
# 158
# node:  325179
# minimum downstream value:  -0.687339571625
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 799
# 758
# 759
# 719
# 679
# 639
# 598
# 557
# 517
# 476
# 436
# 10   10
# 396
# 356
# 316
# 275
# 235
# 195
# 154
# 114
# 74
# node:  331418
# minimum downstream value:  -0.786063213122
# mean upstream value:  -0.414974207621
# std upstream value:  0.199787601875
# minimum downstream value:  -0.786063213122
# mean upstream value:  -0.218057423869
# std upstream value:  0.134354063627
# minimum downstream value:  -0.786063213122
# mean upstream value:  -0.0916844545146
# std upstream value:  0.0658934389713
# 840
# (41, 41)
# 800
# 801
# 761
# 762
# 763
# 723
# 683
# 684
# 685
# 686
# 687
# 10   10
# 688
# 648
# 649
# 609
# 610
# 651
# 692
# 733
# 774
# node:  335176
# minimum downstream value:  -1.40897450805
# mean upstream value:  -1.47922203255
# std upstream value:  0.0110622836289
# minimum downstream value:  -1.32362094321
# mean upstream value:  -1.5006865852
# std upstream value:  0.0275022271893
# minimum downstream value:  -1.40990523387
# mean upstream value:  -1.48015287899
# std upstream value:  0.0533525697051
# minimum downstream value:  -1.40990523387
# mean upstream value:  -1.4186564208
# std upstream value:  0.0927729202222
# minimum downstream value:  -1.47252597733
# mean upstream value:  -1.35590560571
# std upstream value:  0.0404959023697
# minimum downstream value:  -1.47252597733
# mean upstream value:  -1.35748347306
# std upstream value:  0.0425626474701
# minimum downstream value:  -1.49481478604
# mean upstream value:  -1.38988369224
# std upstream value:  0.0292449021535
# minimum downstream value:  -1.53691963528
# mean upstream value:  -1.41739160993
# std upstream value:  0.0100536098607
# minimum downstream value:  -1.53691963528
# mean upstream value:  -1.20856798496
# std upstream value:  0.298259325517
# minimum downstream value:  -1.53691963528
# mean upstream value:  -0.794164202744
# std upstream value:  0.517224950701
# minimum downstream value:  -1.40872421566
# mean upstream value:  -0.334159278116
# std upstream value:  0.323511724151
# 840
# (41, 41)
# 841
# 801
# 761
# 762
# 722
# 723
# 724
# 766
# 767
# 809
# 810
# 10   10
# 852
# 853
# 854
# 855
# 856
# 857
# 858
# 818
# 859
# node:  339051
# minimum downstream value:  -0.286998401989
# mean upstream value:  -0.406131186504
# std upstream value:  0.0105740380693
# minimum downstream value:  -0.275918953032
# mean upstream value:  -0.417924240173
# std upstream value:  0.0134820828108
# minimum downstream value:  -0.305234886441
# mean upstream value:  -0.415963757179
# std upstream value:  0.0161051733175
# minimum downstream value:  -0.385204330263
# mean upstream value:  -0.451519429605
# std upstream value:  0.056087452616
# minimum downstream value:  -0.39730412781
# mean upstream value:  -0.491573368922
# std upstream value:  0.0696097347375
# minimum downstream value:  -0.400091118492
# mean upstream value:  -0.552119640808
# std upstream value:  0.0196773782881
# minimum downstream value:  -0.42099831321
# mean upstream value:  -0.568460416731
# std upstream value:  0.0110470050799
# minimum downstream value:  -0.432683288815
# mean upstream value:  -0.554080204216
# std upstream value:  0.0313802532934
# minimum downstream value:  -0.432683288815
# mean upstream value:  -0.512548032014
# std upstream value:  0.051248365497
# minimum downstream value:  -0.527665330487
# mean upstream value:  -0.478959878914
# std upstream value:  0.0239595461437
# minimum downstream value:  -0.552845106766
# mean upstream value:  -0.489382978799
# std upstream value:  0.0378450755739
# 840
# (41, 41)
# 798
# 757
# 715
# 674
# 633
# 592
# 552
# 510
# 468
# 467
# 466
# 10   10
# 424
# 382
# 341
# 300
# 259
# 218
# 177
# 136
# 95
# node:  359685
# minimum downstream value:  -0.249915202145
# mean upstream value:  -0.0926650377758
# std upstream value:  0.0523769084133
# minimum downstream value:  -0.252656356148
# mean upstream value:  -0.0463697511374
# std upstream value:  0.0360276321797
# 840
# (41, 41)
# 841
# 842
# 884
# 885
# 886
# 887
# 888
# 930
# 931
# 932
# 974
# 10   10
# 1016
# 1058
# 1059
# 1101
# 1102
# 1144
# 1145
# 1187
# 1228
# node:  384940
# minimum downstream value:  -0.398553780416
# mean upstream value:  -0.0941095364738
# std upstream value:  0.0281383610323
# 840
# (41, 41)
# 881
# 923
# 924
# 925
# 926
# 927
# 969
# 970
# 1012
# 1013
# 1014
# 10   10
# 1056
# 1057
# 1058
# 1018
# 978
# 938
# 898
# 899
# 941
# node:  394039
# minimum downstream value:  -0.804223463941
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 883
# 884
# 926
# 968
# 969
# 970
# 1012
# 1054
# 1096
# 1097
# 10   10
# 1098
# 1140
# 1141
# 1142
# 1184
# 1185
# 1186
# 1228
# 1269
# node:  403271
# minimum downstream value:  -0.49365403247
# mean upstream value:  -0.120499240237
# std upstream value:  0.0089711088043
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 594
# 554
# 513
# 472
# 430
# 389
# 10   10
# 348
# 306
# 265
# 223
# 181
# 139
# 98
# 57
# 56
# node:  425251
# minimum downstream value:  -0.529706148291
# mean upstream value:  -0.191561451385
# std upstream value:  0.0243540148406
# 840
# (41, 41)
# 841
# 801
# 802
# 803
# 804
# 846
# 847
# 848
# 890
# 891
# 892
# 10   10
# 934
# 935
# 936
# 978
# 1020
# 1062
# 1104
# 1146
# 1187
# node:  432670
# minimum downstream value:  -0.38876198026
# mean upstream value:  -0.0764941390167
# std upstream value:  0.00333183691123
# 840
# (41, 41)
# 882
# 923
# 924
# 966
# 967
# 1009
# 1051
# 1052
# 1094
# 1136
# 1137
# 10   10
# 1179
# 1180
# 1222
# 1223
# 1224
# 1266
# 1308
# 1309
# 1310
# node:  440018
# minimum downstream value:  -0.591669497283
# mean upstream value:  -0.100782552727
# std upstream value:  0.0365884101836
# 840
# (41, 41)
# 799
# 759
# 719
# 679
# 639
# 599
# 559
# 518
# 478
# 438
# 398
# 10   10
# 358
# 318
# 278
# 238
# 197
# 157
# 116
# 75
# 74
# node:  462914
# minimum downstream value:  -0.661249816653
# mean upstream value:  -0.159182421618
# std upstream value:  0.00813542616074
# 840
# (41, 41)
# 841
# 842
# 843
# 885
# 886
# 887
# 888
# 889
# 890
# 932
# 933
# 10   10
# 934
# 935
# 977
# 978
# 979
# 980
# 981
# 982
# 941
# node:  483169
# minimum downstream value:  -0.642743981403
# mean upstream value:  -0.107637106351
# std upstream value:  0.00228215616672
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 848
# 808
# 809
# 769
# 10   10
# 770
# 771
# 772
# 773
# 774
# 775
# 735
# 736
# 777
# node:  498782
# minimum downstream value:  -0.423412699944
# mean upstream value:  -0.0286508190773
# std upstream value:  0.00486156595398
# 840
# (41, 41)
# 841
# 801
# 843
# 844
# 845
# 846
# 847
# 807
# 808
# 809
# 810
# 10   10
# 811
# 812
# 813
# 773
# 733
# 693
# 694
# 695
# 654
# node:  501485
# minimum downstream value:  -0.600590159299
# mean upstream value:  -0.0623578660887
# std upstream value:  0.0093141922312
# 840
# (41, 41)
# 799
# 758
# 716
# 674
# 632
# 591
# 550
# 509
# 468
# 427
# 385
# 10   10
# 343
# 302
# 261
# 221
# 180
# 139
# 99
# 59
# 60
# node:  518918
# minimum downstream value:  -0.674434737255
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 841
# 801
# 761
# 721
# 680
# 640
# 599
# 558
# 518
# 477
# 437
# 10   10
# 397
# 356
# 315
# 275
# 276
# 236
# 196
# 155
# 115
# node:  531790
# minimum downstream value:  -0.922183191352
# mean upstream value:  -0.863134974705
# std upstream value:  0.0274695114737
# minimum downstream value:  -0.832506021492
# mean upstream value:  -0.885406494141
# std upstream value:  0.0139393381066
# minimum downstream value:  -0.832506021492
# mean upstream value:  -0.891556328936
# std upstream value:  0.0052432095108
# minimum downstream value:  -0.832506021492
# mean upstream value:  -0.864640709597
# std upstream value:  0.0356105887051
# minimum downstream value:  -0.831692661693
# mean upstream value:  -0.836356945817
# std upstream value:  0.033838697409
# minimum downstream value:  -0.86569418926
# mean upstream value:  -0.814273396971
# std upstream value:  0.00313396584187
# minimum downstream value:  -0.895425427101
# mean upstream value:  -0.820221148304
# std upstream value:  0.00924083111529
# minimum downstream value:  -0.895425427101
# mean upstream value:  -0.819903347332
# std upstream value:  0.00958819804585
# minimum downstream value:  -0.895425427101
# mean upstream value:  -0.820189424497
# std upstream value:  0.00953661470733
# minimum downstream value:  -0.89509986606
# mean upstream value:  -0.822848353932
# std upstream value:  0.0130640264383
# minimum downstream value:  -0.884143693645
# mean upstream value:  -0.858069740265
# std upstream value:  0.0411951109929
# 840
# (41, 41)
# 841
# 801
# 802
# 762
# 722
# 682
# 641
# 601
# 561
# 521
# 481
# 10   10
# 482
# 442
# 402
# 403
# 404
# 405
# 365
# 366
# 367
# node:  540217
# minimum downstream value:  -0.972609810207
# mean upstream value:  -1.05946299838
# std upstream value:  0.0234730324562
# minimum downstream value:  -0.981671359699
# mean upstream value:  -1.08642385128
# std upstream value:  0.0189631129647
# minimum downstream value:  -0.999975031072
# mean upstream value:  -1.12071169726
# std upstream value:  0.0336356259541
# minimum downstream value:  -1.03163514872
# mean upstream value:  -1.15654347537
# std upstream value:  0.0348557767477
# minimum downstream value:  -1.03163514872
# mean upstream value:  -1.22399713368
# std upstream value:  0.0633534406641
# minimum downstream value:  -1.06339007592
# mean upstream value:  -1.32040562083
# std upstream value:  0.10709304579
# minimum downstream value:  -1.08604606055
# mean upstream value:  -1.39498044945
# std upstream value:  0.0605803166441
# minimum downstream value:  -1.10983541737
# mean upstream value:  -1.43302706391
# std upstream value:  0.0163020948968
# minimum downstream value:  -1.16625361386
# mean upstream value:  -1.40303395388
# std upstream value:  0.0267977666765
# minimum downstream value:  -1.19354139486
# mean upstream value:  -1.42414950445
# std upstream value:  0.0470200296904
# minimum downstream value:  -1.31219639232
# mean upstream value:  -1.45754896322
# std upstream value:  0.0677347928612
# 840
# (41, 41)
# 800
# 760
# 719
# 679
# 638
# 597
# 557
# 517
# 477
# 437
# 397
# 10   10
# 357
# 316
# 276
# 236
# 196
# 156
# 116
# 76
# 77
# node:  542200
# minimum downstream value:  -0.292293020859
# mean upstream value:  -0.208566135412
# std upstream value:  0.028296255756
# minimum downstream value:  -0.258146384017
# mean upstream value:  -0.18526980434
# std upstream value:  0.0267175285653
# minimum downstream value:  -0.249092071895
# mean upstream value:  -0.163844896399
# std upstream value:  0.00423651957311
# minimum downstream value:  -0.226530655571
# mean upstream value:  -0.157318879179
# std upstream value:  0.00594604241885
# minimum downstream value:  -0.233726531621
# mean upstream value:  -0.154390759776
# std upstream value:  0.0037852822607
# minimum downstream value:  -0.233726531621
# mean upstream value:  -0.158277428668
# std upstream value:  0.00881625799939
# minimum downstream value:  -0.233726531621
# mean upstream value:  -0.171611599928
# std upstream value:  0.0140768765715
# minimum downstream value:  -0.222934647511
# mean upstream value:  -0.183496849653
# std upstream value:  0.00933139158629
# minimum downstream value:  -0.169037227103
# mean upstream value:  -0.191944750558
# std upstream value:  0.00267849054752
# minimum downstream value:  -0.163837538406
# mean upstream value:  -0.194286482136
# std upstream value:  0.00255194022146
# minimum downstream value:  -0.158659923689
# mean upstream value:  -0.198303946393
# std upstream value:  0.00316970917955
# 840
# (41, 41)
# 881
# 923
# 964
# 1005
# 1047
# 1088
# 1130
# 1171
# 1212
# 1254
# 1295
# 10   10
# 1337
# 1378
# 1420
# 1461
# 1503
# 1543
# 1583
# 1623
# 1622
# node:  543850
# minimum downstream value:  -1.17493640764
# mean upstream value:  -0.0196201088243
# std upstream value:  0.0136618985604
# 840
# (41, 41)
# 882
# 842
# 843
# 844
# 804
# 805
# 806
# 766
# 767
# 768
# 728
# 10   10
# 729
# 730
# 731
# 732
# 692
# 693
# 653
# 654
# 613
# node:  544964
# minimum downstream value:  -0.306285390741
# mean upstream value:  -0.170707974038
# std upstream value:  0.00160154028318
# minimum downstream value:  -0.322083484514
# mean upstream value:  -0.17095806539
# std upstream value:  0.00185453602142
# minimum downstream value:  -0.322083484514
# mean upstream value:  -0.177797179291
# std upstream value:  0.00794967126742
# minimum downstream value:  -0.322083484514
# mean upstream value:  -0.176938183851
# std upstream value:  0.00869548905602
# minimum downstream value:  -0.228918746526
# mean upstream value:  -0.169111731809
# std upstream value:  0.0161383659723
# minimum downstream value:  -0.184354276996
# mean upstream value:  -0.147484740407
# std upstream value:  0.0183147915722
# minimum downstream value:  -0.172205989069
# mean upstream value:  -0.127991888677
# std upstream value:  0.0161960300178
# minimum downstream value:  -0.172956263124
# mean upstream value:  -0.113672550488
# std upstream value:  0.00755617588393
# minimum downstream value:  -0.189005131778
# mean upstream value:  -0.105233535465
# std upstream value:  0.00480907524801
# minimum downstream value:  -0.189005131778
# mean upstream value:  -0.110954596277
# std upstream value:  0.0121413747485
# minimum downstream value:  -0.189005131778
# mean upstream value:  -0.110492047899
# std upstream value:  0.012326570408
# 840
# (41, 41)
# 799
# 758
# 717
# 676
# 635
# 595
# 555
# 514
# 474
# 434
# 394
# 10   10
# 353
# 313
# 273
# 233
# 193
# 194
# 154
# 114
# 74
# node:  546746
# minimum downstream value:  -1.04174864999
# mean upstream value:  -0.0142877752131
# std upstream value:  0.0202059654825
# 840
# (41, 41)
# 881
# 922
# 963
# 1003
# 1044
# 1085
# 1125
# 1166
# 1208
# 1249
# 1290
# 10   10
# 1331
# 1372
# 1413
# 1454
# 1495
# 1536
# 1577
# 1618
# 1619
# node:  557697
# minimum downstream value:  -0.312007014459
# mean upstream value:  -0.12926265028
# std upstream value:  0.0165791049929
# minimum downstream value:  -0.312007014459
# mean upstream value:  -0.118828412887
# std upstream value:  0.00568614549102
# minimum downstream value:  -0.312007014459
# mean upstream value:  -0.123228211334
# std upstream value:  0.00228335615243
# minimum downstream value:  -0.262489771183
# mean upstream value:  -0.124201878886
# std upstream value:  0.00328602880175
# minimum downstream value:  -0.248472070505
# mean upstream value:  -0.134565270465
# std upstream value:  0.0117831506581
# minimum downstream value:  -0.194875121588
# mean upstream value:  -0.145185709314
# std upstream value:  0.012313268871
# minimum downstream value:  -0.151318938365
# mean upstream value:  -0.169977723374
# std upstream value:  0.0230414741493
# minimum downstream value:  -0.125122190935
# mean upstream value:  -0.182292269781
# std upstream value:  0.0192203560119
# minimum downstream value:  -0.125122190935
# mean upstream value:  -0.190077026528
# std upstream value:  0.00936024617688
# minimum downstream value:  -0.128043193591
# mean upstream value:  -0.177539448493
# std upstream value:  0.00961837363635
# minimum downstream value:  -0.151106400923
# mean upstream value:  -0.163050152725
# std upstream value:  0.0144156287723
# 840
# (41, 41)
# 881
# 923
# 964
# 1005
# 1046
# 1086
# 1127
# 1169
# 1209
# 1250
# 1291
# 10   10
# 1332
# 1372
# 1413
# 1454
# 1494
# 1535
# 1576
# 1617
# 1618
# node:  557760
# minimum downstream value:  -0.89762751764
# mean upstream value:  -0.592037919639
# std upstream value:  0.0237791221667
# minimum downstream value:  -0.89762751764
# mean upstream value:  -0.543681832013
# std upstream value:  0.0921629770955
# minimum downstream value:  -0.89762751764
# mean upstream value:  -0.340877125857
# std upstream value:  0.253963555178
# minimum downstream value:  -0.59845477319
# mean upstream value:  -0.137781557829
# std upstream value:  0.194852547727
# minimum downstream value:  -0.558412936365
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 880
# 921
# 963
# 1003
# 1044
# 1085
# 1126
# 1166
# 1207
# 1248
# 1288
# 10   10
# 1329
# 1370
# 1411
# 1452
# 1493
# 1534
# 1576
# 1618
# node:  562361
# minimum downstream value:  -0.608414118469
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 800
# 801
# 761
# 762
# 763
# 723
# 683
# 684
# 685
# 686
# 646
# 10   10
# 647
# 607
# 567
# 527
# 486
# 445
# 405
# 365
# 324
# node:  567009
# minimum downstream value:  -1.0993151759
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 883
# 884
# 926
# 927
# 887
# 929
# 930
# 972
# 973
# 1015
# 10   10
# 975
# 1017
# 1058
# 1100
# 1142
# 1183
# 1224
# 1265
# 1266
# node:  578971
# minimum downstream value:  -0.504593438311
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 883
# 884
# 926
# 968
# 1010
# 1052
# 1093
# 1135
# 1176
# 1218
# 10   10
# 1260
# 1302
# 1344
# 1385
# 1426
# 1467
# 1508
# 1549
# 1590
# node:  582440
# minimum downstream value:  -0.274664113644
# mean upstream value:  -0.255613425032
# std upstream value:  0.0153291029588
# minimum downstream value:  -0.267454245345
# mean upstream value:  -0.25041180637
# std upstream value:  0.0166028364933
# minimum downstream value:  -0.250444374537
# mean upstream value:  -0.269693206264
# std upstream value:  0.0217296145761
# minimum downstream value:  -0.24927457425
# mean upstream value:  -0.304521804428
# std upstream value:  0.0563730316899
# minimum downstream value:  -0.256905416255
# mean upstream value:  -0.305898151222
# std upstream value:  0.0548423071129
# minimum downstream value:  -0.256905416255
# mean upstream value:  -0.285356604535
# std upstream value:  0.0658596594104
# minimum downstream value:  -0.273708298272
# mean upstream value:  -0.228284752887
# std upstream value:  0.0159709901927
# minimum downstream value:  -0.273708298272
# mean upstream value:  -0.205213624655
# std upstream value:  0.0229896603053
# minimum downstream value:  -0.294070760252
# mean upstream value:  -0.18508452766
# std upstream value:  0.0155741607969
# minimum downstream value:  -0.378194092762
# mean upstream value:  -0.177354372851
# std upstream value:  0.00485560453766
# 840
# (41, 41)
# 882
# 924
# 966
# 1008
# 1049
# 1090
# 1131
# 1172
# 1213
# 1254
# 1295
# 10   10
# 1337
# 1378
# 1420
# 1461
# 1503
# 1544
# 1585
# 1627
# 1628
# node:  589808
# minimum downstream value:  -0.378194092762
# mean upstream value:  -0.185037685791
# std upstream value:  0.0111424350877
# minimum downstream value:  -0.378194092762
# mean upstream value:  -0.200279467034
# std upstream value:  0.0138973330123
# minimum downstream value:  -0.245429600652
# mean upstream value:  -0.225277786355
# std upstream value:  0.0248687264268
# minimum downstream value:  -0.232446120191
# mean upstream value:  -0.247513722054
# std upstream value:  0.021225957986
# minimum downstream value:  -0.20697853782
# mean upstream value:  -0.270729959561
# std upstream value:  0.0121701320296
# minimum downstream value:  -0.183788073393
# mean upstream value:  -0.277749846889
# std upstream value:  0.0088846817623
# minimum downstream value:  -0.199266154776
# mean upstream value:  -0.270611387311
# std upstream value:  0.0186809030494
# minimum downstream value:  -0.217784172933
# mean upstream value:  -0.240390460953
# std upstream value:  0.0340420681719
# minimum downstream value:  -0.258783031358
# mean upstream value:  -0.212677846313
# std upstream value:  0.0225431009382
# minimum downstream value:  -0.265973961872
# mean upstream value:  -0.202458920686
# std upstream value:  0.00809138584
# minimum downstream value:  -0.287432885453
# mean upstream value:  -0.206283267779
# std upstream value:  0.00715610126221
# 840
# (41, 41)
# 881
# 923
# 964
# 1006
# 1047
# 1089
# 1130
# 1171
# 1213
# 1255
# 1256
# 10   10
# 1297
# 1339
# 1381
# 1422
# 1463
# 1504
# 1546
# 1588
# 1630
# node:  599012
# minimum downstream value:  -0.287432885453
# mean upstream value:  -0.206283267779
# std upstream value:  0.00715610126221
# minimum downstream value:  -0.287432885453
# mean upstream value:  -0.216806685658
# std upstream value:  0.00843202437414
# minimum downstream value:  -0.287432885453
# mean upstream value:  -0.224598559152
# std upstream value:  0.0121349377629
# minimum downstream value:  -0.279842693344
# mean upstream value:  -0.237292464386
# std upstream value:  0.00736879145698
# minimum downstream value:  -0.244558583135
# mean upstream value:  -0.24615253353
# std upstream value:  0.00717717551211
# minimum downstream value:  -0.213901806255
# mean upstream value:  -0.257499845603
# std upstream value:  0.0103738911699
# minimum downstream value:  -0.213901806255
# mean upstream value:  -0.276248695665
# std upstream value:  0.0197893972173
# minimum downstream value:  -0.22827510306
# mean upstream value:  -0.290133630805
# std upstream value:  0.0135318719633
# minimum downstream value:  -0.237277426739
# mean upstream value:  -0.271716694587
# std upstream value:  0.0394269068037
# minimum downstream value:  -0.246324863358
# mean upstream value:  -0.260956212623
# std upstream value:  0.0334967704501
# minimum downstream value:  -0.254855310493
# mean upstream value:  -0.261237625705
# std upstream value:  0.0337964892296
# 840
# (41, 41)
# 841
# 801
# 760
# 720
# 680
# 640
# 600
# 560
# 520
# 480
# 440
# 10   10
# 441
# 401
# 402
# 403
# 363
# 323
# 324
# 284
# 244
# node:  603900
# minimum downstream value:  -1.20180707487
# mean upstream value:  -0.0330964139956
# std upstream value:  0.0332932794373
# 840
# (41, 41)
# 881
# 921
# 961
# 1002
# 1043
# 1084
# 1124
# 1165
# 1207
# 1248
# 1289
# 10   10
# 1330
# 1370
# 1411
# 1451
# 1492
# 1532
# 1572
# 1612
# 1611
# node:  604747
# minimum downstream value:  -0.835848842214
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 881
# 923
# 965
# 966
# 1007
# 1049
# 1091
# 1132
# 1173
# 1214
# 1256
# 10   10
# 1298
# 1340
# 1381
# 1422
# 1463
# 1505
# 1546
# 1587
# 1629
# node:  605455
# minimum downstream value:  -0.22827510306
# mean upstream value:  -0.290133630805
# std upstream value:  0.0135318719633
# minimum downstream value:  -0.237277426739
# mean upstream value:  -0.271716694587
# std upstream value:  0.0394269068037
# minimum downstream value:  -0.246324863358
# mean upstream value:  -0.260956212623
# std upstream value:  0.0334967704501
# minimum downstream value:  -0.254855310493
# mean upstream value:  -0.261237625705
# std upstream value:  0.0337964892296
# minimum downstream value:  -0.271319362957
# mean upstream value:  -0.29080879704
# std upstream value:  0.0148224941709
# minimum downstream value:  -0.302571413545
# mean upstream value:  -0.279028810845
# std upstream value:  0.0313155797759
# minimum downstream value:  -0.302571413545
# mean upstream value:  -0.246876592221
# std upstream value:  0.0432409764826
# minimum downstream value:  -0.302571413545
# mean upstream value:  -0.177365791813
# std upstream value:  0.0590184107946
# minimum downstream value:  -0.296510115914
# mean upstream value:  -0.107522876523
# std upstream value:  0.0720800889928
# minimum downstream value:  -0.29735435516
# mean upstream value:  -0.0405569767606
# std upstream value:  0.0407252335538
# 840
# (41, 41)
# 841
# 842
# 843
# 885
# 927
# 969
# 1011
# 1053
# 1095
# 1096
# 1138
# 10   10
# 1139
# 1140
# 1100
# 1101
# 1102
# 1103
# 1063
# 1064
# 1023
# node:  608500
# minimum downstream value:  -1.12267258233
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 923
# 964
# 1005
# 1046
# 1088
# 1129
# 1170
# 1211
# 1252
# 1293
# 10   10
# 1334
# 1376
# 1418
# 1458
# 1499
# 1540
# 1582
# 1623
# 1624
# node:  610925
# minimum downstream value:  -0.350941895496
# mean upstream value:  -0.0990682207391
# std upstream value:  0.0280013555555
# 840
# (41, 41)
# 841
# 801
# 802
# 762
# 721
# 681
# 640
# 600
# 560
# 520
# 480
# 10   10
# 440
# 400
# 359
# 319
# 278
# 238
# 197
# 157
# 117
# node:  618789
# minimum downstream value:  -0.236924966805
# mean upstream value:  -0.204769290326
# std upstream value:  0.0266412939502
# minimum downstream value:  -0.236924966805
# mean upstream value:  -0.179501579998
# std upstream value:  0.0400376321803
# minimum downstream value:  -0.231597176654
# mean upstream value:  -0.146957216527
# std upstream value:  0.0156048363953
# minimum downstream value:  -0.2303013255
# mean upstream value:  -0.139895754526
# std upstream value:  0.00563343473738
# minimum downstream value:  -0.212361211362
# mean upstream value:  -0.159636968681
# std upstream value:  0.026065056671
# minimum downstream value:  -0.232932833344
# mean upstream value:  -0.163329877087
# std upstream value:  0.0229545645379
# minimum downstream value:  -0.232932833344
# mean upstream value:  -0.184052639485
# std upstream value:  0.0272645201232
# minimum downstream value:  -0.232932833344
# mean upstream value:  -0.16220386289
# std upstream value:  0.0344319603146
# minimum downstream value:  -0.169013826272
# mean upstream value:  -0.156941691563
# std upstream value:  0.0375165651699
# minimum downstream value:  -0.147829440271
# mean upstream value:  -0.12818199027
# std upstream value:  0.00315943197084
# minimum downstream value:  -0.195781722842
# mean upstream value:  -0.118094623953
# std upstream value:  0.0131173578371
# 840
# (41, 41)
# 882
# 883
# 884
# 885
# 927
# 928
# 929
# 930
# 972
# 973
# 974
# 10   10
# 975
# 1017
# 1018
# 978
# 979
# 980
# 981
# 941
# 900
# node:  626943
# minimum downstream value:  -1.82879614547
# mean upstream value:  -1.77718613616
# std upstream value:  0.0659396323759
# minimum downstream value:  -1.82879614547
# mean upstream value:  -1.77455704077
# std upstream value:  0.0643947646968
# minimum downstream value:  -1.8316530974
# mean upstream value:  -1.81814217348
# std upstream value:  0.00811442552244
# minimum downstream value:  -1.858000744
# mean upstream value:  -1.76976980177
# std upstream value:  0.0605540965353
# minimum downstream value:  -1.858000744
# mean upstream value:  -1.79001851641
# std upstream value:  0.0782621719397
# minimum downstream value:  -1.858000744
# mean upstream value:  -1.68444313582
# std upstream value:  0.152186938122
# minimum downstream value:  -1.82929335281
# mean upstream value:  -1.55607052126
# std upstream value:  0.237041020283
# minimum downstream value:  -1.82929335281
# mean upstream value:  -1.32466593907
# std upstream value:  0.13246814441
# minimum downstream value:  -1.82929335281
# mean upstream value:  -1.20971197196
# std upstream value:  0.0638973532472
# minimum downstream value:  -1.81491269801
# mean upstream value:  -1.15625390014
# std upstream value:  0.0156788949
# minimum downstream value:  -1.87096661353
# mean upstream value:  -1.15024587759
# std upstream value:  0.00846781585913
# 840
# (41, 41)
# 841
# 842
# 884
# 926
# 927
# 969
# 1011
# 1012
# 1054
# 1055
# 1097
# 10   10
# 1139
# 1181
# 1222
# 1263
# 1304
# 1345
# 1387
# 1429
# 1471
# node:  628804
# minimum downstream value:  -1.3674901427
# mean upstream value:  -1.67086160733
# std upstream value:  0.0833873813064
# minimum downstream value:  -1.44414028726
# mean upstream value:  -1.7306498853
# std upstream value:  0.0518515648496
# minimum downstream value:  -1.44414028726
# mean upstream value:  -1.80360844829
# std upstream value:  0.0531398907153
# minimum downstream value:  -1.48812564654
# mean upstream value:  -1.82135448029
# std upstream value:  0.0506424423089
# minimum downstream value:  -1.57540688496
# mean upstream value:  -1.82394457429
# std upstream value:  0.0472563531695
# minimum downstream value:  -1.65861830881
# mean upstream value:  -1.70327396921
# std upstream value:  0.135765496726
# minimum downstream value:  -1.77855962821
# mean upstream value:  -1.65539245203
# std upstream value:  0.103487799824
# minimum downstream value:  -1.77855962821
# mean upstream value:  -1.63752241976
# std upstream value:  0.0867114123304
# minimum downstream value:  -1.87749399781
# mean upstream value:  -1.64485427796
# std upstream value:  0.0763990699594
# minimum downstream value:  -1.87749399781
# mean upstream value:  -1.61945207317
# std upstream value:  0.0701967743271
# minimum downstream value:  -1.87749399781
# mean upstream value:  -1.61859231378
# std upstream value:  0.0691028454523
# 840
# (41, 41)
# 841
# 883
# 884
# 885
# 886
# 887
# 929
# 930
# 931
# 932
# 933
# 10   10
# 934
# 935
# 936
# 937
# 938
# 898
# 858
# 818
# 777
# node:  629823
# minimum downstream value:  -0.292192300789
# mean upstream value:  -0.162847908432
# std upstream value:  0.00695052280087
# minimum downstream value:  -0.251442890393
# mean upstream value:  -0.188427348382
# std upstream value:  0.0294141232724
# minimum downstream value:  -0.251442890393
# mean upstream value:  -0.211807592741
# std upstream value:  0.0300630947847
# minimum downstream value:  -0.232288828009
# mean upstream value:  -0.233658580755
# std upstream value:  0.00263857219238
# minimum downstream value:  -0.232288828009
# mean upstream value:  -0.236791236284
# std upstream value:  0.0018724492001
# minimum downstream value:  -0.168676685439
# mean upstream value:  -0.245415889856
# std upstream value:  0.0117837384583
# minimum downstream value:  -0.169435161847
# mean upstream value:  -0.267017188594
# std upstream value:  0.0249315506361
# minimum downstream value:  -0.229974316985
# mean upstream value:  -0.272105944486
# std upstream value:  0.0197994127069
# minimum downstream value:  -0.236013299392
# mean upstream value:  -0.275876252548
# std upstream value:  0.0185308395141
# minimum downstream value:  -0.236013299392
# mean upstream value:  -0.247972330086
# std upstream value:  0.0237899607414
# minimum downstream value:  -0.239372283574
# mean upstream value:  -0.213658590405
# std upstream value:  0.0496320636119
# 840
# (41, 41)
# 841
# 842
# 843
# 803
# 763
# 723
# 724
# 684
# 685
# 645
# 646
# 10   10
# 647
# 607
# 608
# 568
# 528
# 488
# 448
# 408
# 367
# node:  631676
# minimum downstream value:  -0.299792022102
# mean upstream value:  -0.161474858662
# std upstream value:  0.0065683047406
# minimum downstream value:  -0.299792022102
# mean upstream value:  -0.157933573164
# std upstream value:  0.00190713664513
# minimum downstream value:  -0.273198184289
# mean upstream value:  -0.151097796494
# std upstream value:  0.00949094975007
# minimum downstream value:  -0.273198184289
# mean upstream value:  -0.139555356876
# std upstream value:  0.0160495832705
# minimum downstream value:  -0.216080254717
# mean upstream value:  -0.123268539569
# std upstream value:  0.0110962440739
# minimum downstream value:  -0.170593985456
# mean upstream value:  -0.114026176443
# std upstream value:  0.00477321627405
# minimum downstream value:  -0.170593985456
# mean upstream value:  -0.104491986462
# std upstream value:  0.00873193576982
# minimum downstream value:  -0.15997012896
# mean upstream value:  -0.0896253824548
# std upstream value:  0.0179307936572
# minimum downstream value:  -0.15997012896
# mean upstream value:  -0.0669554457834
# std upstream value:  0.0203950916495
# minimum downstream value:  -0.15997012896
# mean upstream value:  -0.0468577911417
# std upstream value:  0.014523289941
# minimum downstream value:  -0.137939332502
# mean upstream value:  -0.0304187880203
# std upstream value:  0.0102609254146
# 840
# (41, 41)
# 881
# 923
# 964
# 1005
# 1047
# 1088
# 1129
# 1170
# 1211
# 1252
# 1293
# 10   10
# 1334
# 1374
# 1414
# 1454
# 1495
# 1536
# 1577
# 1618
# 1619
# node:  636102
# minimum downstream value:  -1.14207645461
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 882
# 924
# 965
# 1007
# 1048
# 1049
# 1091
# 1132
# 1174
# 1216
# 1217
# 10   10
# 1259
# 1260
# 1261
# 1262
# 1263
# 1264
# 1265
# 1266
# 1267
# node:  649075
# minimum downstream value:  -1.54171041255
# mean upstream value:  -1.54961153013
# std upstream value:  0.0352756202329
# minimum downstream value:  -1.54171041255
# mean upstream value:  -1.55019663131
# std upstream value:  0.0359643051761
# minimum downstream value:  -1.51205806204
# mean upstream value:  -1.64444050142
# std upstream value:  0.102434794832
# minimum downstream value:  -1.56862824331
# mean upstream value:  -1.69000175788
# std upstream value:  0.0795200803072
# minimum downstream value:  -1.59095239451
# mean upstream value:  -1.69604809828
# std upstream value:  0.0722496617806
# minimum downstream value:  -1.59095239451
# mean upstream value:  -1.55772152626
# std upstream value:  0.134872240733
# minimum downstream value:  -1.59095239451
# mean upstream value:  -1.39708049307
# std upstream value:  0.16542386487
# minimum downstream value:  -1.59270769805
# mean upstream value:  -1.29838097614
# std upstream value:  0.0681982245529
# minimum downstream value:  -1.78749102566
# mean upstream value:  -1.28864968844
# std upstream value:  0.0582891632169
# minimum downstream value:  -1.78749102566
# mean upstream value:  -1.06394088001
# std upstream value:  0.375077983838
# minimum downstream value:  -1.78749102566
# mean upstream value:  -0.802363620602
# std upstream value:  0.382515166935
# 840
# (41, 41)
# 800
# 801
# 761
# 762
# 763
# 764
# 765
# 766
# 726
# 727
# 687
# 10   10
# 688
# 648
# 608
# 609
# 610
# 570
# 530
# 531
# 490
# node:  658378
# minimum downstream value:  -0.281552883947
# mean upstream value:  -0.228862576491
# std upstream value:  0.0310277265702
# minimum downstream value:  -0.282338500494
# mean upstream value:  -0.249061795563
# std upstream value:  0.00494466735329
# minimum downstream value:  -0.282338500494
# mean upstream value:  -0.254411659693
# std upstream value:  0.00628221567789
# minimum downstream value:  -0.282338500494
# mean upstream value:  -0.245495420514
# std upstream value:  0.0130202694718
# minimum downstream value:  -0.24320869295
# mean upstream value:  -0.258457872393
# std upstream value:  0.022794343369
# minimum downstream value:  -0.245115378157
# mean upstream value:  -0.258865255926
# std upstream value:  0.0228499380028
# minimum downstream value:  -0.256034398739
# mean upstream value:  -0.270116109936
# std upstream value:  0.0104734017784
# minimum downstream value:  -0.256034398739
# mean upstream value:  -0.253916623564
# std upstream value:  0.0124423452231
# minimum downstream value:  -0.261164970549
# mean upstream value:  -0.23549321392
# std upstream value:  0.0228373620792
# minimum downstream value:  -0.261164970549
# mean upstream value:  -0.202439540617
# std upstream value:  0.0297608290298
# minimum downstream value:  -0.28492296543
# mean upstream value:  -0.170302319432
# std upstream value:  0.0278095602359
# 840
# (41, 41)
# 881
# 921
# 962
# 1003
# 1044
# 1085
# 1086
# 1128
# 1170
# 1212
# 1253
# 10   10
# 1295
# 1337
# 1379
# 1380
# 1422
# 1464
# 1506
# 1507
# 1549
# node:  663808
# minimum downstream value:  -1.36502087258
# mean upstream value:  -1.44842999726
# std upstream value:  0.119177263821
# minimum downstream value:  -1.38514438071
# mean upstream value:  -1.50842132367
# std upstream value:  0.0562397557174
# minimum downstream value:  -1.38514438071
# mean upstream value:  -1.43786910589
# std upstream value:  0.140553340279
# minimum downstream value:  -1.38514438071
# mean upstream value:  -1.38165500324
# std upstream value:  0.096200346534
# minimum downstream value:  -1.36594942719
# mean upstream value:  -1.35819928919
# std upstream value:  0.0768789724725
# minimum downstream value:  -1.46138452824
# mean upstream value:  -1.43777642734
# std upstream value:  0.0362177966646
# minimum downstream value:  -1.58748267856
# mean upstream value:  -1.45376771869
# std upstream value:  0.0348933746395
# minimum downstream value:  -1.58748267856
# mean upstream value:  -1.50909138354
# std upstream value:  0.0453527337985
# minimum downstream value:  -1.58748267856
# mean upstream value:  -1.46284961323
# std upstream value:  0.0907832706492
# minimum downstream value:  -1.47639676422
# mean upstream value:  -1.37676551628
# std upstream value:  0.149599339204
# minimum downstream value:  -1.41884037063
# mean upstream value:  -1.25573585721
# std upstream value:  0.0664668622139
# 840
# (41, 41)
# 841
# 842
# 843
# 844
# 845
# 846
# 847
# 848
# 849
# 850
# 851
# 10   10
# 852
# 853
# 895
# 896
# 897
# 898
# 899
# 900
# 859
# node:  666586
# minimum downstream value:  -0.850762408713
# mean upstream value:  -0.128261239475
# std upstream value:  0.0227248849762
# 840
# (41, 41)
# 882
# 924
# 965
# 1006
# 1047
# 1089
# 1130
# 1172
# 1213
# 1254
# 1295
# 10   10
# 1336
# 1377
# 1419
# 1461
# 1502
# 1543
# 1584
# 1625
# 1626
# node:  669225
# minimum downstream value:  -0.331599540861
# mean upstream value:  -0.00887008083981
# std upstream value:  0.012544188623
# 840
# (41, 41)
# 881
# 922
# 963
# 1005
# 1046
# 1087
# 1128
# 1169
# 1210
# 1251
# 1292
# 10   10
# 1334
# 1374
# 1414
# 1456
# 1498
# 1539
# 1580
# 1622
# 1623
# node:  689587
# minimum downstream value:  -0.462686169289
# mean upstream value:  0.0
# std upstream value:  0.0
# 840
# (41, 41)
# 880
# 921
# 962
# 1002
# 1043
# 1084
# 1125
# 1166
# 1206
# 1246
# 1288
# 10   10
# 1328
# 1369
# 1411
# 1453
# 1494
# 1535
# 1577
# 1618
# 1619
# node:  706906
# minimum downstream value:  -0.265545871418
# mean upstream value:  -0.153416770563
# std upstream value:  0.0201649819616
# minimum downstream value:  -0.265545871418
# mean upstream value:  -0.126460581743
# std upstream value:  0.0234199738351
# minimum downstream value:  -0.232714747252
# mean upstream value:  -0.105206998441
# std upstream value:  0.0165871339668
# minimum downstream value:  -0.232714747252
# mean upstream value:  -0.0942695627728
# std upstream value:  0.00279971359211
# minimum downstream value:  -0.210921819031
# mean upstream value:  -0.0943749871336
# std upstream value:  0.00289992076574
# minimum downstream value:  -0.189676156628
# mean upstream value:  -0.0926159844882
# std upstream value:  0.00535132624443
# minimum downstream value:  -0.177741491747
# mean upstream value:  -0.0846520626184
# std upstream value:  0.010427379884
# minimum downstream value:  -0.154145131469
# mean upstream value:  -0.0760080289778
# std upstream value:  0.00643630639608
# minimum downstream value:  -0.128363688473
# mean upstream value:  -0.0715656908761
# std upstream value:  0.000223706912227
# minimum downstream value:  -0.0968729252872
# mean upstream value:  -0.0717971661031
# std upstream value:  0.000447983211442
# minimum downstream value:  -0.0971891983696
# mean upstream value:  -0.0726393547611
# std upstream value:  0.000842361583262
# 840
# (41, 41)
# 800
# 801
# 802
# 803
# 845
# 887
# 929
# 930
# 972
# 932
# 933
# 10   10
# 893
# 935
# 977
# 1019
# 1061
# 1062
# 1104
# 1105
# 1146
# node:  721827
# minimum downstream value:  -0.673561307281
# mean upstream value:  -0.20952335805
# std upstream value:  0.046177896055
# minimum downstream value:  -0.428910327052
# mean upstream value:  -0.166846796772
# std upstream value:  0.0229919892225
# 840
# (41, 41)
# 881
# 923
# 924
# 966
# 1007
# 1049
# 1090
# 1131
# 1172
# 1214
# 1254
# 10   10
# 1296
# 1337
# 1336
# 1376
# 1416
# 1457
# 1498
# 1540
# 1580
# node:  751279
# minimum downstream value:  -0.481492114161
# mean upstream value:  -0.574970431322
# std upstream value:  0.0122820382857
# minimum downstream value:  -0.514867971066
# mean upstream value:  -0.572634449432
# std upstream value:  0.00912046057089
# minimum downstream value:  -0.527300687647
# mean upstream value:  -0.564862719952
# std upstream value:  0.0188882277034
# minimum downstream value:  -0.547551935369
# mean upstream value:  -0.570377113634
# std upstream value:  0.0218570489122
# minimum downstream value:  -0.591789758253
# mean upstream value:  -0.588140475106
# std upstream value:  0.040256134408
# minimum downstream value:  -0.591789758253
# mean upstream value:  -0.519558108685
# std upstream value:  0.133044300996
# minimum downstream value:  -0.591789758253
# mean upstream value:  -0.37928657381
# std upstream value:  0.19537658193
# minimum downstream value:  -0.584781812585
# mean upstream value:  -0.221042638083
# std upstream value:  0.0796986766188
# minimum downstream value:  -0.584781812585
# mean upstream value:  -0.175147095531
# std upstream value:  0.0148261100986

# %% [markdown]
# ### In the final gully head dictionary the key is the point 5 m downstream of the gully head (later CP) and the value is the gully head found by moving back upstream (later GH)

# %%
final_gully_heads
# Out:
# {30156: 29242,
#  39354: 44874,
#  42581: 56386,
#  43106: 37587,
#  45345: 50868,
#  46260: 48093,
#  51782: 56386,
#  55133: 61578,
#  56975: 61578,
#  59138: 64655,
#  66088: 71611,
#  101491: 107014,
#  128377: 133896,
#  261673: 255234,
#  268066: 262548,
#  270845: 265325,
#  300413: 298579,
#  313914: 308392,
#  320359: 309313,
#  325179: 319661,
#  331418: 324982,
#  359685: 353244,
#  384940: 385866,
#  394039: 395884,
#  403271: 406037,
#  425251: 419731,
#  432670: 432676,
#  440018: 443703,
#  462914: 457399,
#  483169: 484095,
#  498782: 498788,
#  501485: 501491,
#  518918: 513395,
#  543850: 549372,
#  546746: 541227,
#  557760: 566960,
#  562361: 567880,
#  567009: 564255,
#  578971: 579897,
#  582440: 594412,
#  603900: 599305,
#  604747: 610265,
#  605455: 618343,
#  608500: 611266,
#  610925: 616447,
#  636102: 641624,
#  666586: 666592,
#  669225: 674748,
#  689587: 695108,
#  721827: 723674,
#  751279: 762323}

# %% [markdown]
# ### Extract only gully heads (GH)

# %%
def get_gully_heads(my_dict):
    gullies_to_keep = []
    for key, value in my_dict.items():
        gullies_to_keep.append(value)
    return gullies_to_keep

# %%
final_gullies = get_gully_heads(final_gully_heads)

# %%
final_gully_head_nodes = np.isin(grid_nodes,final_gullies).astype('uint8')

# %%
len(final_gully_heads)
# Out:
# 51

# %%
final_gullies
# Out:
# [29242,
#  44874,
#  56386,
#  37587,
#  50868,
#  48093,
#  56386,
#  61578,
#  61578,
#  64655,
#  71611,
#  107014,
#  133896,
#  255234,
#  262548,
#  265325,
#  298579,
#  308392,
#  309313,
#  319661,
#  324982,
#  353244,
#  385866,
#  395884,
#  406037,
#  419731,
#  432676,
#  443703,
#  457399,
#  484095,
#  498788,
#  501491,
#  513395,
#  549372,
#  541227,
#  566960,
#  567880,
#  564255,
#  579897,
#  594412,
#  599305,
#  610265,
#  618343,
#  611266,
#  616447,
#  641624,
#  666592,
#  674748,
#  695108,
#  723674,
#  762323]

# %%
def get_key(val, my_dict):
    gullies_to_keep = []
    for key, value in my_dict.items(): 
         if val == value:
                gullies_to_keep.append(key)
    return gullies_to_keep

# %% [markdown]
# ### Check that the new list of gully heads is the same length as the list of gully heads to keep.

# %%
gullies_to_keep_node_list = get_key('yes', gully_head_dict)

# %%
len(gullies_to_keep_node_list)
# Out:
# 51

# %% [markdown]
# # Examine a single gully head

# %%
def singleUpstreamDrainageLine(meters_from_gully_head, input_DEM_resolution, grid_nodes, DEM, import_drainage_area, 
                         import_dfme, catchment_outlet_ids, step_size_m, comparison_distance_m,  
                         slope_above_head, min_depth, gh_elevation):
    
    """This function works its way up the hillslope from a gully head recording 
    catchment area at each grid cell along the way. Then for each gully head it assesses whether divergence is occuring 
    at any point by using the upslopeDivergence function.
    
    meters_from_gully_head == distance upstream from gully head in meters.
    input_DEM_resolution == grid resolution of the input DEM.
    frn == flow receiver nodes stored on the model grid object.
    catchment_outlet_ids == a list of grid cells found using the estimateCatchmentArea function.
    drainage_area == drainage area stored on the model grid object.
    grid_nodes == grid node values stored on the model grid object.
    DEM == initial input_DEM
    step_size_m and comparison_distance_m are both enetered in meters and are then adjusted automatically
    to fit the resolution.
    slope_above_head == the distance from the convergence point that slope is taken."""
    
    catchment_area_node_list = []
    distance_from_node = int(meters_from_gully_head / input_DEM_resolution)
    upslope_divergence_dict = {}
    slope_dict = {}
    slope_at_head = {}
    
    step_size = int(np.round(step_size_m / input_DEM_resolution))
    comparison_distance = int(np.round(comparison_distance_m / input_DEM_resolution))
    
    for i in catchment_outlet_ids:
        
        result = np.where(grid_nodes == i)
        #################################################################################################
        # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
        row_index = result[0][0];
        col_index = result[1][0];
        #################################################################################################
        # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
        # centraL grid node of the subset.
        subset_row_top = int(row_index - distance_from_node)
        subset_row_bot = int(row_index + distance_from_node) + 1
        subset_col_left = int(col_index - distance_from_node)
        subset_col_right = int(col_index + distance_from_node) + 1
        #################################################################################################
        # Restrict the size of the subset in cases where it is on the edge of a DEM.
        subset_row_top_adjusted = max(subset_row_top, 0);
        subset_row_bot_adjusted = min(subset_row_bot, DEM.shape[0]);
        subset_col_left_adjusted = max(subset_col_left, 0);
        subset_col_right_adjusted = min(subset_col_right, DEM.shape[1]);
        #################################################################################################
        # Find the offset required by restricting the size of the subset around DEM edges.
        # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
        offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
        offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
        offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
        offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
        #################################################################################################
        # Create subset around the current gully head grid node. 
        dem_subset_copy = np.copy(DEM);
        dem_subset = dem_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        
        #################################################################################################
        # Find the latitude and longitude index positions of the gully head node in the subset DEM.
        node_lat = distance_from_node + offset_row_top
        node_lon = distance_from_node + offset_col_left
        #################################################################################################  
        # Run M8 for the subset DEM.
        flow_acc_surf_sub = np.copy(dem_subset).astype('float64');
        rows_sub = flow_acc_surf_sub.shape[0];
        cols_sub = flow_acc_surf_sub.shape[1];
        mg1 = RasterModelGrid((rows_sub,cols_sub), 1);
        z1 = mg1.add_field('topographic__elevation', flow_acc_surf_sub, at = 'node');

        sfb = SinkFillerBarnes(mg1, method = 'Steepest', ignore_overfill = True);
        sfb.run_one_step();
        fa = FlowAccumulator(mg1,
                            surface = 'topographic__elevation',
                            flow_director = 'FlowDirectorMFD',
                            diagonals = True);

        fa.run_one_step()
        fd = FlowDirectorMFD(mg1, 'topographic__elevation', diagonals = True);
        fd.run_one_step()
        #################################################################################################
        # Extract required grid properties
        da = np.array(mg1.at_node['drainage_area'].round(4)); # Drainage area.
        
        #da_subset_copy = np.copy(import_drainage_area)
        import_da_subset = import_drainage_area[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]

        flattened_import_da = import_da_subset.reshape(da.shape)
        
        #dfme_subset_copy = np.copy(import_dfme)
        import_dfme_subset = import_dfme[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                     subset_col_left_adjusted:subset_col_right_adjusted]
        flattened_import_dfme = import_dfme_subset.reshape(da.shape)
                
        grid_nodes_subset = grid_nodes[subset_row_top_adjusted:subset_row_bot_adjusted, 
                             subset_col_left_adjusted:subset_col_right_adjusted]
        
        flattened_grid_nodes_subset = grid_nodes_subset.reshape(da.shape)
        
        frn = mg1.at_node['flow__receiver_node'];# Flow receiver nodes.

        frp = np.array(mg1.at_node['flow__receiver_proportions']);# Flow receiver proportions
        flow_rec_surf_rows = cols_sub * rows_sub;
        flow_rec_surf = frp.reshape(flow_rec_surf_rows,8);
        all_receiver_proportions = np.copy(frp);
        grid_nodes_sub = np.array(mg1.nodes.reshape(mg1.shape));
        #################################################################################################
        central_node = grid_nodes_sub[node_lat, node_lon]
        print(central_node)
        print(mg1.shape)
        # Specific the size of the area to be checked. This represents a physical distance from the 
        # outlet but has no unit of measure. Its maximum size is the size of the 'distance_from_node' variable.
        slope = generic_filter(dem_subset, slopeWindowMperM,
                      footprint= rectangleWindow(3,3),
                      mode='constant', extra_arguments = (input_DEM_resolution,input_DEM_resolution,));

        flattened_slope = slope.reshape(da.shape)
        

        # This value is used to initialise the search.
        catchment_outlet_id = central_node

        # Initate an outer loop that iterates through every distance interval from the outlet. Each iteration checks whether 
        # an area equal to the 'contributing_fraction' variable below is being directed in only one direction (converging).
        # Otherwise it moves to the nect grid cell downslope in the direction of steepest slope.

        # Create a grid of node value sfor the subset DEM.
        node_location = mg1.nodes.reshape(da.shape);
        node_area_dict = {}
        slope_mean_dict = {}
        node_dfme_dict = {}
        original_node_id_dict = {}
        # This value is used to initialise the search.
        # Initate an outer loop that iterates through every distance interval from the outlet.
        watershed_grid_cells = []
        ordered_node_list = []

        for d in range(0, distance_from_node):
            target_distance = int(np.floor(slope_above_head/input_DEM_resolution)) 
            # Just look at watershed grid cells here.
            # Create a list initially containing only the outlet grid cell.
            if d == 0:
                candidate_gridcells = [catchment_outlet_id];
            else:
                candidate_gridcells = list(set(upstream_nodes));
            # Empty the list of upsteam nodes.
            upstream_node_dict = {};
            upstream_slope_dict = {};
            upstream_dfme_dict = {};
            upstream_original_node_id = {}
            # Intiate a new loop to check every gridcell at the current interval distance.
            for grid_cell in candidate_gridcells:
                # Check each flow direction of the current grid cell.The second dimension of the 
                # flow__receiver_node object will always be size == 8.
                for j in range(frn.shape[1]):
                    # Return all rows (grid nodes) that send any flow to the target grid cell.
                    # Note: This can only be one grid cell because the prgram is looping through
                    # each direction one at a time so only one grid cell can be sending flow from any
                    # one given direction.
                    flow_from_whole_grid_cell = frn[np.where(frn[:,j] == grid_cell)];
                    # Check if the current direction contributes flow. If not, do nothing. 
                    # Else, append to dictionary.
                    if flow_from_whole_grid_cell.shape[0] == 0:
                        pass
                    else:
                        # Below variable finds the row position of the flow_from_direction gridcell
                        # in the flow__receiver_node array. This corresponds to the contributing
                        # cell's node id.
                        node_id_value = np.where(np.all(flow_from_whole_grid_cell==frn,axis=1))[0][0];
                        #Find the proportion of flow leaving the donor node and heading toward 
                        # the current grid cell.
                        proportion_of_flow = frp[node_id_value, j]
                        # Create a boolean array to use as mask on drainage area.
                        isolate_candidate_grid_cells = np.isin(node_location, node_id_value)
                        node_drainage_area = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_import_da))
                        node_directional_drainage_area = node_drainage_area * proportion_of_flow
                        upstream_node_dict.update({node_id_value:node_directional_drainage_area});
                        node_slope = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_slope))
                        upstream_slope_dict.update({node_id_value:node_slope})
                        original_node_id = np.amax(np.multiply(isolate_candidate_grid_cells, flattened_grid_nodes_subset))
                        upstream_original_node_id.update({node_id_value:original_node_id})
                        node_dfme = np.amin(np.multiply(isolate_candidate_grid_cells, flattened_import_dfme))
                        upstream_dfme_dict.update({node_id_value:node_dfme})

                if len(upstream_node_dict) == 0:
                    pass
                else:
                    primary_flow_direction_id = max(upstream_node_dict.items(), key=operator.itemgetter(1))[0]
                    upstream_nodes = []
                    upstream_nodes.append(primary_flow_direction_id);
                    ordered_node_list.append(primary_flow_direction_id);
                    watershed_grid_cells.append(primary_flow_direction_id);
                    node_area_dict[primary_flow_direction_id] = upstream_node_dict[primary_flow_direction_id]
                    slope_mean_dict[primary_flow_direction_id] = upstream_slope_dict[primary_flow_direction_id]
                    node_dfme_dict[primary_flow_direction_id] = upstream_dfme_dict[primary_flow_direction_id]
                    original_node_id_dict[primary_flow_direction_id] = upstream_original_node_id[primary_flow_direction_id]
                    distance_in_meters = int(d*input_DEM_resolution)
                    if d == target_distance:
                        slope_at_head[i] = [upstream_slope_dict[primary_flow_direction_id],i]
                    else:
                        pass    
                    
        dfme_along_central_drainage_line = []
        for key, value in node_dfme_dict.items():
            dfme_along_central_drainage_line.append(value)
        median_dfme_along_central_drainage_line = ndimage.median_filter(dfme_along_central_drainage_line, size=step_size_m)

        slope_along_central_drainage_line = []
        for key, value in slope_mean_dict.items():
            slope_along_central_drainage_line.append(value)
        slope_mean_above_gully = np.mean(np.array(slope_along_central_drainage_line))
        slope_dict[i] = slope_mean_above_gully
        
        original_node_id_along_central_drainage_line = []
        for key, value in original_node_id_dict.items():
            original_node_id_along_central_drainage_line.append(value)
        
        required_number_of_grid_cells = step_size + comparison_distance + step_size + 1
        if len(median_dfme_along_central_drainage_line) < required_number_of_grid_cells:
            upslope_divergence_dict[i] = 'not enough grid cells'
        else:
            divergence_occuring = checkGullyHead(dfme_along_central_drainage_line, 
                                                    step_size, comparison_distance, min_depth, gh_elevation)
            upslope_divergence_dict[i] = divergence_occuring
    

    
    return original_node_id_along_central_drainage_line, slope_along_central_drainage_line,dfme_along_central_drainage_line

# %%
## Choose a point from the

# %%
start_time = timeit.default_timer()
catchment_outlet_id = [270845]
node_drainage_line, slope_values, dfme_values = singleUpstreamDrainageLine(20, input_DEM_resolution, grid_nodes, 
                                       input_DEM, catchment_area_ha, DFME,catchment_outlet_id, 3, 3, 10, -0.2, -0.2)
timeit.default_timer() - start_time
# Out:
# 840
# (41, 41)
# minimum downstream value:  -0.5363894979
# mean upstream value:  -0.107027759979
# std upstream value:  0.0240616303364
# 0.17208890000620158

# %%
node_location = mg.nodes.reshape(da.shape)

# %%
preliminary_width = np.isin(node_location,node_drainage_line).reshape(mg.shape)

# %%
gully_drainage_values_dict = dict(zip(node_drainage_line, slope_values))

# %%
slope_drainage_values_dict = dict(zip(node_drainage_line, slope_values))
dfme_drainage_values_dict = dict(zip(node_drainage_line, dfme_values))

ds = [slope_drainage_values_dict, dfme_drainage_values_dict]
d = {}
for k in slope_drainage_values_dict.keys():
    d[k] = tuple(d[k] for d in ds) 

new_drainage_parameters = pd.DataFrame.from_dict(d, orient='index')
new_drainage_parameters.rename(columns={0:'Slope', 1:'DFME'}, inplace=True)
new_drainage_parameters.insert(0, "Distance", 0);
for i in range(0, distance_from_outlet):
    new_drainage_parameters.iloc[i,0] = i
new_drainage_parameters['Node ID'] = new_drainage_parameters.index

# %%
sns.set(style = 'ticks')
fig, ax1 = plt.subplots(figsize = (10, 5))
data = new_drainage_parameters

y1 = "Slope"
y2 = "DFME"

sns.lineplot(data = data,x = "Distance",y = y1, color = 'xkcd:cobalt blue')
ax1.set_ylabel(y1, fontsize=15)
ax1.lines[0].set_linestyle("--")
ax1.set_ylim(0, 0.5)
ax1.set_xlabel('Distance upstream of convergence point (m)', fontsize = 15)
ax1.legend([y1],bbox_to_anchor=(0.3, 0.21, 0.53, 0.6))
ax2 = ax1.twinx()

ax2.set_ylim(-1, 1)
sns.lineplot(data=data,x = "Distance",y=y2,color='xkcd:forest green',ax = ax2)
ax2.set_ylabel(y2, fontsize = 15)
#ax2.lines[0].set_linestyle("--")
ax2.legend([y2],bbox_to_anchor=(0.3, 0.5, 0.5, 0.4))
#plt.axvline(x=17, color = 'xkcd:merlot', linestyle = 'dotted')
#plt.axvline(x=20, color = 'xkcd:merlot', linestyle = 'dotted')
plt.axhline(y=0, color = 'xkcd:merlot', linestyle = 'dotted')
#ax1.text(18, -0.8, r'Gully head', fontsize=15, rotation = 90)
plt.title('Change in upstream values for DFME', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Change in upstream values for DFME')

# %% [markdown]
# # Find edges

# %%
def gullyUnknownAngle(lat_dis, lon_dis):
    """Find ... """

    #################################################################################################
    # For gullies perfectly aligned along cardinal dorections. Quadrant is set to zero because they are all on boundaries.
    if lon_dis == 0 and lat_dis < 0:
        exact_angle = 180
        quadrant = 0
        
    elif lon_dis == 0 and lat_dis > 0:
        exact_angle = 0
        quadrant = 0
        
    elif lat_dis == 0 and lon_dis > 0:
        exact_angle = 90
        quadrant = 0
        
    elif lat_dis == 0 and lon_dis < 0:
        exact_angle = 270
        quadrant = 0
    #################################################################################################
    # For gullies of all otehr abgles.
    elif lat_dis > 0 and lon_dis > 0:
        angle_max = 90
        angle_min = 0
        quadrant = 1
        print('Quadrant = Q1', 'min angle', str(angle_min), 'max angle', str(angle_max))
        theta_a = np.degrees(np.arctan(np.abs(lat_dis)/np.abs(lon_dis)))
    
    elif lat_dis > 0 and lon_dis < 0:
        angle_max = 360
        angle_min = 270
        quadrant = 2
        print('Quadrant = Q2', 'min angle', str(angle_min), 'max angle', str(angle_max))
        theta_a = np.degrees(np.arctan(np.abs(lat_dis)/np.abs(lon_dis)))
        
    elif lat_dis < 0 and lon_dis < 0:
        angle_max = 270
        angle_min = 180
        quadrant = 3
        print('Quadrant = Q3', 'min angle', str(angle_min), 'max angle', str(angle_max))
        theta_a = np.degrees(np.arctan(np.abs(lat_dis)/np.abs(lon_dis)))
        
    else:
        angle_max = 180
        angle_min = 90
        quadrant = 4
        print('Quadrant = Q4', 'min angle', str(angle_min), 'max angle', str(angle_max))
        theta_a = np.degrees(np.arctan(np.abs(lat_dis)/np.abs(lon_dis)))   

    if quadrant == 1:
        gully_orientation = angle_max - theta_a
    elif quadrant == 2:
        gully_orientation = angle_min + theta_a
    elif quadrant == 3:
        gully_orientation = angle_max - theta_a
    elif quadrant == 4:
        gully_orientation = angle_min + theta_a
    else:
        gully_orientation = exact_angle
        
    return gully_orientation
class GullyOrientation:
    """Convention for first direction to take (d1) in cross section method 
    follows directional convention used in Landlab."""
    possible_angles = np.array([90, 0, 270, 180, 45, 315, 225, 135, 360])
    def __init__(self, angle, outlet, grid_shape):
        self.angle = angle
        self.outlet = outlet
        self.grid_shape = grid_shape
        idx = (np.abs(self.possible_angles - self.angle)).argmin() 
        find_angle_from_list = self.possible_angles[idx]
        self.closest_angle = find_angle_from_list

    def cross_section(self, line_length):
        cross_section_nodes_d1 = [self.outlet]
        cross_section_nodes_d2 = [self.outlet]
        if self.closest_angle == 90 or self.closest_angle == 270:
            print('east-west gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - self.grid_shape[1]
                next_node_d2 = current_node_d2 + self.grid_shape[1]
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        elif self.closest_angle == 0 or self.closest_angle == 180 or self.closest_angle == 360:
            print('north-south gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 + 1
                next_node_d2 = current_node_d2 - 1
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        elif self.closest_angle == 45 or self.closest_angle == 225:
            print('northeast-southwest gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - (self.grid_shape[1] + 1)
                next_node_d2 = current_node_d2 + (self.grid_shape[1] + 1)
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)
        else:
            print('northwest-southeast gully')
            for i in range(0, line_length):
                current_node_d1 = cross_section_nodes_d1[i]             
                current_node_d2 = cross_section_nodes_d2[i]
                next_node_d1 = current_node_d1 - (self.grid_shape[1] - 1)
                next_node_d2 = current_node_d2 + (self.grid_shape[1] - 1)
                cross_section_nodes_d1.append(next_node_d1)
                cross_section_nodes_d2.append(next_node_d2)

        cross_section_nodes = np.array(list(set(cross_section_nodes_d1 + cross_section_nodes_d2)))
        return cross_section_nodes

# %%
def assignDirection(cross_section_df, approximate_angle):

    d1 = cross_section_parameters_transpose.loc[cross_section_parameters_transpose['Distance']<=0, 'DFME'].values.tolist()
    d1.reverse() # Reversed because starts from end for left side only.
    d1_nodes = cross_section_parameters_transpose.loc[cross_section_parameters_transpose['Distance']<=0, 'Node'].values.tolist()
    d1_nodes.reverse()
    d2 = cross_section_parameters_transpose.loc[cross_section_parameters_transpose['Distance']>=0, 'DFME'].values.tolist()
    d2_nodes = cross_section_parameters_transpose.loc[cross_section_parameters_transpose['Distance']>=0, 'Node'].values.tolist()
   
    return d1, d1_nodes, d2, d2_nodes
def pointsAlongGully(node_at_gully_edge, gully_angle_to_follow, distance, grid_node_array):
    
    """Can do both left and right sides."""

    if gully_angle_to_follow == 0 or gully_angle_to_follow == 360:
        print('north_to_south gully')
        node_next_to_head = node_at_gully_edge - (5 * grid_node_array.shape[1])

    elif gully_angle_to_follow == 180:
        print('south_to_north gully')
        node_next_to_head = node_at_gully_edge + (5 * grid_node_array.shape[1])

    elif gully_angle_to_follow == 270:
        print('west_to_east gully')
        node_next_to_head = node_at_gully_edge - 5
        
    elif gully_angle_to_follow == 90:
        print('east_to_west gully')
        node_next_to_head = node_at_gully_edge + 5
        
    elif gully_angle_to_follow == 45:
        print('northeast_to_southwest gully')
        node_next_to_head = node_at_gully_edge - (5 * grid_node_array.shape[1] - 1)
        
    elif gully_angle_to_follow == 225:
        print('southwest_to_notheast gully')
        node_next_to_head = node_at_gully_edge + (5 * grid_node_array.shape[1] - 1)
        
    elif gully_angle_to_follow == 315:
        print('northwest_to_southeast gully')
        node_next_to_head = node_at_gully_edge - (5 * grid_node_array.shape[1] + 1)
        
    else:
        print('southeast_to_northwest gully')
        node_next_to_head = node_at_gully_edge + (5 * grid_node_array.shape[1] + 1)

    return node_next_to_head

# %%
start_time = timeit.default_timer()

line_length = 20
list_of_final_gully_heads = []
gully_edges_dict = {}
for key, value in final_gully_heads.items():
    cp = key
    print('cp: ',cp)
    gh = value
    print('gh: ', gh)
    gh_lat = np.where(grid_nodes == gh)[0][0]
    cp_lat = np.where(grid_nodes == cp)[0][0]
    gh_lon = np.where(grid_nodes == gh)[1][0]
    cp_lon = np.where(grid_nodes == cp)[1][0]

    lat_displacement = cp_lat - gh_lat
    print('lat: ', lat_displacement)
    lon_displacement = gh_lon - cp_lon
    print('lon: ', lon_displacement)

    # a^2 + b^2 = c^2
    gully_length = np.sqrt(lat_displacement**2 + lon_displacement**2)
    
    gully_angle = gullyUnknownAngle(lat_displacement, lon_displacement)   
    
    gully_and_cross_section = GullyOrientation(gully_angle, key, mg.shape)
    
    approx_angle = gully_and_cross_section.closest_angle
        
    cross_section_nodes = gully_and_cross_section.cross_section(line_length)
    
    result = np.where(grid_nodes == key)
    #################################################################################################
    # Find the index position (in the whole DEM) that corresponds to the current gully head point in the list.
    row_index = result[0][0];
    col_index = result[1][0];
    #################################################################################################
    # Create a subset based on above. Plus 1 to bottom abnd right so that the currenmmt gully ead node is always the 
    # central grid node of the subset.
    subset_row_top = int(row_index - line_length)
    subset_row_bot = int(row_index + line_length) + 1
    subset_col_left = int(col_index - line_length)
    subset_col_right = int(col_index + line_length) + 1
    #################################################################################################
    # Restrict the size of the subset in cases where it is on the edge of a DEM.
    subset_row_top_adjusted = max(subset_row_top, 0);
    subset_row_bot_adjusted = min(subset_row_bot, input_DEM.shape[0]);
    subset_col_left_adjusted = max(subset_col_left, 0);
    subset_col_right_adjusted = min(subset_col_right, input_DEM.shape[1]);
    #################################################################################################
    # Find the offset required by restricting the size of the subset around DEM edges.
    # This offset is needed to find the new location of the current gully head grid cell (no longer center of the subset).
    offset_row_top = int(np.sqrt((subset_row_top - subset_row_top_adjusted)**2)) * -1;
    offset_row_bot = int(np.sqrt((subset_row_bot - subset_row_bot_adjusted)**2));
    offset_col_left = int(np.sqrt((subset_col_left - subset_col_left_adjusted)**2)) * -1;
    offset_col_right = int(np.sqrt((subset_col_right - subset_col_right_adjusted)**2));
    #################################################################################################
    # Create subset around the current gully head grid node. 
    grid_nodes_subset_copy = np.copy(grid_nodes).astype('int32');
    grid_nodes_subset = grid_nodes_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                 subset_col_left_adjusted:subset_col_right_adjusted]

    lat = grid_nodes_subset.shape[0]
    lon = grid_nodes_subset.shape[1]

    nodes_1d = np.squeeze(grid_nodes_subset.reshape(1, lat * lon))

    cross_section_subset_mask = np.isin(nodes_1d,cross_section_nodes).reshape(grid_nodes_subset.shape)
    cross_section_subset_image = cross_section_subset_mask.astype('uint8')

    #################################################################################################
    # Take subsets of desired surface parameters for gulyl analysis (e.g. DFME, slope, curvature etc)
    #################################################################################################
    elevation_subset_copy = np.copy(input_DEM).astype('float32');
    cross_section_elevation = elevation_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                 subset_col_left_adjusted:subset_col_right_adjusted]

    cross_section_elevation[~cross_section_subset_mask] = np.nan
    cross_section_elevation_1d = np.squeeze(cross_section_elevation.reshape(1, lat * lon))
    #################################################################################################
    dfme_subset_copy = np.copy(DFME).astype('float32');
    cross_section_dfme = dfme_subset_copy[subset_row_top_adjusted:subset_row_bot_adjusted, 
                                 subset_col_left_adjusted:subset_col_right_adjusted]

    cross_section_dfme[~cross_section_subset_mask] = np.nan
    cross_section_dfme_1d = np.squeeze(cross_section_dfme.reshape(1, lat * lon))
    #################################################################################################
    
    node_cross_section_dfme_dict = {}
    for A, B in zip(nodes_1d, cross_section_dfme_1d):
        node_cross_section_dfme_dict[A] = B
    
    node_cross_section_elevation_dict = {}
    for A, B in zip(nodes_1d, cross_section_elevation_1d):
        node_cross_section_elevation_dict[A] = B
        
    dfme_cross_section_unordered = { key:value for key, 
                                     value in node_cross_section_dfme_dict.items() if ~np.isnan(value) }

    elevation_cross_section_unordered = { key:value for key, 
                                         value in node_cross_section_elevation_dict.items() if ~np.isnan(value) }

    ds = [dfme_cross_section_unordered, elevation_cross_section_unordered]
    d = {}
    for k in dfme_cross_section_unordered.keys():
        d[k] = tuple(d[k] for d in ds)

    cross_section_parameters = pd.DataFrame.from_dict(d)

    cross_section_parameters.rename(index={0:'DFME', 1:'Elevation'}, inplace=True)

    cross_section_parameters_transpose = cross_section_parameters.T

    cross_section_parameters_transpose.insert(0, "Distance", 0)
    
    for j in range(0, (line_length * 2)+1):
        if j < line_length:
            cross_section_parameters_transpose.iloc[j,0] = -line_length + j
        else:
            cross_section_parameters_transpose.iloc[j,0] = j - line_length
        
    cross_section_parameters_transpose['Node'] = cross_section_parameters_transpose.index.values
    
    dir1, dir1_nodes, dir2, dir2_nodes = assignDirection(cross_section_parameters_transpose, 
                                                 gully_and_cross_section.closest_angle)

    outcome_d1, D1 = checkGullyEdges(dir1,3,3,-0.2,-0.2)
    outcome_d2, D2 = checkGullyEdges(dir2,3,3,-0.2,-0.2)
    if outcome_d1 == 'yes' and outcome_d2 == 'yes':
        list_of_final_gully_heads.append(key)
        # Directions will depend on orientation so need two sets of schemes.
        if approx_angle == 180 or approx_angle == 225 or approx_angle == 270 or approx_angle == 315:
            
            points_next_to_head_d1 = pointsAlongGully(dir1_nodes[D1], approx_angle, 5, grid_nodes)
            points_next_to_head_d2 = pointsAlongGully(dir2_nodes[D2], approx_angle, 5, grid_nodes)
            
            print('d1 : ', dir1_nodes[D1], 'd2: ', dir2_nodes[D2], 'New points: ', 
                  points_next_to_head_d1, points_next_to_head_d2, 'angle: ', approx_angle)
            
            gully_edges_dict[key] = [dir1_nodes[D1], dir2_nodes[D2], points_next_to_head_d1, points_next_to_head_d2]
            
        else:           
            points_next_to_head_d1 = pointsAlongGully(dir1_nodes[D1], approx_angle, 5, grid_nodes)
            points_next_to_head_d2 = pointsAlongGully(dir2_nodes[D2], approx_angle, 5, grid_nodes)
            
            print('d1 : ', dir1_nodes[D1], 'd2: ', dir2_nodes[D2], 'New points: ', 
                  points_next_to_head_d1, points_next_to_head_d2, 'angle: ', approx_angle)
            
            gully_edges_dict[key] = [dir2_nodes[D2],dir1_nodes[D1], points_next_to_head_d2, points_next_to_head_d1]
        
    else:
        print('no')

    
timeit.default_timer() - start_time
# Out:
# cp:  30156
# gh:  29242
# lat:  1
# lon:  6
# Quadrant = Q1 min angle 0 max angle 90
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  24636 d2:  40276 New points:  24641 40281 angle:  90
# cp:  39354
# gh:  44874
# lat:  -6
# lon:  0
# north-south gully
# no
# cp:  42581
# gh:  56386
# lat:  -15
# lon:  5
# Quadrant = Q4 min angle 90 max angle 180
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  42575 d2:  42587 New points:  47175 47187 angle:  180
# cp:  43106
# gh:  37587
# lat:  6
# lon:  1
# Quadrant = Q1 min angle 0 max angle 90
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  43100 d2:  43113 New points:  38500 38513 angle:  0
# cp:  45345
# gh:  50868
# lat:  -6
# lon:  3
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  39831 d2:  50859 New points:  44432 55460 angle:  135
# cp:  46260
# gh:  48093
# lat:  -2
# lon:  -7
# Quadrant = Q3 min angle 180 max angle 270
# east-west gully
# west_to_east gully
# west_to_east gully
# d1 :  40740 d2:  57300 New points:  40735 57295 angle:  270
# cp:  51782
# gh:  56386
# lat:  -5
# lon:  4
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  46268 d2:  57296 New points:  50869 61897 angle:  135
# cp:  55133
# gh:  61578
# lat:  -7
# lon:  5
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  49619 d2:  60647 New points:  54220 65248 angle:  135
# cp:  56975
# gh:  61578
# lat:  -5
# lon:  3
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  51461 d2:  62489 New points:  56062 67090 angle:  135
# cp:  59138
# gh:  64655
# lat:  -6
# lon:  -3
# Quadrant = Q3 min angle 180 max angle 270
# northeast-southwest gully
# southwest_to_notheast gully
# southwest_to_notheast gully
# d1 :  53612 d2:  64664 New points:  58211 69263 angle:  225
# cp:  66088
# gh:  71611
# lat:  -6
# lon:  3
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  60574 d2:  71602 New points:  65175 76203 angle:  135
# cp:  101491
# gh:  107014
# lat:  -6
# lon:  3
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  95977 d2:  107005 New points:  100578 111606 angle:  135
# cp:  128377
# gh:  133896
# lat:  -6
# lon:  -1
# Quadrant = Q3 min angle 180 max angle 270
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  128371 d2:  128383 New points:  132971 132983 angle:  180
# cp:  261673
# gh:  255234
# lat:  7
# lon:  1
# Quadrant = Q1 min angle 0 max angle 90
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  261667 d2:  261679 New points:  257067 257079 angle:  0
# cp:  268066
# gh:  262548
# lat:  6
# lon:  2
# Quadrant = Q1 min angle 0 max angle 90
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  268060 d2:  268072 New points:  263460 263472 angle:  0
# cp:  270845
# gh:  265325
# lat:  6
# lon:  0
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  270839 d2:  270851 New points:  266239 266251 angle:  0
# cp:  300413
# gh:  298579
# lat:  2
# lon:  6
# Quadrant = Q1 min angle 0 max angle 90
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  294893 d2:  305933 New points:  294898 305938 angle:  90
# cp:  313914
# gh:  308392
# lat:  6
# lon:  -2
# Quadrant = Q2 min angle 270 max angle 360
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  313908 d2:  313920 New points:  309308 309320 angle:  360
# cp:  320359
# gh:  309313
# lat:  12
# lon:  -6
# Quadrant = Q2 min angle 270 max angle 360
# northwest-southeast gully
# northwest_to_southeast gully
# northwest_to_southeast gully
# d1 :  314845 d2:  325873 New points:  310244 321272 angle:  315
# cp:  325179
# gh:  319661
# lat:  6
# lon:  2
# Quadrant = Q1 min angle 0 max angle 90
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  325173 d2:  325185 New points:  320573 320585 angle:  0
# cp:  331418
# gh:  324982
# lat:  7
# lon:  4
# Quadrant = Q1 min angle 0 max angle 90
# northeast-southwest gully
# northeast_to_southwest gully
# northeast_to_southwest gully
# d1 :  325892 d2:  336944 New points:  321293 332345 angle:  45
# cp:  359685
# gh:  353244
# lat:  7
# lon:  -1
# Quadrant = Q2 min angle 270 max angle 360
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  359679 d2:  359691 New points:  355079 355091 angle:  360
# cp:  384940
# gh:  385866
# lat:  -1
# lon:  6
# Quadrant = Q4 min angle 90 max angle 180
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  379420 d2:  390460 New points:  379425 390465 angle:  90
# cp:  394039
# gh:  395884
# lat:  -2
# lon:  5
# Quadrant = Q4 min angle 90 max angle 180
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  388519 d2:  399559 New points:  388524 399564 angle:  90
# cp:  403271
# gh:  406037
# lat:  -3
# lon:  6
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  397757 d2:  408785 New points:  402358 413386 angle:  135
# cp:  425251
# gh:  419731
# lat:  6
# lon:  0
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  425245 d2:  425261 New points:  420645 420661 angle:  0
# cp:  432670
# gh:  432676
# lat:  0
# lon:  6
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  427150 d2:  438190 New points:  427155 438195 angle:  90
# cp:  440018
# gh:  443703
# lat:  -4
# lon:  5
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  428990 d2:  445532 New points:  433591 450133 angle:  135
# cp:  462914
# gh:  457399
# lat:  6
# lon:  5
# Quadrant = Q1 min angle 0 max angle 90
# northeast-southwest gully
# no
# cp:  483169
# gh:  484095
# lat:  -1
# lon:  6
# Quadrant = Q4 min angle 90 max angle 180
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  467529 d2:  488689 New points:  467534 488694 angle:  90
# cp:  498782
# gh:  498788
# lat:  0
# lon:  6
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  486822 d2:  505222 New points:  486827 505227 angle:  90
# cp:  501485
# gh:  501491
# lat:  0
# lon:  6
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  495965 d2:  507005 New points:  495970 507010 angle:  90
# cp:  518918
# gh:  513395
# lat:  6
# lon:  -3
# Quadrant = Q2 min angle 270 max angle 360
# northwest-southeast gully
# northwest_to_southeast gully
# northwest_to_southeast gully
# d1 :  509728 d2:  524432 New points:  505127 519831 angle:  315
# cp:  543850
# gh:  549372
# lat:  -6
# lon:  2
# Quadrant = Q4 min angle 90 max angle 180
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  543844 d2:  543856 New points:  548444 548456 angle:  180
# cp:  546746
# gh:  541227
# lat:  6
# lon:  1
# Quadrant = Q1 min angle 0 max angle 90
# north-south gully
# north_to_south gully
# north_to_south gully
# d1 :  546740 d2:  546752 New points:  542140 542152 angle:  0
# cp:  557760
# gh:  566960
# lat:  -10
# lon:  0
# north-south gully
# no
# cp:  562361
# gh:  567880
# lat:  -6
# lon:  -1
# Quadrant = Q3 min angle 180 max angle 270
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  562355 d2:  562368 New points:  566955 566968 angle:  180
# cp:  567009
# gh:  564255
# lat:  3
# lon:  6
# Quadrant = Q1 min angle 0 max angle 90
# northeast-southwest gully
# northeast_to_southwest gully
# northeast_to_southwest gully
# d1 :  561483 d2:  577140 New points:  556884 572541 angle:  45
# cp:  578971
# gh:  579897
# lat:  -1
# lon:  6
# Quadrant = Q4 min angle 90 max angle 180
# east-west gully
# no
# cp:  582440
# gh:  594412
# lat:  -13
# lon:  12
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  576926 d2:  587954 New points:  581527 592555 angle:  135
# cp:  603900
# gh:  599305
# lat:  5
# lon:  5
# Quadrant = Q1 min angle 0 max angle 90
# northeast-southwest gully
# northeast_to_southwest gully
# northeast_to_southwest gully
# d1 :  598374 d2:  609426 New points:  593775 604827 angle:  45
# cp:  604747
# gh:  610265
# lat:  -6
# lon:  -2
# Quadrant = Q3 min angle 180 max angle 270
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  604741 d2:  604762 New points:  609341 609362 angle:  180
# cp:  605455
# gh:  618343
# lat:  -14
# lon:  8
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# no
# cp:  608500
# gh:  611266
# lat:  -3
# lon:  6
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  602986 d2:  616771 New points:  607587 621372 angle:  135
# cp:  610925
# gh:  616447
# lat:  -6
# lon:  2
# Quadrant = Q4 min angle 90 max angle 180
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  610919 d2:  610931 New points:  615519 615531 angle:  180
# cp:  636102
# gh:  641624
# lat:  -6
# lon:  2
# Quadrant = Q4 min angle 90 max angle 180
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  636096 d2:  636108 New points:  640696 640708 angle:  180
# cp:  666586
# gh:  666592
# lat:  0
# lon:  6
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  661066 d2:  672106 New points:  661071 672111 angle:  90
# cp:  669225
# gh:  674748
# lat:  -6
# lon:  3
# Quadrant = Q4 min angle 90 max angle 180
# northwest-southeast gully
# southeast_to_northwest gully
# southeast_to_northwest gully
# d1 :  663711 d2:  674739 New points:  668312 679340 angle:  135
# cp:  689587
# gh:  695108
# lat:  -6
# lon:  1
# Quadrant = Q4 min angle 90 max angle 180
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  689581 d2:  689601 New points:  694181 694201 angle:  180
# cp:  721827
# gh:  723674
# lat:  -2
# lon:  7
# Quadrant = Q4 min angle 90 max angle 180
# east-west gully
# east_to_west gully
# east_to_west gully
# d1 :  716307 d2:  736547 New points:  716312 736552 angle:  90
# cp:  751279
# gh:  762323
# lat:  -12
# lon:  4
# Quadrant = Q4 min angle 90 max angle 180
# north-south gully
# south_to_north gully
# south_to_north gully
# d1 :  751273 d2:  751285 New points:  755873 755885 angle:  180
# 3.683301600001869

# %%
gully_angle
# Out:
# 161.56505117707798

# %%
gully_edges_df = pd.DataFrame.from_dict(gully_edges_dict).T

# %%
gully_edges_df.columns = ['LeftCP', 'RightCP', 'LeftGH', 'RightGH']

# %%
left_edge_points = gully_edges_df['LeftCP'].values
right_edge_points = gully_edges_df['RightCP'].values
left_head_points = gully_edges_df['LeftGH'].values
right_head_points = gully_edges_df['RightGH'].values

# %%
gully_left_edges = np.isin(grid_nodes,left_edge_points).astype('uint8')
gully_right_edges = np.isin(grid_nodes,right_edge_points).astype('uint8')
gully_left_head = np.isin(grid_nodes,left_head_points).astype('uint8')
gully_right_head = np.isin(grid_nodes,right_head_points).astype('uint8')

# %%
gully_edges_df
# Out:
#         LeftCP  RightCP  LeftGH  RightGH
# 30156    40276    24636   40281    24641
# 42581    42575    42587   47175    47187
# 43106    43113    43100   38513    38500
# 45345    50859    39831   55460    44432
# 46260    40740    57300   40735    57295
# 51782    57296    46268   61897    50869
# 55133    60647    49619   65248    54220
# 56975    62489    51461   67090    56062
# 59138    53612    64664   58211    69263
# 66088    71602    60574   76203    65175
# 101491  107005    95977  111606   100578
# 128377  128371   128383  132971   132983
# 261673  261679   261667  257079   257067
# 268066  268072   268060  263472   263460
# 270845  270851   270839  266251   266239
# 300413  305933   294893  305938   294898
# 313914  313920   313908  309320   309308
# 320359  314845   325873  310244   321272
# 325179  325185   325173  320585   320573
# 331418  336944   325892  332345   321293
# 359685  359691   359679  355091   355079
# 384940  390460   379420  390465   379425
# 394039  399559   388519  399564   388524
# 403271  408785   397757  413386   402358
# 425251  425261   425245  420661   420645
# 432670  438190   427150  438195   427155
# 440018  445532   428990  450133   433591
# 483169  488689   467529  488694   467534
# 498782  505222   486822  505227   486827
# 501485  507005   495965  507010   495970
# 518918  509728   524432  505127   519831
# 543850  543844   543856  548444   548456
# 546746  546752   546740  542152   542140
# 562361  562355   562368  566955   566968
# 567009  577140   561483  572541   556884
# 582440  587954   576926  592555   581527
# 603900  609426   598374  604827   593775
# 604747  604741   604762  609341   609362
# 608500  616771   602986  621372   607587
# 610925  610919   610931  615519   615531
# 636102  636096   636108  640696   640708
# 666586  672106   661066  672111   661071
# 669225  674739   663711  679340   668312
# 689587  689581   689601  694181   694201
# 721827  736547   716307  736552   716312
# 751279  751273   751285  755873   755885

# %%
len(list_of_final_gully_heads)
# Out:
# 46

# %%
all_final_gully_head_nodes = np.isin(grid_nodes,list_of_final_gully_heads).astype('uint8')

# %%
def np_array_to_Geotiff(newfile, original_tiff, np_array, dtype):
    
    cols = np_array.shape[1]
    rows = np_array.shape[0]
    originX, pixelWidth, b, originY, d, pixelHeight = original_tiff.GetGeoTransform() 
    driver = gdal.GetDriverByName('GTiff')
    GDT_dtype = gdal.GDT_Unknown
    if dtype == "Float64": 
        GDT_dtype = gdal.GDT_Float64
    elif dtype == "Float32":
        GDT_dtype = gdal.GDT_Float32
    else:
        print("Not supported data type.")
    
    if np_array.ndim == 2:
        band_num = 1
    else:
        band_num = np_array.shape[2]

    outRaster = driver.Create(newfile, cols, rows, band_num, GDT_dtype)
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    
    # Loop over all bands.
    for b in range(band_num):
        outband = outRaster.GetRasterBand(b + 1)
    
        # Read in the band's data into the third dimension of our array
        if band_num == 1:
            outband.WriteArray(np_array)
        else:
            outband.WriteArray(np_array[:,:,b])

    # setteing srs from input tif file.
    prj=original_tiff.GetProjection()
    outRasterSRS = osr.SpatialReference(wkt=prj)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    outRaster = None
    
    return outRaster

# %%
np_array_to_Geotiff('fann_right_gh_2.tif', input_geotiff, gully_right_head, drainage_area.dtype)
# Out:
# C:\Users\sjwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
